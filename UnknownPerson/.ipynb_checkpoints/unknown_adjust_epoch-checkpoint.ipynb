# %%
import scipy.io
import numpy as np
import random
import os

# %%
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
from feature_emotion import feature_extract, split_data, label_unique_tuples, split_data_unknown
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
for test_person_id_single in person_nums:
    test_person_id = [test_person_id_single]
    flag_tr_val_te = split_data_unknown(test_person_id, walk_nums_all, trace_nums_all, people_nums_all, person_nums, rand_seed = 42)
    ## Data Normalization before training ans testing
    import tensorflow as tf
    tf.compat.v1.disable_v2_behavior()
    from tensorflow.keras.models import Model
    from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
    from sklearn.preprocessing import StandardScaler
    scalers = []
    X_train_normalized = []
    X_val_normalized = []
    X_test_normalized = []
    train_idx = np.where(flag_tr_val_te ==0)[0]
    np.random.shuffle(train_idx)
    val_idx = np.where(flag_tr_val_te ==1)[0]
    test_idx = np.where(flag_tr_val_te ==2)[0]
    
    for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features]):
        scaler = StandardScaler()
        if len(feature.shape)==2:
            X_train_i = feature[train_idx,:]
            X_val_i = feature[val_idx,:]
            X_test_i = feature[test_idx,:]
            X_train_normalized_i = scaler.fit_transform(X_train_i)
            X_val_normalized_i = scaler.transform(X_val_i)
            X_test_normalized_i = scaler.transform(X_test_i)
            scalers.append(scaler)
        else:
            X_train_i = feature[train_idx,:,:]
            X_val_i = feature[val_idx,:,:]
            X_test_i = feature[test_idx,:,:]
            X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
            X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
            X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
            scalers.append(scaler)
        X_train_normalized.append(X_train_normalized_i)
        X_val_normalized.append(X_val_normalized_i)
        X_test_normalized.append(X_test_normalized_i)
    y_train = gts[train_idx,:]
    y_val = gts[val_idx,:]
    y_test = gts[test_idx,:]
    X_train_normalized_new = []
    combined_feature = np.empty((len(X_train_normalized[0]),0))
    for feature in X_train_normalized:
        if len(feature.shape) == 3:
            X_train_normalized_new.append(feature)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
        else:
            X_train_normalized_new.append(feature)
    X_train_normalized_new.append(combined_feature)
    
    X_val_normalized_new = []
    combined_feature = np.empty((len(X_val_normalized[0]),0))
    for feature in X_val_normalized:
        if len(feature.shape) == 3:
            X_val_normalized_new.append(feature)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
        else:
            X_val_normalized_new.append(feature)
    X_val_normalized_new.append(combined_feature)
    
    X_test_normalized_new = []
    combined_feature = np.empty((len(X_test_normalized[0]),0))
    for feature in X_test_normalized:
        if len(feature.shape) == 3:
            X_test_normalized_new.append(feature)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
        else:
            X_test_normalized_new.append(feature)
    X_test_normalized_new.append(combined_feature)
    
    model = individual_model(X_train_normalized)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    num_epochs = 50
    
    
    # Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    
    
    rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
    idx = 0
    for r in rates:
        model_name = './checkpoints/unknown_person_baseline_p'+str(test_person_id[0])+'_'+str(idx)+'.h5'
        checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    
        pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
        model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
        import tensorflow as tf
        model = tf.keras.models.load_model(model_name)
        from tensorflow.keras.models import Model
        layers = model.layers
        second_last_layer_output = layers[-4].output
        feature_extractor_model = Model(inputs=model.input, outputs=second_last_layer_output)
        train_features = feature_extractor_model.predict(X_train_normalized_new)
        test_features = feature_extractor_model.predict(X_test_normalized_new)
        
        p_train = people_nums[train_idx,:]
        p_val = people_nums[val_idx,:]
        p_test = people_nums[test_idx,:]
        ## Calculate the distance between test person and training person
        def euclidean_distance(a, b):
            return np.sqrt(np.sum((a - b) ** 2, axis=1))
        
        distance_dict = {}
        for ii in range(len(person_nums)):
            if person_nums[ii] == test_person_id[0]:
                continue
            else:
                
                ind = np.where(p_train ==person_nums[ii])[0]
                tmp_train_features = train_features[ind, :]
                distances = np.array([euclidean_distance(train_sample, test_features) for train_sample in tmp_train_features])
                print(distances.shape)
                average_distances = np.mean(distances, axis=1)
        
                # Step 4: Find the overall average distance
                overall_average_distance = np.mean(average_distances)
                distance_dict[person_nums[ii]] = overall_average_distance
        
        
        def normalize_to_weights(distance_dict):
            distances = np.array(list(distance_dict.values()))
            # Handle the case where a distance is zero to avoid division by zero
            distances = np.clip(distances, a_min=1e-10, a_max=None)
            weights = 1 / distances
            normalized_weights = weights
            # normalized_weights = weights / sum(weights)
            # print(sum(weights))
            # print(sum(normalized_weights))
            # Assign the normalized weights back to the dictionary
            normalized_weight_dict = dict(zip(distance_dict.keys(), normalized_weights))
            return normalized_weight_dict
        def scale_dict_values(my_dict):
            scaled_dict = my_dict.copy()
            min_val = min(scaled_dict.values())
            max_val = max(scaled_dict.values())
            
            for key in scaled_dict:
                scaled_dict[key] = 1 + 9 * (scaled_dict[key] - min_val) / (max_val - min_val)
            
            return scaled_dict
        weights_dict = normalize_to_weights(distance_dict)
        weights_dict = scale_dict_values(weights_dict)
        print(weights_dict)
        
        w_train = np.zeros_like(p_train)
        for i in range(len(w_train)):
            w_train[i] = weights_dict[int(p_train[i])]
        
        w_train = np.squeeze(w_train)
        
        import sys
        sys.path.append('..')
        # for layer in model.layers[-4:]:
        #     layer.trainable = False
        # model = individual_model.individual_model(X_train_normalized)
        model_name = './checkpoints/unknown_person_p'+str(test_person_id[0])+'_'+str(idx)+'.h5'
        checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
        pruning_callback = PruningCallback(initial_pruning_factor=r, final_pruning_factor=r, start_epoch=1, end_epoch=50, frequency=1)
        
        history = model.fit(x=X_train_normalized_new, y=y_train,sample_weight= w_train,epochs=50, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
        import sys
        sys.path.append('..')
        # for layer in model.layers[-4:]:
        #     layer.trainable = False
        # model = individual_model.individual_model(X_train_normalized)
        model_name = './checkpoints/unknown_person_baseline_2_p'+str(test_person_id[0])+'_'+str(idx)+'.h5'
        idx += 1
        checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
        pruning_callback = PruningCallback(initial_pruning_factor=r, final_pruning_factor=r, start_epoch=1, end_epoch=50, frequency=1)
        
        history = model.fit(x=X_train_normalized_new, y=y_train,epochs=50, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# 2023-11-07 00:50:39.820325: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# 35408
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-07 00:52:33.081472: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:33.093036: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:33.093361: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:33.096673: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:33.096879: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:33.097048: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:33.154429: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:33.154631: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:33.154805: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:33.154946: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-07 00:52:33.155290: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-07 00:52:34.113798: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:34.114074: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:34.114257: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:34.114463: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:34.114639: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:52:34.114775: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-07 00:52:34.114805: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-07 00:52:34.137173: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-07 00:52:34.189245: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_19/lstm_cell_19/bias/Assign' id:3180 op device:{requested: '', assigned: ''} def:{{{node lstm_19/lstm_cell_19/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_19/lstm_cell_19/bias, lstm_19/lstm_cell_19/bias/Initializer/concat)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-07 00:52:34.320687: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:3634 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-07 00:52:34.354477: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:3635 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (31870, 95)
# Train on 31870 samples, validate on 3538 samples
# 2023-11-07 00:52:38.824886: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_1/lstm_cell_1/recurrent_kernel/m/Assign' id:16414 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_1/lstm_cell_1/recurrent_kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_1/lstm_cell_1/recurrent_kernel/m, training/Adam/lstm_1/lstm_cell_1/recurrent_kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/50
# 2023-11-07 00:52:42.696502: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-07 00:52:44.953454: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-07 00:52:54.968811: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 957.00MiB (rounded to 1003487232)requested by op conv2d/Relu
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-11-07 00:52:54.969005: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2023-11-07 00:52:54.969019: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 347, Chunks in use: 345. 86.8KiB allocated for chunks. 86.2KiB in use in bin. 28.1KiB client-requested in use in bin.
# 2023-11-07 00:52:54.969029: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 2, Chunks in use: 2. 1.0KiB allocated for chunks. 1.0KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2023-11-07 00:52:54.969038: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 4, Chunks in use: 4. 5.0KiB allocated for chunks. 5.0KiB in use in bin. 4.4KiB client-requested in use in bin.
# 2023-11-07 00:52:54.969046: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-07 00:52:54.969057: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 1987, Chunks in use: 1987. 7.80MiB allocated for chunks. 7.80MiB in use in bin. 7.76MiB client-requested in use in bin.
# 2023-11-07 00:52:54.969069: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 4, Chunks in use: 3. 36.0KiB allocated for chunks. 24.0KiB in use in bin. 24.0KiB client-requested in use in bin.
# 2023-11-07 00:52:54.969080: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 4137, Chunks in use: 4137. 65.36MiB allocated for chunks. 65.36MiB in use in bin. 64.65MiB client-requested in use in bin.
# 2023-11-07 00:52:54.969092: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 4, Chunks in use: 2. 205.5KiB allocated for chunks. 105.5KiB in use in bin. 105.5KiB client-requested in use in bin.
# 2023-11-07 00:52:54.969104: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 14, Chunks in use: 0. 1.07MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-07 00:52:54.969112: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 10, Chunks in use: 7. 1.36MiB allocated for chunks. 980.0KiB in use in bin. 980.0KiB client-requested in use in bin.
# 2023-11-07 00:52:54.969125: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 2, Chunks in use: 2. 876.0KiB allocated for chunks. 876.0KiB in use in bin. 876.0KiB client-requested in use in bin.
# 2023-11-07 00:52:54.969137: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 5, Chunks in use: 5. 2.92MiB allocated for chunks. 2.92MiB in use in bin. 2.58MiB client-requested in use in bin.
# 2023-11-07 00:52:54.969147: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-07 00:52:54.969156: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 6, Chunks in use: 6. 16.12MiB allocated for chunks. 16.12MiB in use in bin. 16.12MiB client-requested in use in bin.
# 2023-11-07 00:52:54.969167: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-07 00:52:54.969178: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-07 00:52:54.969187: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 31.62MiB allocated for chunks. 31.62MiB in use in bin. 31.62MiB client-requested in use in bin.
# 2023-11-07 00:52:54.969196: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-07 00:52:54.969205: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-07 00:52:54.969212: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 1, Chunks in use: 0. 240.63MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-07 00:52:54.969220: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 1, Chunks in use: 1. 957.00MiB allocated for chunks. 957.00MiB in use in bin. 957.00MiB client-requested in use in bin.
# 2023-11-07 00:52:54.969229: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 957.00MiB was 256.00MiB, Chunk State:
# 2023-11-07 00:52:54.969237: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 1389428736
# 2023-11-07 00:52:54.969248: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880000000 of size 1280 next 1
# 2023-11-07 00:52:54.969257: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880000500 of size 256 next 2
# 2023-11-07 00:52:54.969267: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880000600 of size 256 next 3
# 2023-11-07 00:52:54.969278: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880000700 of size 256 next 4
# 2023-11-07 00:52:54.969286: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880000800 of size 256 next 5
# 2023-11-07 00:52:54.969294: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880000900 of size 256 next 6
# 2023-11-07 00:52:54.969302: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880000a00 of size 256 next 7
# 2023-11-07 00:52:54.969307: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880000b00 of size 256 next 8
# 2023-11-07 00:52:54.969313: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880000c00 of size 256 next 9
# 2023-11-07 00:52:54.969320: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880000d00 of size 256 next 10
# 2023-11-07 00:52:54.969328: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880000e00 of size 256 next 11
# 2023-11-07 00:52:54.969334: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880000f00 of size 256 next 12
# 2023-11-07 00:52:54.969340: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001000 of size 256 next 13
# 2023-11-07 00:52:54.969348: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001100 of size 256 next 14
# 2023-11-07 00:52:54.969354: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001200 of size 256 next 15
# 2023-11-07 00:52:54.969365: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001300 of size 256 next 16
# 2023-11-07 00:52:54.969375: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001400 of size 256 next 17
# 2023-11-07 00:52:54.969384: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001500 of size 256 next 18
# 2023-11-07 00:52:54.969394: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001600 of size 256 next 19
# 2023-11-07 00:52:54.969403: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001700 of size 256 next 20
# 2023-11-07 00:52:54.969414: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001800 of size 256 next 21
# 2023-11-07 00:52:54.969424: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001900 of size 256 next 22
# 2023-11-07 00:52:54.969433: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001a00 of size 256 next 23
# 2023-11-07 00:52:54.969440: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001b00 of size 256 next 24
# 2023-11-07 00:52:54.969451: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001c00 of size 256 next 25
# 2023-11-07 00:52:54.969460: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001d00 of size 256 next 26
# 2023-11-07 00:52:54.969470: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001e00 of size 256 next 27
# 2023-11-07 00:52:54.969478: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880001f00 of size 256 next 36
# 2023-11-07 00:52:54.969485: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002000 of size 256 next 29
# 2023-11-07 00:52:54.969493: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002100 of size 256 next 30
# 2023-11-07 00:52:54.969501: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002200 of size 256 next 31
# 2023-11-07 00:52:54.969511: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002300 of size 256 next 32
# 2023-11-07 00:52:54.969521: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002400 of size 256 next 48
# 2023-11-07 00:52:54.969531: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002500 of size 256 next 34
# 2023-11-07 00:52:54.969540: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002600 of size 256 next 35
# 2023-11-07 00:52:54.969551: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002700 of size 256 next 68
# 2023-11-07 00:52:54.969563: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002800 of size 256 next 37
# 2023-11-07 00:52:54.969573: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002900 of size 256 next 38
# 2023-11-07 00:52:54.969583: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002a00 of size 256 next 39
# 2023-11-07 00:52:54.969593: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002b00 of size 256 next 40
# 2023-11-07 00:52:54.969603: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002c00 of size 256 next 41
# 2023-11-07 00:52:54.969615: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002d00 of size 256 next 42
# 2023-11-07 00:52:54.969626: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002e00 of size 256 next 49
# 2023-11-07 00:52:54.969637: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880002f00 of size 256 next 45
# 2023-11-07 00:52:54.969647: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003000 of size 256 next 44
# 2023-11-07 00:52:54.969660: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003100 of size 256 next 46
# 2023-11-07 00:52:54.969671: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003200 of size 256 next 47
# 2023-11-07 00:52:54.969680: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003300 of size 256 next 69
# 2023-11-07 00:52:54.969691: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003400 of size 256 next 67
# 2023-11-07 00:52:54.969700: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003500 of size 256 next 50
# 2023-11-07 00:52:54.969710: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003600 of size 256 next 51
# 2023-11-07 00:52:54.969720: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003700 of size 256 next 52
# 2023-11-07 00:52:54.969732: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003800 of size 256 next 53
# 2023-11-07 00:52:54.969825: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003900 of size 256 next 54
# 2023-11-07 00:52:54.969840: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003a00 of size 256 next 55
# 2023-11-07 00:52:54.969854: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003b00 of size 256 next 56
# 2023-11-07 00:52:54.969869: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003c00 of size 256 next 57
# 2023-11-07 00:52:54.969883: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003d00 of size 256 next 58
# 2023-11-07 00:52:54.969894: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003e00 of size 256 next 59
# 2023-11-07 00:52:54.969902: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880003f00 of size 256 next 60
# 2023-11-07 00:52:54.969910: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004000 of size 256 next 61
# 2023-11-07 00:52:54.969918: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004100 of size 256 next 62
# 2023-11-07 00:52:54.969928: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004200 of size 256 next 63
# 2023-11-07 00:52:54.969937: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004300 of size 256 next 64
# 2023-11-07 00:52:54.969947: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004400 of size 256 next 65
# 2023-11-07 00:52:54.969956: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004500 of size 256 next 66
# 2023-11-07 00:52:54.969965: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004600 of size 256 next 43
# 2023-11-07 00:52:54.969975: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004700 of size 256 next 33
# 2023-11-07 00:52:54.969984: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004800 of size 256 next 75
# 2023-11-07 00:52:54.969992: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004900 of size 256 next 71
# 2023-11-07 00:52:54.970003: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004a00 of size 256 next 70
# 2023-11-07 00:52:54.970012: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004b00 of size 256 next 72
# 2023-11-07 00:52:54.970021: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004c00 of size 256 next 73
# 2023-11-07 00:52:54.970030: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004d00 of size 256 next 74
# 2023-11-07 00:52:54.970039: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004e00 of size 256 next 28
# 2023-11-07 00:52:54.970047: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880004f00 of size 256 next 76
# 2023-11-07 00:52:54.970056: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005000 of size 256 next 77
# 2023-11-07 00:52:54.970065: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005100 of size 256 next 78
# 2023-11-07 00:52:54.970075: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005200 of size 256 next 79
# 2023-11-07 00:52:54.970083: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005300 of size 256 next 80
# 2023-11-07 00:52:54.970092: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005400 of size 256 next 81
# 2023-11-07 00:52:54.970101: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005500 of size 256 next 82
# 2023-11-07 00:52:54.970110: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005600 of size 256 next 83
# 2023-11-07 00:52:54.970119: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005700 of size 256 next 84
# 2023-11-07 00:52:54.970128: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005800 of size 256 next 85
# 2023-11-07 00:52:54.970137: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005900 of size 256 next 86
# 2023-11-07 00:52:54.970146: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005a00 of size 256 next 87
# 2023-11-07 00:52:54.970155: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005b00 of size 256 next 88
# 2023-11-07 00:52:54.970163: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005c00 of size 256 next 89
# 2023-11-07 00:52:54.970172: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005d00 of size 256 next 90
# 2023-11-07 00:52:54.970182: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005e00 of size 256 next 91
# 2023-11-07 00:52:54.970191: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880005f00 of size 256 next 92
# 2023-11-07 00:52:54.970200: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880006000 of size 256 next 93
# 2023-11-07 00:52:54.970208: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880006100 of size 256 next 94
# 2023-11-07 00:52:54.970217: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880006200 of size 256 next 95
# 2023-11-07 00:52:54.970227: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880006300 of size 256 next 96
# 2023-11-07 00:52:54.970236: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880006400 of size 256 next 97
# 2023-11-07 00:52:54.970244: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880006500 of size 256 next 98
# 2023-11-07 00:52:54.970253: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880006600 of size 256 next 99
# 2023-11-07 00:52:54.970262: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880006700 of size 256 next 100
# 2023-11-07 00:52:54.970271: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880006800 of size 256 next 101
# 2023-11-07 00:52:54.970280: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880006900 of size 256 next 102
# 2023-11-07 00:52:54.970289: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880006a00 of size 256 next 103
# 2023-11-07 00:52:54.970299: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880006b00 of size 256 next 104
# 2023-11-07 00:52:54.970308: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880006c00 of size 1280 next 105
# 2023-11-07 00:52:54.970318: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880007100 of size 256 next 106
# 2023-11-07 00:52:54.970326: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880007200 of size 18432 next 107
# 2023-11-07 00:52:54.970336: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb88000ba00 of size 256 next 108
# 2023-11-07 00:52:54.970345: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb88000bb00 of size 512 next 109
# 2023-11-07 00:52:54.970354: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb88000bd00 of size 256 next 110
# 2023-11-07 00:52:54.970365: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb88000be00 of size 256 next 111
# 2023-11-07 00:52:54.970374: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb88000bf00 of size 256 next 112
# 2023-11-07 00:52:54.970382: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb88000c000 of size 256 next 113
# 2023-11-07 00:52:54.970391: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb88000c100 of size 17920 next 114
# 2023-11-07 00:52:54.970401: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880010700 of size 256 next 115
# 2023-11-07 00:52:54.970411: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880010800 of size 54016 next 116
# 2023-11-07 00:52:54.970420: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb88001db00 of size 256 next 117
# 2023-11-07 00:52:54.970430: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb88001dc00 of size 8192 next 118
# 2023-11-07 00:52:54.970440: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb88001fc00 of size 256 next 119
# 2023-11-07 00:52:54.970451: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb88001fd00 of size 256 next 120
# 2023-11-07 00:52:54.970460: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb88001fe00 of size 256 next 121
# 2023-11-07 00:52:54.970469: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb88001ff00 of size 256 next 122
# 2023-11-07 00:52:54.970477: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020000 of size 256 next 123
# 2023-11-07 00:52:54.970486: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020100 of size 256 next 124
# 2023-11-07 00:52:54.970495: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020200 of size 256 next 125
# 2023-11-07 00:52:54.970504: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020300 of size 256 next 126
# 2023-11-07 00:52:54.970513: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020400 of size 256 next 127
# 2023-11-07 00:52:54.970522: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020500 of size 256 next 128
# 2023-11-07 00:52:54.970531: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020600 of size 256 next 129
# 2023-11-07 00:52:54.970540: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020700 of size 256 next 130
# 2023-11-07 00:52:54.970549: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020800 of size 256 next 131
# 2023-11-07 00:52:54.970558: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020900 of size 256 next 132
# 2023-11-07 00:52:54.970567: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020a00 of size 256 next 133
# 2023-11-07 00:52:54.970576: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020b00 of size 256 next 134
# 2023-11-07 00:52:54.970585: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020c00 of size 256 next 135
# 2023-11-07 00:52:54.970594: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020d00 of size 256 next 136
# 2023-11-07 00:52:54.970603: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020e00 of size 256 next 137
# 2023-11-07 00:52:54.970612: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880020f00 of size 256 next 138
# 2023-11-07 00:52:54.970620: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021000 of size 256 next 139
# 2023-11-07 00:52:54.970629: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021100 of size 256 next 140
# 2023-11-07 00:52:54.970639: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021200 of size 256 next 141
# 2023-11-07 00:52:54.970648: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021300 of size 256 next 142
# 2023-11-07 00:52:54.970657: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021400 of size 256 next 143
# 2023-11-07 00:52:54.970665: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021500 of size 256 next 144
# 2023-11-07 00:52:54.970675: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021600 of size 256 next 145
# 2023-11-07 00:52:54.970684: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021700 of size 256 next 146
# 2023-11-07 00:52:54.970693: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021800 of size 256 next 147
# 2023-11-07 00:52:54.970701: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021900 of size 256 next 148
# 2023-11-07 00:52:54.970711: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021a00 of size 256 next 149
# 2023-11-07 00:52:54.970720: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021b00 of size 256 next 150
# 2023-11-07 00:52:54.970729: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021c00 of size 256 next 151
# 2023-11-07 00:52:54.970738: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021d00 of size 256 next 152
# 2023-11-07 00:52:54.970747: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021e00 of size 256 next 153
# 2023-11-07 00:52:54.970756: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880021f00 of size 256 next 154
# 2023-11-07 00:52:54.970766: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022000 of size 256 next 155
# 2023-11-07 00:52:54.970775: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022100 of size 256 next 156
# 2023-11-07 00:52:54.970784: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022200 of size 256 next 157
# 2023-11-07 00:52:54.970793: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022300 of size 256 next 158
# 2023-11-07 00:52:54.970803: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022400 of size 256 next 159
# 2023-11-07 00:52:54.970812: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022500 of size 256 next 160
# 2023-11-07 00:52:54.970821: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022600 of size 256 next 161
# 2023-11-07 00:52:54.970830: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022700 of size 256 next 162
# 2023-11-07 00:52:54.970839: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022800 of size 256 next 163
# 2023-11-07 00:52:54.970848: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022900 of size 256 next 164
# 2023-11-07 00:52:54.970858: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022a00 of size 256 next 165
# 2023-11-07 00:52:54.970867: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022b00 of size 256 next 166
# 2023-11-07 00:52:54.970876: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022c00 of size 256 next 167
# 2023-11-07 00:52:54.970884: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022d00 of size 256 next 168
# 2023-11-07 00:52:54.970893: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022e00 of size 256 next 169
# 2023-11-07 00:52:54.970900: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880022f00 of size 256 next 170
# 2023-11-07 00:52:54.970908: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023000 of size 256 next 171
# 2023-11-07 00:52:54.970916: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023100 of size 256 next 172
# 2023-11-07 00:52:54.970925: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023200 of size 256 next 173
# 2023-11-07 00:52:54.970934: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023300 of size 256 next 174
# 2023-11-07 00:52:54.970943: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023400 of size 256 next 175
# 2023-11-07 00:52:54.970952: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023500 of size 256 next 176
# 2023-11-07 00:52:54.970961: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023600 of size 256 next 177
# 2023-11-07 00:52:54.970970: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023700 of size 256 next 178
# 2023-11-07 00:52:54.970977: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023800 of size 256 next 179
# 2023-11-07 00:52:54.970985: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023900 of size 256 next 180
# 2023-11-07 00:52:54.970994: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023a00 of size 256 next 181
# 2023-11-07 00:52:54.971003: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023b00 of size 256 next 182
# 2023-11-07 00:52:54.971012: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023c00 of size 256 next 183
# 2023-11-07 00:52:54.971021: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023d00 of size 256 next 184
# 2023-11-07 00:52:54.971029: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023e00 of size 256 next 185
# 2023-11-07 00:52:54.971035: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880023f00 of size 256 next 186
# 2023-11-07 00:52:54.971044: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024000 of size 256 next 187
# 2023-11-07 00:52:54.971053: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024100 of size 256 next 188
# 2023-11-07 00:52:54.971062: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024200 of size 256 next 189
# 2023-11-07 00:52:54.971071: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024300 of size 256 next 190
# 2023-11-07 00:52:54.971080: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024400 of size 256 next 191
# 2023-11-07 00:52:54.971089: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024500 of size 256 next 192
# 2023-11-07 00:52:54.971098: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024600 of size 256 next 193
# 2023-11-07 00:52:54.971107: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024700 of size 256 next 194
# 2023-11-07 00:52:54.971116: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024800 of size 256 next 195
# 2023-11-07 00:52:54.971125: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024900 of size 256 next 196
# 2023-11-07 00:52:54.971134: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024a00 of size 256 next 197
# 2023-11-07 00:52:54.971143: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024b00 of size 256 next 198
# 2023-11-07 00:52:54.971152: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024c00 of size 256 next 199
# 2023-11-07 00:52:54.971161: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024d00 of size 256 next 200
# 2023-11-07 00:52:54.971170: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024e00 of size 256 next 201
# 2023-11-07 00:52:54.971179: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880024f00 of size 256 next 202
# 2023-11-07 00:52:54.971188: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025000 of size 256 next 203
# 2023-11-07 00:52:54.971198: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025100 of size 256 next 204
# 2023-11-07 00:52:54.971207: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025200 of size 256 next 205
# 2023-11-07 00:52:54.971217: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025300 of size 256 next 206
# 2023-11-07 00:52:54.971225: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025400 of size 256 next 207
# 2023-11-07 00:52:54.971234: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025500 of size 256 next 208
# 2023-11-07 00:52:54.971243: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025600 of size 256 next 209
# 2023-11-07 00:52:54.971252: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025700 of size 256 next 210
# 2023-11-07 00:52:54.971261: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025800 of size 256 next 211
# 2023-11-07 00:52:54.971270: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025900 of size 256 next 212
# 2023-11-07 00:52:54.971279: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025a00 of size 256 next 213
# 2023-11-07 00:52:54.971288: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025b00 of size 256 next 214
# 2023-11-07 00:52:54.971296: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025c00 of size 256 next 215
# 2023-11-07 00:52:54.971304: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025d00 of size 256 next 216
# 2023-11-07 00:52:54.971312: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025e00 of size 256 next 217
# 2023-11-07 00:52:54.971320: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880025f00 of size 256 next 218
# 2023-11-07 00:52:54.971329: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880026000 of size 256 next 219
# 2023-11-07 00:52:54.971339: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880026100 of size 256 next 220
# 2023-11-07 00:52:54.971347: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880026200 of size 256 next 221
# 2023-11-07 00:52:54.971356: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880026300 of size 256 next 222
# 2023-11-07 00:52:54.971364: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880026400 of size 256 next 223
# 2023-11-07 00:52:54.971371: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880026500 of size 256 next 224
# 2023-11-07 00:52:54.971379: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb880026600 of size 256 next 225
# ...
# 2023-11-07 00:52:55.023774: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3907100 of size 16384 next 6570
# 2023-11-07 00:52:55.023782: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c390b100 of size 16384 next 6571
# 2023-11-07 00:52:55.023791: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c390f100 of size 16384 next 6572
# 2023-11-07 00:52:55.023800: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3913100 of size 16384 next 6573
# 2023-11-07 00:52:55.023809: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3917100 of size 16384 next 6574
# 2023-11-07 00:52:55.023818: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c391b100 of size 16384 next 6575
# 2023-11-07 00:52:55.023824: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c391f100 of size 16384 next 6576
# 2023-11-07 00:52:55.023831: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3923100 of size 16384 next 6577
# 2023-11-07 00:52:55.023837: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7fb8c3927100 of size 49152 next 6579
# 2023-11-07 00:52:55.023845: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3933100 of size 16384 next 6581
# 2023-11-07 00:52:55.023851: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3937100 of size 16384 next 6582
# 2023-11-07 00:52:55.023859: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c393b100 of size 16384 next 6583
# 2023-11-07 00:52:55.023866: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c393f100 of size 16384 next 6584
# 2023-11-07 00:52:55.023874: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3943100 of size 16384 next 6585
# 2023-11-07 00:52:55.023882: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3947100 of size 16384 next 6586
# 2023-11-07 00:52:55.023890: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7fb8c394b100 of size 65536 next 6588
# 2023-11-07 00:52:55.023897: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c395b100 of size 16384 next 6589
# 2023-11-07 00:52:55.023905: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c395f100 of size 16384 next 6590
# 2023-11-07 00:52:55.023913: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3963100 of size 16384 next 6591
# 2023-11-07 00:52:55.023920: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3967100 of size 16384 next 6592
# 2023-11-07 00:52:55.023928: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c396b100 of size 16384 next 6593
# 2023-11-07 00:52:55.023936: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c396f100 of size 16384 next 6594
# 2023-11-07 00:52:55.023943: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3973100 of size 16384 next 5921
# 2023-11-07 00:52:55.023951: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3977100 of size 16384 next 6596
# 2023-11-07 00:52:55.023958: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c397b100 of size 16384 next 6597
# 2023-11-07 00:52:55.023968: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c397f100 of size 16384 next 6598
# 2023-11-07 00:52:55.023976: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3983100 of size 16384 next 6599
# 2023-11-07 00:52:55.023984: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3987100 of size 16384 next 6600
# 2023-11-07 00:52:55.023993: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c398b100 of size 16384 next 6601
# 2023-11-07 00:52:55.023999: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c398f100 of size 16384 next 6602
# 2023-11-07 00:52:55.024007: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3993100 of size 16384 next 6603
# 2023-11-07 00:52:55.024015: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c3997100 of size 16384 next 6604
# 2023-11-07 00:52:55.024021: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c399b100 of size 16384 next 6605
# 2023-11-07 00:52:55.024029: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c399f100 of size 16384 next 6606
# 2023-11-07 00:52:55.024037: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c39a3100 of size 16384 next 6607
# 2023-11-07 00:52:55.024043: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c39a7100 of size 16384 next 6608
# 2023-11-07 00:52:55.024049: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c39ab100 of size 16384 next 6609
# 2023-11-07 00:52:55.024056: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fb8c39af100 of size 2883584 next 6610
# 2023-11-07 00:52:55.024064: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7fb8c3c6f100 of size 252317440 next 18446744073709551615
# 2023-11-07 00:52:55.024070: I tensorflow/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2023-11-07 00:52:55.024079: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 345 Chunks of size 256 totalling 86.2KiB
# 2023-11-07 00:52:55.024085: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 512 totalling 1.0KiB
# 2023-11-07 00:52:55.024093: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 1280 totalling 5.0KiB
# 2023-11-07 00:52:55.024101: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1975 Chunks of size 4096 totalling 7.71MiB
# 2023-11-07 00:52:55.024109: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 6400 totalling 6.2KiB
# 2023-11-07 00:52:55.024116: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 6656 totalling 6.5KiB
# 2023-11-07 00:52:55.024124: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 10 Chunks of size 7680 totalling 75.0KiB
# 2023-11-07 00:52:55.024132: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 8192 totalling 24.0KiB
# 2023-11-07 00:52:55.024140: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4061 Chunks of size 16384 totalling 63.45MiB
# 2023-11-07 00:52:55.024149: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 17920 totalling 35.0KiB
# 2023-11-07 00:52:55.024158: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 18432 totalling 36.0KiB
# 2023-11-07 00:52:55.024166: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 19968 totalling 19.5KiB
# 2023-11-07 00:52:55.024175: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 20224 totalling 19.8KiB
# 2023-11-07 00:52:55.024183: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 9 Chunks of size 20480 totalling 180.0KiB
# 2023-11-07 00:52:55.024191: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 24064 totalling 23.5KiB
# 2023-11-07 00:52:55.024199: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 13 Chunks of size 24576 totalling 312.0KiB
# 2023-11-07 00:52:55.024206: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 44 Chunks of size 28672 totalling 1.20MiB
# 2023-11-07 00:52:55.024214: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 29696 totalling 29.0KiB
# 2023-11-07 00:52:55.024221: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 32512 totalling 63.5KiB
# 2023-11-07 00:52:55.024229: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 54016 totalling 105.5KiB
# 2023-11-07 00:52:55.024237: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 135168 totalling 792.0KiB
# 2023-11-07 00:52:55.024245: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 192512 totalling 188.0KiB
# 2023-11-07 00:52:55.024252: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 389120 totalling 380.0KiB
# 2023-11-07 00:52:55.024260: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 507904 totalling 496.0KiB
# 2023-11-07 00:52:55.024268: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 540672 totalling 1.55MiB
# 2023-11-07 00:52:55.024275: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 688128 totalling 672.0KiB
# 2023-11-07 00:52:55.024282: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 753664 totalling 736.0KiB
# 2023-11-07 00:52:55.024290: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2490368 totalling 2.38MiB
# 2023-11-07 00:52:55.024297: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 2883584 totalling 13.75MiB
# 2023-11-07 00:52:55.024304: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 33161216 totalling 31.62MiB
# 2023-11-07 00:52:55.024311: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1003487232 totalling 957.00MiB
# 2023-11-07 00:52:55.024319: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 1.06GiB
# 2023-11-07 00:52:55.024329: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 1389428736 memory_limit_: 1389428736 available bytes: 0 curr_region_allocation_bytes_: 2778857472
# 2023-11-07 00:52:55.024341: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      1389428736
# InUse:                      1135460096
# MaxInUse:                   1137026560
# NumAllocs:                       20754
# MaxAllocSize:               1003487232
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-11-07 00:52:55.024404: W tensorflow/tsl/framework/bfc_allocator.cc:497] **********************************************************************************__________________
# 2023-11-07 00:52:55.024428: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at conv_ops_fused_impl.h:568 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1024,32,44,174] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2023-11-07 00:52:55.024461: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 4236242970584339552
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[2], line 239
#     236 checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
#     238 pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
# --> 239 model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
#     240 import tensorflow as tf
#     241 model = tf.keras.models.load_model(model_name)
#
# File /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:856, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     853 self._check_call_args("fit")
#     855 func = self._select_training_loop(x)
# --> 856 return func.fit(
#     857     self,
#     858     x=x,
#     859     y=y,
#     860     batch_size=batch_size,
#     861     epochs=epochs,
#     862     verbose=verbose,
#     863     callbacks=callbacks,
#     864     validation_split=validation_split,
#     865     validation_data=validation_data,
#     866     shuffle=shuffle,
#     867     class_weight=class_weight,
#     868     sample_weight=sample_weight,
#     869     initial_epoch=initial_epoch,
#     870     steps_per_epoch=steps_per_epoch,
#     871     validation_steps=validation_steps,
#     872     validation_freq=validation_freq,
#     873     max_queue_size=max_queue_size,
#     874     workers=workers,
#     875     use_multiprocessing=use_multiprocessing,
#     876 )
#
# File /usr/lib/python3.11/site-packages/keras/engine/training_arrays_v1.py:734, in ArrayLikeTrainingLoop.fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     728         raise ValueError(
#     729             "`validation_steps` should not be specified if "
#     730             "`validation_data` is None."
#     731         )
#     732     val_x, val_y, val_sample_weights = None, None, None
# --> 734 return fit_loop(
#     735     model,
#     736     inputs=x,
#     737     targets=y,
#     738     sample_weights=sample_weights,
#     739     batch_size=batch_size,
#     740     epochs=epochs,
#     741     verbose=verbose,
#     742     callbacks=callbacks,
#     743     val_inputs=val_x,
#     744     val_targets=val_y,
#     745     val_sample_weights=val_sample_weights,
#     746     shuffle=shuffle,
#     747     initial_epoch=initial_epoch,
#     748     steps_per_epoch=steps_per_epoch,
#     749     validation_steps=validation_steps,
#     750     validation_freq=validation_freq,
#     751     steps_name="steps_per_epoch",
#     752 )
#
# File /usr/lib/python3.11/site-packages/keras/engine/training_arrays_v1.py:421, in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     416 callbacks._call_batch_hook(
#     417     mode, "begin", batch_index, batch_logs
#     418 )
#     420 # Get outputs.
# --> 421 batch_outs = f(ins_batch)
#     422 if not isinstance(batch_outs, list):
#     423     batch_outs = [batch_outs]
#
# File /usr/lib/python3.11/site-packages/keras/backend.py:4608, in GraphExecutionFunction.__call__(self, inputs)
#    4598 if (
#    4599     self._callable_fn is None
#    4600     or feed_arrays != self._feed_arrays
#    (...)
#    4604     or session != self._session
#    4605 ):
#    4606     self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
# -> 4608 fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    4609 self._call_fetch_callbacks(fetched[-len(self._fetches) :])
#    4610 output_structure = tf.nest.pack_sequence_as(
#    4611     self._outputs_structure,
#    4612     fetched[: len(self.outputs)],
#    4613     expand_composites=True,
#    4614 )
#
# File /usr/lib/python3.11/site-packages/tensorflow/python/client/session.py:1482, in BaseSession._Callable.__call__(self, *args, **kwargs)
#    1480 try:
#    1481   run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# -> 1482   ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1483                                          self._handle, args,
#    1484                                          run_metadata_ptr)
#    1485   if run_metadata:
#    1486     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1024,32,44,174] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node conv2d/Relu}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[loss_1/mul/_1349]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
#   (1) RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1024,32,44,174] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node conv2d/Relu}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 0 successful operations.
# 0 derived errors ignored.

# %%
people_nums_all.shape
# Out:
# (37001,)

# %%
train_val_idx.shape
# Out:
# (35408,)

# %%
test_idx.shape
# Out:
# (1593,)

# %%
35408 + 1593
# Out:
# 37001

# %%
len(trace_wlk_num)
# Out:
# 37001

# %%
u.shape
# Out:
# (3090,)
