# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([wlk_fre, wlk_fres_trace, double_support_time, pdps_new, energy_alls, log_energy_alls, smoothe_energy_alls, dur_time_1_alls, dur_time_2_alls]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Adaptive_prune_model_only_bio_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-08 23:50:26.695364: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:26.706715: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:26.706952: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:26.710797: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:26.710988: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:26.711153: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:26.792159: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:26.792359: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:26.792522: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:26.792661: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-12-08 23:50:26.792898: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# (29601, 6)
# Train on 29601 samples, validate on 3694 samples
# 2023-12-08 23:50:27.277505: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:27.277745: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:27.277919: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:27.278127: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:27.278300: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 23:50:27.278436: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-12-08 23:50:27.278467: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-12-08 23:50:27.293607: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# Epoch 1/100
# 2023-12-08 23:50:27.501419: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense/kernel/v/Assign' id:1701 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense/kernel/v, training/Adam/dense/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
#  1024/29601 [>.............................] - ETA: 10s - loss: 4.9541
# 2023-12-08 23:50:27.844793: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 29601/29601 [==============================] - ETA: 0s - loss: 4.4888
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-12-08 23:50:30.443547: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:638 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 3.76287, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 108us/sample - loss: 4.4888 - val_loss: 3.7629
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 2.6973
# Epoch 2: val_loss improved from 3.76287 to 2.00763, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 90us/sample - loss: 2.6973 - val_loss: 2.0076
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.8453
# Epoch 3: val_loss improved from 2.00763 to 1.65171, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.8453 - val_loss: 1.6517
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.7000
# Epoch 4: val_loss improved from 1.65171 to 1.59252, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.7000 - val_loss: 1.5925
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6481
# Epoch 5: val_loss improved from 1.59252 to 1.56794, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.6481 - val_loss: 1.5679
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6187
# Epoch 6: val_loss improved from 1.56794 to 1.55852, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.6187 - val_loss: 1.5585
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6062
# Epoch 7: val_loss improved from 1.55852 to 1.55224, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.6062 - val_loss: 1.5522
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5966
# Epoch 8: val_loss improved from 1.55224 to 1.54884, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.5966 - val_loss: 1.5488
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5911
# Epoch 9: val_loss did not improve from 1.54884
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5911 - val_loss: 1.5512
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5823
# Epoch 10: val_loss improved from 1.54884 to 1.54441, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5823 - val_loss: 1.5444
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5708
# Epoch 11: val_loss improved from 1.54441 to 1.53900, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.5708 - val_loss: 1.5390
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5649
# Epoch 12: val_loss improved from 1.53900 to 1.53738, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.5649 - val_loss: 1.5374
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5605
# Epoch 13: val_loss improved from 1.53738 to 1.53146, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 107us/sample - loss: 1.5605 - val_loss: 1.5315
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5494
# Epoch 14: val_loss did not improve from 1.53146
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5494 - val_loss: 1.5403
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5461
# Epoch 15: val_loss did not improve from 1.53146
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5461 - val_loss: 1.5323
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5419
# Epoch 16: val_loss did not improve from 1.53146
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.5419 - val_loss: 1.5361
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5370
# Epoch 17: val_loss improved from 1.53146 to 1.52985, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 103us/sample - loss: 1.5370 - val_loss: 1.5298
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5323
# Epoch 18: val_loss improved from 1.52985 to 1.52591, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5323 - val_loss: 1.5259
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5322
# Epoch 19: val_loss improved from 1.52591 to 1.52104, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5322 - val_loss: 1.5210
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5266
# Epoch 20: val_loss did not improve from 1.52104
# 29601/29601 [==============================] - 3s 103us/sample - loss: 1.5266 - val_loss: 1.5292
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5244
# Epoch 21: val_loss did not improve from 1.52104
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5244 - val_loss: 1.5215
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5255
# Epoch 22: val_loss improved from 1.52104 to 1.51951, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5255 - val_loss: 1.5195
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5196
# Epoch 23: val_loss improved from 1.51951 to 1.51733, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5196 - val_loss: 1.5173
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5200
# Epoch 24: val_loss improved from 1.51733 to 1.51727, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5200 - val_loss: 1.5173
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5171
# Epoch 25: val_loss improved from 1.51727 to 1.51247, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.5171 - val_loss: 1.5125
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5169
# Epoch 26: val_loss improved from 1.51247 to 1.51116, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5169 - val_loss: 1.5112
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5153
# Epoch 27: val_loss did not improve from 1.51116
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5153 - val_loss: 1.5131
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5146
# Epoch 28: val_loss improved from 1.51116 to 1.50988, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.5146 - val_loss: 1.5099
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5143
# Epoch 29: val_loss improved from 1.50988 to 1.50857, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.5143 - val_loss: 1.5086
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5129
# Epoch 30: val_loss improved from 1.50857 to 1.50809, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.5129 - val_loss: 1.5081
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5108
# Epoch 31: val_loss did not improve from 1.50809
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5108 - val_loss: 1.5127
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5108
# Epoch 32: val_loss improved from 1.50809 to 1.50514, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5108 - val_loss: 1.5051
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5092
# Epoch 33: val_loss improved from 1.50514 to 1.50371, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5092 - val_loss: 1.5037
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5091
# Epoch 34: val_loss did not improve from 1.50371
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.5091 - val_loss: 1.5069
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5080
# Epoch 35: val_loss did not improve from 1.50371
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5080 - val_loss: 1.5058
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5070
# Epoch 36: val_loss did not improve from 1.50371
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5070 - val_loss: 1.5064
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5081
# Epoch 37: val_loss did not improve from 1.50371
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5081 - val_loss: 1.5052
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5065
# Epoch 38: val_loss did not improve from 1.50371
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5065 - val_loss: 1.5039
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5047
# Epoch 39: val_loss did not improve from 1.50371
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5047 - val_loss: 1.5044
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5041
# Epoch 40: val_loss did not improve from 1.50371
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5041 - val_loss: 1.5060
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5019
# Epoch 41: val_loss improved from 1.50371 to 1.50141, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5019 - val_loss: 1.5014
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5031
# Epoch 42: val_loss did not improve from 1.50141
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5031 - val_loss: 1.5022
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5036
# Epoch 43: val_loss did not improve from 1.50141
# 29601/29601 [==============================] - 3s 98us/sample - loss: 1.5036 - val_loss: 1.5015
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5012
# Epoch 44: val_loss did not improve from 1.50141
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.5012 - val_loss: 1.5021
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5034
# Epoch 45: val_loss improved from 1.50141 to 1.49863, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.5034 - val_loss: 1.4986
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5001
# Epoch 46: val_loss did not improve from 1.49863
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5001 - val_loss: 1.5005
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5003
# Epoch 47: val_loss did not improve from 1.49863
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5003 - val_loss: 1.4988
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4997
# Epoch 48: val_loss did not improve from 1.49863
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4997 - val_loss: 1.4990
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5008
# Epoch 49: val_loss did not improve from 1.49863
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5008 - val_loss: 1.4997
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4991
# Epoch 50: val_loss improved from 1.49863 to 1.49656, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 107us/sample - loss: 1.4991 - val_loss: 1.4966
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4978
# Epoch 51: val_loss did not improve from 1.49656
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4978 - val_loss: 1.4995
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4996
# Epoch 52: val_loss did not improve from 1.49656
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4996 - val_loss: 1.4988
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4975
# Epoch 53: val_loss did not improve from 1.49656
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4975 - val_loss: 1.4977
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4972
# Epoch 54: val_loss improved from 1.49656 to 1.49620, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4972 - val_loss: 1.4962
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4961
# Epoch 55: val_loss did not improve from 1.49620
# 29601/29601 [==============================] - 3s 101us/sample - loss: 1.4961 - val_loss: 1.4990
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4941
# Epoch 56: val_loss did not improve from 1.49620
# 29601/29601 [==============================] - 3s 96us/sample - loss: 1.4941 - val_loss: 1.4971
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4970
# Epoch 57: val_loss did not improve from 1.49620
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.4970 - val_loss: 1.4966
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4951
# Epoch 58: val_loss improved from 1.49620 to 1.49588, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.4951 - val_loss: 1.4959
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4944
# Epoch 59: val_loss did not improve from 1.49588
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4944 - val_loss: 1.4960
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4950
# Epoch 60: val_loss did not improve from 1.49588
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4950 - val_loss: 1.4976
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4926
# Epoch 61: val_loss improved from 1.49588 to 1.49536, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4926 - val_loss: 1.4954
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4910
# Epoch 62: val_loss did not improve from 1.49536
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4910 - val_loss: 1.4960
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4951
# Epoch 63: val_loss did not improve from 1.49536
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4951 - val_loss: 1.4960
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4918
# Epoch 64: val_loss did not improve from 1.49536
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4918 - val_loss: 1.4956
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4934
# Epoch 65: val_loss improved from 1.49536 to 1.49441, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.4934 - val_loss: 1.4944
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4913
# Epoch 66: val_loss did not improve from 1.49441
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4913 - val_loss: 1.4977
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4931
# Epoch 67: val_loss did not improve from 1.49441
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4931 - val_loss: 1.4946
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4921
# Epoch 68: val_loss did not improve from 1.49441
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4921 - val_loss: 1.4964
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4905
# Epoch 69: val_loss did not improve from 1.49441
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4905 - val_loss: 1.4960
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4901
# Epoch 70: val_loss improved from 1.49441 to 1.49418, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4901 - val_loss: 1.4942
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4903
# Epoch 71: val_loss did not improve from 1.49418
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4903 - val_loss: 1.4946
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4891
# Epoch 72: val_loss did not improve from 1.49418
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4891 - val_loss: 1.4967
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4898
# Epoch 73: val_loss did not improve from 1.49418
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4898 - val_loss: 1.4949
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4914
# Epoch 74: val_loss did not improve from 1.49418
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4914 - val_loss: 1.4946
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4892
# Epoch 75: val_loss improved from 1.49418 to 1.49378, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4892 - val_loss: 1.4938
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4890
# Epoch 76: val_loss did not improve from 1.49378
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4890 - val_loss: 1.4942
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4896
# Epoch 77: val_loss did not improve from 1.49378
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4896 - val_loss: 1.4944
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4880
# Epoch 78: val_loss improved from 1.49378 to 1.49266, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4880 - val_loss: 1.4927
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4899
# Epoch 79: val_loss improved from 1.49266 to 1.49249, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4899 - val_loss: 1.4925
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4870
# Epoch 80: val_loss did not improve from 1.49249
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4870 - val_loss: 1.4926
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4893
# Epoch 81: val_loss did not improve from 1.49249
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4893 - val_loss: 1.4926
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4882
# Epoch 82: val_loss did not improve from 1.49249
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4882 - val_loss: 1.4932
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4873
# Epoch 83: val_loss improved from 1.49249 to 1.49201, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4873 - val_loss: 1.4920
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4872
# Epoch 84: val_loss improved from 1.49201 to 1.49104, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4872 - val_loss: 1.4910
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4851
# Epoch 85: val_loss did not improve from 1.49104
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4851 - val_loss: 1.4916
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4853
# Epoch 86: val_loss did not improve from 1.49104
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4853 - val_loss: 1.4936
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4893
# Epoch 87: val_loss improved from 1.49104 to 1.49042, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4893 - val_loss: 1.4904
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4870
# Epoch 88: val_loss did not improve from 1.49042
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4870 - val_loss: 1.4918
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4857
# Epoch 89: val_loss improved from 1.49042 to 1.49029, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4857 - val_loss: 1.4903
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4862
# Epoch 90: val_loss improved from 1.49029 to 1.49028, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4862 - val_loss: 1.4903
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4852
# Epoch 91: val_loss did not improve from 1.49028
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4852 - val_loss: 1.4923
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4845
# Epoch 92: val_loss did not improve from 1.49028
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4845 - val_loss: 1.4925
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4862
# Epoch 93: val_loss did not improve from 1.49028
# 29601/29601 [==============================] - 3s 92us/sample - loss: 1.4862 - val_loss: 1.4943
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4864
# Epoch 94: val_loss improved from 1.49028 to 1.48894, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4864 - val_loss: 1.4889
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4858
# Epoch 95: val_loss did not improve from 1.48894
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4858 - val_loss: 1.4922
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4836
# Epoch 96: val_loss improved from 1.48894 to 1.48790, saving model to ./checkpoints/Adaptive_prune_model_only_bio_0.h5
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4836 - val_loss: 1.4879
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4832
# Epoch 97: val_loss did not improve from 1.48790
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4832 - val_loss: 1.4885
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4844
# Epoch 98: val_loss did not improve from 1.48790
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4844 - val_loss: 1.4882
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4852
# Epoch 99: val_loss did not improve from 1.48790
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4852 - val_loss: 1.4940
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4838
# Epoch 100: val_loss did not improve from 1.48790
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4838 - val_loss: 1.4910
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4831
# Epoch 1: val_loss improved from inf to 1.49585, saving model to ./checkpoints/Adaptive_prune_model_only_bio_1.h5
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4831 - val_loss: 1.4958
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4857
# Epoch 2: val_loss improved from 1.49585 to 1.49508, saving model to ./checkpoints/Adaptive_prune_model_only_bio_1.h5
# 29601/29601 [==============================] - 3s 97us/sample - loss: 1.4857 - val_loss: 1.4951
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4840
# Epoch 3: val_loss improved from 1.49508 to 1.48871, saving model to ./checkpoints/Adaptive_prune_model_only_bio_1.h5
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4840 - val_loss: 1.4887
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4824
# Epoch 4: val_loss did not improve from 1.48871
# 29601/29601 [==============================] - 3s 107us/sample - loss: 1.4824 - val_loss: 1.4902
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4833
# Epoch 5: val_loss did not improve from 1.48871
# 29601/29601 [==============================] - 3s 101us/sample - loss: 1.4833 - val_loss: 1.4927
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4832
# Epoch 6: val_loss improved from 1.48871 to 1.48700, saving model to ./checkpoints/Adaptive_prune_model_only_bio_1.h5
# 29601/29601 [==============================] - 3s 92us/sample - loss: 1.4832 - val_loss: 1.4870
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4825
# Epoch 7: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4825 - val_loss: 1.4889
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4811
# Epoch 8: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4811 - val_loss: 1.4896
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4837
# Epoch 9: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 96us/sample - loss: 1.4837 - val_loss: 1.4898
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4828
# Epoch 10: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 92us/sample - loss: 1.4828 - val_loss: 1.4898
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4840
# Epoch 11: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4840 - val_loss: 1.4941
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4868
# Epoch 12: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4868 - val_loss: 1.4894
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4820
# Epoch 13: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4820 - val_loss: 1.4888
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4839
# Epoch 14: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.4839 - val_loss: 1.4918
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4824
# Epoch 15: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4824 - val_loss: 1.4878
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4827
# Epoch 16: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.4827 - val_loss: 1.4943
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4830
# Epoch 17: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4830 - val_loss: 1.4914
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4820
# Epoch 18: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.4820 - val_loss: 1.4894
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4884
# Epoch 19: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.4884 - val_loss: 1.4879
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4850
# Epoch 20: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4850 - val_loss: 1.4908
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4822
# Epoch 21: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.4822 - val_loss: 1.4896
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4830
# Epoch 22: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4830 - val_loss: 1.4903
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4806
# Epoch 23: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.4806 - val_loss: 1.4874
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4832
# Epoch 24: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4832 - val_loss: 1.4888
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4801
# Epoch 25: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4801 - val_loss: 1.4899
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4815
# Epoch 26: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4815 - val_loss: 1.4923
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4805
# Epoch 27: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4805 - val_loss: 1.4917
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4852
# Epoch 28: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4852 - val_loss: 1.4905
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4797
# Epoch 29: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4797 - val_loss: 1.4883
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4830
# Epoch 30: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.4830 - val_loss: 1.4898
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4824
# Epoch 31: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4824 - val_loss: 1.4872
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4800
# Epoch 32: val_loss did not improve from 1.48700
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4800 - val_loss: 1.4887
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4807
# Epoch 33: val_loss improved from 1.48700 to 1.48576, saving model to ./checkpoints/Adaptive_prune_model_only_bio_1.h5
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4807 - val_loss: 1.4858
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4802
# Epoch 34: val_loss did not improve from 1.48576
# 29601/29601 [==============================] - 3s 100us/sample - loss: 1.4802 - val_loss: 1.4899
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4791
# Epoch 35: val_loss did not improve from 1.48576
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.4791 - val_loss: 1.4865
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4805
# Epoch 36: val_loss did not improve from 1.48576
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.4805 - val_loss: 1.4870
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4811
# Epoch 37: val_loss did not improve from 1.48576
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4811 - val_loss: 1.4871
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4788
# Epoch 38: val_loss did not improve from 1.48576
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4788 - val_loss: 1.4879
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4793
# Epoch 39: val_loss did not improve from 1.48576
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.4793 - val_loss: 1.4882
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4796
# Epoch 40: val_loss did not improve from 1.48576
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4796 - val_loss: 1.4872
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4801
# Epoch 41: val_loss did not improve from 1.48576
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4801 - val_loss: 1.4878
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4789
# Epoch 42: val_loss did not improve from 1.48576
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4789 - val_loss: 1.4879
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4803
# Epoch 43: val_loss improved from 1.48576 to 1.48247, saving model to ./checkpoints/Adaptive_prune_model_only_bio_1.h5
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.4803 - val_loss: 1.4825
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4808
# Epoch 44: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 107us/sample - loss: 1.4808 - val_loss: 1.4841
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4803
# Epoch 45: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.4803 - val_loss: 1.4876
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4793
# Epoch 46: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 98us/sample - loss: 1.4793 - val_loss: 1.4881
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4809
# Epoch 47: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 99us/sample - loss: 1.4809 - val_loss: 1.4900
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4798
# Epoch 48: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4798 - val_loss: 1.4867
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4798
# Epoch 49: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4798 - val_loss: 1.4890
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4800
# Epoch 50: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4800 - val_loss: 1.4870
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4786
# Epoch 51: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4786 - val_loss: 1.4883
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4784
# Epoch 52: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 107us/sample - loss: 1.4784 - val_loss: 1.4842
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4777
# Epoch 53: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4777 - val_loss: 1.4853
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4769
# Epoch 54: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 107us/sample - loss: 1.4769 - val_loss: 1.4873
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4780
# Epoch 55: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4780 - val_loss: 1.4855
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4766
# Epoch 56: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4766 - val_loss: 1.4868
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4800
# Epoch 57: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4800 - val_loss: 1.4867
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4764
# Epoch 58: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4764 - val_loss: 1.4845
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4779
# Epoch 59: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4779 - val_loss: 1.4866
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4772
# Epoch 60: val_loss did not improve from 1.48247
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4772 - val_loss: 1.4836
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4777
# Epoch 61: val_loss improved from 1.48247 to 1.48104, saving model to ./checkpoints/Adaptive_prune_model_only_bio_1.h5
# ...
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4620
# Epoch 31: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4620 - val_loss: 1.4743
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4620
# Epoch 32: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4620 - val_loss: 1.4678
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4665
# Epoch 33: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4665 - val_loss: 1.4698
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4617
# Epoch 34: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.4617 - val_loss: 1.4718
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4631
# Epoch 35: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4631 - val_loss: 1.4699
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4642
# Epoch 36: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4642 - val_loss: 1.4687
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4630
# Epoch 37: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4630 - val_loss: 1.4753
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4644
# Epoch 38: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4644 - val_loss: 1.4728
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4632
# Epoch 39: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4632 - val_loss: 1.4691
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4622
# Epoch 40: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4622 - val_loss: 1.4705
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4683
# Epoch 41: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4683 - val_loss: 1.4727
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4627
# Epoch 42: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4627 - val_loss: 1.4709
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4683
# Epoch 43: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4683 - val_loss: 1.4768
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4644
# Epoch 44: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4644 - val_loss: 1.4737
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4649
# Epoch 45: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.4649 - val_loss: 1.4725
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4642
# Epoch 46: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.4642 - val_loss: 1.4760
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4656
# Epoch 47: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.4656 - val_loss: 1.4728
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4640
# Epoch 48: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.4640 - val_loss: 1.4732
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4694
# Epoch 49: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.4694 - val_loss: 1.4776
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4666
# Epoch 50: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4666 - val_loss: 1.4772
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4810
# Epoch 51: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.4810 - val_loss: 1.4833
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4741
# Epoch 52: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 107us/sample - loss: 1.4741 - val_loss: 1.4788
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4675
# Epoch 53: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 108us/sample - loss: 1.4675 - val_loss: 1.4766
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4661
# Epoch 54: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4661 - val_loss: 1.4808
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4657
# Epoch 55: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4657 - val_loss: 1.4755
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4646
# Epoch 56: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4646 - val_loss: 1.4733
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4652
# Epoch 57: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4652 - val_loss: 1.4720
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4638
# Epoch 58: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 108us/sample - loss: 1.4638 - val_loss: 1.4764
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4635
# Epoch 59: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4635 - val_loss: 1.4725
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4652
# Epoch 60: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4652 - val_loss: 1.4733
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4649
# Epoch 61: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 103us/sample - loss: 1.4649 - val_loss: 1.4759
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4638
# Epoch 62: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4638 - val_loss: 1.4753
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4636
# Epoch 63: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4636 - val_loss: 1.4768
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4624
# Epoch 64: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4624 - val_loss: 1.4744
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4626
# Epoch 65: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4626 - val_loss: 1.4734
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4642
# Epoch 66: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4642 - val_loss: 1.4743
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4619
# Epoch 67: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4619 - val_loss: 1.4754
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4638
# Epoch 68: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4638 - val_loss: 1.4722
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4642
# Epoch 69: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4642 - val_loss: 1.4728
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4616
# Epoch 70: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4616 - val_loss: 1.4732
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4620
# Epoch 71: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4620 - val_loss: 1.4734
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4628
# Epoch 72: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4628 - val_loss: 1.4685
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4642
# Epoch 73: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4642 - val_loss: 1.4743
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4649
# Epoch 74: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4649 - val_loss: 1.4712
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4625
# Epoch 75: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4625 - val_loss: 1.4756
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4628
# Epoch 76: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4628 - val_loss: 1.4712
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4649
# Epoch 77: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4649 - val_loss: 1.4677
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4624
# Epoch 78: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4624 - val_loss: 1.4714
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4627
# Epoch 79: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 97us/sample - loss: 1.4627 - val_loss: 1.4717
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4617
# Epoch 80: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4617 - val_loss: 1.4692
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4611
# Epoch 81: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4611 - val_loss: 1.4696
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4639
# Epoch 82: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4639 - val_loss: 1.4698
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4611
# Epoch 83: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.4611 - val_loss: 1.4697
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4619
# Epoch 84: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.4619 - val_loss: 1.4676
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4622
# Epoch 85: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4622 - val_loss: 1.4698
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4618
# Epoch 86: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4618 - val_loss: 1.4687
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4612
# Epoch 87: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4612 - val_loss: 1.4704
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4689
# Epoch 88: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.4689 - val_loss: 1.4780
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4678
# Epoch 89: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.4678 - val_loss: 1.4780
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4673
# Epoch 90: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4673 - val_loss: 1.4764
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4657
# Epoch 91: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4657 - val_loss: 1.4734
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4657
# Epoch 92: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4657 - val_loss: 1.4804
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4657
# Epoch 93: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4657 - val_loss: 1.4767
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4655
# Epoch 94: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4655 - val_loss: 1.4728
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4647
# Epoch 95: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4647 - val_loss: 1.4747
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4636
# Epoch 96: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4636 - val_loss: 1.4744
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4632
# Epoch 97: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.4632 - val_loss: 1.4733
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4639
# Epoch 98: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.4639 - val_loss: 1.4749
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4635
# Epoch 99: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 93us/sample - loss: 1.4635 - val_loss: 1.4714
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4619
# Epoch 100: val_loss did not improve from 1.46736
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.4619 - val_loss: 1.4702

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_only_bio_0.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:32:34.231219: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_7/lstm_cell_15/recurrent_kernel/Assign' id:5199 op device:{requested: '', assigned: ''} def:{{{node lstm_7/lstm_cell_15/recurrent_kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_7/lstm_cell_15/recurrent_kernel, lstm_7/lstm_cell_15/recurrent_kernel/Initializer/mul_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:32:34.475394: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_8/kernel/v/Assign' id:5999 op device:{requested: '', assigned: ''} def:{{{node dense_8/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_8/kernel/v, dense_8/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-12-13 23:32:34.724783: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_5/BiasAdd' id:5750 op device:{requested: '', assigned: ''} def:{{{node dense_3_5/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_5/MatMul, dense_3_5/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.4471235961381383
# 1.424570851187104

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_only_bio_1.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:32:38.251208: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1_6/kernel/Assign' id:6728 op device:{requested: '', assigned: ''} def:{{{node dense_1_6/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_1_6/kernel, dense_1_6/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:32:38.513277: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_8/lstm_cell_18/recurrent_kernel/m/Assign' id:6902 op device:{requested: '', assigned: ''} def:{{{node lstm_8/lstm_cell_18/recurrent_kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_8/lstm_cell_18/recurrent_kernel/m, lstm_8/lstm_cell_18/recurrent_kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:32:38.785277: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_6/BiasAdd' id:6780 op device:{requested: '', assigned: ''} def:{{{node dense_3_6/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_6/MatMul, dense_3_6/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.4384044476026339
# 1.4142582232126526

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_only_bio_2.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:32:42.299854: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_2_7/lstm_cell_23/kernel/Assign' id:7559 op device:{requested: '', assigned: ''} def:{{{node lstm_2_7/lstm_cell_23/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_2_7/lstm_cell_23/kernel, lstm_2_7/lstm_cell_23/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:32:42.588447: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_1_7/lstm_cell_22/kernel/v/Assign' id:8029 op device:{requested: '', assigned: ''} def:{{{node lstm_1_7/lstm_cell_22/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_1_7/lstm_cell_22/kernel/v, lstm_1_7/lstm_cell_22/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:32:42.884455: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_7/BiasAdd' id:7810 op device:{requested: '', assigned: ''} def:{{{node dense_3_7/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_7/MatMul, dense_3_7/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.4370292436896437
# 1.409579981337859

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_only_bio_3.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:32:46.435735: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_8/bias/Assign' id:8835 op device:{requested: '', assigned: ''} def:{{{node dense_3_8/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_3_8/bias, dense_3_8/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:32:46.747731: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_8/bias/m/Assign' id:9039 op device:{requested: '', assigned: ''} def:{{{node dense_3_8/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_3_8/bias/m, dense_3_8/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:32:47.069155: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_8/BiasAdd' id:8840 op device:{requested: '', assigned: ''} def:{{{node dense_3_8/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_8/MatMul, dense_3_8/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.436237477345912
# 1.406749451893433

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_only_bio_4.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:32:50.666309: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_2_9/lstm_cell_29/kernel/Assign' id:9619 op device:{requested: '', assigned: ''} def:{{{node lstm_2_9/lstm_cell_29/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_2_9/lstm_cell_29/kernel, lstm_2_9/lstm_cell_29/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:32:51.003834: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_9/kernel/v/Assign' id:10151 op device:{requested: '', assigned: ''} def:{{{node dense_3_9/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_3_9/kernel/v, dense_3_9/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:32:51.354802: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_9/BiasAdd' id:9870 op device:{requested: '', assigned: ''} def:{{{node dense_3_9/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_9/MatMul, dense_3_9/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.4398288758908873
# 1.4083234686681754

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_only_bio_5.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:32:55.020655: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_2_10/lstm_cell_32/bias/Assign' id:10678 op device:{requested: '', assigned: ''} def:{{{node lstm_2_10/lstm_cell_32/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_2_10/lstm_cell_32/bias, lstm_2_10/lstm_cell_32/bias/Initializer/concat)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:32:55.386210: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_2_10/lstm_cell_32/kernel/m/Assign' id:11047 op device:{requested: '', assigned: ''} def:{{{node lstm_2_10/lstm_cell_32/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_2_10/lstm_cell_32/kernel/m, lstm_2_10/lstm_cell_32/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:32:55.760317: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_10/BiasAdd' id:10900 op device:{requested: '', assigned: ''} def:{{{node dense_3_10/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_10/MatMul, dense_3_10/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.4304689965406368
# 1.4043904890906076

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_only_bio_6.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:33:14.084644: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_2_14/lstm_cell_44/bias/Assign' id:14798 op device:{requested: '', assigned: ''} def:{{{node lstm_2_14/lstm_cell_44/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_2_14/lstm_cell_44/bias, lstm_2_14/lstm_cell_44/bias/Initializer/concat)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:33:14.570921: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_16/lstm_cell_42/recurrent_kernel/m/Assign' id:15142 op device:{requested: '', assigned: ''} def:{{{node lstm_16/lstm_cell_42/recurrent_kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_16/lstm_cell_42/recurrent_kernel/m, lstm_16/lstm_cell_42/recurrent_kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:33:15.202111: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_14/BiasAdd' id:15020 op device:{requested: '', assigned: ''} def:{{{node dense_3_14/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_14/MatMul, dense_3_14/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.439867212472577
# 1.413234358389401

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_only_bio_7.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:32:59.412114: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1_11/bias/Assign' id:11883 op device:{requested: '', assigned: ''} def:{{{node dense_1_11/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_1_11/bias, dense_1_11/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:32:59.806699: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_2_11/kernel/m/Assign' id:12114 op device:{requested: '', assigned: ''} def:{{{node dense_2_11/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_2_11/kernel/m, dense_2_11/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:33:00.210305: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_11/BiasAdd' id:11930 op device:{requested: '', assigned: ''} def:{{{node dense_3_11/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_11/MatMul, dense_3_11/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.440609697815025
# 1.412809039242445

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_only_bio_8.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:33:03.874132: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_12/bias/Assign' id:12955 op device:{requested: '', assigned: ''} def:{{{node dense_3_12/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_3_12/bias, dense_3_12/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:33:04.297711: W tensorflow/c/c_api.cc:304] Operation '{name:'beta_1_12/Assign' id:13057 op device:{requested: '', assigned: ''} def:{{{node beta_1_12/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](beta_1_12, beta_1_12/Initializer/initial_value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:33:04.731692: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_12/BiasAdd' id:12960 op device:{requested: '', assigned: ''} def:{{{node dense_3_12/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_12/MatMul, dense_3_12/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.4522570058872295
# 1.419936553791503

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_only_bio_9.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:33:08.897198: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_2_13/kernel/Assign' id:13959 op device:{requested: '', assigned: ''} def:{{{node dense_2_13/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_2_13/kernel, dense_2_13/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:33:09.348898: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_15/lstm_cell_39/kernel/m/Assign' id:14107 op device:{requested: '', assigned: ''} def:{{{node lstm_15/lstm_cell_39/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_15/lstm_cell_39/kernel/m, lstm_15/lstm_cell_39/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:33:09.813052: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_13/BiasAdd' id:13990 op device:{requested: '', assigned: ''} def:{{{node dense_3_13/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_13/MatMul, dense_3_13/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.442963969173524
# 1.4135370351735828
