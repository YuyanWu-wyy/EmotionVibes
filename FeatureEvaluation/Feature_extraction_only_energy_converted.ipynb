# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([energy_alls, log_energy_alls, smoothe_energy_alls]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-07 01:11:03.443582: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
# rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

# for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
model_name = './checkpoints/Feature_extraction_only_energy.h5'

checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
# pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=0.35, start_epoch=5, end_epoch=50, frequency=1)
model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-07 00:07:57.392345: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.403947: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.404184: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.407968: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.408173: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.408342: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.493292: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.493546: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.493718: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.493856: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-07 00:07:57.494102: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# (29601, 0)
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 2023-11-07 00:07:57.973961: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.974218: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.974390: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.974592: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.974762: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:07:57.974898: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-07 00:07:57.974930: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-07 00:07:57.990057: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-07 00:07:58.194103: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_3/bias/v/Assign' id:1738 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_3/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_3/bias/v, training/Adam/dense_3/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
#  1024/29601 [>.............................] - ETA: 18s - loss: 4.9743
# 2023-11-07 00:07:58.497599: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 29601/29601 [==============================] - ETA: 0s - loss: 4.7209
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-07 00:08:01.478478: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:638 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 4.33349, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 4s 130us/sample - loss: 4.7209 - val_loss: 4.3335
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 3.6664
# Epoch 2: val_loss improved from 4.33349 to 2.79900, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 107us/sample - loss: 3.6664 - val_loss: 2.7990
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 2.2472
# Epoch 3: val_loss improved from 2.79900 to 1.80611, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 105us/sample - loss: 2.2472 - val_loss: 1.8061
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.7478
# Epoch 4: val_loss improved from 1.80611 to 1.64232, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.7478 - val_loss: 1.6423
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6602
# Epoch 5: val_loss improved from 1.64232 to 1.59900, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.6602 - val_loss: 1.5990
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6386
# Epoch 6: val_loss improved from 1.59900 to 1.59322, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.6386 - val_loss: 1.5932
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6262
# Epoch 7: val_loss did not improve from 1.59322
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.6262 - val_loss: 1.5981
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6141
# Epoch 8: val_loss improved from 1.59322 to 1.59204, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.6141 - val_loss: 1.5920
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6063
# Epoch 9: val_loss did not improve from 1.59204
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.6063 - val_loss: 1.5953
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5997
# Epoch 10: val_loss did not improve from 1.59204
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5997 - val_loss: 1.5944
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5912
# Epoch 11: val_loss improved from 1.59204 to 1.58909, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 108us/sample - loss: 1.5912 - val_loss: 1.5891
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5824
# Epoch 12: val_loss did not improve from 1.58909
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5824 - val_loss: 1.5930
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5784
# Epoch 13: val_loss improved from 1.58909 to 1.58662, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 107us/sample - loss: 1.5784 - val_loss: 1.5866
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5754
# Epoch 14: val_loss did not improve from 1.58662
# 29601/29601 [==============================] - 3s 103us/sample - loss: 1.5754 - val_loss: 1.5989
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5715
# Epoch 15: val_loss did not improve from 1.58662
# 29601/29601 [==============================] - 3s 96us/sample - loss: 1.5715 - val_loss: 1.5912
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5684
# Epoch 16: val_loss did not improve from 1.58662
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.5684 - val_loss: 1.5954
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5693
# Epoch 17: val_loss did not improve from 1.58662
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5693 - val_loss: 1.5897
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5663
# Epoch 18: val_loss improved from 1.58662 to 1.58392, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5663 - val_loss: 1.5839
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5641
# Epoch 19: val_loss improved from 1.58392 to 1.58206, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.5641 - val_loss: 1.5821
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5634
# Epoch 20: val_loss did not improve from 1.58206
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.5634 - val_loss: 1.5885
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5623
# Epoch 21: val_loss improved from 1.58206 to 1.57799, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 93us/sample - loss: 1.5623 - val_loss: 1.5780
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5620
# Epoch 22: val_loss did not improve from 1.57799
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.5620 - val_loss: 1.5794
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5613
# Epoch 23: val_loss did not improve from 1.57799
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5613 - val_loss: 1.5781
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5605
# Epoch 24: val_loss improved from 1.57799 to 1.57665, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 100us/sample - loss: 1.5605 - val_loss: 1.5767
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5583
# Epoch 25: val_loss improved from 1.57665 to 1.57334, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5583 - val_loss: 1.5733
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5594
# Epoch 26: val_loss did not improve from 1.57334
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5594 - val_loss: 1.5736
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5593
# Epoch 27: val_loss did not improve from 1.57334
# 29601/29601 [==============================] - 3s 97us/sample - loss: 1.5593 - val_loss: 1.5754
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5589
# Epoch 28: val_loss did not improve from 1.57334
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5589 - val_loss: 1.5763
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5577
# Epoch 29: val_loss improved from 1.57334 to 1.57286, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5577 - val_loss: 1.5729
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5573
# Epoch 30: val_loss improved from 1.57286 to 1.57163, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5573 - val_loss: 1.5716
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5577
# Epoch 31: val_loss did not improve from 1.57163
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5577 - val_loss: 1.5744
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5562
# Epoch 32: val_loss did not improve from 1.57163
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5562 - val_loss: 1.5733
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5569
# Epoch 33: val_loss did not improve from 1.57163
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5569 - val_loss: 1.5724
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5562
# Epoch 34: val_loss improved from 1.57163 to 1.57114, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5562 - val_loss: 1.5711
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5566
# Epoch 35: val_loss did not improve from 1.57114
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5566 - val_loss: 1.5723
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5560
# Epoch 36: val_loss did not improve from 1.57114
# 29601/29601 [==============================] - 3s 103us/sample - loss: 1.5560 - val_loss: 1.5719
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5557
# Epoch 37: val_loss did not improve from 1.57114
# 29601/29601 [==============================] - 3s 103us/sample - loss: 1.5557 - val_loss: 1.5718
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5564
# Epoch 38: val_loss did not improve from 1.57114
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5564 - val_loss: 1.5732
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5562
# Epoch 39: val_loss did not improve from 1.57114
# 29601/29601 [==============================] - 3s 103us/sample - loss: 1.5562 - val_loss: 1.5723
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5565
# Epoch 40: val_loss improved from 1.57114 to 1.57113, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.5565 - val_loss: 1.5711
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5552
# Epoch 41: val_loss improved from 1.57113 to 1.56977, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5552 - val_loss: 1.5698
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5563
# Epoch 42: val_loss did not improve from 1.56977
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5563 - val_loss: 1.5702
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5554
# Epoch 43: val_loss did not improve from 1.56977
# 29601/29601 [==============================] - 3s 101us/sample - loss: 1.5554 - val_loss: 1.5717
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5554
# Epoch 44: val_loss did not improve from 1.56977
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5554 - val_loss: 1.5713
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5558
# Epoch 45: val_loss improved from 1.56977 to 1.56975, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 92us/sample - loss: 1.5558 - val_loss: 1.5697
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5560
# Epoch 46: val_loss improved from 1.56975 to 1.56955, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 93us/sample - loss: 1.5560 - val_loss: 1.5695
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5557
# Epoch 47: val_loss improved from 1.56955 to 1.56845, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 94us/sample - loss: 1.5557 - val_loss: 1.5684
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5559
# Epoch 48: val_loss improved from 1.56845 to 1.56620, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.5559 - val_loss: 1.5662
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5552
# Epoch 49: val_loss did not improve from 1.56620
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5552 - val_loss: 1.5682
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5545
# Epoch 50: val_loss did not improve from 1.56620
# 29601/29601 [==============================] - 3s 101us/sample - loss: 1.5545 - val_loss: 1.5688
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5542
# Epoch 51: val_loss did not improve from 1.56620
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5542 - val_loss: 1.5689
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5557
# Epoch 52: val_loss did not improve from 1.56620
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5557 - val_loss: 1.5685
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5544
# Epoch 53: val_loss did not improve from 1.56620
# 29601/29601 [==============================] - 3s 103us/sample - loss: 1.5544 - val_loss: 1.5684
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5557
# Epoch 54: val_loss did not improve from 1.56620
# 29601/29601 [==============================] - 3s 103us/sample - loss: 1.5557 - val_loss: 1.5675
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5558
# Epoch 55: val_loss did not improve from 1.56620
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5558 - val_loss: 1.5693
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5547
# Epoch 56: val_loss did not improve from 1.56620
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5547 - val_loss: 1.5677
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5549
# Epoch 57: val_loss did not improve from 1.56620
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5549 - val_loss: 1.5694
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5543
# Epoch 58: val_loss did not improve from 1.56620
# 29601/29601 [==============================] - 3s 106us/sample - loss: 1.5543 - val_loss: 1.5662
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5555
# Epoch 59: val_loss did not improve from 1.56620
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5555 - val_loss: 1.5675
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5545
# Epoch 60: val_loss did not improve from 1.56620
# 29601/29601 [==============================] - 3s 104us/sample - loss: 1.5545 - val_loss: 1.5666
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5546
# Epoch 61: val_loss improved from 1.56620 to 1.56611, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 105us/sample - loss: 1.5546 - val_loss: 1.5661
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5545
# Epoch 62: val_loss did not improve from 1.56611
# 29601/29601 [==============================] - 3s 95us/sample - loss: 1.5545 - val_loss: 1.5663
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5545
# Epoch 63: val_loss did not improve from 1.56611
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5545 - val_loss: 1.5664
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5544
# Epoch 64: val_loss did not improve from 1.56611
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5544 - val_loss: 1.5695
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5540
# Epoch 65: val_loss did not improve from 1.56611
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5540 - val_loss: 1.5672
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5538
# Epoch 66: val_loss did not improve from 1.56611
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5538 - val_loss: 1.5668
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5550
# Epoch 67: val_loss did not improve from 1.56611
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5550 - val_loss: 1.5664
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5541
# Epoch 68: val_loss did not improve from 1.56611
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5541 - val_loss: 1.5686
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5541
# Epoch 69: val_loss did not improve from 1.56611
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5541 - val_loss: 1.5664
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5541
# Epoch 70: val_loss improved from 1.56611 to 1.56454, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 92us/sample - loss: 1.5541 - val_loss: 1.5645
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5540
# Epoch 71: val_loss did not improve from 1.56454
# 29601/29601 [==============================] - 3s 92us/sample - loss: 1.5540 - val_loss: 1.5649
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5532
# Epoch 72: val_loss did not improve from 1.56454
# 29601/29601 [==============================] - 3s 92us/sample - loss: 1.5532 - val_loss: 1.5661
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5534
# Epoch 73: val_loss did not improve from 1.56454
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5534 - val_loss: 1.5669
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5541
# Epoch 74: val_loss did not improve from 1.56454
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5541 - val_loss: 1.5661
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5542
# Epoch 75: val_loss did not improve from 1.56454
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5542 - val_loss: 1.5650
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5539
# Epoch 76: val_loss did not improve from 1.56454
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5539 - val_loss: 1.5655
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5539
# Epoch 77: val_loss did not improve from 1.56454
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5539 - val_loss: 1.5656
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5533
# Epoch 78: val_loss did not improve from 1.56454
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5533 - val_loss: 1.5646
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5540
# Epoch 79: val_loss did not improve from 1.56454
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.5540 - val_loss: 1.5655
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5532
# Epoch 80: val_loss did not improve from 1.56454
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.5532 - val_loss: 1.5649
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5543
# Epoch 81: val_loss did not improve from 1.56454
# 29601/29601 [==============================] - 3s 93us/sample - loss: 1.5543 - val_loss: 1.5652
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5530
# Epoch 82: val_loss did not improve from 1.56454
# 29601/29601 [==============================] - 3s 92us/sample - loss: 1.5530 - val_loss: 1.5653
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5532
# Epoch 83: val_loss improved from 1.56454 to 1.56432, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.5532 - val_loss: 1.5643
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5524
# Epoch 84: val_loss did not improve from 1.56432
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.5524 - val_loss: 1.5666
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5527
# Epoch 85: val_loss did not improve from 1.56432
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5527 - val_loss: 1.5652
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5523
# Epoch 86: val_loss did not improve from 1.56432
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5523 - val_loss: 1.5662
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5530
# Epoch 87: val_loss improved from 1.56432 to 1.56426, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5530 - val_loss: 1.5643
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5517
# Epoch 88: val_loss did not improve from 1.56426
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.5517 - val_loss: 1.5644
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5522
# Epoch 89: val_loss did not improve from 1.56426
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.5522 - val_loss: 1.5650
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5524
# Epoch 90: val_loss improved from 1.56426 to 1.56328, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5524 - val_loss: 1.5633
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5524
# Epoch 91: val_loss improved from 1.56328 to 1.56305, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 94us/sample - loss: 1.5524 - val_loss: 1.5630
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5521
# Epoch 92: val_loss did not improve from 1.56305
# 29601/29601 [==============================] - 3s 91us/sample - loss: 1.5521 - val_loss: 1.5640
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5521
# Epoch 93: val_loss did not improve from 1.56305
# 29601/29601 [==============================] - 3s 98us/sample - loss: 1.5521 - val_loss: 1.5632
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5519
# Epoch 94: val_loss did not improve from 1.56305
# 29601/29601 [==============================] - 3s 92us/sample - loss: 1.5519 - val_loss: 1.5635
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5516
# Epoch 95: val_loss did not improve from 1.56305
# 29601/29601 [==============================] - 3s 96us/sample - loss: 1.5516 - val_loss: 1.5650
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5509
# Epoch 96: val_loss did not improve from 1.56305
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5509 - val_loss: 1.5655
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5510
# Epoch 97: val_loss improved from 1.56305 to 1.56257, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5510 - val_loss: 1.5626
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5508
# Epoch 98: val_loss improved from 1.56257 to 1.56239, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5508 - val_loss: 1.5624
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5504
# Epoch 99: val_loss did not improve from 1.56239
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.5504 - val_loss: 1.5624
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5497
# Epoch 100: val_loss improved from 1.56239 to 1.56129, saving model to ./checkpoints/Feature_extraction_only_energy.h5
# 29601/29601 [==============================] - 3s 90us/sample - loss: 1.5497 - val_loss: 1.5613

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_only_energy.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-07 01:12:05.081314: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.093393: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.093621: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.097391: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.097577: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.097742: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.150905: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.151107: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.151271: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.151415: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-07 01:12:05.151804: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-07 01:12:05.334307: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.334539: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.334719: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.334934: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.335105: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 01:12:05.335246: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-07 01:12:05.335277: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-07 01:12:05.340143: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-07 01:12:05.361348: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3/bias/Assign' id:595 op device:{requested: '', assigned: ''} def:{{{node dense_3/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_3/bias, dense_3/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-07 01:12:05.505732: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_1/lstm_cell_1/recurrent_kernel/v/Assign' id:824 op device:{requested: '', assigned: ''} def:{{{node lstm_1/lstm_cell_1/recurrent_kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_1/lstm_cell_1/recurrent_kernel/v, lstm_1/lstm_cell_1/recurrent_kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-11-07 01:12:05.648654: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3/BiasAdd' id:600 op device:{requested: '', assigned: ''} def:{{{node dense_3/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3/MatMul, dense_3/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-07 01:12:05.720923: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Test MAE:
# 1.528600867130405
# 1.517328001766143
