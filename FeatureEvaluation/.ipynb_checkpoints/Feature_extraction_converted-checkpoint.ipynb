# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([delta_spe_flux, delta_spe_slope, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
# rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

# for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
model_name = './checkpoints/Feature_extraction.h5'

checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
# pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=0.35, start_epoch=5, end_epoch=50, frequency=1)
model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-06 23:36:59.916166: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:36:59.927619: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:36:59.927839: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:36:59.930781: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:36:59.930974: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:36:59.931140: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:36:59.990536: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:36:59.990738: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:36:59.990903: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:36:59.991043: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-06 23:36:59.991287: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-06 23:37:00.082945: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:37:00.083161: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:37:00.083338: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:37:00.083591: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:37:00.083768: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:37:00.083910: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-06 23:37:00.083942: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-06 23:37:00.086316: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-06 23:37:00.266858: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_1/lstm_cell_1/bias/Assign' id:210 op device:{requested: '', assigned: ''} def:{{{node lstm_1/lstm_cell_1/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_1/lstm_cell_1/bias, lstm_1/lstm_cell_1/bias/Initializer/concat)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-06 23:37:00.291469: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:334 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-06 23:37:00.296491: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:335 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 73)
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 2023-11-06 23:37:02.004863: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_2/bias/v/Assign' id:5792 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_2/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_2/bias/v, training/Adam/dense_2/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-06 23:37:02.388398: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-06 23:37:02.999345: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 2023-11-06 23:37:03.006451: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 29601/29601 [==============================] - ETA: 0s - loss: 3.0607
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-06 23:37:14.816285: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:2127 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 2.05114, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 14s 481us/sample - loss: 3.0607 - val_loss: 2.0511
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.9171
# Epoch 2: val_loss improved from 2.05114 to 1.74694, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 11s 384us/sample - loss: 1.9171 - val_loss: 1.7469
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6723
# Epoch 3: val_loss improved from 1.74694 to 1.59827, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 340us/sample - loss: 1.6723 - val_loss: 1.5983
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5870
# Epoch 4: val_loss improved from 1.59827 to 1.54520, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 337us/sample - loss: 1.5870 - val_loss: 1.5452
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5510
# Epoch 5: val_loss improved from 1.54520 to 1.51453, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 338us/sample - loss: 1.5510 - val_loss: 1.5145
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5306
# Epoch 6: val_loss improved from 1.51453 to 1.50049, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 337us/sample - loss: 1.5306 - val_loss: 1.5005
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5258
# Epoch 7: val_loss improved from 1.50049 to 1.48472, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 335us/sample - loss: 1.5258 - val_loss: 1.4847
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5137
# Epoch 8: val_loss did not improve from 1.48472
# 29601/29601 [==============================] - 11s 355us/sample - loss: 1.5137 - val_loss: 1.4902
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5041
# Epoch 9: val_loss improved from 1.48472 to 1.48319, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 339us/sample - loss: 1.5041 - val_loss: 1.4832
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4948
# Epoch 10: val_loss improved from 1.48319 to 1.46888, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 337us/sample - loss: 1.4948 - val_loss: 1.4689
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4921
# Epoch 11: val_loss improved from 1.46888 to 1.46130, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 348us/sample - loss: 1.4921 - val_loss: 1.4613
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4876
# Epoch 12: val_loss did not improve from 1.46130
# 29601/29601 [==============================] - 10s 347us/sample - loss: 1.4876 - val_loss: 1.4650
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4833
# Epoch 13: val_loss improved from 1.46130 to 1.45458, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 338us/sample - loss: 1.4833 - val_loss: 1.4546
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4766
# Epoch 14: val_loss did not improve from 1.45458
# 29601/29601 [==============================] - 10s 351us/sample - loss: 1.4766 - val_loss: 1.4568
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4743
# Epoch 15: val_loss improved from 1.45458 to 1.44667, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 339us/sample - loss: 1.4743 - val_loss: 1.4467
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4668
# Epoch 16: val_loss improved from 1.44667 to 1.44208, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 343us/sample - loss: 1.4668 - val_loss: 1.4421
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4664
# Epoch 17: val_loss improved from 1.44208 to 1.44171, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 338us/sample - loss: 1.4664 - val_loss: 1.4417
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4585
# Epoch 18: val_loss improved from 1.44171 to 1.43302, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 337us/sample - loss: 1.4585 - val_loss: 1.4330
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4553
# Epoch 19: val_loss improved from 1.43302 to 1.43178, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 337us/sample - loss: 1.4553 - val_loss: 1.4318
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4521
# Epoch 20: val_loss did not improve from 1.43178
# 29601/29601 [==============================] - 10s 335us/sample - loss: 1.4521 - val_loss: 1.4419
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4511
# Epoch 21: val_loss improved from 1.43178 to 1.42093, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 11s 380us/sample - loss: 1.4511 - val_loss: 1.4209
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4440
# Epoch 22: val_loss did not improve from 1.42093
# 29601/29601 [==============================] - 11s 382us/sample - loss: 1.4440 - val_loss: 1.4257
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4431
# Epoch 23: val_loss improved from 1.42093 to 1.41753, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 11s 361us/sample - loss: 1.4431 - val_loss: 1.4175
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4410
# Epoch 24: val_loss improved from 1.41753 to 1.41587, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 346us/sample - loss: 1.4410 - val_loss: 1.4159
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4365
# Epoch 25: val_loss improved from 1.41587 to 1.41429, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 341us/sample - loss: 1.4365 - val_loss: 1.4143
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4392
# Epoch 26: val_loss improved from 1.41429 to 1.41182, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 339us/sample - loss: 1.4392 - val_loss: 1.4118
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4324
# Epoch 27: val_loss improved from 1.41182 to 1.41025, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 338us/sample - loss: 1.4324 - val_loss: 1.4103
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4300
# Epoch 28: val_loss improved from 1.41025 to 1.40911, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 342us/sample - loss: 1.4300 - val_loss: 1.4091
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4239
# Epoch 29: val_loss did not improve from 1.40911
# 29601/29601 [==============================] - 10s 348us/sample - loss: 1.4239 - val_loss: 1.4103
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4264
# Epoch 30: val_loss improved from 1.40911 to 1.40536, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 341us/sample - loss: 1.4264 - val_loss: 1.4054
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4227
# Epoch 31: val_loss did not improve from 1.40536
# 29601/29601 [==============================] - 10s 340us/sample - loss: 1.4227 - val_loss: 1.4131
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4242
# Epoch 32: val_loss improved from 1.40536 to 1.40029, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 343us/sample - loss: 1.4242 - val_loss: 1.4003
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4221
# Epoch 33: val_loss did not improve from 1.40029
# 29601/29601 [==============================] - 10s 341us/sample - loss: 1.4221 - val_loss: 1.4030
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4196
# Epoch 34: val_loss did not improve from 1.40029
# 29601/29601 [==============================] - 10s 342us/sample - loss: 1.4196 - val_loss: 1.4033
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4172
# Epoch 35: val_loss did not improve from 1.40029
# 29601/29601 [==============================] - 10s 339us/sample - loss: 1.4172 - val_loss: 1.4038
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4149
# Epoch 36: val_loss did not improve from 1.40029
# 29601/29601 [==============================] - 10s 339us/sample - loss: 1.4149 - val_loss: 1.4118
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4108
# Epoch 37: val_loss did not improve from 1.40029
# 29601/29601 [==============================] - 10s 336us/sample - loss: 1.4108 - val_loss: 1.4066
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4124
# Epoch 38: val_loss improved from 1.40029 to 1.39695, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 340us/sample - loss: 1.4124 - val_loss: 1.3969
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4078
# Epoch 39: val_loss did not improve from 1.39695
# 29601/29601 [==============================] - 10s 338us/sample - loss: 1.4078 - val_loss: 1.4011
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4077
# Epoch 40: val_loss did not improve from 1.39695
# 29601/29601 [==============================] - 10s 336us/sample - loss: 1.4077 - val_loss: 1.3991
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4063
# Epoch 41: val_loss improved from 1.39695 to 1.39115, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 338us/sample - loss: 1.4063 - val_loss: 1.3911
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4067
# Epoch 42: val_loss did not improve from 1.39115
# 29601/29601 [==============================] - 11s 361us/sample - loss: 1.4067 - val_loss: 1.3955
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4051
# Epoch 43: val_loss did not improve from 1.39115
# 29601/29601 [==============================] - 11s 382us/sample - loss: 1.4051 - val_loss: 1.4007
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4043
# Epoch 44: val_loss did not improve from 1.39115
# 29601/29601 [==============================] - 11s 380us/sample - loss: 1.4043 - val_loss: 1.4005
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4028
# Epoch 45: val_loss improved from 1.39115 to 1.38792, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 11s 384us/sample - loss: 1.4028 - val_loss: 1.3879
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3970
# Epoch 46: val_loss did not improve from 1.38792
# 29601/29601 [==============================] - 11s 386us/sample - loss: 1.3970 - val_loss: 1.3981
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3965
# Epoch 47: val_loss improved from 1.38792 to 1.38609, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 11s 371us/sample - loss: 1.3965 - val_loss: 1.3861
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3985
# Epoch 48: val_loss did not improve from 1.38609
# 29601/29601 [==============================] - 10s 338us/sample - loss: 1.3985 - val_loss: 1.3876
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3956
# Epoch 49: val_loss did not improve from 1.38609
# 29601/29601 [==============================] - 10s 336us/sample - loss: 1.3956 - val_loss: 1.3902
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3941
# Epoch 50: val_loss improved from 1.38609 to 1.38595, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 339us/sample - loss: 1.3941 - val_loss: 1.3859
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3915
# Epoch 51: val_loss did not improve from 1.38595
# 29601/29601 [==============================] - 11s 362us/sample - loss: 1.3915 - val_loss: 1.3933
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3907
# Epoch 52: val_loss improved from 1.38595 to 1.38424, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 11s 378us/sample - loss: 1.3907 - val_loss: 1.3842
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3909
# Epoch 53: val_loss did not improve from 1.38424
# 29601/29601 [==============================] - 10s 335us/sample - loss: 1.3909 - val_loss: 1.3882
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3917
# Epoch 54: val_loss did not improve from 1.38424
# 29601/29601 [==============================] - 10s 336us/sample - loss: 1.3917 - val_loss: 1.3858
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3917
# Epoch 55: val_loss did not improve from 1.38424
# 29601/29601 [==============================] - 11s 364us/sample - loss: 1.3917 - val_loss: 1.3962
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3902
# Epoch 56: val_loss did not improve from 1.38424
# 29601/29601 [==============================] - 11s 366us/sample - loss: 1.3902 - val_loss: 1.3889
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3893
# Epoch 57: val_loss did not improve from 1.38424
# 29601/29601 [==============================] - 10s 348us/sample - loss: 1.3893 - val_loss: 1.3966
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3876
# Epoch 58: val_loss did not improve from 1.38424
# 29601/29601 [==============================] - 11s 361us/sample - loss: 1.3876 - val_loss: 1.3857
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3865
# Epoch 59: val_loss improved from 1.38424 to 1.38373, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 336us/sample - loss: 1.3865 - val_loss: 1.3837
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3856
# Epoch 60: val_loss did not improve from 1.38373
# 29601/29601 [==============================] - 10s 335us/sample - loss: 1.3856 - val_loss: 1.3907
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3849
# Epoch 61: val_loss did not improve from 1.38373
# 29601/29601 [==============================] - 10s 334us/sample - loss: 1.3849 - val_loss: 1.3872
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3853
# Epoch 62: val_loss improved from 1.38373 to 1.38217, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 11s 360us/sample - loss: 1.3853 - val_loss: 1.3822
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3830
# Epoch 63: val_loss did not improve from 1.38217
# 29601/29601 [==============================] - 11s 383us/sample - loss: 1.3830 - val_loss: 1.3835
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3803
# Epoch 64: val_loss improved from 1.38217 to 1.38085, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 11s 366us/sample - loss: 1.3803 - val_loss: 1.3809
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3787
# Epoch 65: val_loss did not improve from 1.38085
# 29601/29601 [==============================] - 10s 345us/sample - loss: 1.3787 - val_loss: 1.3909
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3776
# Epoch 66: val_loss did not improve from 1.38085
# 29601/29601 [==============================] - 10s 332us/sample - loss: 1.3776 - val_loss: 1.3810
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3777
# Epoch 67: val_loss did not improve from 1.38085
# 29601/29601 [==============================] - 10s 335us/sample - loss: 1.3777 - val_loss: 1.3848
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3757
# Epoch 68: val_loss did not improve from 1.38085
# 29601/29601 [==============================] - 10s 346us/sample - loss: 1.3757 - val_loss: 1.3811
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3783
# Epoch 69: val_loss did not improve from 1.38085
# 29601/29601 [==============================] - 11s 382us/sample - loss: 1.3783 - val_loss: 1.3987
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3787
# Epoch 70: val_loss improved from 1.38085 to 1.37821, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 11s 381us/sample - loss: 1.3787 - val_loss: 1.3782
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3743
# Epoch 71: val_loss did not improve from 1.37821
# 29601/29601 [==============================] - 11s 380us/sample - loss: 1.3743 - val_loss: 1.3789
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3723
# Epoch 72: val_loss did not improve from 1.37821
# 29601/29601 [==============================] - 11s 380us/sample - loss: 1.3723 - val_loss: 1.3844
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3728
# Epoch 73: val_loss did not improve from 1.37821
# 29601/29601 [==============================] - 11s 381us/sample - loss: 1.3728 - val_loss: 1.3869
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3722
# Epoch 74: val_loss did not improve from 1.37821
# 29601/29601 [==============================] - 11s 384us/sample - loss: 1.3722 - val_loss: 1.3858
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3727
# Epoch 75: val_loss did not improve from 1.37821
# 29601/29601 [==============================] - 11s 355us/sample - loss: 1.3727 - val_loss: 1.3817
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3704
# Epoch 76: val_loss did not improve from 1.37821
# 29601/29601 [==============================] - 11s 361us/sample - loss: 1.3704 - val_loss: 1.3839
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3676
# Epoch 77: val_loss did not improve from 1.37821
# 29601/29601 [==============================] - 11s 382us/sample - loss: 1.3676 - val_loss: 1.3821
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3720
# Epoch 78: val_loss improved from 1.37821 to 1.37794, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 11s 365us/sample - loss: 1.3720 - val_loss: 1.3779
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3710
# Epoch 79: val_loss did not improve from 1.37794
# 29601/29601 [==============================] - 11s 379us/sample - loss: 1.3710 - val_loss: 1.3809
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3671
# Epoch 80: val_loss did not improve from 1.37794
# 29601/29601 [==============================] - 11s 380us/sample - loss: 1.3671 - val_loss: 1.3785
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3639
# Epoch 81: val_loss did not improve from 1.37794
# 29601/29601 [==============================] - 11s 360us/sample - loss: 1.3639 - val_loss: 1.3824
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3676
# Epoch 82: val_loss did not improve from 1.37794
# 29601/29601 [==============================] - 10s 347us/sample - loss: 1.3676 - val_loss: 1.3806
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3675
# Epoch 83: val_loss improved from 1.37794 to 1.37696, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 348us/sample - loss: 1.3675 - val_loss: 1.3770
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3648
# Epoch 84: val_loss did not improve from 1.37696
# 29601/29601 [==============================] - 11s 384us/sample - loss: 1.3648 - val_loss: 1.3802
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3654
# Epoch 85: val_loss did not improve from 1.37696
# 29601/29601 [==============================] - 11s 366us/sample - loss: 1.3654 - val_loss: 1.3814
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3627
# Epoch 86: val_loss did not improve from 1.37696
# 29601/29601 [==============================] - 11s 355us/sample - loss: 1.3627 - val_loss: 1.3857
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3624
# Epoch 87: val_loss improved from 1.37696 to 1.37331, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 341us/sample - loss: 1.3624 - val_loss: 1.3733
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3612
# Epoch 88: val_loss did not improve from 1.37331
# 29601/29601 [==============================] - 11s 357us/sample - loss: 1.3612 - val_loss: 1.3779
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3598
# Epoch 89: val_loss did not improve from 1.37331
# 29601/29601 [==============================] - 11s 382us/sample - loss: 1.3598 - val_loss: 1.3788
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3632
# Epoch 90: val_loss did not improve from 1.37331
# 29601/29601 [==============================] - 11s 386us/sample - loss: 1.3632 - val_loss: 1.3744
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3605
# Epoch 91: val_loss improved from 1.37331 to 1.36926, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 11s 365us/sample - loss: 1.3605 - val_loss: 1.3693
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3595
# Epoch 92: val_loss did not improve from 1.36926
# 29601/29601 [==============================] - 11s 382us/sample - loss: 1.3595 - val_loss: 1.3707
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3650
# Epoch 93: val_loss did not improve from 1.36926
# 29601/29601 [==============================] - 11s 380us/sample - loss: 1.3650 - val_loss: 1.3807
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3613
# Epoch 94: val_loss did not improve from 1.36926
# 29601/29601 [==============================] - 11s 381us/sample - loss: 1.3613 - val_loss: 1.3768
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3618
# Epoch 95: val_loss did not improve from 1.36926
# 29601/29601 [==============================] - 10s 341us/sample - loss: 1.3618 - val_loss: 1.3759
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3608
# Epoch 96: val_loss did not improve from 1.36926
# 29601/29601 [==============================] - 10s 335us/sample - loss: 1.3608 - val_loss: 1.3845
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3629
# Epoch 97: val_loss improved from 1.36926 to 1.36893, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 337us/sample - loss: 1.3629 - val_loss: 1.3689
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3581
# Epoch 98: val_loss improved from 1.36893 to 1.36700, saving model to ./checkpoints/Feature_extraction.h5
# 29601/29601 [==============================] - 10s 339us/sample - loss: 1.3581 - val_loss: 1.3670
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3569
# Epoch 99: val_loss did not improve from 1.36700
# 29601/29601 [==============================] - 11s 378us/sample - loss: 1.3569 - val_loss: 1.3746
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3557
# Epoch 100: val_loss did not improve from 1.36700
# 29601/29601 [==============================] - 11s 374us/sample - loss: 1.3557 - val_loss: 1.3694
