# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-08 01:16:29.115288: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Feature_extraction_remove_gaitpara_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-08 01:17:05.211732: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:05.226917: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:05.227214: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:05.234678: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:05.234960: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:05.235190: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:05.350308: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:05.350548: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:05.350753: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:05.350914: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-08 01:17:05.351919: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-08 01:17:06.806853: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:06.807605: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:06.808074: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:06.808368: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:06.808622: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-08 01:17:06.808812: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-08 01:17:06.808879: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-08 01:17:06.848937: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-08 01:17:07.187410: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_20/lstm_cell_20/kernel/Assign' id:3316 op device:{requested: '', assigned: ''} def:{{{node lstm_20/lstm_cell_20/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_20/lstm_cell_20/kernel, lstm_20/lstm_cell_20/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-08 01:17:07.425036: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:3634 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-08 01:17:07.494224: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:3635 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 81)
# Train on 29601 samples, validate on 3694 samples
# 2023-11-08 01:17:14.658337: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_4/lstm_cell_4/bias/v/Assign' id:17107 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_4/lstm_cell_4/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_4/lstm_cell_4/bias/v, training/Adam/lstm_4/lstm_cell_4/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-11-08 01:17:21.459747: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-08 01:17:25.646260: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-08 01:17:25.761310: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 29601/29601 [==============================] - ETA: 0s - loss: 3.4634
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-08 01:17:56.208402: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:6477 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 1.96734, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 44s 1ms/sample - loss: 3.4634 - val_loss: 1.9673
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.9139
# Epoch 2: val_loss improved from 1.96734 to 1.66386, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.9139 - val_loss: 1.6639
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6425
# Epoch 3: val_loss improved from 1.66386 to 1.56812, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.6425 - val_loss: 1.5681
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5649
# Epoch 4: val_loss improved from 1.56812 to 1.53811, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 29s 995us/sample - loss: 1.5649 - val_loss: 1.5381
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5414
# Epoch 5: val_loss improved from 1.53811 to 1.51846, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 29s 990us/sample - loss: 1.5414 - val_loss: 1.5185
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5259
# Epoch 6: val_loss improved from 1.51846 to 1.51124, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 29s 984us/sample - loss: 1.5259 - val_loss: 1.5112
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5181
# Epoch 7: val_loss improved from 1.51124 to 1.49833, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.5181 - val_loss: 1.4983
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5081
# Epoch 8: val_loss improved from 1.49833 to 1.49506, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.5081 - val_loss: 1.4951
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5024
# Epoch 9: val_loss improved from 1.49506 to 1.48841, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 29s 995us/sample - loss: 1.5024 - val_loss: 1.4884
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4973
# Epoch 10: val_loss improved from 1.48841 to 1.48139, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4973 - val_loss: 1.4814
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4965
# Epoch 11: val_loss improved from 1.48139 to 1.47577, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4965 - val_loss: 1.4758
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4921
# Epoch 12: val_loss improved from 1.47577 to 1.47537, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4921 - val_loss: 1.4754
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4873
# Epoch 13: val_loss improved from 1.47537 to 1.46999, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4873 - val_loss: 1.4700
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4814
# Epoch 14: val_loss improved from 1.46999 to 1.46462, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4814 - val_loss: 1.4646
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4788
# Epoch 15: val_loss improved from 1.46462 to 1.46376, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 29s 982us/sample - loss: 1.4788 - val_loss: 1.4638
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4753
# Epoch 16: val_loss did not improve from 1.46376
# 29601/29601 [==============================] - 29s 979us/sample - loss: 1.4753 - val_loss: 1.4660
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4714
# Epoch 17: val_loss improved from 1.46376 to 1.45780, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4714 - val_loss: 1.4578
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4702
# Epoch 18: val_loss improved from 1.45780 to 1.45624, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 29s 989us/sample - loss: 1.4702 - val_loss: 1.4562
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4689
# Epoch 19: val_loss improved from 1.45624 to 1.45287, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 29s 986us/sample - loss: 1.4689 - val_loss: 1.4529
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4660
# Epoch 20: val_loss improved from 1.45287 to 1.45017, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 32s 1ms/sample - loss: 1.4660 - val_loss: 1.4502
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4649
# Epoch 21: val_loss did not improve from 1.45017
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4649 - val_loss: 1.4505
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4630
# Epoch 22: val_loss improved from 1.45017 to 1.44904, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 32s 1ms/sample - loss: 1.4630 - val_loss: 1.4490
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4637
# Epoch 23: val_loss improved from 1.44904 to 1.44522, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4637 - val_loss: 1.4452
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4567
# Epoch 24: val_loss improved from 1.44522 to 1.44035, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4567 - val_loss: 1.4404
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4553
# Epoch 25: val_loss did not improve from 1.44035
# 29601/29601 [==============================] - 28s 944us/sample - loss: 1.4553 - val_loss: 1.4420
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4520
# Epoch 26: val_loss did not improve from 1.44035
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4520 - val_loss: 1.4419
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4531
# Epoch 27: val_loss improved from 1.44035 to 1.43716, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4531 - val_loss: 1.4372
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4504
# Epoch 28: val_loss did not improve from 1.43716
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4504 - val_loss: 1.4431
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4457
# Epoch 29: val_loss did not improve from 1.43716
# 29601/29601 [==============================] - 29s 995us/sample - loss: 1.4457 - val_loss: 1.4381
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4440
# Epoch 30: val_loss improved from 1.43716 to 1.43230, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 33s 1ms/sample - loss: 1.4440 - val_loss: 1.4323
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4414
# Epoch 31: val_loss improved from 1.43230 to 1.43122, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4414 - val_loss: 1.4312
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4439
# Epoch 32: val_loss improved from 1.43122 to 1.43011, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 32s 1ms/sample - loss: 1.4439 - val_loss: 1.4301
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4400
# Epoch 33: val_loss did not improve from 1.43011
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4400 - val_loss: 1.4302
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4368
# Epoch 34: val_loss improved from 1.43011 to 1.42565, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4368 - val_loss: 1.4256
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4357
# Epoch 35: val_loss improved from 1.42565 to 1.42446, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4357 - val_loss: 1.4245
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4321
# Epoch 36: val_loss improved from 1.42446 to 1.42123, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 29s 994us/sample - loss: 1.4321 - val_loss: 1.4212
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4295
# Epoch 37: val_loss did not improve from 1.42123
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4295 - val_loss: 1.4267
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4290
# Epoch 38: val_loss improved from 1.42123 to 1.41673, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4290 - val_loss: 1.4167
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4289
# Epoch 39: val_loss did not improve from 1.41673
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4289 - val_loss: 1.4170
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4270
# Epoch 40: val_loss did not improve from 1.41673
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4270 - val_loss: 1.4224
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4262
# Epoch 41: val_loss improved from 1.41673 to 1.41638, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 29s 989us/sample - loss: 1.4262 - val_loss: 1.4164
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4228
# Epoch 42: val_loss improved from 1.41638 to 1.41466, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4228 - val_loss: 1.4147
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4227
# Epoch 43: val_loss did not improve from 1.41466
# 29601/29601 [==============================] - 27s 924us/sample - loss: 1.4227 - val_loss: 1.4149
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4187
# Epoch 44: val_loss did not improve from 1.41466
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4187 - val_loss: 1.4155
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4209
# Epoch 45: val_loss improved from 1.41466 to 1.41321, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4209 - val_loss: 1.4132
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4142
# Epoch 46: val_loss improved from 1.41321 to 1.41272, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4142 - val_loss: 1.4127
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4136
# Epoch 47: val_loss improved from 1.41272 to 1.40791, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 29s 978us/sample - loss: 1.4136 - val_loss: 1.4079
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4156
# Epoch 48: val_loss did not improve from 1.40791
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4156 - val_loss: 1.4088
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4167
# Epoch 49: val_loss did not improve from 1.40791
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4167 - val_loss: 1.4125
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4142
# Epoch 50: val_loss improved from 1.40791 to 1.40635, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4142 - val_loss: 1.4063
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4166
# Epoch 51: val_loss did not improve from 1.40635
# 29601/29601 [==============================] - 29s 974us/sample - loss: 1.4166 - val_loss: 1.4096
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4095
# Epoch 52: val_loss improved from 1.40635 to 1.40357, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4095 - val_loss: 1.4036
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4100
# Epoch 53: val_loss did not improve from 1.40357
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4100 - val_loss: 1.4058
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4114
# Epoch 54: val_loss did not improve from 1.40357
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4114 - val_loss: 1.4054
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4103
# Epoch 55: val_loss did not improve from 1.40357
# 29601/29601 [==============================] - 29s 983us/sample - loss: 1.4103 - val_loss: 1.4074
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4101
# Epoch 56: val_loss improved from 1.40357 to 1.40134, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4101 - val_loss: 1.4013
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4042
# Epoch 57: val_loss did not improve from 1.40134
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4042 - val_loss: 1.4092
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4031
# Epoch 58: val_loss did not improve from 1.40134
# 29601/29601 [==============================] - 28s 959us/sample - loss: 1.4031 - val_loss: 1.4067
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4018
# Epoch 59: val_loss did not improve from 1.40134
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4018 - val_loss: 1.4017
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4030
# Epoch 60: val_loss did not improve from 1.40134
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4030 - val_loss: 1.4021
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4030
# Epoch 61: val_loss did not improve from 1.40134
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4030 - val_loss: 1.4074
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4003
# Epoch 62: val_loss improved from 1.40134 to 1.40124, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4003 - val_loss: 1.4012
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3988
# Epoch 63: val_loss did not improve from 1.40124
# 29601/29601 [==============================] - 27s 926us/sample - loss: 1.3988 - val_loss: 1.4019
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3984
# Epoch 64: val_loss improved from 1.40124 to 1.39997, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 999us/sample - loss: 1.3984 - val_loss: 1.4000
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3962
# Epoch 65: val_loss did not improve from 1.39997
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3962 - val_loss: 1.4027
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3949
# Epoch 66: val_loss improved from 1.39997 to 1.39743, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 32s 1ms/sample - loss: 1.3949 - val_loss: 1.3974
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3942
# Epoch 67: val_loss improved from 1.39743 to 1.39578, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3942 - val_loss: 1.3958
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3926
# Epoch 68: val_loss did not improve from 1.39578
# 29601/29601 [==============================] - 28s 943us/sample - loss: 1.3926 - val_loss: 1.4000
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3936
# Epoch 69: val_loss improved from 1.39578 to 1.39416, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3936 - val_loss: 1.3942
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3907
# Epoch 70: val_loss improved from 1.39416 to 1.39388, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 27s 920us/sample - loss: 1.3907 - val_loss: 1.3939
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3924
# Epoch 71: val_loss did not improve from 1.39388
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3924 - val_loss: 1.3948
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3902
# Epoch 72: val_loss did not improve from 1.39388
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.3902 - val_loss: 1.3941
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3886
# Epoch 73: val_loss improved from 1.39388 to 1.39311, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3886 - val_loss: 1.3931
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3874
# Epoch 74: val_loss did not improve from 1.39311
# 29601/29601 [==============================] - 29s 967us/sample - loss: 1.3874 - val_loss: 1.3947
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3878
# Epoch 75: val_loss did not improve from 1.39311
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.3878 - val_loss: 1.3955
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3888
# Epoch 76: val_loss did not improve from 1.39311
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3888 - val_loss: 1.3952
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3834
# Epoch 77: val_loss improved from 1.39311 to 1.39202, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.3834 - val_loss: 1.3920
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3843
# Epoch 78: val_loss improved from 1.39202 to 1.38905, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 29s 984us/sample - loss: 1.3843 - val_loss: 1.3890
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3830
# Epoch 79: val_loss did not improve from 1.38905
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.3830 - val_loss: 1.3921
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3834
# Epoch 80: val_loss did not improve from 1.38905
# 29601/29601 [==============================] - 29s 992us/sample - loss: 1.3834 - val_loss: 1.3955
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3798
# Epoch 81: val_loss did not improve from 1.38905
# 29601/29601 [==============================] - 33s 1ms/sample - loss: 1.3798 - val_loss: 1.3913
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3770
# Epoch 82: val_loss did not improve from 1.38905
# 29601/29601 [==============================] - 30s 999us/sample - loss: 1.3770 - val_loss: 1.3947
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3837
# Epoch 83: val_loss improved from 1.38905 to 1.38541, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3837 - val_loss: 1.3854
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3782
# Epoch 84: val_loss did not improve from 1.38541
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3782 - val_loss: 1.3932
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3796
# Epoch 85: val_loss did not improve from 1.38541
# 29601/29601 [==============================] - 29s 986us/sample - loss: 1.3796 - val_loss: 1.3886
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3753
# Epoch 86: val_loss did not improve from 1.38541
# 29601/29601 [==============================] - 29s 977us/sample - loss: 1.3753 - val_loss: 1.3935
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3748
# Epoch 87: val_loss did not improve from 1.38541
# 29601/29601 [==============================] - 28s 948us/sample - loss: 1.3748 - val_loss: 1.3884
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3763
# Epoch 88: val_loss did not improve from 1.38541
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3763 - val_loss: 1.3874
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3758
# Epoch 89: val_loss did not improve from 1.38541
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.3758 - val_loss: 1.3918
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3739
# Epoch 90: val_loss did not improve from 1.38541
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.3739 - val_loss: 1.3906
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3733
# Epoch 91: val_loss improved from 1.38541 to 1.38470, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 29s 988us/sample - loss: 1.3733 - val_loss: 1.3847
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3734
# Epoch 92: val_loss did not improve from 1.38470
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3734 - val_loss: 1.3861
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3725
# Epoch 93: val_loss did not improve from 1.38470
# 29601/29601 [==============================] - 29s 976us/sample - loss: 1.3725 - val_loss: 1.3891
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3710
# Epoch 94: val_loss did not improve from 1.38470
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3710 - val_loss: 1.3892
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3720
# Epoch 95: val_loss did not improve from 1.38470
# 29601/29601 [==============================] - 29s 979us/sample - loss: 1.3720 - val_loss: 1.3873
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3686
# Epoch 96: val_loss did not improve from 1.38470
# 29601/29601 [==============================] - 32s 1ms/sample - loss: 1.3686 - val_loss: 1.3867
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3705
# Epoch 97: val_loss improved from 1.38470 to 1.38332, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 29s 976us/sample - loss: 1.3705 - val_loss: 1.3833
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3650
# Epoch 98: val_loss did not improve from 1.38332
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.3650 - val_loss: 1.3839
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3673
# Epoch 99: val_loss did not improve from 1.38332
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.3673 - val_loss: 1.3868
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3647
# Epoch 100: val_loss did not improve from 1.38332
# 29601/29601 [==============================] - 28s 956us/sample - loss: 1.3647 - val_loss: 1.3874
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3620
# Epoch 1: val_loss improved from inf to 1.39485, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_1.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3620 - val_loss: 1.3949
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3674
# Epoch 2: val_loss improved from 1.39485 to 1.38191, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_1.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3674 - val_loss: 1.3819
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3669
# Epoch 3: val_loss did not improve from 1.38191
# 29601/29601 [==============================] - 29s 987us/sample - loss: 1.3669 - val_loss: 1.3886
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3632
# Epoch 4: val_loss did not improve from 1.38191
# 29601/29601 [==============================] - 29s 986us/sample - loss: 1.3632 - val_loss: 1.3842
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3609
# Epoch 5: val_loss improved from 1.38191 to 1.38100, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_1.h5
# 29601/29601 [==============================] - 30s 997us/sample - loss: 1.3609 - val_loss: 1.3810
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3602
# Epoch 6: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3602 - val_loss: 1.3851
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3591
# Epoch 7: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 30s 997us/sample - loss: 1.3591 - val_loss: 1.3810
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3604
# Epoch 8: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3604 - val_loss: 1.3866
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3581
# Epoch 9: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 29s 983us/sample - loss: 1.3581 - val_loss: 1.3835
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3606
# Epoch 10: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 29s 986us/sample - loss: 1.3606 - val_loss: 1.3824
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3598
# Epoch 11: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.3598 - val_loss: 1.3906
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3585
# Epoch 12: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 28s 959us/sample - loss: 1.3585 - val_loss: 1.3900
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3587
# Epoch 13: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 29s 979us/sample - loss: 1.3587 - val_loss: 1.3895
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3597
# Epoch 14: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 29s 976us/sample - loss: 1.3597 - val_loss: 1.3841
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3565
# Epoch 15: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 29s 977us/sample - loss: 1.3565 - val_loss: 1.3840
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3536
# Epoch 16: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 29s 994us/sample - loss: 1.3536 - val_loss: 1.3896
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3572
# Epoch 17: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 29s 992us/sample - loss: 1.3572 - val_loss: 1.3824
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3563
# Epoch 18: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3563 - val_loss: 1.3850
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3530
# Epoch 19: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3530 - val_loss: 1.3867
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3544
# Epoch 20: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3544 - val_loss: 1.3893
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3556
# Epoch 21: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.3556 - val_loss: 1.3833
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3524
# Epoch 22: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3524 - val_loss: 1.3862
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3519
# Epoch 23: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 32s 1ms/sample - loss: 1.3519 - val_loss: 1.3843
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3502
# Epoch 24: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.3502 - val_loss: 1.3840
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3523
# Epoch 25: val_loss did not improve from 1.38100
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.3523 - val_loss: 1.3840
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3499
# ...
# Epoch 32: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 20s 675us/sample - loss: 1.2943 - val_loss: 1.3997
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2977
# Epoch 33: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 20s 691us/sample - loss: 1.2977 - val_loss: 1.4000
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2989
# Epoch 34: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 21s 695us/sample - loss: 1.2989 - val_loss: 1.4012
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2996
# Epoch 35: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 19s 650us/sample - loss: 1.2996 - val_loss: 1.4034
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3058
# Epoch 36: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 20s 688us/sample - loss: 1.3058 - val_loss: 1.4008
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3031
# Epoch 37: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.3031 - val_loss: 1.4077
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3054
# Epoch 38: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 20s 676us/sample - loss: 1.3054 - val_loss: 1.4051
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3070
# Epoch 39: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 20s 677us/sample - loss: 1.3070 - val_loss: 1.4050
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3081
# Epoch 40: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 20s 673us/sample - loss: 1.3081 - val_loss: 1.4038
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3129
# Epoch 41: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3129 - val_loss: 1.4024
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3106
# Epoch 42: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.3106 - val_loss: 1.4048
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3117
# Epoch 43: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.3117 - val_loss: 1.4069
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3171
# Epoch 44: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 20s 675us/sample - loss: 1.3171 - val_loss: 1.4071
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3185
# Epoch 45: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.3185 - val_loss: 1.4030
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3183
# Epoch 46: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 621us/sample - loss: 1.3183 - val_loss: 1.3991
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3258
# Epoch 47: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 608us/sample - loss: 1.3258 - val_loss: 1.4113
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3252
# Epoch 48: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 608us/sample - loss: 1.3252 - val_loss: 1.4042
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3298
# Epoch 49: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3298 - val_loss: 1.4086
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3250
# Epoch 50: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 604us/sample - loss: 1.3250 - val_loss: 1.4081
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3361
# Epoch 51: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.3361 - val_loss: 1.4031
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3363
# Epoch 52: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 604us/sample - loss: 1.3363 - val_loss: 1.4022
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3366
# Epoch 53: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.3366 - val_loss: 1.4100
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3305
# Epoch 54: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.3305 - val_loss: 1.4031
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3364
# Epoch 55: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.3364 - val_loss: 1.4036
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3312
# Epoch 56: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 17s 591us/sample - loss: 1.3312 - val_loss: 1.4062
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3319
# Epoch 57: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.3319 - val_loss: 1.4066
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3350
# Epoch 58: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.3350 - val_loss: 1.4101
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3293
# Epoch 59: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.3293 - val_loss: 1.4084
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3316
# Epoch 60: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 597us/sample - loss: 1.3316 - val_loss: 1.4080
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3295
# Epoch 61: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3295 - val_loss: 1.4069
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3285
# Epoch 62: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 19s 629us/sample - loss: 1.3285 - val_loss: 1.4013
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3282
# Epoch 63: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 20s 692us/sample - loss: 1.3282 - val_loss: 1.4044
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3265
# Epoch 64: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 20s 688us/sample - loss: 1.3265 - val_loss: 1.4067
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3228
# Epoch 65: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 20s 688us/sample - loss: 1.3228 - val_loss: 1.4046
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3225
# Epoch 66: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3225 - val_loss: 1.4071
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3250
# Epoch 67: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 608us/sample - loss: 1.3250 - val_loss: 1.4008
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3205
# Epoch 68: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 623us/sample - loss: 1.3205 - val_loss: 1.4048
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3215
# Epoch 69: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 593us/sample - loss: 1.3215 - val_loss: 1.4045
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3220
# Epoch 70: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.3220 - val_loss: 1.4157
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3196
# Epoch 71: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 604us/sample - loss: 1.3196 - val_loss: 1.3997
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3215
# Epoch 72: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.3215 - val_loss: 1.3996
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3207
# Epoch 73: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.3207 - val_loss: 1.3972
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3168
# Epoch 74: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 624us/sample - loss: 1.3168 - val_loss: 1.4041
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3207
# Epoch 75: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 617us/sample - loss: 1.3207 - val_loss: 1.4095
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3172
# Epoch 76: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 615us/sample - loss: 1.3172 - val_loss: 1.4073
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3162
# Epoch 77: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 20s 687us/sample - loss: 1.3162 - val_loss: 1.4071
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3147
# Epoch 78: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 21s 694us/sample - loss: 1.3147 - val_loss: 1.4022
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3160
# Epoch 79: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 20s 689us/sample - loss: 1.3160 - val_loss: 1.4019
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3126
# Epoch 80: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 606us/sample - loss: 1.3126 - val_loss: 1.4009
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3132
# Epoch 81: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3132 - val_loss: 1.4039
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3138
# Epoch 82: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 18s 597us/sample - loss: 1.3138 - val_loss: 1.4011
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3128
# Epoch 83: val_loss did not improve from 1.39488
# 29601/29601 [==============================] - 17s 587us/sample - loss: 1.3128 - val_loss: 1.3981
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3123
# Epoch 84: val_loss improved from 1.39488 to 1.39321, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_9.h5
# 29601/29601 [==============================] - 20s 661us/sample - loss: 1.3123 - val_loss: 1.3932
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3118
# Epoch 85: val_loss did not improve from 1.39321
# 29601/29601 [==============================] - 17s 587us/sample - loss: 1.3118 - val_loss: 1.4033
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3129
# Epoch 86: val_loss did not improve from 1.39321
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.3129 - val_loss: 1.4018
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3135
# Epoch 87: val_loss did not improve from 1.39321
# 29601/29601 [==============================] - 20s 673us/sample - loss: 1.3135 - val_loss: 1.3999
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3118
# Epoch 88: val_loss did not improve from 1.39321
# 29601/29601 [==============================] - 20s 691us/sample - loss: 1.3118 - val_loss: 1.4064
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3118
# Epoch 89: val_loss did not improve from 1.39321
# 29601/29601 [==============================] - 20s 689us/sample - loss: 1.3118 - val_loss: 1.3999
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3120
# Epoch 90: val_loss did not improve from 1.39321
# 29601/29601 [==============================] - 17s 590us/sample - loss: 1.3120 - val_loss: 1.4023
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3116
# Epoch 91: val_loss did not improve from 1.39321
# 29601/29601 [==============================] - 19s 626us/sample - loss: 1.3116 - val_loss: 1.3949
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3091
# Epoch 92: val_loss did not improve from 1.39321
# 29601/29601 [==============================] - 19s 648us/sample - loss: 1.3091 - val_loss: 1.3961
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3069
# Epoch 93: val_loss did not improve from 1.39321
# 29601/29601 [==============================] - 20s 686us/sample - loss: 1.3069 - val_loss: 1.3945
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3075
# Epoch 94: val_loss did not improve from 1.39321
# 29601/29601 [==============================] - 19s 630us/sample - loss: 1.3075 - val_loss: 1.4025
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3048
# Epoch 95: val_loss did not improve from 1.39321
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.3048 - val_loss: 1.3978
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3073
# Epoch 96: val_loss improved from 1.39321 to 1.39107, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_9.h5
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.3073 - val_loss: 1.3911
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3071
# Epoch 97: val_loss did not improve from 1.39107
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.3071 - val_loss: 1.3972
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3059
# Epoch 98: val_loss improved from 1.39107 to 1.39076, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_9.h5
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3059 - val_loss: 1.3908
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3093
# Epoch 99: val_loss did not improve from 1.39076
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.3093 - val_loss: 1.3990
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3076
# Epoch 100: val_loss did not improve from 1.39076
# 29601/29601 [==============================] - 19s 629us/sample - loss: 1.3076 - val_loss: 1.3947
