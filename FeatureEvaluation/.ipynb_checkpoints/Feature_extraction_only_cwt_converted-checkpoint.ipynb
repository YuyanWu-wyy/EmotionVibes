# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
# rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

# for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
model_name = './checkpoints/Feature_extraction_only_cwt.h5'

checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
# pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=0.35, start_epoch=5, end_epoch=50, frequency=1)
model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[checkpoint])
# Out:
# 2023-11-07 00:01:25.752194: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:01:25.763587: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:01:25.763825: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:01:25.767509: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:01:25.767698: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:01:25.767860: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:01:25.837555: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:01:25.837764: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:01:25.837937: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:01:25.838083: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-07 00:01:25.838341: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-07 00:01:25.838872: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-07 00:01:26.027091: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:4 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-07 00:01:26.029378: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:5 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# (29601, 72)
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 2023-11-07 00:01:26.318101: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_2/bias/m/Assign' id:703 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_2/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_2/bias/m, training/Adam/dense_2/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-07 00:01:26.389021: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-07 00:01:26.475830: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-07 00:01:26.484870: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 29601/29601 [==============================] - ETA: 0s - loss: 4.0933
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-07 00:01:29.646006: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:305 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 2.26014, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 4s 124us/sample - loss: 4.0933 - val_loss: 2.2601
# Epoch 2/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 2.1456
# Epoch 2: val_loss improved from 2.26014 to 1.89653, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 54us/sample - loss: 2.1403 - val_loss: 1.8965
# Epoch 3/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.8517
# Epoch 3: val_loss improved from 1.89653 to 1.73132, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.8488 - val_loss: 1.7313
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.7301
# Epoch 4: val_loss improved from 1.73132 to 1.66441, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.7301 - val_loss: 1.6644
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6790
# Epoch 5: val_loss improved from 1.66441 to 1.63344, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.6790 - val_loss: 1.6334
# Epoch 6/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.6472
# Epoch 6: val_loss improved from 1.63344 to 1.58827, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.6472 - val_loss: 1.5883
# Epoch 7/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.6275
# Epoch 7: val_loss improved from 1.58827 to 1.56921, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.6282 - val_loss: 1.5692
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6127
# Epoch 8: val_loss did not improve from 1.56921
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.6127 - val_loss: 1.5862
# Epoch 9/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.6033
# Epoch 9: val_loss did not improve from 1.56921
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.6026 - val_loss: 1.5857
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5903
# Epoch 10: val_loss did not improve from 1.56921
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.5903 - val_loss: 1.5732
# Epoch 11/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5828
# Epoch 11: val_loss did not improve from 1.56921
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.5812 - val_loss: 1.5768
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5741
# Epoch 12: val_loss did not improve from 1.56921
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.5741 - val_loss: 1.5974
# Epoch 13/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5657
# Epoch 13: val_loss did not improve from 1.56921
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.5654 - val_loss: 1.5717
# Epoch 14/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5545
# Epoch 14: val_loss did not improve from 1.56921
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.5551 - val_loss: 1.5854
# Epoch 15/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5476
# Epoch 15: val_loss improved from 1.56921 to 1.54846, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.5480 - val_loss: 1.5485
# Epoch 16/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5452
# Epoch 16: val_loss did not improve from 1.54846
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.5446 - val_loss: 1.5534
# Epoch 17/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5409
# Epoch 17: val_loss did not improve from 1.54846
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.5396 - val_loss: 1.5695
# Epoch 18/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5323
# Epoch 18: val_loss improved from 1.54846 to 1.53198, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.5322 - val_loss: 1.5320
# Epoch 19/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5254
# Epoch 19: val_loss did not improve from 1.53198
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.5261 - val_loss: 1.5406
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5220
# Epoch 20: val_loss did not improve from 1.53198
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.5220 - val_loss: 1.5428
# Epoch 21/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5159
# Epoch 21: val_loss improved from 1.53198 to 1.52884, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.5158 - val_loss: 1.5288
# Epoch 22/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5124
# Epoch 22: val_loss improved from 1.52884 to 1.52198, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.5123 - val_loss: 1.5220
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5092
# Epoch 23: val_loss improved from 1.52198 to 1.51776, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.5092 - val_loss: 1.5178
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5096
# Epoch 24: val_loss did not improve from 1.51776
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.5096 - val_loss: 1.5301
# Epoch 25/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5036
# Epoch 25: val_loss improved from 1.51776 to 1.50494, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.5032 - val_loss: 1.5049
# Epoch 26/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5023
# Epoch 26: val_loss did not improve from 1.50494
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.5034 - val_loss: 1.5109
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4990
# Epoch 27: val_loss did not improve from 1.50494
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.4990 - val_loss: 1.5094
# Epoch 28/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4970
# Epoch 28: val_loss improved from 1.50494 to 1.50282, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.4962 - val_loss: 1.5028
# Epoch 29/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4941
# Epoch 29: val_loss improved from 1.50282 to 1.50200, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.4932 - val_loss: 1.5020
# Epoch 30/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4935
# Epoch 30: val_loss did not improve from 1.50200
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.4934 - val_loss: 1.5112
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4907
# Epoch 31: val_loss did not improve from 1.50200
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.4907 - val_loss: 1.5176
# Epoch 32/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4885
# Epoch 32: val_loss improved from 1.50200 to 1.49653, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4899 - val_loss: 1.4965
# Epoch 33/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4890
# Epoch 33: val_loss did not improve from 1.49653
# 29601/29601 [==============================] - 2s 56us/sample - loss: 1.4871 - val_loss: 1.5036
# Epoch 34/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4860
# Epoch 34: val_loss improved from 1.49653 to 1.49476, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4845 - val_loss: 1.4948
# Epoch 35/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4871
# Epoch 35: val_loss improved from 1.49476 to 1.49079, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4860 - val_loss: 1.4908
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4854
# Epoch 36: val_loss did not improve from 1.49079
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.4854 - val_loss: 1.5130
# Epoch 37/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4826
# Epoch 37: val_loss did not improve from 1.49079
# 29601/29601 [==============================] - 2s 56us/sample - loss: 1.4836 - val_loss: 1.5018
# Epoch 38/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4821
# Epoch 38: val_loss did not improve from 1.49079
# 29601/29601 [==============================] - 2s 56us/sample - loss: 1.4828 - val_loss: 1.4914
# Epoch 39/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4810
# Epoch 39: val_loss improved from 1.49079 to 1.49073, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 56us/sample - loss: 1.4811 - val_loss: 1.4907
# Epoch 40/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4811
# Epoch 40: val_loss did not improve from 1.49073
# 29601/29601 [==============================] - 2s 56us/sample - loss: 1.4810 - val_loss: 1.4942
# Epoch 41/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4782
# Epoch 41: val_loss did not improve from 1.49073
# 29601/29601 [==============================] - 2s 56us/sample - loss: 1.4782 - val_loss: 1.4998
# Epoch 42/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4773
# Epoch 42: val_loss improved from 1.49073 to 1.48738, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 56us/sample - loss: 1.4775 - val_loss: 1.4874
# Epoch 43/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4761
# Epoch 43: val_loss did not improve from 1.48738
# 29601/29601 [==============================] - 2s 56us/sample - loss: 1.4760 - val_loss: 1.4882
# Epoch 44/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4778
# Epoch 44: val_loss improved from 1.48738 to 1.48634, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 57us/sample - loss: 1.4772 - val_loss: 1.4863
# Epoch 45/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4738
# Epoch 45: val_loss did not improve from 1.48634
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4732 - val_loss: 1.4884
# Epoch 46/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4728
# Epoch 46: val_loss improved from 1.48634 to 1.48050, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4721 - val_loss: 1.4805
# Epoch 47/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4748
# Epoch 47: val_loss improved from 1.48050 to 1.47636, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4741 - val_loss: 1.4764
# Epoch 48/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4751
# Epoch 48: val_loss did not improve from 1.47636
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4749 - val_loss: 1.4884
# Epoch 49/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4736
# Epoch 49: val_loss did not improve from 1.47636
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4712 - val_loss: 1.4824
# Epoch 50/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4668
# Epoch 50: val_loss improved from 1.47636 to 1.47479, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4681 - val_loss: 1.4748
# Epoch 51/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4708
# Epoch 51: val_loss did not improve from 1.47479
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4712 - val_loss: 1.4834
# Epoch 52/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4697
# Epoch 52: val_loss did not improve from 1.47479
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4688 - val_loss: 1.4753
# Epoch 53/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4691
# Epoch 53: val_loss improved from 1.47479 to 1.47226, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4683 - val_loss: 1.4723
# Epoch 54/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4685
# Epoch 54: val_loss did not improve from 1.47226
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4679 - val_loss: 1.4741
# Epoch 55/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4646
# Epoch 55: val_loss did not improve from 1.47226
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4658 - val_loss: 1.4744
# Epoch 56/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4673
# Epoch 56: val_loss did not improve from 1.47226
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.4666 - val_loss: 1.4756
# Epoch 57/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4662
# Epoch 57: val_loss did not improve from 1.47226
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4649 - val_loss: 1.4784
# Epoch 58/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4675
# Epoch 58: val_loss improved from 1.47226 to 1.46866, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4663 - val_loss: 1.4687
# Epoch 59/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4624
# Epoch 59: val_loss did not improve from 1.46866
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4636 - val_loss: 1.4745
# Epoch 60/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4631
# Epoch 60: val_loss did not improve from 1.46866
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4640 - val_loss: 1.4712
# Epoch 61/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4621
# Epoch 61: val_loss improved from 1.46866 to 1.46478, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4616 - val_loss: 1.4648
# Epoch 62/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4615
# Epoch 62: val_loss did not improve from 1.46478
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4618 - val_loss: 1.4648
# Epoch 63/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4627
# Epoch 63: val_loss did not improve from 1.46478
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4604 - val_loss: 1.4706
# Epoch 64/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4594
# Epoch 64: val_loss did not improve from 1.46478
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4592 - val_loss: 1.4689
# Epoch 65/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4584
# Epoch 65: val_loss did not improve from 1.46478
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4597 - val_loss: 1.4665
# Epoch 66/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4578
# Epoch 66: val_loss did not improve from 1.46478
# 29601/29601 [==============================] - 2s 60us/sample - loss: 1.4585 - val_loss: 1.4685
# Epoch 67/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4566
# Epoch 67: val_loss did not improve from 1.46478
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4574 - val_loss: 1.4681
# Epoch 68/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4555
# Epoch 68: val_loss improved from 1.46478 to 1.46017, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 57us/sample - loss: 1.4560 - val_loss: 1.4602
# Epoch 69/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4579
# Epoch 69: val_loss did not improve from 1.46017
# 29601/29601 [==============================] - 2s 56us/sample - loss: 1.4581 - val_loss: 1.4739
# Epoch 70/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4561
# Epoch 70: val_loss did not improve from 1.46017
# 29601/29601 [==============================] - 2s 56us/sample - loss: 1.4570 - val_loss: 1.4616
# Epoch 71/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4556
# Epoch 71: val_loss did not improve from 1.46017
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4553 - val_loss: 1.4635
# Epoch 72/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4541
# Epoch 72: val_loss improved from 1.46017 to 1.45808, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4537 - val_loss: 1.4581
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4543
# Epoch 73: val_loss did not improve from 1.45808
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4543 - val_loss: 1.4650
# Epoch 74/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4539
# Epoch 74: val_loss did not improve from 1.45808
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.4537 - val_loss: 1.4614
# Epoch 75/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4549
# Epoch 75: val_loss improved from 1.45808 to 1.45604, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4555 - val_loss: 1.4560
# Epoch 76/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4531
# Epoch 76: val_loss did not improve from 1.45604
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4540 - val_loss: 1.4694
# Epoch 77/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4530
# Epoch 77: val_loss did not improve from 1.45604
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4516 - val_loss: 1.4688
# Epoch 78/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4508
# Epoch 78: val_loss did not improve from 1.45604
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4518 - val_loss: 1.4570
# Epoch 79/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4522
# Epoch 79: val_loss did not improve from 1.45604
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4515 - val_loss: 1.4619
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4490
# Epoch 80: val_loss did not improve from 1.45604
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4490 - val_loss: 1.4569
# Epoch 81/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4461
# Epoch 81: val_loss did not improve from 1.45604
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4468 - val_loss: 1.4657
# Epoch 82/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4485
# Epoch 82: val_loss did not improve from 1.45604
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4489 - val_loss: 1.4566
# Epoch 83/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4485
# Epoch 83: val_loss did not improve from 1.45604
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4485 - val_loss: 1.4598
# Epoch 84/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4479
# Epoch 84: val_loss did not improve from 1.45604
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4473 - val_loss: 1.4588
# Epoch 85/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4464
# Epoch 85: val_loss improved from 1.45604 to 1.45453, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4466 - val_loss: 1.4545
# Epoch 86/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4458
# Epoch 86: val_loss did not improve from 1.45453
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4461 - val_loss: 1.4673
# Epoch 87/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4466
# Epoch 87: val_loss did not improve from 1.45453
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4467 - val_loss: 1.4582
# Epoch 88/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4434
# Epoch 88: val_loss improved from 1.45453 to 1.45333, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4436 - val_loss: 1.4533
# Epoch 89/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4476
# Epoch 89: val_loss did not improve from 1.45333
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4470 - val_loss: 1.4607
# Epoch 90/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4409
# Epoch 90: val_loss did not improve from 1.45333
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4421 - val_loss: 1.4568
# Epoch 91/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4423
# Epoch 91: val_loss improved from 1.45333 to 1.44653, saving model to ./checkpoints/Feature_extraction_only_cwt.h5
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4424 - val_loss: 1.4465
# Epoch 92/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4426
# Epoch 92: val_loss did not improve from 1.44653
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4422 - val_loss: 1.4595
# Epoch 93/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4449
# Epoch 93: val_loss did not improve from 1.44653
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4442 - val_loss: 1.4569
# Epoch 94/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4413
# Epoch 94: val_loss did not improve from 1.44653
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4426 - val_loss: 1.4502
# Epoch 95/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4404
# Epoch 95: val_loss did not improve from 1.44653
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4415 - val_loss: 1.4523
# Epoch 96/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4398
# Epoch 96: val_loss did not improve from 1.44653
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4400 - val_loss: 1.4532
# Epoch 97/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4434
# Epoch 97: val_loss did not improve from 1.44653
# 29601/29601 [==============================] - 2s 55us/sample - loss: 1.4431 - val_loss: 1.4518
# Epoch 98/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4422
# Epoch 98: val_loss did not improve from 1.44653
# 29601/29601 [==============================] - 2s 56us/sample - loss: 1.4422 - val_loss: 1.4506
# Epoch 99/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4418
# Epoch 99: val_loss did not improve from 1.44653
# 29601/29601 [==============================] - 2s 56us/sample - loss: 1.4414 - val_loss: 1.4527
# Epoch 100/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4371
# Epoch 100: val_loss did not improve from 1.44653
# 29601/29601 [==============================] - 2s 56us/sample - loss: 1.4384 - val_loss: 1.4523
