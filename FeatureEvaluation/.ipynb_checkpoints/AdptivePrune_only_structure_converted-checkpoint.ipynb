# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([cwt_figs_all, fft_features, high_fre_compos, pitchs, low_fre_compos, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, feature]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-12-09 00:37:59.939071: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Adaptive_prune_model_only_structure_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# 2023-12-09 00:38:33.339445: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.350964: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.351204: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.354450: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.354644: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.354817: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.434997: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.435207: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.435377: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.435520: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-12-09 00:38:33.435757: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-12-09 00:38:33.436146: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-09 00:38:33.617982: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:4 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-09 00:38:33.621901: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:5 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-09 00:38:33.709270: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.709517: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.709702: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.709911: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.710141: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-09 00:38:33.710277: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-12-09 00:38:33.710304: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 82)
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 2023-12-09 00:38:34.459212: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_2/kernel/m/Assign' id:2454 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_2/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_2/kernel/m, training/Adam/dense_2/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-09 00:38:34.768167: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-12-09 00:38:35.026817: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-09 00:38:35.040797: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 29601/29601 [==============================] - ETA: 0s - loss: 3.3653
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-12-09 00:38:40.310403: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:965 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 2.05840, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 6s 217us/sample - loss: 3.3653 - val_loss: 2.0584
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 2.0380
# Epoch 2: val_loss improved from 2.05840 to 1.80741, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 127us/sample - loss: 2.0380 - val_loss: 1.8074
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.7896
# Epoch 3: val_loss improved from 1.80741 to 1.70002, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 128us/sample - loss: 1.7896 - val_loss: 1.7000
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6921
# Epoch 4: val_loss improved from 1.70002 to 1.62523, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 138us/sample - loss: 1.6921 - val_loss: 1.6252
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6224
# Epoch 5: val_loss improved from 1.62523 to 1.57145, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.6224 - val_loss: 1.5714
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5838
# Epoch 6: val_loss improved from 1.57145 to 1.53701, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 143us/sample - loss: 1.5838 - val_loss: 1.5370
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5633
# Epoch 7: val_loss improved from 1.53701 to 1.51618, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.5633 - val_loss: 1.5162
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5492
# Epoch 8: val_loss did not improve from 1.51618
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.5492 - val_loss: 1.5243
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5399
# Epoch 9: val_loss improved from 1.51618 to 1.51141, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 143us/sample - loss: 1.5399 - val_loss: 1.5114
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5330
# Epoch 10: val_loss improved from 1.51141 to 1.50351, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 143us/sample - loss: 1.5330 - val_loss: 1.5035
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5244
# Epoch 11: val_loss improved from 1.50351 to 1.49320, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.5244 - val_loss: 1.4932
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5190
# Epoch 12: val_loss improved from 1.49320 to 1.49233, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.5190 - val_loss: 1.4923
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5171
# Epoch 13: val_loss improved from 1.49233 to 1.48717, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 144us/sample - loss: 1.5171 - val_loss: 1.4872
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5128
# Epoch 14: val_loss did not improve from 1.48717
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.5128 - val_loss: 1.4911
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5091
# Epoch 15: val_loss improved from 1.48717 to 1.47647, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.5091 - val_loss: 1.4765
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5033
# Epoch 16: val_loss did not improve from 1.47647
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.5033 - val_loss: 1.4777
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5021
# Epoch 17: val_loss did not improve from 1.47647
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.5021 - val_loss: 1.4825
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4993
# Epoch 18: val_loss improved from 1.47647 to 1.47158, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 136us/sample - loss: 1.4993 - val_loss: 1.4716
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4951
# Epoch 19: val_loss improved from 1.47158 to 1.47096, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 131us/sample - loss: 1.4951 - val_loss: 1.4710
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4944
# Epoch 20: val_loss did not improve from 1.47096
# 29601/29601 [==============================] - 4s 129us/sample - loss: 1.4944 - val_loss: 1.4767
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4883
# Epoch 21: val_loss improved from 1.47096 to 1.46593, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 130us/sample - loss: 1.4883 - val_loss: 1.4659
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4883
# Epoch 22: val_loss did not improve from 1.46593
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4883 - val_loss: 1.4708
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4846
# Epoch 23: val_loss improved from 1.46593 to 1.46218, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4846 - val_loss: 1.4622
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4834
# Epoch 24: val_loss improved from 1.46218 to 1.46154, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 128us/sample - loss: 1.4834 - val_loss: 1.4615
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4783
# Epoch 25: val_loss improved from 1.46154 to 1.45480, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 128us/sample - loss: 1.4783 - val_loss: 1.4548
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4766
# Epoch 26: val_loss did not improve from 1.45480
# 29601/29601 [==============================] - 4s 128us/sample - loss: 1.4766 - val_loss: 1.4624
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4750
# Epoch 27: val_loss improved from 1.45480 to 1.45328, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 128us/sample - loss: 1.4750 - val_loss: 1.4533
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4703
# Epoch 28: val_loss did not improve from 1.45328
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4703 - val_loss: 1.4562
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4688
# Epoch 29: val_loss did not improve from 1.45328
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4688 - val_loss: 1.4559
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4685
# Epoch 30: val_loss did not improve from 1.45328
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4685 - val_loss: 1.4612
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4692
# Epoch 31: val_loss did not improve from 1.45328
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4692 - val_loss: 1.4562
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4613
# Epoch 32: val_loss improved from 1.45328 to 1.45027, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4613 - val_loss: 1.4503
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4600
# Epoch 33: val_loss did not improve from 1.45027
# 29601/29601 [==============================] - 4s 125us/sample - loss: 1.4600 - val_loss: 1.4533
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4572
# Epoch 34: val_loss improved from 1.45027 to 1.44955, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 128us/sample - loss: 1.4572 - val_loss: 1.4495
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4604
# Epoch 35: val_loss improved from 1.44955 to 1.44357, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4604 - val_loss: 1.4436
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4578
# Epoch 36: val_loss did not improve from 1.44357
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4578 - val_loss: 1.4586
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4544
# Epoch 37: val_loss did not improve from 1.44357
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4544 - val_loss: 1.4547
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4553
# Epoch 38: val_loss did not improve from 1.44357
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4553 - val_loss: 1.4486
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4531
# Epoch 39: val_loss did not improve from 1.44357
# 29601/29601 [==============================] - 4s 125us/sample - loss: 1.4531 - val_loss: 1.4493
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4514
# Epoch 40: val_loss did not improve from 1.44357
# 29601/29601 [==============================] - 4s 128us/sample - loss: 1.4514 - val_loss: 1.4465
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4519
# Epoch 41: val_loss did not improve from 1.44357
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4519 - val_loss: 1.4504
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4479
# Epoch 42: val_loss did not improve from 1.44357
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4479 - val_loss: 1.4461
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4472
# Epoch 43: val_loss did not improve from 1.44357
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4472 - val_loss: 1.4442
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4462
# Epoch 44: val_loss did not improve from 1.44357
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.4462 - val_loss: 1.4446
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4472
# Epoch 45: val_loss improved from 1.44357 to 1.43877, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4472 - val_loss: 1.4388
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4431
# Epoch 46: val_loss did not improve from 1.43877
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4431 - val_loss: 1.4533
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4436
# Epoch 47: val_loss did not improve from 1.43877
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4436 - val_loss: 1.4433
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4444
# Epoch 48: val_loss did not improve from 1.43877
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4444 - val_loss: 1.4485
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4417
# Epoch 49: val_loss did not improve from 1.43877
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4417 - val_loss: 1.4427
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4386
# Epoch 50: val_loss improved from 1.43877 to 1.43399, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 130us/sample - loss: 1.4386 - val_loss: 1.4340
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4402
# Epoch 51: val_loss did not improve from 1.43399
# 29601/29601 [==============================] - 4s 130us/sample - loss: 1.4402 - val_loss: 1.4435
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4362
# Epoch 52: val_loss did not improve from 1.43399
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4362 - val_loss: 1.4365
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4386
# Epoch 53: val_loss did not improve from 1.43399
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4386 - val_loss: 1.4417
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4363
# Epoch 54: val_loss improved from 1.43399 to 1.42984, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 128us/sample - loss: 1.4363 - val_loss: 1.4298
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4391
# Epoch 55: val_loss did not improve from 1.42984
# 29601/29601 [==============================] - 4s 125us/sample - loss: 1.4391 - val_loss: 1.4482
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4362
# Epoch 56: val_loss did not improve from 1.42984
# 29601/29601 [==============================] - 4s 125us/sample - loss: 1.4362 - val_loss: 1.4325
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4354
# Epoch 57: val_loss did not improve from 1.42984
# 29601/29601 [==============================] - 4s 125us/sample - loss: 1.4354 - val_loss: 1.4464
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4344
# Epoch 58: val_loss improved from 1.42984 to 1.42821, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4344 - val_loss: 1.4282
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4329
# Epoch 59: val_loss did not improve from 1.42821
# 29601/29601 [==============================] - 4s 125us/sample - loss: 1.4329 - val_loss: 1.4345
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4338
# Epoch 60: val_loss did not improve from 1.42821
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4338 - val_loss: 1.4365
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4324
# Epoch 61: val_loss did not improve from 1.42821
# 29601/29601 [==============================] - 4s 140us/sample - loss: 1.4324 - val_loss: 1.4349
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4293
# Epoch 62: val_loss did not improve from 1.42821
# 29601/29601 [==============================] - 4s 139us/sample - loss: 1.4293 - val_loss: 1.4328
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4302
# Epoch 63: val_loss did not improve from 1.42821
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4302 - val_loss: 1.4299
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4300
# Epoch 64: val_loss did not improve from 1.42821
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4300 - val_loss: 1.4392
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4276
# Epoch 65: val_loss did not improve from 1.42821
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4276 - val_loss: 1.4321
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4277
# Epoch 66: val_loss did not improve from 1.42821
# 29601/29601 [==============================] - 4s 128us/sample - loss: 1.4277 - val_loss: 1.4319
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4263
# Epoch 67: val_loss did not improve from 1.42821
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4263 - val_loss: 1.4364
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4274
# Epoch 68: val_loss did not improve from 1.42821
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4274 - val_loss: 1.4293
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4256
# Epoch 69: val_loss did not improve from 1.42821
# 29601/29601 [==============================] - 4s 128us/sample - loss: 1.4256 - val_loss: 1.4428
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4257
# Epoch 70: val_loss improved from 1.42821 to 1.42626, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4257 - val_loss: 1.4263
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4246
# Epoch 71: val_loss improved from 1.42626 to 1.42526, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4246 - val_loss: 1.4253
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4253
# Epoch 72: val_loss improved from 1.42526 to 1.42515, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4253 - val_loss: 1.4251
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4218
# Epoch 73: val_loss did not improve from 1.42515
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.4218 - val_loss: 1.4319
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4223
# Epoch 74: val_loss did not improve from 1.42515
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4223 - val_loss: 1.4262
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4201
# Epoch 75: val_loss did not improve from 1.42515
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.4201 - val_loss: 1.4288
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4215
# Epoch 76: val_loss did not improve from 1.42515
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4215 - val_loss: 1.4338
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4205
# Epoch 77: val_loss did not improve from 1.42515
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.4205 - val_loss: 1.4261
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4210
# Epoch 78: val_loss did not improve from 1.42515
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.4210 - val_loss: 1.4270
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4200
# Epoch 79: val_loss did not improve from 1.42515
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.4200 - val_loss: 1.4287
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4176
# Epoch 80: val_loss did not improve from 1.42515
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.4176 - val_loss: 1.4316
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4188
# Epoch 81: val_loss did not improve from 1.42515
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4188 - val_loss: 1.4279
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4154
# Epoch 82: val_loss did not improve from 1.42515
# 29601/29601 [==============================] - 4s 131us/sample - loss: 1.4154 - val_loss: 1.4261
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4176
# Epoch 83: val_loss improved from 1.42515 to 1.42454, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4176 - val_loss: 1.4245
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4177
# Epoch 84: val_loss did not improve from 1.42454
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4177 - val_loss: 1.4279
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4181
# Epoch 85: val_loss did not improve from 1.42454
# 29601/29601 [==============================] - 4s 138us/sample - loss: 1.4181 - val_loss: 1.4273
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4147
# Epoch 86: val_loss did not improve from 1.42454
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4147 - val_loss: 1.4282
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4160
# Epoch 87: val_loss did not improve from 1.42454
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4160 - val_loss: 1.4268
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4142
# Epoch 88: val_loss improved from 1.42454 to 1.42261, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 144us/sample - loss: 1.4142 - val_loss: 1.4226
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4141
# Epoch 89: val_loss did not improve from 1.42261
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4141 - val_loss: 1.4268
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4135
# Epoch 90: val_loss improved from 1.42261 to 1.42207, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4135 - val_loss: 1.4221
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4137
# Epoch 91: val_loss improved from 1.42207 to 1.41855, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 143us/sample - loss: 1.4137 - val_loss: 1.4185
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4137
# Epoch 92: val_loss did not improve from 1.41855
# 29601/29601 [==============================] - 4s 143us/sample - loss: 1.4137 - val_loss: 1.4229
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4113
# Epoch 93: val_loss did not improve from 1.41855
# 29601/29601 [==============================] - 4s 139us/sample - loss: 1.4113 - val_loss: 1.4260
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4092
# Epoch 94: val_loss did not improve from 1.41855
# 29601/29601 [==============================] - 4s 131us/sample - loss: 1.4092 - val_loss: 1.4191
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4104
# Epoch 95: val_loss did not improve from 1.41855
# 29601/29601 [==============================] - 4s 132us/sample - loss: 1.4104 - val_loss: 1.4233
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4116
# Epoch 96: val_loss did not improve from 1.41855
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4116 - val_loss: 1.4197
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4095
# Epoch 97: val_loss did not improve from 1.41855
# 29601/29601 [==============================] - 4s 145us/sample - loss: 1.4095 - val_loss: 1.4218
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4086
# Epoch 98: val_loss improved from 1.41855 to 1.41554, saving model to ./checkpoints/Adaptive_prune_model_only_structure_0.h5
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4086 - val_loss: 1.4155
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4079
# Epoch 99: val_loss did not improve from 1.41554
# 29601/29601 [==============================] - 4s 124us/sample - loss: 1.4079 - val_loss: 1.4252
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4092
# Epoch 100: val_loss did not improve from 1.41554
# 29601/29601 [==============================] - 4s 125us/sample - loss: 1.4092 - val_loss: 1.4171
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4078
# Epoch 1: val_loss improved from inf to 1.42848, saving model to ./checkpoints/Adaptive_prune_model_only_structure_1.h5
# 29601/29601 [==============================] - 4s 125us/sample - loss: 1.4078 - val_loss: 1.4285
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4067
# Epoch 2: val_loss improved from 1.42848 to 1.41805, saving model to ./checkpoints/Adaptive_prune_model_only_structure_1.h5
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4067 - val_loss: 1.4180
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4067
# Epoch 3: val_loss did not improve from 1.41805
# 29601/29601 [==============================] - 4s 135us/sample - loss: 1.4067 - val_loss: 1.4230
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4046
# Epoch 4: val_loss did not improve from 1.41805
# 29601/29601 [==============================] - 4s 143us/sample - loss: 1.4046 - val_loss: 1.4187
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4064
# Epoch 5: val_loss did not improve from 1.41805
# 29601/29601 [==============================] - 4s 143us/sample - loss: 1.4064 - val_loss: 1.4215
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4039
# Epoch 6: val_loss did not improve from 1.41805
# 29601/29601 [==============================] - 4s 140us/sample - loss: 1.4039 - val_loss: 1.4210
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4069
# Epoch 7: val_loss improved from 1.41805 to 1.41378, saving model to ./checkpoints/Adaptive_prune_model_only_structure_1.h5
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.4069 - val_loss: 1.4138
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4048
# Epoch 8: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.4048 - val_loss: 1.4168
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4054
# Epoch 9: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4054 - val_loss: 1.4235
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4035
# Epoch 10: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 140us/sample - loss: 1.4035 - val_loss: 1.4179
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4039
# Epoch 11: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.4039 - val_loss: 1.4204
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4045
# Epoch 12: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 140us/sample - loss: 1.4045 - val_loss: 1.4171
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4034
# Epoch 13: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.4034 - val_loss: 1.4274
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4041
# Epoch 14: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4041 - val_loss: 1.4147
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4017
# Epoch 15: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4017 - val_loss: 1.4188
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4010
# Epoch 16: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4010 - val_loss: 1.4200
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4014
# Epoch 17: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4014 - val_loss: 1.4138
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3994
# Epoch 18: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.3994 - val_loss: 1.4226
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4004
# Epoch 19: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4004 - val_loss: 1.4168
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4018
# Epoch 20: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.4018 - val_loss: 1.4191
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4025
# Epoch 21: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 134us/sample - loss: 1.4025 - val_loss: 1.4159
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4001
# Epoch 22: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.4001 - val_loss: 1.4202
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3983
# Epoch 23: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.3983 - val_loss: 1.4141
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3989
# Epoch 24: val_loss did not improve from 1.41378
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.3989 - val_loss: 1.4226
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4020
# Epoch 25: val_loss improved from 1.41378 to 1.41242, saving model to ./checkpoints/Adaptive_prune_model_only_structure_1.h5
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.4020 - val_loss: 1.4124
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3976
# Epoch 26: val_loss did not improve from 1.41242
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.3976 - val_loss: 1.4173
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3970
# Epoch 27: val_loss did not improve from 1.41242
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.3970 - val_loss: 1.4162
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3988
# Epoch 28: val_loss did not improve from 1.41242
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.3988 - val_loss: 1.4124
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4007
# Epoch 29: val_loss did not improve from 1.41242
# 29601/29601 [==============================] - 4s 143us/sample - loss: 1.4007 - val_loss: 1.4185
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3972
# Epoch 30: val_loss did not improve from 1.41242
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.3972 - val_loss: 1.4135
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3960
# Epoch 31: val_loss did not improve from 1.41242
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.3960 - val_loss: 1.4136
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3976
# Epoch 32: val_loss did not improve from 1.41242
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.3976 - val_loss: 1.4150
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3963
# Epoch 33: val_loss did not improve from 1.41242
# 29601/29601 [==============================] - 4s 136us/sample - loss: 1.3963 - val_loss: 1.4157
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3949
# Epoch 34: val_loss improved from 1.41242 to 1.40813, saving model to ./checkpoints/Adaptive_prune_model_only_structure_1.h5
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.3949 - val_loss: 1.4081
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4071
# Epoch 35: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.4071 - val_loss: 1.4153
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3973
# Epoch 36: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.3973 - val_loss: 1.4087
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3985
# Epoch 37: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 130us/sample - loss: 1.3985 - val_loss: 1.4171
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3951
# Epoch 38: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 128us/sample - loss: 1.3951 - val_loss: 1.4104
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3943
# Epoch 39: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 128us/sample - loss: 1.3943 - val_loss: 1.4134
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3948
# Epoch 40: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.3948 - val_loss: 1.4125
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3947
# Epoch 41: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.3947 - val_loss: 1.4116
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3950
# Epoch 42: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.3950 - val_loss: 1.4135
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3935
# Epoch 43: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.3935 - val_loss: 1.4094
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3944
# Epoch 44: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.3944 - val_loss: 1.4104
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3959
# Epoch 45: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 127us/sample - loss: 1.3959 - val_loss: 1.4127
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3941
# Epoch 46: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 129us/sample - loss: 1.3941 - val_loss: 1.4127
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3972
# Epoch 47: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 132us/sample - loss: 1.3972 - val_loss: 1.4132
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3939
# Epoch 48: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 141us/sample - loss: 1.3939 - val_loss: 1.4135
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3917
# Epoch 49: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 142us/sample - loss: 1.3917 - val_loss: 1.4129
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3934
# Epoch 50: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 140us/sample - loss: 1.3934 - val_loss: 1.4099
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4100
# Epoch 51: val_loss did not improve from 1.40813
# 29601/29601 [==============================] - 4s 136us/sample - loss: 1.4100 - val_loss: 1.4158
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3972
# Epoch 52: val_loss improved from 1.40813 to 1.40604, saving model to ./checkpoints/Adaptive_prune_model_only_structure_1.h5
# 29601/29601 [==============================] - 4s 143us/sample - loss: 1.3972 - val_loss: 1.4060
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3915
# Epoch 53: val_loss improved from 1.40604 to 1.40599, saving model to ./checkpoints/Adaptive_prune_model_only_structure_1.h5
# 29601/29601 [==============================] - 4s 139us/sample - loss: 1.3915 - val_loss: 1.4060
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3929
# Epoch 54: val_loss did not improve from 1.40599
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.3929 - val_loss: 1.4090
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3937
# Epoch 55: val_loss did not improve from 1.40599
# 29601/29601 [==============================] - 4s 126us/sample - loss: 1.3937 - val_loss: 1.4078
# Epoch 56/100
# ...
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3804
# Epoch 31: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 185us/sample - loss: 1.3804 - val_loss: 1.3926
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3817
# Epoch 32: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 183us/sample - loss: 1.3817 - val_loss: 1.3994
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3825
# Epoch 33: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 178us/sample - loss: 1.3825 - val_loss: 1.3932
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3858
# Epoch 34: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 178us/sample - loss: 1.3858 - val_loss: 1.3954
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3829
# Epoch 35: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 187us/sample - loss: 1.3829 - val_loss: 1.3915
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4039
# Epoch 36: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 183us/sample - loss: 1.4039 - val_loss: 1.4042
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4013
# Epoch 37: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 188us/sample - loss: 1.4013 - val_loss: 1.4057
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3876
# Epoch 38: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 188us/sample - loss: 1.3876 - val_loss: 1.4013
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3886
# Epoch 39: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 184us/sample - loss: 1.3886 - val_loss: 1.3988
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3881
# Epoch 40: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 182us/sample - loss: 1.3881 - val_loss: 1.3948
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3885
# Epoch 41: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 185us/sample - loss: 1.3885 - val_loss: 1.3965
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3888
# Epoch 42: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 181us/sample - loss: 1.3888 - val_loss: 1.4028
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3909
# Epoch 43: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 178us/sample - loss: 1.3909 - val_loss: 1.3938
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3915
# Epoch 44: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 179us/sample - loss: 1.3915 - val_loss: 1.3931
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3912
# Epoch 45: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 182us/sample - loss: 1.3912 - val_loss: 1.3920
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3913
# Epoch 46: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 184us/sample - loss: 1.3913 - val_loss: 1.3958
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3938
# Epoch 47: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 180us/sample - loss: 1.3938 - val_loss: 1.4042
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3945
# Epoch 48: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 180us/sample - loss: 1.3945 - val_loss: 1.3921
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3919
# Epoch 49: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 185us/sample - loss: 1.3919 - val_loss: 1.3986
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3937
# Epoch 50: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 179us/sample - loss: 1.3937 - val_loss: 1.3966
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3924
# Epoch 51: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 188us/sample - loss: 1.3924 - val_loss: 1.3949
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3955
# Epoch 52: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 186us/sample - loss: 1.3955 - val_loss: 1.3963
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3964
# Epoch 53: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 179us/sample - loss: 1.3964 - val_loss: 1.3946
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3962
# Epoch 54: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 177us/sample - loss: 1.3962 - val_loss: 1.3987
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3916
# Epoch 55: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 187us/sample - loss: 1.3916 - val_loss: 1.4006
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3935
# Epoch 56: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 191us/sample - loss: 1.3935 - val_loss: 1.4047
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3954
# Epoch 57: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 188us/sample - loss: 1.3954 - val_loss: 1.3984
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3918
# Epoch 58: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 181us/sample - loss: 1.3918 - val_loss: 1.4049
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3897
# Epoch 59: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 187us/sample - loss: 1.3897 - val_loss: 1.3938
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3894
# Epoch 60: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 182us/sample - loss: 1.3894 - val_loss: 1.4014
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3895
# Epoch 61: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 184us/sample - loss: 1.3895 - val_loss: 1.3970
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3916
# Epoch 62: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 176us/sample - loss: 1.3916 - val_loss: 1.3924
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3877
# Epoch 63: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 184us/sample - loss: 1.3877 - val_loss: 1.3980
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3869
# Epoch 64: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 190us/sample - loss: 1.3869 - val_loss: 1.3931
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3849
# Epoch 65: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 190us/sample - loss: 1.3849 - val_loss: 1.3948
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3861
# Epoch 66: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 185us/sample - loss: 1.3861 - val_loss: 1.3942
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3823
# Epoch 67: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 184us/sample - loss: 1.3823 - val_loss: 1.3945
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3828
# Epoch 68: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 188us/sample - loss: 1.3828 - val_loss: 1.3868
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3836
# Epoch 69: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 192us/sample - loss: 1.3836 - val_loss: 1.3919
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3857
# Epoch 70: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 188us/sample - loss: 1.3857 - val_loss: 1.3931
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3859
# Epoch 71: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 192us/sample - loss: 1.3859 - val_loss: 1.3913
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3839
# Epoch 72: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 183us/sample - loss: 1.3839 - val_loss: 1.3901
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3847
# Epoch 73: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 194us/sample - loss: 1.3847 - val_loss: 1.3903
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3814
# Epoch 74: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 182us/sample - loss: 1.3814 - val_loss: 1.3973
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3797
# Epoch 75: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 181us/sample - loss: 1.3797 - val_loss: 1.3945
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3788
# Epoch 76: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 182us/sample - loss: 1.3788 - val_loss: 1.3927
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3785
# Epoch 77: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 189us/sample - loss: 1.3785 - val_loss: 1.3934
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3783
# Epoch 78: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 173us/sample - loss: 1.3783 - val_loss: 1.3928
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3803
# Epoch 79: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 189us/sample - loss: 1.3803 - val_loss: 1.3906
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3784
# Epoch 80: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 188us/sample - loss: 1.3784 - val_loss: 1.3914
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3782
# Epoch 81: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 191us/sample - loss: 1.3782 - val_loss: 1.3997
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3802
# Epoch 82: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 183us/sample - loss: 1.3802 - val_loss: 1.3915
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3788
# Epoch 83: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 195us/sample - loss: 1.3788 - val_loss: 1.3907
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3771
# Epoch 84: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 187us/sample - loss: 1.3771 - val_loss: 1.3935
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3764
# Epoch 85: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 180us/sample - loss: 1.3764 - val_loss: 1.3914
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3790
# Epoch 86: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 187us/sample - loss: 1.3790 - val_loss: 1.3936
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3754
# Epoch 87: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 190us/sample - loss: 1.3754 - val_loss: 1.3877
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3775
# Epoch 88: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 183us/sample - loss: 1.3775 - val_loss: 1.3952
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3747
# Epoch 89: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 181us/sample - loss: 1.3747 - val_loss: 1.3949
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3747
# Epoch 90: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 184us/sample - loss: 1.3747 - val_loss: 1.3937
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3759
# Epoch 91: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 189us/sample - loss: 1.3759 - val_loss: 1.3885
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3736
# Epoch 92: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 189us/sample - loss: 1.3736 - val_loss: 1.3875
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3740
# Epoch 93: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 188us/sample - loss: 1.3740 - val_loss: 1.3871
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3748
# Epoch 94: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 181us/sample - loss: 1.3748 - val_loss: 1.3932
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3741
# Epoch 95: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 188us/sample - loss: 1.3741 - val_loss: 1.3910
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3749
# Epoch 96: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 182us/sample - loss: 1.3749 - val_loss: 1.3847
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3719
# Epoch 97: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 6s 187us/sample - loss: 1.3719 - val_loss: 1.3845
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3737
# Epoch 98: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 186us/sample - loss: 1.3737 - val_loss: 1.3864
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3703
# Epoch 99: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 185us/sample - loss: 1.3703 - val_loss: 1.3899
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3705
# Epoch 100: val_loss did not improve from 1.38119
# 29601/29601 [==============================] - 5s 162us/sample - loss: 1.3705 - val_loss: 1.3870
