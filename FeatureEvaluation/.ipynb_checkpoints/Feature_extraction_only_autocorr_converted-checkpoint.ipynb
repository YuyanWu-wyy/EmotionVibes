# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([auto_corrs]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
# rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

# for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
model_name = './checkpoints/Feature_extraction_only_autocorr.h5'

checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
# pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=0.35, start_epoch=5, end_epoch=50, frequency=1)
model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-06 23:55:59.313199: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.324847: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.325081: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.329065: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.329306: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.329470: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.400077: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.400321: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.400487: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.400625: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-06 23:55:59.401044: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# (29601, 0)
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 2023-11-06 23:55:59.640269: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.640511: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.640682: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.640888: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.641062: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 23:55:59.641206: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-06 23:55:59.641238: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-06 23:55:59.650631: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-06 23:55:59.841057: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_1/kernel/v/Assign' id:803 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_1/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_1/kernel/v, training/Adam/dense_1/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-06 23:56:00.001693: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 29601/29601 [==============================] - ETA: 0s - loss: 4.8958
# Epoch 1: val_loss improved from inf to 4.66802, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-06 23:56:02.570239: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:308 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 29601/29601 [==============================] - 3s 106us/sample - loss: 4.8958 - val_loss: 4.6680
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 4.2256
# Epoch 2: val_loss improved from 4.66802 to 3.43714, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 3s 88us/sample - loss: 4.2256 - val_loss: 3.4371
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 2.4642
# Epoch 3: val_loss improved from 3.43714 to 1.72621, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 3s 89us/sample - loss: 2.4642 - val_loss: 1.7262
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.7300
# Epoch 4: val_loss improved from 1.72621 to 1.63391, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.7300 - val_loss: 1.6339
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6614
# Epoch 5: val_loss improved from 1.63391 to 1.61110, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.6614 - val_loss: 1.6111
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6332
# Epoch 6: val_loss improved from 1.61110 to 1.59899, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.6332 - val_loss: 1.5990
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6154
# Epoch 7: val_loss improved from 1.59899 to 1.59608, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.6154 - val_loss: 1.5961
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6007
# Epoch 8: val_loss improved from 1.59608 to 1.59208, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 3s 86us/sample - loss: 1.6007 - val_loss: 1.5921
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5933
# Epoch 9: val_loss did not improve from 1.59208
# 29601/29601 [==============================] - 2s 76us/sample - loss: 1.5933 - val_loss: 1.5948
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5878
# Epoch 10: val_loss improved from 1.59208 to 1.58938, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 78us/sample - loss: 1.5878 - val_loss: 1.5894
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5827
# Epoch 11: val_loss improved from 1.58938 to 1.58906, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 78us/sample - loss: 1.5827 - val_loss: 1.5891
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5805
# Epoch 12: val_loss improved from 1.58906 to 1.58754, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5805 - val_loss: 1.5875
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5775
# Epoch 13: val_loss improved from 1.58754 to 1.58614, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5775 - val_loss: 1.5861
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5761
# Epoch 14: val_loss improved from 1.58614 to 1.58594, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5761 - val_loss: 1.5859
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5752
# Epoch 15: val_loss improved from 1.58594 to 1.58407, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5752 - val_loss: 1.5841
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5736
# Epoch 16: val_loss did not improve from 1.58407
# 29601/29601 [==============================] - 2s 78us/sample - loss: 1.5736 - val_loss: 1.5852
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5727
# Epoch 17: val_loss improved from 1.58407 to 1.58326, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 80us/sample - loss: 1.5727 - val_loss: 1.5833
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5727
# Epoch 18: val_loss improved from 1.58326 to 1.58278, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5727 - val_loss: 1.5828
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5720
# Epoch 19: val_loss improved from 1.58278 to 1.58175, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5720 - val_loss: 1.5818
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5712
# Epoch 20: val_loss improved from 1.58175 to 1.58172, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5712 - val_loss: 1.5817
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5708
# Epoch 21: val_loss improved from 1.58172 to 1.58127, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5708 - val_loss: 1.5813
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5702
# Epoch 22: val_loss improved from 1.58127 to 1.58056, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5702 - val_loss: 1.5806
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5706
# Epoch 23: val_loss improved from 1.58056 to 1.58006, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5706 - val_loss: 1.5801
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5706
# Epoch 24: val_loss improved from 1.58006 to 1.57961, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5706 - val_loss: 1.5796
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5703
# Epoch 25: val_loss did not improve from 1.57961
# 29601/29601 [==============================] - 2s 74us/sample - loss: 1.5703 - val_loss: 1.5802
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5694
# Epoch 26: val_loss did not improve from 1.57961
# 29601/29601 [==============================] - 2s 84us/sample - loss: 1.5694 - val_loss: 1.5805
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5709
# Epoch 27: val_loss improved from 1.57961 to 1.57953, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5709 - val_loss: 1.5795
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5700
# Epoch 28: val_loss did not improve from 1.57953
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.5700 - val_loss: 1.5808
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5707
# Epoch 29: val_loss did not improve from 1.57953
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5707 - val_loss: 1.5822
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5695
# Epoch 30: val_loss improved from 1.57953 to 1.57905, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5695 - val_loss: 1.5790
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5697
# Epoch 31: val_loss improved from 1.57905 to 1.57889, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5697 - val_loss: 1.5789
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5692
# Epoch 32: val_loss improved from 1.57889 to 1.57860, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 3s 89us/sample - loss: 1.5692 - val_loss: 1.5786
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5685
# Epoch 33: val_loss did not improve from 1.57860
# 29601/29601 [==============================] - 2s 82us/sample - loss: 1.5685 - val_loss: 1.5789
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5691
# Epoch 34: val_loss did not improve from 1.57860
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5691 - val_loss: 1.5791
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5688
# Epoch 35: val_loss did not improve from 1.57860
# 29601/29601 [==============================] - 2s 78us/sample - loss: 1.5688 - val_loss: 1.5788
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5688
# Epoch 36: val_loss did not improve from 1.57860
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5688 - val_loss: 1.5788
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5688
# Epoch 37: val_loss did not improve from 1.57860
# 29601/29601 [==============================] - 2s 83us/sample - loss: 1.5688 - val_loss: 1.5796
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5684
# Epoch 38: val_loss improved from 1.57860 to 1.57796, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 78us/sample - loss: 1.5684 - val_loss: 1.5780
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5679
# Epoch 39: val_loss improved from 1.57796 to 1.57758, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5679 - val_loss: 1.5776
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5684
# Epoch 40: val_loss did not improve from 1.57758
# 29601/29601 [==============================] - 3s 85us/sample - loss: 1.5684 - val_loss: 1.5791
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5692
# Epoch 41: val_loss improved from 1.57758 to 1.57714, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 80us/sample - loss: 1.5692 - val_loss: 1.5771
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5676
# Epoch 42: val_loss did not improve from 1.57714
# 29601/29601 [==============================] - 2s 79us/sample - loss: 1.5676 - val_loss: 1.5786
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5683
# Epoch 43: val_loss did not improve from 1.57714
# 29601/29601 [==============================] - 2s 77us/sample - loss: 1.5683 - val_loss: 1.5773
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5675
# Epoch 44: val_loss did not improve from 1.57714
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5675 - val_loss: 1.5780
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5676
# Epoch 45: val_loss did not improve from 1.57714
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5676 - val_loss: 1.5772
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5675
# Epoch 46: val_loss improved from 1.57714 to 1.57684, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5675 - val_loss: 1.5768
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5671
# Epoch 47: val_loss improved from 1.57684 to 1.57642, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 76us/sample - loss: 1.5671 - val_loss: 1.5764
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5675
# Epoch 48: val_loss did not improve from 1.57642
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5675 - val_loss: 1.5764
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5667
# Epoch 49: val_loss improved from 1.57642 to 1.57614, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 78us/sample - loss: 1.5667 - val_loss: 1.5761
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5670
# Epoch 50: val_loss did not improve from 1.57614
# 29601/29601 [==============================] - 2s 76us/sample - loss: 1.5670 - val_loss: 1.5764
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5665
# Epoch 51: val_loss improved from 1.57614 to 1.57587, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 82us/sample - loss: 1.5665 - val_loss: 1.5759
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5665
# Epoch 52: val_loss did not improve from 1.57587
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5665 - val_loss: 1.5762
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5671
# Epoch 53: val_loss did not improve from 1.57587
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5671 - val_loss: 1.5765
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5662
# Epoch 54: val_loss did not improve from 1.57587
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5662 - val_loss: 1.5759
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5670
# Epoch 55: val_loss improved from 1.57587 to 1.57584, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 3s 86us/sample - loss: 1.5670 - val_loss: 1.5758
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5669
# Epoch 56: val_loss did not improve from 1.57584
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5669 - val_loss: 1.5764
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5666
# Epoch 57: val_loss did not improve from 1.57584
# 29601/29601 [==============================] - 3s 86us/sample - loss: 1.5666 - val_loss: 1.5765
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5664
# Epoch 58: val_loss did not improve from 1.57584
# 29601/29601 [==============================] - 2s 82us/sample - loss: 1.5664 - val_loss: 1.5759
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5662
# Epoch 59: val_loss improved from 1.57584 to 1.57539, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5662 - val_loss: 1.5754
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5665
# Epoch 60: val_loss did not improve from 1.57539
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5665 - val_loss: 1.5757
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5667
# Epoch 61: val_loss did not improve from 1.57539
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5667 - val_loss: 1.5755
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5663
# Epoch 62: val_loss did not improve from 1.57539
# 29601/29601 [==============================] - 2s 80us/sample - loss: 1.5663 - val_loss: 1.5760
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5658
# Epoch 63: val_loss improved from 1.57539 to 1.57515, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 76us/sample - loss: 1.5658 - val_loss: 1.5751
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5662
# Epoch 64: val_loss did not improve from 1.57515
# 29601/29601 [==============================] - 2s 84us/sample - loss: 1.5662 - val_loss: 1.5783
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5666
# Epoch 65: val_loss did not improve from 1.57515
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.5666 - val_loss: 1.5761
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5670
# Epoch 66: val_loss did not improve from 1.57515
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5670 - val_loss: 1.5752
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5660
# Epoch 67: val_loss did not improve from 1.57515
# 29601/29601 [==============================] - 3s 86us/sample - loss: 1.5660 - val_loss: 1.5753
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5665
# Epoch 68: val_loss did not improve from 1.57515
# 29601/29601 [==============================] - 3s 86us/sample - loss: 1.5665 - val_loss: 1.5756
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5663
# Epoch 69: val_loss did not improve from 1.57515
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5663 - val_loss: 1.5754
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5665
# Epoch 70: val_loss did not improve from 1.57515
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5665 - val_loss: 1.5768
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5665
# Epoch 71: val_loss improved from 1.57515 to 1.57438, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 84us/sample - loss: 1.5665 - val_loss: 1.5744
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5662
# Epoch 72: val_loss did not improve from 1.57438
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5662 - val_loss: 1.5773
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5670
# Epoch 73: val_loss did not improve from 1.57438
# 29601/29601 [==============================] - 2s 74us/sample - loss: 1.5670 - val_loss: 1.5755
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5659
# Epoch 74: val_loss improved from 1.57438 to 1.57379, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5659 - val_loss: 1.5738
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5658
# Epoch 75: val_loss did not improve from 1.57379
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5658 - val_loss: 1.5751
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5663
# Epoch 76: val_loss did not improve from 1.57379
# 29601/29601 [==============================] - 2s 81us/sample - loss: 1.5663 - val_loss: 1.5755
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5658
# Epoch 77: val_loss did not improve from 1.57379
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5658 - val_loss: 1.5757
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5658
# Epoch 78: val_loss did not improve from 1.57379
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5658 - val_loss: 1.5750
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5661
# Epoch 79: val_loss did not improve from 1.57379
# 29601/29601 [==============================] - 3s 86us/sample - loss: 1.5661 - val_loss: 1.5741
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5670
# Epoch 80: val_loss did not improve from 1.57379
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5670 - val_loss: 1.5766
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5663
# Epoch 81: val_loss did not improve from 1.57379
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5663 - val_loss: 1.5755
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5663
# Epoch 82: val_loss did not improve from 1.57379
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5663 - val_loss: 1.5750
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5663
# Epoch 83: val_loss did not improve from 1.57379
# 29601/29601 [==============================] - 2s 76us/sample - loss: 1.5663 - val_loss: 1.5747
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5664
# Epoch 84: val_loss did not improve from 1.57379
# 29601/29601 [==============================] - 2s 74us/sample - loss: 1.5664 - val_loss: 1.5773
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5662
# Epoch 85: val_loss improved from 1.57379 to 1.57364, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5662 - val_loss: 1.5736
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5655
# Epoch 86: val_loss improved from 1.57364 to 1.57359, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5655 - val_loss: 1.5736
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5652
# Epoch 87: val_loss did not improve from 1.57359
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5652 - val_loss: 1.5743
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5657
# Epoch 88: val_loss did not improve from 1.57359
# 29601/29601 [==============================] - 3s 87us/sample - loss: 1.5657 - val_loss: 1.5741
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5648
# Epoch 89: val_loss did not improve from 1.57359
# 29601/29601 [==============================] - 3s 86us/sample - loss: 1.5648 - val_loss: 1.5759
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5667
# Epoch 90: val_loss did not improve from 1.57359
# 29601/29601 [==============================] - 3s 88us/sample - loss: 1.5667 - val_loss: 1.5740
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5658
# Epoch 91: val_loss did not improve from 1.57359
# 29601/29601 [==============================] - 3s 86us/sample - loss: 1.5658 - val_loss: 1.5745
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5657
# Epoch 92: val_loss improved from 1.57359 to 1.57336, saving model to ./checkpoints/Feature_extraction_only_autocorr.h5
# 29601/29601 [==============================] - 2s 76us/sample - loss: 1.5657 - val_loss: 1.5734
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5656
# Epoch 93: val_loss did not improve from 1.57336
# 29601/29601 [==============================] - 2s 77us/sample - loss: 1.5656 - val_loss: 1.5735
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5653
# Epoch 94: val_loss did not improve from 1.57336
# 29601/29601 [==============================] - 2s 76us/sample - loss: 1.5653 - val_loss: 1.5747
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5662
# Epoch 95: val_loss did not improve from 1.57336
# 29601/29601 [==============================] - 2s 77us/sample - loss: 1.5662 - val_loss: 1.5761
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5657
# Epoch 96: val_loss did not improve from 1.57336
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5657 - val_loss: 1.5749
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5659
# Epoch 97: val_loss did not improve from 1.57336
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5659 - val_loss: 1.5761
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5655
# Epoch 98: val_loss did not improve from 1.57336
# 29601/29601 [==============================] - 2s 78us/sample - loss: 1.5655 - val_loss: 1.5735
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5649
# Epoch 99: val_loss did not improve from 1.57336
# 29601/29601 [==============================] - 2s 76us/sample - loss: 1.5649 - val_loss: 1.5754
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5652
# Epoch 100: val_loss did not improve from 1.57336
# 29601/29601 [==============================] - 2s 75us/sample - loss: 1.5652 - val_loss: 1.5742
