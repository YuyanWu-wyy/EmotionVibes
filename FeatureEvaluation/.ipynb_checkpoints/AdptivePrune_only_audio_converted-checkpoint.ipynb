# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, slope, lpcs, legendres, ceps_features, real_hils, imag_hils, jitters, shimmers, jitter_rap, auto_corrs, hrs,zcrs]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Adaptive_prune_model_only_audio_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-08 20:17:20.643422: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:20.655260: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:20.655496: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:20.658828: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:20.659018: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:20.659185: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.752550: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.752985: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.753437: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.753654: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-12-08 20:17:50.753932: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 7)
# Train on 29601 samples, validate on 3694 samples
# 2023-12-08 20:17:54.682869: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:54.683163: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:54.683348: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:54.683562: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:54.683737: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:54.683877: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-12-08 20:17:54.683914: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-12-08 20:17:54.800582: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-12-08 20:17:55.164626: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_2/kernel/v/Assign' id:13960 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_2/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_2/kernel/v, training/Adam/dense_2/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-12-08 20:17:59.340056: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 29601/29601 [==============================] - ETA: 0s - loss: 4.5175
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-12-08 20:18:11.096631: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:5093 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 3.50208, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 16s 551us/sample - loss: 4.5175 - val_loss: 3.5021
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 2.2115
# Epoch 2: val_loss improved from 3.50208 to 1.66125, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 417us/sample - loss: 2.2115 - val_loss: 1.6613
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6620
# Epoch 3: val_loss improved from 1.66125 to 1.62001, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 418us/sample - loss: 1.6620 - val_loss: 1.6200
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6174
# Epoch 4: val_loss improved from 1.62001 to 1.60044, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 409us/sample - loss: 1.6174 - val_loss: 1.6004
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5976
# Epoch 5: val_loss improved from 1.60044 to 1.59082, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 462us/sample - loss: 1.5976 - val_loss: 1.5908
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5849
# Epoch 6: val_loss improved from 1.59082 to 1.58001, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 434us/sample - loss: 1.5849 - val_loss: 1.5800
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5805
# Epoch 7: val_loss improved from 1.58001 to 1.57138, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.5805 - val_loss: 1.5714
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5707
# Epoch 8: val_loss improved from 1.57138 to 1.56862, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 458us/sample - loss: 1.5707 - val_loss: 1.5686
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5678
# Epoch 9: val_loss improved from 1.56862 to 1.56197, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 416us/sample - loss: 1.5678 - val_loss: 1.5620
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5616
# Epoch 10: val_loss did not improve from 1.56197
# 29601/29601 [==============================] - 12s 405us/sample - loss: 1.5616 - val_loss: 1.5628
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5544
# Epoch 11: val_loss improved from 1.56197 to 1.55141, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 412us/sample - loss: 1.5544 - val_loss: 1.5514
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5555
# Epoch 12: val_loss did not improve from 1.55141
# 29601/29601 [==============================] - 12s 406us/sample - loss: 1.5555 - val_loss: 1.5516
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5485
# Epoch 13: val_loss improved from 1.55141 to 1.54683, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 410us/sample - loss: 1.5485 - val_loss: 1.5468
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5455
# Epoch 14: val_loss improved from 1.54683 to 1.54031, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 409us/sample - loss: 1.5455 - val_loss: 1.5403
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5429
# Epoch 15: val_loss improved from 1.54031 to 1.53668, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 433us/sample - loss: 1.5429 - val_loss: 1.5367
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5347
# Epoch 16: val_loss improved from 1.53668 to 1.53234, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 470us/sample - loss: 1.5347 - val_loss: 1.5323
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5323
# Epoch 17: val_loss improved from 1.53234 to 1.52397, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 475us/sample - loss: 1.5323 - val_loss: 1.5240
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5304
# Epoch 18: val_loss improved from 1.52397 to 1.52330, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 425us/sample - loss: 1.5304 - val_loss: 1.5233
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5282
# Epoch 19: val_loss improved from 1.52330 to 1.52265, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 409us/sample - loss: 1.5282 - val_loss: 1.5227
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5236
# Epoch 20: val_loss improved from 1.52265 to 1.52045, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 408us/sample - loss: 1.5236 - val_loss: 1.5204
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5269
# Epoch 21: val_loss did not improve from 1.52045
# 29601/29601 [==============================] - 12s 418us/sample - loss: 1.5269 - val_loss: 1.5207
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5266
# Epoch 22: val_loss did not improve from 1.52045
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.5266 - val_loss: 1.5322
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5244
# Epoch 23: val_loss improved from 1.52045 to 1.51650, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 413us/sample - loss: 1.5244 - val_loss: 1.5165
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5214
# Epoch 24: val_loss improved from 1.51650 to 1.51383, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 404us/sample - loss: 1.5214 - val_loss: 1.5138
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5180
# Epoch 25: val_loss improved from 1.51383 to 1.51378, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 407us/sample - loss: 1.5180 - val_loss: 1.5138
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5171
# Epoch 26: val_loss improved from 1.51378 to 1.50810, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 415us/sample - loss: 1.5171 - val_loss: 1.5081
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5134
# Epoch 27: val_loss improved from 1.50810 to 1.50665, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 461us/sample - loss: 1.5134 - val_loss: 1.5066
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5105
# Epoch 28: val_loss improved from 1.50665 to 1.50612, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 474us/sample - loss: 1.5105 - val_loss: 1.5061
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5094
# Epoch 29: val_loss improved from 1.50612 to 1.50351, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 477us/sample - loss: 1.5094 - val_loss: 1.5035
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5078
# Epoch 30: val_loss improved from 1.50351 to 1.49827, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.5078 - val_loss: 1.4983
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5046
# Epoch 31: val_loss did not improve from 1.49827
# 29601/29601 [==============================] - 12s 412us/sample - loss: 1.5046 - val_loss: 1.5013
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5054
# Epoch 32: val_loss improved from 1.49827 to 1.49698, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 414us/sample - loss: 1.5054 - val_loss: 1.4970
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5037
# Epoch 33: val_loss improved from 1.49698 to 1.49452, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 415us/sample - loss: 1.5037 - val_loss: 1.4945
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5000
# Epoch 34: val_loss improved from 1.49452 to 1.49350, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 413us/sample - loss: 1.5000 - val_loss: 1.4935
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4996
# Epoch 35: val_loss did not improve from 1.49350
# 29601/29601 [==============================] - 12s 414us/sample - loss: 1.4996 - val_loss: 1.4956
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5015
# Epoch 36: val_loss did not improve from 1.49350
# 29601/29601 [==============================] - 14s 471us/sample - loss: 1.5015 - val_loss: 1.4974
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4969
# Epoch 37: val_loss improved from 1.49350 to 1.48943, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 479us/sample - loss: 1.4969 - val_loss: 1.4894
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4973
# Epoch 38: val_loss improved from 1.48943 to 1.48831, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 466us/sample - loss: 1.4973 - val_loss: 1.4883
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4973
# Epoch 39: val_loss improved from 1.48831 to 1.48718, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 425us/sample - loss: 1.4973 - val_loss: 1.4872
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4932
# Epoch 40: val_loss improved from 1.48718 to 1.48684, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 412us/sample - loss: 1.4932 - val_loss: 1.4868
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4921
# Epoch 41: val_loss improved from 1.48684 to 1.48464, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 413us/sample - loss: 1.4921 - val_loss: 1.4846
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4915
# Epoch 42: val_loss did not improve from 1.48464
# 29601/29601 [==============================] - 13s 448us/sample - loss: 1.4915 - val_loss: 1.4855
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4917
# Epoch 43: val_loss did not improve from 1.48464
# 29601/29601 [==============================] - 14s 471us/sample - loss: 1.4917 - val_loss: 1.4850
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4882
# Epoch 44: val_loss did not improve from 1.48464
# 29601/29601 [==============================] - 14s 469us/sample - loss: 1.4882 - val_loss: 1.4848
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4856
# Epoch 45: val_loss improved from 1.48464 to 1.48097, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 422us/sample - loss: 1.4856 - val_loss: 1.4810
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4849
# Epoch 46: val_loss improved from 1.48097 to 1.47868, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 440us/sample - loss: 1.4849 - val_loss: 1.4787
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4849
# Epoch 47: val_loss improved from 1.47868 to 1.47779, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 421us/sample - loss: 1.4849 - val_loss: 1.4778
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4845
# Epoch 48: val_loss improved from 1.47779 to 1.47712, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 474us/sample - loss: 1.4845 - val_loss: 1.4771
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4828
# Epoch 49: val_loss did not improve from 1.47712
# 29601/29601 [==============================] - 14s 467us/sample - loss: 1.4828 - val_loss: 1.4791
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4814
# Epoch 50: val_loss improved from 1.47712 to 1.47710, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 470us/sample - loss: 1.4814 - val_loss: 1.4771
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4810
# Epoch 51: val_loss improved from 1.47710 to 1.47651, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 446us/sample - loss: 1.4810 - val_loss: 1.4765
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4786
# Epoch 52: val_loss improved from 1.47651 to 1.47335, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 408us/sample - loss: 1.4786 - val_loss: 1.4734
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4753
# Epoch 53: val_loss improved from 1.47335 to 1.47182, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 432us/sample - loss: 1.4753 - val_loss: 1.4718
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4780
# Epoch 54: val_loss did not improve from 1.47182
# 29601/29601 [==============================] - 12s 406us/sample - loss: 1.4780 - val_loss: 1.4763
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4778
# Epoch 55: val_loss did not improve from 1.47182
# 29601/29601 [==============================] - 12s 404us/sample - loss: 1.4778 - val_loss: 1.4768
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4736
# Epoch 56: val_loss improved from 1.47182 to 1.47011, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 433us/sample - loss: 1.4736 - val_loss: 1.4701
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4756
# Epoch 57: val_loss did not improve from 1.47011
# 29601/29601 [==============================] - 12s 396us/sample - loss: 1.4756 - val_loss: 1.4776
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4729
# Epoch 58: val_loss did not improve from 1.47011
# 29601/29601 [==============================] - 12s 405us/sample - loss: 1.4729 - val_loss: 1.4733
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4729
# Epoch 59: val_loss improved from 1.47011 to 1.46111, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 446us/sample - loss: 1.4729 - val_loss: 1.4611
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4712
# Epoch 60: val_loss did not improve from 1.46111
# 29601/29601 [==============================] - 12s 410us/sample - loss: 1.4712 - val_loss: 1.4677
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4735
# Epoch 61: val_loss did not improve from 1.46111
# 29601/29601 [==============================] - 13s 428us/sample - loss: 1.4735 - val_loss: 1.4716
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4686
# Epoch 62: val_loss did not improve from 1.46111
# 29601/29601 [==============================] - 14s 470us/sample - loss: 1.4686 - val_loss: 1.4657
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4673
# Epoch 63: val_loss did not improve from 1.46111
# 29601/29601 [==============================] - 14s 469us/sample - loss: 1.4673 - val_loss: 1.4643
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4647
# Epoch 64: val_loss did not improve from 1.46111
# 29601/29601 [==============================] - 14s 463us/sample - loss: 1.4647 - val_loss: 1.4672
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4672
# Epoch 65: val_loss improved from 1.46111 to 1.46050, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 430us/sample - loss: 1.4672 - val_loss: 1.4605
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4637
# Epoch 66: val_loss improved from 1.46050 to 1.45842, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 474us/sample - loss: 1.4637 - val_loss: 1.4584
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4617
# Epoch 67: val_loss did not improve from 1.45842
# 29601/29601 [==============================] - 14s 466us/sample - loss: 1.4617 - val_loss: 1.4617
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4619
# Epoch 68: val_loss did not improve from 1.45842
# 29601/29601 [==============================] - 14s 472us/sample - loss: 1.4619 - val_loss: 1.4661
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4612
# Epoch 69: val_loss did not improve from 1.45842
# 29601/29601 [==============================] - 14s 466us/sample - loss: 1.4612 - val_loss: 1.4629
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4612
# Epoch 70: val_loss did not improve from 1.45842
# 29601/29601 [==============================] - 14s 469us/sample - loss: 1.4612 - val_loss: 1.4625
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4592
# Epoch 71: val_loss improved from 1.45842 to 1.45459, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 457us/sample - loss: 1.4592 - val_loss: 1.4546
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4575
# Epoch 72: val_loss did not improve from 1.45459
# 29601/29601 [==============================] - 13s 433us/sample - loss: 1.4575 - val_loss: 1.4577
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4576
# Epoch 73: val_loss did not improve from 1.45459
# 29601/29601 [==============================] - 12s 414us/sample - loss: 1.4576 - val_loss: 1.4555
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4574
# Epoch 74: val_loss improved from 1.45459 to 1.45326, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 426us/sample - loss: 1.4574 - val_loss: 1.4533
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4561
# Epoch 75: val_loss did not improve from 1.45326
# 29601/29601 [==============================] - 13s 431us/sample - loss: 1.4561 - val_loss: 1.4551
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4597
# Epoch 76: val_loss did not improve from 1.45326
# 29601/29601 [==============================] - 14s 464us/sample - loss: 1.4597 - val_loss: 1.4569
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4570
# Epoch 77: val_loss did not improve from 1.45326
# 29601/29601 [==============================] - 14s 467us/sample - loss: 1.4570 - val_loss: 1.4534
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4523
# Epoch 78: val_loss did not improve from 1.45326
# 29601/29601 [==============================] - 14s 467us/sample - loss: 1.4523 - val_loss: 1.4550
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4524
# Epoch 79: val_loss did not improve from 1.45326
# 29601/29601 [==============================] - 14s 470us/sample - loss: 1.4524 - val_loss: 1.4535
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4509
# Epoch 80: val_loss improved from 1.45326 to 1.44853, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 470us/sample - loss: 1.4509 - val_loss: 1.4485
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4506
# Epoch 81: val_loss did not improve from 1.44853
# 29601/29601 [==============================] - 14s 471us/sample - loss: 1.4506 - val_loss: 1.4486
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4528
# Epoch 82: val_loss did not improve from 1.44853
# 29601/29601 [==============================] - 14s 469us/sample - loss: 1.4528 - val_loss: 1.4507
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4537
# Epoch 83: val_loss did not improve from 1.44853
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.4537 - val_loss: 1.4511
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4495
# Epoch 84: val_loss did not improve from 1.44853
# 29601/29601 [==============================] - 13s 446us/sample - loss: 1.4495 - val_loss: 1.4541
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4480
# Epoch 85: val_loss improved from 1.44853 to 1.44808, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 472us/sample - loss: 1.4480 - val_loss: 1.4481
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4471
# Epoch 86: val_loss did not improve from 1.44808
# 29601/29601 [==============================] - 13s 433us/sample - loss: 1.4471 - val_loss: 1.4483
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4433
# Epoch 87: val_loss improved from 1.44808 to 1.44742, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 13s 448us/sample - loss: 1.4433 - val_loss: 1.4474
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4458
# Epoch 88: val_loss improved from 1.44742 to 1.44102, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 12s 401us/sample - loss: 1.4458 - val_loss: 1.4410
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4440
# Epoch 89: val_loss did not improve from 1.44102
# 29601/29601 [==============================] - 12s 400us/sample - loss: 1.4440 - val_loss: 1.4440
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4446
# Epoch 90: val_loss did not improve from 1.44102
# 29601/29601 [==============================] - 13s 432us/sample - loss: 1.4446 - val_loss: 1.4443
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4424
# Epoch 91: val_loss did not improve from 1.44102
# 29601/29601 [==============================] - 14s 467us/sample - loss: 1.4424 - val_loss: 1.4420
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4413
# Epoch 92: val_loss improved from 1.44102 to 1.44068, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 468us/sample - loss: 1.4413 - val_loss: 1.4407
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4423
# Epoch 93: val_loss improved from 1.44068 to 1.43705, saving model to ./checkpoints/Adaptive_prune_model_only_audio_0.h5
# 29601/29601 [==============================] - 14s 470us/sample - loss: 1.4423 - val_loss: 1.4370
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4392
# Epoch 94: val_loss did not improve from 1.43705
# 29601/29601 [==============================] - 12s 415us/sample - loss: 1.4392 - val_loss: 1.4400
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4420
# Epoch 95: val_loss did not improve from 1.43705
# 29601/29601 [==============================] - 13s 440us/sample - loss: 1.4420 - val_loss: 1.4393
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4394
# Epoch 96: val_loss did not improve from 1.43705
# 29601/29601 [==============================] - 14s 457us/sample - loss: 1.4394 - val_loss: 1.4390
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4388
# Epoch 97: val_loss did not improve from 1.43705
# 29601/29601 [==============================] - 13s 447us/sample - loss: 1.4388 - val_loss: 1.4419
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4387
# Epoch 98: val_loss did not improve from 1.43705
# 29601/29601 [==============================] - 13s 437us/sample - loss: 1.4387 - val_loss: 1.4401
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4389
# Epoch 99: val_loss did not improve from 1.43705
# 29601/29601 [==============================] - 14s 460us/sample - loss: 1.4389 - val_loss: 1.4465
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4368
# Epoch 100: val_loss did not improve from 1.43705
# 29601/29601 [==============================] - 14s 461us/sample - loss: 1.4368 - val_loss: 1.4444
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4374
# Epoch 1: val_loss improved from inf to 1.43688, saving model to ./checkpoints/Adaptive_prune_model_only_audio_1.h5
# 29601/29601 [==============================] - 12s 415us/sample - loss: 1.4374 - val_loss: 1.4369
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4391
# Epoch 2: val_loss improved from 1.43688 to 1.43528, saving model to ./checkpoints/Adaptive_prune_model_only_audio_1.h5
# 29601/29601 [==============================] - 14s 460us/sample - loss: 1.4391 - val_loss: 1.4353
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4365
# Epoch 3: val_loss did not improve from 1.43528
# 29601/29601 [==============================] - 14s 467us/sample - loss: 1.4365 - val_loss: 1.4387
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4356
# Epoch 4: val_loss improved from 1.43528 to 1.43324, saving model to ./checkpoints/Adaptive_prune_model_only_audio_1.h5
# 29601/29601 [==============================] - 14s 474us/sample - loss: 1.4356 - val_loss: 1.4332
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4340
# Epoch 5: val_loss did not improve from 1.43324
# 29601/29601 [==============================] - 14s 466us/sample - loss: 1.4340 - val_loss: 1.4350
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4340
# Epoch 6: val_loss did not improve from 1.43324
# 29601/29601 [==============================] - 14s 469us/sample - loss: 1.4340 - val_loss: 1.4371
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4313
# Epoch 7: val_loss did not improve from 1.43324
# 29601/29601 [==============================] - 14s 465us/sample - loss: 1.4313 - val_loss: 1.4386
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4319
# Epoch 8: val_loss did not improve from 1.43324
# 29601/29601 [==============================] - 13s 429us/sample - loss: 1.4319 - val_loss: 1.4391
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4333
# Epoch 9: val_loss did not improve from 1.43324
# 29601/29601 [==============================] - 13s 429us/sample - loss: 1.4333 - val_loss: 1.4370
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4290
# Epoch 10: val_loss improved from 1.43324 to 1.42662, saving model to ./checkpoints/Adaptive_prune_model_only_audio_1.h5
# 29601/29601 [==============================] - 14s 468us/sample - loss: 1.4290 - val_loss: 1.4266
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4280
# Epoch 11: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 13s 431us/sample - loss: 1.4280 - val_loss: 1.4313
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4306
# Epoch 12: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 12s 409us/sample - loss: 1.4306 - val_loss: 1.4321
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4270
# Epoch 13: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 13s 441us/sample - loss: 1.4270 - val_loss: 1.4294
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4298
# Epoch 14: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 12s 404us/sample - loss: 1.4298 - val_loss: 1.4298
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4267
# Epoch 15: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 12s 405us/sample - loss: 1.4267 - val_loss: 1.4336
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4245
# Epoch 16: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 13s 431us/sample - loss: 1.4245 - val_loss: 1.4334
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4280
# Epoch 17: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 14s 466us/sample - loss: 1.4280 - val_loss: 1.4312
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4268
# Epoch 18: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 13s 426us/sample - loss: 1.4268 - val_loss: 1.4320
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4238
# Epoch 19: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 12s 415us/sample - loss: 1.4238 - val_loss: 1.4320
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4238
# Epoch 20: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 12s 409us/sample - loss: 1.4238 - val_loss: 1.4285
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4224
# Epoch 21: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 13s 449us/sample - loss: 1.4224 - val_loss: 1.4311
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4229
# Epoch 22: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 14s 470us/sample - loss: 1.4229 - val_loss: 1.4272
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4221
# Epoch 23: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 13s 441us/sample - loss: 1.4221 - val_loss: 1.4288
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4209
# Epoch 24: val_loss did not improve from 1.42662
# 29601/29601 [==============================] - 14s 463us/sample - loss: 1.4209 - val_loss: 1.4273
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4223
# Epoch 25: val_loss improved from 1.42662 to 1.42556, saving model to ./checkpoints/Adaptive_prune_model_only_audio_1.h5
# 29601/29601 [==============================] - 14s 473us/sample - loss: 1.4223 - val_loss: 1.4256
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4201
# Epoch 26: val_loss did not improve from 1.42556
# 29601/29601 [==============================] - 13s 442us/sample - loss: 1.4201 - val_loss: 1.4316
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4226
# Epoch 27: val_loss did not improve from 1.42556
# 29601/29601 [==============================] - 12s 417us/sample - loss: 1.4226 - val_loss: 1.4339
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4225
# Epoch 28: val_loss did not improve from 1.42556
# 29601/29601 [==============================] - 13s 426us/sample - loss: 1.4225 - val_loss: 1.4316
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4223
# Epoch 29: val_loss did not improve from 1.42556
# 29601/29601 [==============================] - 12s 420us/sample - loss: 1.4223 - val_loss: 1.4272
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4209
# Epoch 30: val_loss did not improve from 1.42556
# 29601/29601 [==============================] - 13s 423us/sample - loss: 1.4209 - val_loss: 1.4289
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4220
# Epoch 31: val_loss did not improve from 1.42556
# 29601/29601 [==============================] - 13s 428us/sample - loss: 1.4220 - val_loss: 1.4262
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4175
# Epoch 32: val_loss did not improve from 1.42556
# 29601/29601 [==============================] - 13s 422us/sample - loss: 1.4175 - val_loss: 1.4270
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4167
# Epoch 33: val_loss improved from 1.42556 to 1.42466, saving model to ./checkpoints/Adaptive_prune_model_only_audio_1.h5
# 29601/29601 [==============================] - 12s 415us/sample - loss: 1.4167 - val_loss: 1.4247
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4230
# Epoch 34: val_loss did not improve from 1.42466
# 29601/29601 [==============================] - 12s 410us/sample - loss: 1.4230 - val_loss: 1.4277
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4169
# Epoch 35: val_loss did not improve from 1.42466
# 29601/29601 [==============================] - 12s 416us/sample - loss: 1.4169 - val_loss: 1.4248
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4167
# Epoch 36: val_loss did not improve from 1.42466
# 29601/29601 [==============================] - 12s 420us/sample - loss: 1.4167 - val_loss: 1.4261
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4170
# Epoch 37: val_loss did not improve from 1.42466
# 29601/29601 [==============================] - 12s 404us/sample - loss: 1.4170 - val_loss: 1.4258
# Epoch 38/100
# ...
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3613
# Epoch 32: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 455us/sample - loss: 1.3613 - val_loss: 1.4211
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3654
# Epoch 33: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3654 - val_loss: 1.4213
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3649
# Epoch 34: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 446us/sample - loss: 1.3649 - val_loss: 1.4248
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3663
# Epoch 35: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 447us/sample - loss: 1.3663 - val_loss: 1.4208
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3658
# Epoch 36: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 433us/sample - loss: 1.3658 - val_loss: 1.4252
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3688
# Epoch 37: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 448us/sample - loss: 1.3688 - val_loss: 1.4306
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3707
# Epoch 38: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 403us/sample - loss: 1.3707 - val_loss: 1.4243
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3704
# Epoch 39: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 405us/sample - loss: 1.3704 - val_loss: 1.4282
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3786
# Epoch 40: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.3786 - val_loss: 1.4279
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3689
# Epoch 41: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 420us/sample - loss: 1.3689 - val_loss: 1.4226
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3747
# Epoch 42: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 435us/sample - loss: 1.3747 - val_loss: 1.4292
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3740
# Epoch 43: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 397us/sample - loss: 1.3740 - val_loss: 1.4314
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3792
# Epoch 44: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 401us/sample - loss: 1.3792 - val_loss: 1.4262
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3796
# Epoch 45: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 445us/sample - loss: 1.3796 - val_loss: 1.4272
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3814
# Epoch 46: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 449us/sample - loss: 1.3814 - val_loss: 1.4295
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3859
# Epoch 47: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 450us/sample - loss: 1.3859 - val_loss: 1.4328
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3874
# Epoch 48: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 396us/sample - loss: 1.3874 - val_loss: 1.4275
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3925
# Epoch 49: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 445us/sample - loss: 1.3925 - val_loss: 1.4359
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3885
# Epoch 50: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 391us/sample - loss: 1.3885 - val_loss: 1.4301
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3891
# Epoch 51: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 409us/sample - loss: 1.3891 - val_loss: 1.4316
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3921
# Epoch 52: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 414us/sample - loss: 1.3921 - val_loss: 1.4241
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3931
# Epoch 53: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 437us/sample - loss: 1.3931 - val_loss: 1.4292
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3944
# Epoch 54: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.3944 - val_loss: 1.4275
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3907
# Epoch 55: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.3907 - val_loss: 1.4250
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3903
# Epoch 56: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.3903 - val_loss: 1.4274
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3870
# Epoch 57: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 407us/sample - loss: 1.3870 - val_loss: 1.4279
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3902
# Epoch 58: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 408us/sample - loss: 1.3902 - val_loss: 1.4243
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3909
# Epoch 59: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.3909 - val_loss: 1.4259
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3866
# Epoch 60: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 435us/sample - loss: 1.3866 - val_loss: 1.4255
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3854
# Epoch 61: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 389us/sample - loss: 1.3854 - val_loss: 1.4280
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3860
# Epoch 62: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 431us/sample - loss: 1.3860 - val_loss: 1.4271
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3859
# Epoch 63: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 437us/sample - loss: 1.3859 - val_loss: 1.4266
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3825
# Epoch 64: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 389us/sample - loss: 1.3825 - val_loss: 1.4260
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3823
# Epoch 65: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 442us/sample - loss: 1.3823 - val_loss: 1.4248
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3852
# Epoch 66: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 448us/sample - loss: 1.3852 - val_loss: 1.4268
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3837
# Epoch 67: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 414us/sample - loss: 1.3837 - val_loss: 1.4276
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3836
# Epoch 68: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 11s 384us/sample - loss: 1.3836 - val_loss: 1.4291
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3799
# Epoch 69: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 11s 387us/sample - loss: 1.3799 - val_loss: 1.4226
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3825
# Epoch 70: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 12s 414us/sample - loss: 1.3825 - val_loss: 1.4258
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3790
# Epoch 71: val_loss did not improve from 1.41963
# 29601/29601 [==============================] - 13s 450us/sample - loss: 1.3790 - val_loss: 1.4256
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3820
# Epoch 72: val_loss improved from 1.41963 to 1.41903, saving model to ./checkpoints/Adaptive_prune_model_only_audio_9.h5
# 29601/29601 [==============================] - 12s 419us/sample - loss: 1.3820 - val_loss: 1.4190
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3815
# Epoch 73: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 13s 432us/sample - loss: 1.3815 - val_loss: 1.4229
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3799
# Epoch 74: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 13s 450us/sample - loss: 1.3799 - val_loss: 1.4257
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3775
# Epoch 75: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 12s 417us/sample - loss: 1.3775 - val_loss: 1.4301
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3802
# Epoch 76: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 12s 412us/sample - loss: 1.3802 - val_loss: 1.4245
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3776
# Epoch 77: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.3776 - val_loss: 1.4224
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3781
# Epoch 78: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.3781 - val_loss: 1.4243
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3781
# Epoch 79: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 13s 448us/sample - loss: 1.3781 - val_loss: 1.4199
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3778
# Epoch 80: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.3778 - val_loss: 1.4258
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3743
# Epoch 81: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 13s 450us/sample - loss: 1.3743 - val_loss: 1.4227
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3752
# Epoch 82: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 12s 407us/sample - loss: 1.3752 - val_loss: 1.4251
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3738
# Epoch 83: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 12s 394us/sample - loss: 1.3738 - val_loss: 1.4237
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3759
# Epoch 84: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 12s 396us/sample - loss: 1.3759 - val_loss: 1.4205
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3749
# Epoch 85: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.3749 - val_loss: 1.4240
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3741
# Epoch 86: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 13s 440us/sample - loss: 1.3741 - val_loss: 1.4215
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3726
# Epoch 87: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 13s 447us/sample - loss: 1.3726 - val_loss: 1.4197
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3760
# Epoch 88: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 13s 437us/sample - loss: 1.3760 - val_loss: 1.4276
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3745
# Epoch 89: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 11s 384us/sample - loss: 1.3745 - val_loss: 1.4266
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3745
# Epoch 90: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 11s 385us/sample - loss: 1.3745 - val_loss: 1.4230
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3736
# Epoch 91: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 12s 391us/sample - loss: 1.3736 - val_loss: 1.4206
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3748
# Epoch 92: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 12s 413us/sample - loss: 1.3748 - val_loss: 1.4229
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3732
# Epoch 93: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 13s 442us/sample - loss: 1.3732 - val_loss: 1.4262
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3693
# Epoch 94: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 12s 395us/sample - loss: 1.3693 - val_loss: 1.4252
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3721
# Epoch 95: val_loss did not improve from 1.41903
# 29601/29601 [==============================] - 12s 392us/sample - loss: 1.3721 - val_loss: 1.4240
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3721
# Epoch 96: val_loss improved from 1.41903 to 1.41565, saving model to ./checkpoints/Adaptive_prune_model_only_audio_9.h5
# 29601/29601 [==============================] - 12s 414us/sample - loss: 1.3721 - val_loss: 1.4157
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3731
# Epoch 97: val_loss did not improve from 1.41565
# 29601/29601 [==============================] - 13s 449us/sample - loss: 1.3731 - val_loss: 1.4207
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3703
# Epoch 98: val_loss did not improve from 1.41565
# 29601/29601 [==============================] - 13s 448us/sample - loss: 1.3703 - val_loss: 1.4189
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3680
# Epoch 99: val_loss did not improve from 1.41565
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.3680 - val_loss: 1.4276
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3713
# Epoch 100: val_loss did not improve from 1.41565
# 29601/29601 [==============================] - 13s 449us/sample - loss: 1.3713 - val_loss: 1.4248
