# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Feature_extraction_remove_fft_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-07 16:09:21.960098: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:21.971511: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:21.971753: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:21.975771: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:21.975966: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:21.976135: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:22.055119: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:22.055422: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:22.055593: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:22.055736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-07 16:09:22.056128: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-07 16:09:22.977380: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:22.977721: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:22.977913: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:22.978128: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:22.978306: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 16:09:22.978445: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-07 16:09:22.978476: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-07 16:09:23.000854: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-07 16:09:23.218699: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_19/lstm_cell_19/kernel/Assign' id:3151 op device:{requested: '', assigned: ''} def:{{{node lstm_19/lstm_cell_19/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_19/lstm_cell_19/kernel, lstm_19/lstm_cell_19/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-07 16:09:23.352652: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:3634 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-07 16:09:23.385908: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:3635 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 95)
# Train on 29601 samples, validate on 3694 samples
# 2023-11-07 16:09:27.704830: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_7/lstm_cell_7/bias/v/Assign' id:16714 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_7/lstm_cell_7/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_7/lstm_cell_7/bias/v, training/Adam/lstm_7/lstm_cell_7/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-11-07 16:09:31.409818: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-07 16:09:33.467958: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-07 16:09:33.481132: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 29601/29601 [==============================] - ETA: 0s - loss: 3.1407
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-07 16:09:53.732035: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:6312 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 1.92140, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 27s 920us/sample - loss: 3.1407 - val_loss: 1.9214
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.7916
# Epoch 2: val_loss improved from 1.92140 to 1.60734, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.7916 - val_loss: 1.6073
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5988
# Epoch 3: val_loss improved from 1.60734 to 1.54986, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 18s 609us/sample - loss: 1.5988 - val_loss: 1.5499
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5455
# Epoch 4: val_loss improved from 1.54986 to 1.51616, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 669us/sample - loss: 1.5455 - val_loss: 1.5162
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5183
# Epoch 5: val_loss improved from 1.51616 to 1.49413, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 680us/sample - loss: 1.5183 - val_loss: 1.4941
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4999
# Epoch 6: val_loss improved from 1.49413 to 1.48073, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 19s 653us/sample - loss: 1.4999 - val_loss: 1.4807
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4902
# Epoch 7: val_loss improved from 1.48073 to 1.47034, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.4902 - val_loss: 1.4703
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4822
# Epoch 8: val_loss did not improve from 1.47034
# 29601/29601 [==============================] - 19s 639us/sample - loss: 1.4822 - val_loss: 1.4707
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4736
# Epoch 9: val_loss improved from 1.47034 to 1.45683, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.4736 - val_loss: 1.4568
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4642
# Epoch 10: val_loss improved from 1.45683 to 1.44741, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 19s 653us/sample - loss: 1.4642 - val_loss: 1.4474
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4584
# Epoch 11: val_loss improved from 1.44741 to 1.43992, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 683us/sample - loss: 1.4584 - val_loss: 1.4399
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4524
# Epoch 12: val_loss improved from 1.43992 to 1.43811, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 665us/sample - loss: 1.4524 - val_loss: 1.4381
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4464
# Epoch 13: val_loss improved from 1.43811 to 1.42601, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 19s 650us/sample - loss: 1.4464 - val_loss: 1.4260
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4408
# Epoch 14: val_loss did not improve from 1.42601
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.4408 - val_loss: 1.4288
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4369
# Epoch 15: val_loss improved from 1.42601 to 1.42578, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 19s 644us/sample - loss: 1.4369 - val_loss: 1.4258
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4308
# Epoch 16: val_loss improved from 1.42578 to 1.41931, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 19s 659us/sample - loss: 1.4308 - val_loss: 1.4193
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4297
# Epoch 17: val_loss improved from 1.41931 to 1.41798, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.4297 - val_loss: 1.4180
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4293
# Epoch 18: val_loss improved from 1.41798 to 1.41403, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.4293 - val_loss: 1.4140
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4225
# Epoch 19: val_loss improved from 1.41403 to 1.40675, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 18s 593us/sample - loss: 1.4225 - val_loss: 1.4067
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4186
# Epoch 20: val_loss did not improve from 1.40675
# 29601/29601 [==============================] - 20s 674us/sample - loss: 1.4186 - val_loss: 1.4106
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4154
# Epoch 21: val_loss improved from 1.40675 to 1.40190, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.4154 - val_loss: 1.4019
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4135
# Epoch 22: val_loss did not improve from 1.40190
# 29601/29601 [==============================] - 20s 674us/sample - loss: 1.4135 - val_loss: 1.4060
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4142
# Epoch 23: val_loss improved from 1.40190 to 1.39929, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 680us/sample - loss: 1.4142 - val_loss: 1.3993
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4107
# Epoch 24: val_loss did not improve from 1.39929
# 29601/29601 [==============================] - 20s 675us/sample - loss: 1.4107 - val_loss: 1.4003
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4056
# Epoch 25: val_loss improved from 1.39929 to 1.39799, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.4056 - val_loss: 1.3980
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4039
# Epoch 26: val_loss did not improve from 1.39799
# 29601/29601 [==============================] - 20s 671us/sample - loss: 1.4039 - val_loss: 1.3988
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4061
# Epoch 27: val_loss did not improve from 1.39799
# 29601/29601 [==============================] - 19s 637us/sample - loss: 1.4061 - val_loss: 1.3992
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4009
# Epoch 28: val_loss improved from 1.39799 to 1.39650, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.4009 - val_loss: 1.3965
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3987
# Epoch 29: val_loss improved from 1.39650 to 1.39473, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.3987 - val_loss: 1.3947
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3978
# Epoch 30: val_loss improved from 1.39473 to 1.39451, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 19s 627us/sample - loss: 1.3978 - val_loss: 1.3945
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3957
# Epoch 31: val_loss improved from 1.39451 to 1.39150, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 19s 643us/sample - loss: 1.3957 - val_loss: 1.3915
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3937
# Epoch 32: val_loss improved from 1.39150 to 1.39048, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 18s 606us/sample - loss: 1.3937 - val_loss: 1.3905
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3937
# Epoch 33: val_loss did not improve from 1.39048
# 29601/29601 [==============================] - 18s 593us/sample - loss: 1.3937 - val_loss: 1.4009
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3927
# Epoch 34: val_loss improved from 1.39048 to 1.38878, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 663us/sample - loss: 1.3927 - val_loss: 1.3888
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3931
# Epoch 35: val_loss did not improve from 1.38878
# 29601/29601 [==============================] - 20s 675us/sample - loss: 1.3931 - val_loss: 1.3895
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3878
# Epoch 36: val_loss did not improve from 1.38878
# 29601/29601 [==============================] - 20s 672us/sample - loss: 1.3878 - val_loss: 1.3913
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3839
# Epoch 37: val_loss improved from 1.38878 to 1.38823, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 18s 606us/sample - loss: 1.3839 - val_loss: 1.3882
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3819
# Epoch 38: val_loss improved from 1.38823 to 1.38042, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 668us/sample - loss: 1.3819 - val_loss: 1.3804
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3804
# Epoch 39: val_loss did not improve from 1.38042
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.3804 - val_loss: 1.3813
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3778
# Epoch 40: val_loss did not improve from 1.38042
# 29601/29601 [==============================] - 20s 667us/sample - loss: 1.3778 - val_loss: 1.3871
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3772
# Epoch 41: val_loss improved from 1.38042 to 1.37856, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.3772 - val_loss: 1.3786
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3761
# Epoch 42: val_loss improved from 1.37856 to 1.37463, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 670us/sample - loss: 1.3761 - val_loss: 1.3746
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3780
# Epoch 43: val_loss did not improve from 1.37463
# 29601/29601 [==============================] - 19s 634us/sample - loss: 1.3780 - val_loss: 1.3754
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3750
# Epoch 44: val_loss did not improve from 1.37463
# 29601/29601 [==============================] - 20s 673us/sample - loss: 1.3750 - val_loss: 1.3764
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3717
# Epoch 45: val_loss did not improve from 1.37463
# 29601/29601 [==============================] - 20s 671us/sample - loss: 1.3717 - val_loss: 1.3754
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3699
# Epoch 46: val_loss improved from 1.37463 to 1.37460, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.3699 - val_loss: 1.3746
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3670
# Epoch 47: val_loss improved from 1.37460 to 1.36956, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 676us/sample - loss: 1.3670 - val_loss: 1.3696
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3645
# Epoch 48: val_loss did not improve from 1.36956
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.3645 - val_loss: 1.3711
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3655
# Epoch 49: val_loss did not improve from 1.36956
# 29601/29601 [==============================] - 19s 632us/sample - loss: 1.3655 - val_loss: 1.3713
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3631
# Epoch 50: val_loss did not improve from 1.36956
# 29601/29601 [==============================] - 20s 676us/sample - loss: 1.3631 - val_loss: 1.3697
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3621
# Epoch 51: val_loss did not improve from 1.36956
# 29601/29601 [==============================] - 19s 654us/sample - loss: 1.3621 - val_loss: 1.3748
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3596
# Epoch 52: val_loss improved from 1.36956 to 1.36729, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 18s 612us/sample - loss: 1.3596 - val_loss: 1.3673
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3605
# Epoch 53: val_loss did not improve from 1.36729
# 29601/29601 [==============================] - 18s 617us/sample - loss: 1.3605 - val_loss: 1.3711
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3590
# Epoch 54: val_loss improved from 1.36729 to 1.36180, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 19s 651us/sample - loss: 1.3590 - val_loss: 1.3618
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3586
# Epoch 55: val_loss did not improve from 1.36180
# 29601/29601 [==============================] - 20s 674us/sample - loss: 1.3586 - val_loss: 1.3683
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3562
# Epoch 56: val_loss did not improve from 1.36180
# 29601/29601 [==============================] - 18s 622us/sample - loss: 1.3562 - val_loss: 1.3666
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3542
# Epoch 57: val_loss did not improve from 1.36180
# 29601/29601 [==============================] - 18s 618us/sample - loss: 1.3542 - val_loss: 1.3753
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3526
# Epoch 58: val_loss did not improve from 1.36180
# 29601/29601 [==============================] - 20s 676us/sample - loss: 1.3526 - val_loss: 1.3651
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3492
# Epoch 59: val_loss did not improve from 1.36180
# 29601/29601 [==============================] - 19s 638us/sample - loss: 1.3492 - val_loss: 1.3649
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3519
# Epoch 60: val_loss improved from 1.36180 to 1.35944, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 679us/sample - loss: 1.3519 - val_loss: 1.3594
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3526
# Epoch 61: val_loss did not improve from 1.35944
# 29601/29601 [==============================] - 20s 673us/sample - loss: 1.3526 - val_loss: 1.3660
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3527
# Epoch 62: val_loss did not improve from 1.35944
# 29601/29601 [==============================] - 20s 669us/sample - loss: 1.3527 - val_loss: 1.3646
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3466
# Epoch 63: val_loss did not improve from 1.35944
# 29601/29601 [==============================] - 20s 673us/sample - loss: 1.3466 - val_loss: 1.3639
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3468
# Epoch 64: val_loss did not improve from 1.35944
# 29601/29601 [==============================] - 20s 673us/sample - loss: 1.3468 - val_loss: 1.3660
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3438
# Epoch 65: val_loss did not improve from 1.35944
# 29601/29601 [==============================] - 19s 657us/sample - loss: 1.3438 - val_loss: 1.3654
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3408
# Epoch 66: val_loss did not improve from 1.35944
# 29601/29601 [==============================] - 20s 672us/sample - loss: 1.3408 - val_loss: 1.3620
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3376
# Epoch 67: val_loss did not improve from 1.35944
# 29601/29601 [==============================] - 20s 672us/sample - loss: 1.3376 - val_loss: 1.3632
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3410
# Epoch 68: val_loss did not improve from 1.35944
# 29601/29601 [==============================] - 20s 661us/sample - loss: 1.3410 - val_loss: 1.3630
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3406
# Epoch 69: val_loss did not improve from 1.35944
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.3406 - val_loss: 1.3656
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3388
# Epoch 70: val_loss improved from 1.35944 to 1.35545, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.3388 - val_loss: 1.3554
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3370
# Epoch 71: val_loss did not improve from 1.35545
# 29601/29601 [==============================] - 19s 640us/sample - loss: 1.3370 - val_loss: 1.3607
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3364
# Epoch 72: val_loss did not improve from 1.35545
# 29601/29601 [==============================] - 20s 674us/sample - loss: 1.3364 - val_loss: 1.3581
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3343
# Epoch 73: val_loss did not improve from 1.35545
# 29601/29601 [==============================] - 20s 669us/sample - loss: 1.3343 - val_loss: 1.3577
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3366
# Epoch 74: val_loss did not improve from 1.35545
# 29601/29601 [==============================] - 17s 588us/sample - loss: 1.3366 - val_loss: 1.3613
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3335
# Epoch 75: val_loss improved from 1.35545 to 1.35307, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 20s 680us/sample - loss: 1.3335 - val_loss: 1.3531
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3330
# Epoch 76: val_loss did not improve from 1.35307
# 29601/29601 [==============================] - 19s 640us/sample - loss: 1.3330 - val_loss: 1.3643
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3288
# Epoch 77: val_loss did not improve from 1.35307
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.3288 - val_loss: 1.3590
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3309
# Epoch 78: val_loss did not improve from 1.35307
# 29601/29601 [==============================] - 19s 656us/sample - loss: 1.3309 - val_loss: 1.3616
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3287
# Epoch 79: val_loss did not improve from 1.35307
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3287 - val_loss: 1.3531
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3306
# Epoch 80: val_loss did not improve from 1.35307
# 29601/29601 [==============================] - 17s 579us/sample - loss: 1.3306 - val_loss: 1.3571
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3275
# Epoch 81: val_loss did not improve from 1.35307
# 29601/29601 [==============================] - 17s 582us/sample - loss: 1.3275 - val_loss: 1.3567
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3261
# Epoch 82: val_loss did not improve from 1.35307
# 29601/29601 [==============================] - 17s 579us/sample - loss: 1.3261 - val_loss: 1.3568
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3271
# Epoch 83: val_loss improved from 1.35307 to 1.35100, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.3271 - val_loss: 1.3510
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3248
# Epoch 84: val_loss did not improve from 1.35100
# 29601/29601 [==============================] - 19s 651us/sample - loss: 1.3248 - val_loss: 1.3550
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3233
# Epoch 85: val_loss did not improve from 1.35100
# 29601/29601 [==============================] - 20s 671us/sample - loss: 1.3233 - val_loss: 1.3547
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3244
# Epoch 86: val_loss did not improve from 1.35100
# 29601/29601 [==============================] - 20s 676us/sample - loss: 1.3244 - val_loss: 1.3570
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3209
# Epoch 87: val_loss did not improve from 1.35100
# 29601/29601 [==============================] - 20s 674us/sample - loss: 1.3209 - val_loss: 1.3521
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3204
# Epoch 88: val_loss did not improve from 1.35100
# 29601/29601 [==============================] - 19s 630us/sample - loss: 1.3204 - val_loss: 1.3526
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3191
# Epoch 89: val_loss did not improve from 1.35100
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.3191 - val_loss: 1.3553
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3218
# Epoch 90: val_loss did not improve from 1.35100
# 29601/29601 [==============================] - 17s 587us/sample - loss: 1.3218 - val_loss: 1.3533
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3188
# Epoch 91: val_loss did not improve from 1.35100
# 29601/29601 [==============================] - 17s 584us/sample - loss: 1.3188 - val_loss: 1.3528
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3173
# Epoch 92: val_loss did not improve from 1.35100
# 29601/29601 [==============================] - 18s 604us/sample - loss: 1.3173 - val_loss: 1.3518
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3165
# Epoch 93: val_loss did not improve from 1.35100
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.3165 - val_loss: 1.3543
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3133
# Epoch 94: val_loss did not improve from 1.35100
# 29601/29601 [==============================] - 18s 614us/sample - loss: 1.3133 - val_loss: 1.3512
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3154
# Epoch 95: val_loss improved from 1.35100 to 1.34918, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 19s 654us/sample - loss: 1.3154 - val_loss: 1.3492
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3133
# Epoch 96: val_loss did not improve from 1.34918
# 29601/29601 [==============================] - 20s 672us/sample - loss: 1.3133 - val_loss: 1.3497
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3123
# Epoch 97: val_loss improved from 1.34918 to 1.34917, saving model to ./checkpoints/Feature_extraction_remove_fft_0.h5
# 29601/29601 [==============================] - 18s 623us/sample - loss: 1.3123 - val_loss: 1.3492
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3114
# Epoch 98: val_loss did not improve from 1.34917
# 29601/29601 [==============================] - 18s 604us/sample - loss: 1.3114 - val_loss: 1.3497
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3095
# Epoch 99: val_loss did not improve from 1.34917
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.3095 - val_loss: 1.3538
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3102
# Epoch 100: val_loss did not improve from 1.34917
# 29601/29601 [==============================] - 17s 590us/sample - loss: 1.3102 - val_loss: 1.3548
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3099
# Epoch 1: val_loss improved from inf to 1.35705, saving model to ./checkpoints/Feature_extraction_remove_fft_1.h5
# 29601/29601 [==============================] - 18s 612us/sample - loss: 1.3099 - val_loss: 1.3571
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3115
# Epoch 2: val_loss improved from 1.35705 to 1.35543, saving model to ./checkpoints/Feature_extraction_remove_fft_1.h5
# 29601/29601 [==============================] - 17s 590us/sample - loss: 1.3115 - val_loss: 1.3554
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3091
# Epoch 3: val_loss improved from 1.35543 to 1.34961, saving model to ./checkpoints/Feature_extraction_remove_fft_1.h5
# 29601/29601 [==============================] - 19s 635us/sample - loss: 1.3091 - val_loss: 1.3496
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3080
# Epoch 4: val_loss improved from 1.34961 to 1.34778, saving model to ./checkpoints/Feature_extraction_remove_fft_1.h5
# 29601/29601 [==============================] - 20s 676us/sample - loss: 1.3080 - val_loss: 1.3478
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3037
# Epoch 5: val_loss did not improve from 1.34778
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.3037 - val_loss: 1.3548
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3024
# Epoch 6: val_loss improved from 1.34778 to 1.34609, saving model to ./checkpoints/Feature_extraction_remove_fft_1.h5
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.3024 - val_loss: 1.3461
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3041
# Epoch 7: val_loss improved from 1.34609 to 1.34296, saving model to ./checkpoints/Feature_extraction_remove_fft_1.h5
# 29601/29601 [==============================] - 19s 646us/sample - loss: 1.3041 - val_loss: 1.3430
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3033
# Epoch 8: val_loss did not improve from 1.34296
# 29601/29601 [==============================] - 18s 613us/sample - loss: 1.3033 - val_loss: 1.3487
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3031
# Epoch 9: val_loss did not improve from 1.34296
# 29601/29601 [==============================] - 20s 670us/sample - loss: 1.3031 - val_loss: 1.3527
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3006
# Epoch 10: val_loss did not improve from 1.34296
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.3006 - val_loss: 1.3470
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3036
# Epoch 11: val_loss did not improve from 1.34296
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.3036 - val_loss: 1.3482
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3022
# Epoch 12: val_loss did not improve from 1.34296
# 29601/29601 [==============================] - 17s 580us/sample - loss: 1.3022 - val_loss: 1.3552
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3007
# Epoch 13: val_loss did not improve from 1.34296
# 29601/29601 [==============================] - 17s 584us/sample - loss: 1.3007 - val_loss: 1.3518
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2998
# Epoch 14: val_loss did not improve from 1.34296
# 29601/29601 [==============================] - 18s 623us/sample - loss: 1.2998 - val_loss: 1.3447
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3004
# Epoch 15: val_loss did not improve from 1.34296
# 29601/29601 [==============================] - 18s 621us/sample - loss: 1.3004 - val_loss: 1.3467
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2999
# Epoch 16: val_loss did not improve from 1.34296
# 29601/29601 [==============================] - 18s 611us/sample - loss: 1.2999 - val_loss: 1.3464
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2998
# Epoch 17: val_loss did not improve from 1.34296
# 29601/29601 [==============================] - 20s 675us/sample - loss: 1.2998 - val_loss: 1.3497
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3002
# Epoch 18: val_loss did not improve from 1.34296
# 29601/29601 [==============================] - 20s 671us/sample - loss: 1.3002 - val_loss: 1.3520
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2989
# Epoch 19: val_loss did not improve from 1.34296
# 29601/29601 [==============================] - 19s 625us/sample - loss: 1.2989 - val_loss: 1.3520
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2953
# Epoch 20: val_loss improved from 1.34296 to 1.34256, saving model to ./checkpoints/Feature_extraction_remove_fft_1.h5
# 29601/29601 [==============================] - 17s 584us/sample - loss: 1.2953 - val_loss: 1.3426
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2932
# Epoch 21: val_loss did not improve from 1.34256
# 29601/29601 [==============================] - 18s 616us/sample - loss: 1.2932 - val_loss: 1.3496
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2987
# Epoch 22: val_loss did not improve from 1.34256
# 29601/29601 [==============================] - 19s 639us/sample - loss: 1.2987 - val_loss: 1.3478
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2937
# Epoch 23: val_loss improved from 1.34256 to 1.34001, saving model to ./checkpoints/Feature_extraction_remove_fft_1.h5
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.2937 - val_loss: 1.3400
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2961
# Epoch 24: val_loss did not improve from 1.34001
# 29601/29601 [==============================] - 18s 608us/sample - loss: 1.2961 - val_loss: 1.3562
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2958
# Epoch 25: val_loss did not improve from 1.34001
# 29601/29601 [==============================] - 20s 659us/sample - loss: 1.2958 - val_loss: 1.3431
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2947
# Epoch 26: val_loss did not improve from 1.34001
# 29601/29601 [==============================] - 17s 582us/sample - loss: 1.2947 - val_loss: 1.3401
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2924
# Epoch 27: val_loss did not improve from 1.34001
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.2924 - val_loss: 1.3484
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2896
# Epoch 28: val_loss did not improve from 1.34001
# 29601/29601 [==============================] - 18s 606us/sample - loss: 1.2896 - val_loss: 1.3503
# Epoch 29/100
# ...
# Epoch 31: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 651us/sample - loss: 1.2430 - val_loss: 1.3478
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2393
# Epoch 32: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.2393 - val_loss: 1.3422
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2445
# Epoch 33: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 629us/sample - loss: 1.2445 - val_loss: 1.3424
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2417
# Epoch 34: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 638us/sample - loss: 1.2417 - val_loss: 1.3430
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2479
# Epoch 35: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 658us/sample - loss: 1.2479 - val_loss: 1.3402
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2507
# Epoch 36: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 655us/sample - loss: 1.2507 - val_loss: 1.3367
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2487
# Epoch 37: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 657us/sample - loss: 1.2487 - val_loss: 1.3411
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2506
# Epoch 38: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 18s 619us/sample - loss: 1.2506 - val_loss: 1.3372
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2521
# Epoch 39: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.2521 - val_loss: 1.3382
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2582
# Epoch 40: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 648us/sample - loss: 1.2582 - val_loss: 1.3348
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2599
# Epoch 41: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 633us/sample - loss: 1.2599 - val_loss: 1.3383
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2606
# Epoch 42: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 568us/sample - loss: 1.2606 - val_loss: 1.3462
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2615
# Epoch 43: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 565us/sample - loss: 1.2615 - val_loss: 1.3468
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2590
# Epoch 44: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 18s 610us/sample - loss: 1.2590 - val_loss: 1.3442
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2657
# Epoch 45: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 649us/sample - loss: 1.2657 - val_loss: 1.3412
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2640
# Epoch 46: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 632us/sample - loss: 1.2640 - val_loss: 1.3485
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2696
# Epoch 47: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 563us/sample - loss: 1.2696 - val_loss: 1.3407
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2772
# Epoch 48: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 580us/sample - loss: 1.2772 - val_loss: 1.3450
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2750
# Epoch 49: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 562us/sample - loss: 1.2750 - val_loss: 1.3523
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2777
# Epoch 50: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 588us/sample - loss: 1.2777 - val_loss: 1.3385
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2885
# Epoch 51: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.2885 - val_loss: 1.3412
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2895
# Epoch 52: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 591us/sample - loss: 1.2895 - val_loss: 1.3480
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2878
# Epoch 53: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 564us/sample - loss: 1.2878 - val_loss: 1.3434
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2906
# Epoch 54: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 566us/sample - loss: 1.2906 - val_loss: 1.3470
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2869
# Epoch 55: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 564us/sample - loss: 1.2869 - val_loss: 1.3454
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2844
# Epoch 56: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 563us/sample - loss: 1.2844 - val_loss: 1.3511
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2862
# Epoch 57: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 562us/sample - loss: 1.2862 - val_loss: 1.3497
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2877
# Epoch 58: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 562us/sample - loss: 1.2877 - val_loss: 1.3452
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2840
# Epoch 59: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 562us/sample - loss: 1.2840 - val_loss: 1.3441
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2818
# Epoch 60: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 577us/sample - loss: 1.2818 - val_loss: 1.3527
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2827
# Epoch 61: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 649us/sample - loss: 1.2827 - val_loss: 1.3504
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2791
# Epoch 62: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.2791 - val_loss: 1.3440
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2815
# Epoch 63: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 649us/sample - loss: 1.2815 - val_loss: 1.3496
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2773
# Epoch 64: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 648us/sample - loss: 1.2773 - val_loss: 1.3471
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2744
# Epoch 65: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 648us/sample - loss: 1.2744 - val_loss: 1.3473
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2754
# Epoch 66: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.2754 - val_loss: 1.3513
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2740
# Epoch 67: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.2740 - val_loss: 1.3486
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2723
# Epoch 68: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 648us/sample - loss: 1.2723 - val_loss: 1.3446
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2709
# Epoch 69: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 646us/sample - loss: 1.2709 - val_loss: 1.3494
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2733
# Epoch 70: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 652us/sample - loss: 1.2733 - val_loss: 1.3507
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2687
# Epoch 71: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 652us/sample - loss: 1.2687 - val_loss: 1.3442
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2711
# Epoch 72: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 653us/sample - loss: 1.2711 - val_loss: 1.3441
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2697
# Epoch 73: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 649us/sample - loss: 1.2697 - val_loss: 1.3445
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2688
# Epoch 74: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 19s 651us/sample - loss: 1.2688 - val_loss: 1.3440
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2656
# Epoch 75: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 18s 617us/sample - loss: 1.2656 - val_loss: 1.3515
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2676
# Epoch 76: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 581us/sample - loss: 1.2676 - val_loss: 1.3485
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2653
# Epoch 77: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 579us/sample - loss: 1.2653 - val_loss: 1.3494
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2648
# Epoch 78: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 579us/sample - loss: 1.2648 - val_loss: 1.3465
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2662
# Epoch 79: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 578us/sample - loss: 1.2662 - val_loss: 1.3464
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2651
# Epoch 80: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 577us/sample - loss: 1.2651 - val_loss: 1.3434
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2657
# Epoch 81: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 573us/sample - loss: 1.2657 - val_loss: 1.3478
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2627
# Epoch 82: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 574us/sample - loss: 1.2627 - val_loss: 1.3509
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2621
# Epoch 83: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 569us/sample - loss: 1.2621 - val_loss: 1.3437
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2617
# Epoch 84: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 574us/sample - loss: 1.2617 - val_loss: 1.3442
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2630
# Epoch 85: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 574us/sample - loss: 1.2630 - val_loss: 1.3491
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2606
# Epoch 86: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 574us/sample - loss: 1.2606 - val_loss: 1.3510
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2589
# Epoch 87: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 577us/sample - loss: 1.2589 - val_loss: 1.3416
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2602
# Epoch 88: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 574us/sample - loss: 1.2602 - val_loss: 1.3496
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2572
# Epoch 89: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 574us/sample - loss: 1.2572 - val_loss: 1.3531
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2592
# Epoch 90: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 574us/sample - loss: 1.2592 - val_loss: 1.3502
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2577
# Epoch 91: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 570us/sample - loss: 1.2577 - val_loss: 1.3473
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2567
# Epoch 92: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 571us/sample - loss: 1.2567 - val_loss: 1.3452
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2589
# Epoch 93: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 567us/sample - loss: 1.2589 - val_loss: 1.3476
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2538
# Epoch 94: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 570us/sample - loss: 1.2538 - val_loss: 1.3510
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2565
# Epoch 95: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 569us/sample - loss: 1.2565 - val_loss: 1.3508
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2568
# Epoch 96: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 570us/sample - loss: 1.2568 - val_loss: 1.3396
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2566
# Epoch 97: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 570us/sample - loss: 1.2566 - val_loss: 1.3451
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2543
# Epoch 98: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 570us/sample - loss: 1.2543 - val_loss: 1.3441
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2519
# Epoch 99: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 569us/sample - loss: 1.2519 - val_loss: 1.3502
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2552
# Epoch 100: val_loss did not improve from 1.33468
# 29601/29601 [==============================] - 17s 568us/sample - loss: 1.2552 - val_loss: 1.3501
