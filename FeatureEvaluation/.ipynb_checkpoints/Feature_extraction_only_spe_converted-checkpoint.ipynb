# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-07 00:15:06.793586: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np


model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
# rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

# for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
model_name = './checkpoints/Feature_extraction_only_spe.h5'

checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
# pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=0.35, start_epoch=5, end_epoch=50, frequency=1)
model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-07 00:15:38.532447: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:38.546821: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:38.547090: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:38.551300: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:38.551511: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:38.551674: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:38.639740: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:38.640115: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:38.640335: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:38.640491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-07 00:15:38.640809: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 0)
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 2023-11-07 00:15:41.555451: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:41.555762: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:41.555953: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:41.556172: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:41.556354: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:15:41.556492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-07 00:15:41.556538: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-07 00:15:41.643533: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-07 00:15:41.960328: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_18/lstm_cell_18/kernel/v/Assign' id:10252 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_18/lstm_cell_18/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_18/lstm_cell_18/kernel/v, training/Adam/lstm_18/lstm_cell_18/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
#  1024/29601 [>.............................] - ETA: 1:12 - loss: 4.8974
# 2023-11-07 00:15:43.970525: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 29601/29601 [==============================] - ETA: 0s - loss: 4.2425
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-07 00:15:48.794715: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:3773 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 3.03495, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 9s 302us/sample - loss: 4.2425 - val_loss: 3.0350
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.9939
# Epoch 2: val_loss improved from 3.03495 to 1.62996, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 5s 153us/sample - loss: 1.9939 - val_loss: 1.6300
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6464
# Epoch 3: val_loss improved from 1.62996 to 1.60617, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 151us/sample - loss: 1.6464 - val_loss: 1.6062
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6177
# Epoch 4: val_loss improved from 1.60617 to 1.59396, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 5s 153us/sample - loss: 1.6177 - val_loss: 1.5940
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6081
# Epoch 5: val_loss improved from 1.59396 to 1.58786, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 151us/sample - loss: 1.6081 - val_loss: 1.5879
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5997
# Epoch 6: val_loss improved from 1.58786 to 1.58312, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 148us/sample - loss: 1.5997 - val_loss: 1.5831
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5964
# Epoch 7: val_loss improved from 1.58312 to 1.58139, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 148us/sample - loss: 1.5964 - val_loss: 1.5814
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5868
# Epoch 8: val_loss improved from 1.58139 to 1.57742, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 145us/sample - loss: 1.5868 - val_loss: 1.5774
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5807
# Epoch 9: val_loss improved from 1.57742 to 1.57355, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 146us/sample - loss: 1.5807 - val_loss: 1.5735
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5780
# Epoch 10: val_loss did not improve from 1.57355
# 29601/29601 [==============================] - 4s 144us/sample - loss: 1.5780 - val_loss: 1.5737
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5746
# Epoch 11: val_loss improved from 1.57355 to 1.56766, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 146us/sample - loss: 1.5746 - val_loss: 1.5677
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5723
# Epoch 12: val_loss did not improve from 1.56766
# 29601/29601 [==============================] - 4s 146us/sample - loss: 1.5723 - val_loss: 1.5708
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5702
# Epoch 13: val_loss did not improve from 1.56766
# 29601/29601 [==============================] - 4s 145us/sample - loss: 1.5702 - val_loss: 1.5744
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5684
# Epoch 14: val_loss improved from 1.56766 to 1.56298, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 5s 168us/sample - loss: 1.5684 - val_loss: 1.5630
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5659
# Epoch 15: val_loss improved from 1.56298 to 1.55996, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 5s 183us/sample - loss: 1.5659 - val_loss: 1.5600
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5607
# Epoch 16: val_loss did not improve from 1.55996
# 29601/29601 [==============================] - 5s 154us/sample - loss: 1.5607 - val_loss: 1.5610
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5588
# Epoch 17: val_loss improved from 1.55996 to 1.55021, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 150us/sample - loss: 1.5588 - val_loss: 1.5502
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5512
# Epoch 18: val_loss improved from 1.55021 to 1.54813, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 149us/sample - loss: 1.5512 - val_loss: 1.5481
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5508
# Epoch 19: val_loss improved from 1.54813 to 1.54325, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 151us/sample - loss: 1.5508 - val_loss: 1.5432
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5480
# Epoch 20: val_loss did not improve from 1.54325
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.5480 - val_loss: 1.5433
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5453
# Epoch 21: val_loss improved from 1.54325 to 1.53791, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.5453 - val_loss: 1.5379
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5422
# Epoch 22: val_loss did not improve from 1.53791
# 29601/29601 [==============================] - 4s 144us/sample - loss: 1.5422 - val_loss: 1.5397
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5375
# Epoch 23: val_loss improved from 1.53791 to 1.53564, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.5375 - val_loss: 1.5356
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5374
# Epoch 24: val_loss improved from 1.53564 to 1.53294, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 146us/sample - loss: 1.5374 - val_loss: 1.5329
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5359
# Epoch 25: val_loss did not improve from 1.53294
# 29601/29601 [==============================] - 4s 144us/sample - loss: 1.5359 - val_loss: 1.5335
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5333
# Epoch 26: val_loss did not improve from 1.53294
# 29601/29601 [==============================] - 4s 144us/sample - loss: 1.5333 - val_loss: 1.5343
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5293
# Epoch 27: val_loss improved from 1.53294 to 1.53238, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 148us/sample - loss: 1.5293 - val_loss: 1.5324
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5284
# Epoch 28: val_loss improved from 1.53238 to 1.52812, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.5284 - val_loss: 1.5281
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5271
# Epoch 29: val_loss did not improve from 1.52812
# 29601/29601 [==============================] - 4s 144us/sample - loss: 1.5271 - val_loss: 1.5300
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5240
# Epoch 30: val_loss improved from 1.52812 to 1.52418, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.5240 - val_loss: 1.5242
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5227
# Epoch 31: val_loss did not improve from 1.52418
# 29601/29601 [==============================] - 4s 144us/sample - loss: 1.5227 - val_loss: 1.5283
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5205
# Epoch 32: val_loss improved from 1.52418 to 1.52156, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 146us/sample - loss: 1.5205 - val_loss: 1.5216
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5210
# Epoch 33: val_loss did not improve from 1.52156
# 29601/29601 [==============================] - 4s 146us/sample - loss: 1.5210 - val_loss: 1.5228
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5152
# Epoch 34: val_loss improved from 1.52156 to 1.51768, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.5152 - val_loss: 1.5177
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5148
# Epoch 35: val_loss did not improve from 1.51768
# 29601/29601 [==============================] - 4s 145us/sample - loss: 1.5148 - val_loss: 1.5212
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5169
# Epoch 36: val_loss did not improve from 1.51768
# 29601/29601 [==============================] - 4s 144us/sample - loss: 1.5169 - val_loss: 1.5251
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5144
# Epoch 37: val_loss improved from 1.51768 to 1.51419, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 146us/sample - loss: 1.5144 - val_loss: 1.5142
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5137
# Epoch 38: val_loss did not improve from 1.51419
# 29601/29601 [==============================] - 4s 144us/sample - loss: 1.5137 - val_loss: 1.5152
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5119
# Epoch 39: val_loss improved from 1.51419 to 1.51035, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 146us/sample - loss: 1.5119 - val_loss: 1.5103
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5093
# Epoch 40: val_loss improved from 1.51035 to 1.50980, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 145us/sample - loss: 1.5093 - val_loss: 1.5098
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5100
# Epoch 41: val_loss improved from 1.50980 to 1.50891, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 150us/sample - loss: 1.5100 - val_loss: 1.5089
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5090
# Epoch 42: val_loss did not improve from 1.50891
# 29601/29601 [==============================] - 4s 146us/sample - loss: 1.5090 - val_loss: 1.5143
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5077
# Epoch 43: val_loss improved from 1.50891 to 1.50877, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 151us/sample - loss: 1.5077 - val_loss: 1.5088
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5036
# Epoch 44: val_loss improved from 1.50877 to 1.50452, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 5s 181us/sample - loss: 1.5036 - val_loss: 1.5045
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5058
# Epoch 45: val_loss did not improve from 1.50452
# 29601/29601 [==============================] - 5s 179us/sample - loss: 1.5058 - val_loss: 1.5052
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5048
# Epoch 46: val_loss did not improve from 1.50452
# 29601/29601 [==============================] - 5s 181us/sample - loss: 1.5048 - val_loss: 1.5065
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5013
# Epoch 47: val_loss did not improve from 1.50452
# 29601/29601 [==============================] - 5s 168us/sample - loss: 1.5013 - val_loss: 1.5046
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5021
# Epoch 48: val_loss did not improve from 1.50452
# 29601/29601 [==============================] - 4s 145us/sample - loss: 1.5021 - val_loss: 1.5081
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5016
# Epoch 49: val_loss improved from 1.50452 to 1.50166, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.5016 - val_loss: 1.5017
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5010
# Epoch 50: val_loss did not improve from 1.50166
# 29601/29601 [==============================] - 4s 145us/sample - loss: 1.5010 - val_loss: 1.5071
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4999
# Epoch 51: val_loss did not improve from 1.50166
# 29601/29601 [==============================] - 4s 145us/sample - loss: 1.4999 - val_loss: 1.5066
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4994
# Epoch 52: val_loss did not improve from 1.50166
# 29601/29601 [==============================] - 4s 145us/sample - loss: 1.4994 - val_loss: 1.5035
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4958
# Epoch 53: val_loss did not improve from 1.50166
# 29601/29601 [==============================] - 4s 144us/sample - loss: 1.4958 - val_loss: 1.5038
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4963
# Epoch 54: val_loss improved from 1.50166 to 1.50158, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.4963 - val_loss: 1.5016
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4964
# Epoch 55: val_loss improved from 1.50158 to 1.49800, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.4964 - val_loss: 1.4980
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4955
# Epoch 56: val_loss improved from 1.49800 to 1.49704, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 151us/sample - loss: 1.4955 - val_loss: 1.4970
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4943
# Epoch 57: val_loss did not improve from 1.49704
# 29601/29601 [==============================] - 4s 145us/sample - loss: 1.4943 - val_loss: 1.4982
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4916
# Epoch 58: val_loss improved from 1.49704 to 1.49351, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 151us/sample - loss: 1.4916 - val_loss: 1.4935
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4936
# Epoch 59: val_loss improved from 1.49351 to 1.49285, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 150us/sample - loss: 1.4936 - val_loss: 1.4928
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4925
# Epoch 60: val_loss did not improve from 1.49285
# 29601/29601 [==============================] - 4s 151us/sample - loss: 1.4925 - val_loss: 1.4960
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4928
# Epoch 61: val_loss did not improve from 1.49285
# 29601/29601 [==============================] - 4s 146us/sample - loss: 1.4928 - val_loss: 1.4962
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4885
# Epoch 62: val_loss did not improve from 1.49285
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.4885 - val_loss: 1.4972
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4882
# Epoch 63: val_loss did not improve from 1.49285
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.4882 - val_loss: 1.4975
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4879
# Epoch 64: val_loss did not improve from 1.49285
# 29601/29601 [==============================] - 4s 145us/sample - loss: 1.4879 - val_loss: 1.5013
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4868
# Epoch 65: val_loss improved from 1.49285 to 1.49169, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 148us/sample - loss: 1.4868 - val_loss: 1.4917
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4840
# Epoch 66: val_loss improved from 1.49169 to 1.49145, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 148us/sample - loss: 1.4840 - val_loss: 1.4914
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4836
# Epoch 67: val_loss improved from 1.49145 to 1.48910, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 151us/sample - loss: 1.4836 - val_loss: 1.4891
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4843
# Epoch 68: val_loss did not improve from 1.48910
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.4843 - val_loss: 1.4923
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4826
# Epoch 69: val_loss did not improve from 1.48910
# 29601/29601 [==============================] - 4s 146us/sample - loss: 1.4826 - val_loss: 1.4900
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4827
# Epoch 70: val_loss improved from 1.48910 to 1.48337, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 149us/sample - loss: 1.4827 - val_loss: 1.4834
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4826
# Epoch 71: val_loss improved from 1.48337 to 1.48332, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 150us/sample - loss: 1.4826 - val_loss: 1.4833
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4800
# Epoch 72: val_loss did not improve from 1.48332
# 29601/29601 [==============================] - 5s 156us/sample - loss: 1.4800 - val_loss: 1.4852
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4808
# Epoch 73: val_loss improved from 1.48332 to 1.48306, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 5s 154us/sample - loss: 1.4808 - val_loss: 1.4831
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4797
# Epoch 74: val_loss improved from 1.48306 to 1.47871, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 148us/sample - loss: 1.4797 - val_loss: 1.4787
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4783
# Epoch 75: val_loss improved from 1.47871 to 1.47821, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 5s 154us/sample - loss: 1.4783 - val_loss: 1.4782
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4768
# Epoch 76: val_loss improved from 1.47821 to 1.47798, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 5s 182us/sample - loss: 1.4768 - val_loss: 1.4780
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4769
# Epoch 77: val_loss did not improve from 1.47798
# 29601/29601 [==============================] - 5s 180us/sample - loss: 1.4769 - val_loss: 1.4797
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4736
# Epoch 78: val_loss did not improve from 1.47798
# 29601/29601 [==============================] - 5s 180us/sample - loss: 1.4736 - val_loss: 1.4804
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4716
# Epoch 79: val_loss improved from 1.47798 to 1.47518, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 5s 182us/sample - loss: 1.4716 - val_loss: 1.4752
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4705
# Epoch 80: val_loss improved from 1.47518 to 1.46998, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 5s 181us/sample - loss: 1.4705 - val_loss: 1.4700
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4702
# Epoch 81: val_loss did not improve from 1.46998
# 29601/29601 [==============================] - 5s 162us/sample - loss: 1.4702 - val_loss: 1.4759
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4696
# Epoch 82: val_loss improved from 1.46998 to 1.46710, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 152us/sample - loss: 1.4696 - val_loss: 1.4671
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4693
# Epoch 83: val_loss did not improve from 1.46710
# 29601/29601 [==============================] - 4s 149us/sample - loss: 1.4693 - val_loss: 1.4701
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4673
# Epoch 84: val_loss did not improve from 1.46710
# 29601/29601 [==============================] - 4s 149us/sample - loss: 1.4673 - val_loss: 1.4750
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4658
# Epoch 85: val_loss improved from 1.46710 to 1.46637, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.4658 - val_loss: 1.4664
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4661
# Epoch 86: val_loss improved from 1.46637 to 1.46255, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 149us/sample - loss: 1.4661 - val_loss: 1.4625
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4648
# Epoch 87: val_loss did not improve from 1.46255
# 29601/29601 [==============================] - 4s 149us/sample - loss: 1.4648 - val_loss: 1.4659
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4631
# Epoch 88: val_loss improved from 1.46255 to 1.46061, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 148us/sample - loss: 1.4631 - val_loss: 1.4606
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4611
# Epoch 89: val_loss did not improve from 1.46061
# 29601/29601 [==============================] - 4s 145us/sample - loss: 1.4611 - val_loss: 1.4621
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4621
# Epoch 90: val_loss did not improve from 1.46061
# 29601/29601 [==============================] - 4s 149us/sample - loss: 1.4621 - val_loss: 1.4634
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4611
# Epoch 91: val_loss improved from 1.46061 to 1.45853, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 149us/sample - loss: 1.4611 - val_loss: 1.4585
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4591
# Epoch 92: val_loss improved from 1.45853 to 1.45699, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 151us/sample - loss: 1.4591 - val_loss: 1.4570
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4604
# Epoch 93: val_loss improved from 1.45699 to 1.45328, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.4604 - val_loss: 1.4533
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4578
# Epoch 94: val_loss improved from 1.45328 to 1.45318, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.4578 - val_loss: 1.4532
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4565
# Epoch 95: val_loss did not improve from 1.45318
# 29601/29601 [==============================] - 4s 146us/sample - loss: 1.4565 - val_loss: 1.4568
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4575
# Epoch 96: val_loss improved from 1.45318 to 1.45133, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.4575 - val_loss: 1.4513
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4543
# Epoch 97: val_loss did not improve from 1.45133
# 29601/29601 [==============================] - 4s 147us/sample - loss: 1.4543 - val_loss: 1.4514
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4539
# Epoch 98: val_loss improved from 1.45133 to 1.45106, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 4s 148us/sample - loss: 1.4539 - val_loss: 1.4511
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4535
# Epoch 99: val_loss did not improve from 1.45106
# 29601/29601 [==============================] - 4s 146us/sample - loss: 1.4535 - val_loss: 1.4545
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4528
# Epoch 100: val_loss improved from 1.45106 to 1.44935, saving model to ./checkpoints/Feature_extraction_only_spe.h5
# 29601/29601 [==============================] - 5s 162us/sample - loss: 1.4528 - val_loss: 1.4494
