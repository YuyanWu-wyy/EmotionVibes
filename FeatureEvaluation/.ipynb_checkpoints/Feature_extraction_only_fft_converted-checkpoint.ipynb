# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([fft_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-07 00:05:01.152533: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
# rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

# for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
model_name = './checkpoints/Feature_extraction_only_fft.h5'

checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
# pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=0.35, start_epoch=5, end_epoch=50, frequency=1)
model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-07 00:05:32.762487: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:32.773950: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:32.774179: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:32.778557: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:32.778748: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:32.778914: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:32.852794: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:32.852984: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:32.853146: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:32.853279: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-07 00:05:32.853612: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# (29601, 0)
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 2023-11-07 00:05:33.092789: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:33.093011: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:33.093182: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:33.093413: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:33.093593: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:05:33.093729: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-07 00:05:33.093757: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-07 00:05:33.102454: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-07 00:05:33.292814: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_3/bias/v/Assign' id:830 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_3/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_3/bias/v, training/Adam/dense_3/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
#  4096/29601 [===>..........................] - ETA: 3s - loss: 4.9889
# 2023-11-07 00:05:33.449601: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 28672/29601 [============================>.] - ETA: 0s - loss: 4.8677
# Epoch 1: val_loss improved from inf to 4.64294, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 37us/sample - loss: 4.8619 - val_loss: 4.6429
# Epoch 2/100
#  1024/29601 [>.............................] - ETA: 1s - loss: 4.6565
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-07 00:05:34.068334: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:308 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 27648/29601 [===========================>..] - ETA: 0s - loss: 4.2273
# Epoch 2: val_loss improved from 4.64294 to 3.38475, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 21us/sample - loss: 4.1808 - val_loss: 3.3847
# Epoch 3/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 2.4107
# Epoch 3: val_loss improved from 3.38475 to 1.74965, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 2.3935 - val_loss: 1.7497
# Epoch 4/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.7591
# Epoch 4: val_loss improved from 1.74965 to 1.63872, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.7560 - val_loss: 1.6387
# Epoch 5/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.6665
# Epoch 5: val_loss improved from 1.63872 to 1.60899, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.6653 - val_loss: 1.6090
# Epoch 6/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.6388
# Epoch 6: val_loss improved from 1.60899 to 1.60082, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.6389 - val_loss: 1.6008
# Epoch 7/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.6163
# Epoch 7: val_loss did not improve from 1.60082
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.6163 - val_loss: 1.6053
# Epoch 8/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.6052
# Epoch 8: val_loss improved from 1.60082 to 1.60055, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.6038 - val_loss: 1.6006
# Epoch 9/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5937
# Epoch 9: val_loss did not improve from 1.60055
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5935 - val_loss: 1.6064
# Epoch 10/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5867
# Epoch 10: val_loss did not improve from 1.60055
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5870 - val_loss: 1.6011
# Epoch 11/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5815
# Epoch 11: val_loss did not improve from 1.60055
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5812 - val_loss: 1.6009
# Epoch 12/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5751
# Epoch 12: val_loss did not improve from 1.60055
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5757 - val_loss: 1.6028
# Epoch 13/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5715
# Epoch 13: val_loss improved from 1.60055 to 1.59835, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5707 - val_loss: 1.5983
# Epoch 14/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5664
# Epoch 14: val_loss improved from 1.59835 to 1.59780, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5679 - val_loss: 1.5978
# Epoch 15/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5655
# Epoch 15: val_loss improved from 1.59780 to 1.59151, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 21us/sample - loss: 1.5663 - val_loss: 1.5915
# Epoch 16/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5642
# Epoch 16: val_loss did not improve from 1.59151
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5635 - val_loss: 1.5920
# Epoch 17/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5618
# Epoch 17: val_loss improved from 1.59151 to 1.58872, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5607 - val_loss: 1.5887
# Epoch 18/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5599
# Epoch 18: val_loss did not improve from 1.58872
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5595 - val_loss: 1.5888
# Epoch 19/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5582
# Epoch 19: val_loss improved from 1.58872 to 1.58543, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5586 - val_loss: 1.5854
# Epoch 20/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5576
# Epoch 20: val_loss improved from 1.58543 to 1.58467, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5579 - val_loss: 1.5847
# Epoch 21/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.5564
# Epoch 21: val_loss improved from 1.58467 to 1.58175, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5564 - val_loss: 1.5817
# Epoch 22/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5570
# Epoch 22: val_loss improved from 1.58175 to 1.57793, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5572 - val_loss: 1.5779
# Epoch 23/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5554
# Epoch 23: val_loss did not improve from 1.57793
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5553 - val_loss: 1.5785
# Epoch 24/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5535
# Epoch 24: val_loss did not improve from 1.57793
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5543 - val_loss: 1.5785
# Epoch 25/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5525
# Epoch 25: val_loss did not improve from 1.57793
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5522 - val_loss: 1.5785
# Epoch 26/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5511
# Epoch 26: val_loss improved from 1.57793 to 1.57628, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5515 - val_loss: 1.5763
# Epoch 27/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5515
# Epoch 27: val_loss did not improve from 1.57628
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5529 - val_loss: 1.5802
# Epoch 28/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5520
# Epoch 28: val_loss did not improve from 1.57628
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5515 - val_loss: 1.5778
# Epoch 29/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5515
# Epoch 29: val_loss did not improve from 1.57628
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5510 - val_loss: 1.5798
# Epoch 30/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5502
# Epoch 30: val_loss did not improve from 1.57628
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5496 - val_loss: 1.5780
# Epoch 31/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5489
# Epoch 31: val_loss did not improve from 1.57628
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5494 - val_loss: 1.5778
# Epoch 32/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5478
# Epoch 32: val_loss improved from 1.57628 to 1.57566, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5492 - val_loss: 1.5757
# Epoch 33/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5501
# Epoch 33: val_loss did not improve from 1.57566
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5488 - val_loss: 1.5764
# Epoch 34/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5489
# Epoch 34: val_loss improved from 1.57566 to 1.57558, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5480 - val_loss: 1.5756
# Epoch 35/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5491
# Epoch 35: val_loss improved from 1.57558 to 1.57543, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5478 - val_loss: 1.5754
# Epoch 36/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5495
# Epoch 36: val_loss improved from 1.57543 to 1.57336, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5475 - val_loss: 1.5734
# Epoch 37/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5469
# Epoch 37: val_loss did not improve from 1.57336
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5482 - val_loss: 1.5748
# Epoch 38/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5481
# Epoch 38: val_loss did not improve from 1.57336
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5478 - val_loss: 1.5762
# Epoch 39/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5485
# Epoch 39: val_loss improved from 1.57336 to 1.57319, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5484 - val_loss: 1.5732
# Epoch 40/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5466
# Epoch 40: val_loss did not improve from 1.57319
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5471 - val_loss: 1.5745
# Epoch 41/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5482
# Epoch 41: val_loss improved from 1.57319 to 1.57168, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5486 - val_loss: 1.5717
# Epoch 42/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5465
# Epoch 42: val_loss improved from 1.57168 to 1.57054, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5465 - val_loss: 1.5705
# Epoch 43/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5479
# Epoch 43: val_loss did not improve from 1.57054
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5478 - val_loss: 1.5723
# Epoch 44/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5503
# Epoch 44: val_loss did not improve from 1.57054
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5492 - val_loss: 1.5708
# Epoch 45/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5496
# Epoch 45: val_loss improved from 1.57054 to 1.56923, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5487 - val_loss: 1.5692
# Epoch 46/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5483
# Epoch 46: val_loss improved from 1.56923 to 1.56813, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5475 - val_loss: 1.5681
# Epoch 47/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5469
# Epoch 47: val_loss improved from 1.56813 to 1.56749, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5470 - val_loss: 1.5675
# Epoch 48/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5472
# Epoch 48: val_loss improved from 1.56749 to 1.56474, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 20us/sample - loss: 1.5469 - val_loss: 1.5647
# Epoch 49/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5503
# Epoch 49: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5471 - val_loss: 1.5683
# Epoch 50/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5463
# Epoch 50: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5467 - val_loss: 1.5717
# Epoch 51/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5456
# Epoch 51: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5466 - val_loss: 1.5702
# Epoch 52/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5466
# Epoch 52: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5460 - val_loss: 1.5685
# Epoch 53/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5472
# Epoch 53: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5458 - val_loss: 1.5688
# Epoch 54/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5463
# Epoch 54: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5455 - val_loss: 1.5679
# Epoch 55/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5449
# Epoch 55: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5452 - val_loss: 1.5714
# Epoch 56/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5463
# Epoch 56: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5460 - val_loss: 1.5648
# Epoch 57/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5471
# Epoch 57: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5459 - val_loss: 1.5689
# Epoch 58/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5462
# Epoch 58: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5455 - val_loss: 1.5681
# Epoch 59/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5449
# Epoch 59: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5455 - val_loss: 1.5692
# Epoch 60/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5449
# Epoch 60: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5457 - val_loss: 1.5703
# Epoch 61/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5513
# Epoch 61: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5502 - val_loss: 1.5726
# Epoch 62/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5493
# Epoch 62: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5491 - val_loss: 1.5695
# Epoch 63/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5503
# Epoch 63: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5475 - val_loss: 1.5668
# Epoch 64/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5460
# Epoch 64: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5460 - val_loss: 1.5684
# Epoch 65/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5449
# Epoch 65: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5458 - val_loss: 1.5664
# Epoch 66/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5458
# Epoch 66: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5460 - val_loss: 1.5655
# Epoch 67/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5445
# Epoch 67: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5459 - val_loss: 1.5676
# Epoch 68/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5458
# Epoch 68: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5462 - val_loss: 1.5689
# Epoch 69/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5452
# Epoch 69: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5459 - val_loss: 1.5678
# Epoch 70/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5464
# Epoch 70: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5468 - val_loss: 1.5648
# Epoch 71/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5459
# Epoch 71: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5456 - val_loss: 1.5665
# Epoch 72/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5454
# Epoch 72: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5455 - val_loss: 1.5686
# Epoch 73/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5447
# Epoch 73: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5449 - val_loss: 1.5710
# Epoch 74/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5501
# Epoch 74: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5498 - val_loss: 1.5706
# Epoch 75/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5505
# Epoch 75: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5505 - val_loss: 1.5720
# Epoch 76/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5477
# Epoch 76: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5484 - val_loss: 1.5685
# Epoch 77/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5475
# Epoch 77: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5472 - val_loss: 1.5658
# Epoch 78/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5447
# Epoch 78: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5450 - val_loss: 1.5658
# Epoch 79/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5457
# Epoch 79: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5456 - val_loss: 1.5670
# Epoch 80/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5466
# Epoch 80: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5462 - val_loss: 1.5674
# Epoch 81/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5447
# Epoch 81: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5457 - val_loss: 1.5658
# Epoch 82/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5456
# Epoch 82: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5464 - val_loss: 1.5665
# Epoch 83/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5475
# Epoch 83: val_loss did not improve from 1.56474
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5480 - val_loss: 1.5667
# Epoch 84/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5466
# Epoch 84: val_loss improved from 1.56474 to 1.56316, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.5464 - val_loss: 1.5632
# Epoch 85/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5457
# Epoch 85: val_loss did not improve from 1.56316
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5459 - val_loss: 1.5653
# Epoch 86/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5454
# Epoch 86: val_loss did not improve from 1.56316
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5455 - val_loss: 1.5645
# Epoch 87/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5439
# Epoch 87: val_loss did not improve from 1.56316
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5442 - val_loss: 1.5652
# Epoch 88/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5452
# Epoch 88: val_loss did not improve from 1.56316
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.5447 - val_loss: 1.5641
# Epoch 89/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5453
# Epoch 89: val_loss did not improve from 1.56316
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5446 - val_loss: 1.5636
# Epoch 90/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5435
# Epoch 90: val_loss did not improve from 1.56316
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5445 - val_loss: 1.5653
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5450
# Epoch 91: val_loss did not improve from 1.56316
# 29601/29601 [==============================] - 1s 24us/sample - loss: 1.5450 - val_loss: 1.5647
# Epoch 92/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5447
# Epoch 92: val_loss improved from 1.56316 to 1.56282, saving model to ./checkpoints/Feature_extraction_only_fft.h5
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.5447 - val_loss: 1.5628
# Epoch 93/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.5464
# Epoch 93: val_loss did not improve from 1.56282
# 29601/29601 [==============================] - 1s 24us/sample - loss: 1.5445 - val_loss: 1.5666
# Epoch 94/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5437
# Epoch 94: val_loss did not improve from 1.56282
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5441 - val_loss: 1.5668
# Epoch 95/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5449
# Epoch 95: val_loss did not improve from 1.56282
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5454 - val_loss: 1.5662
# Epoch 96/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5451
# Epoch 96: val_loss did not improve from 1.56282
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5447 - val_loss: 1.5691
# Epoch 97/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5449
# Epoch 97: val_loss did not improve from 1.56282
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5449 - val_loss: 1.5641
# Epoch 98/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5446
# Epoch 98: val_loss did not improve from 1.56282
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5443 - val_loss: 1.5675
# Epoch 99/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5442
# Epoch 99: val_loss did not improve from 1.56282
# 29601/29601 [==============================] - 1s 22us/sample - loss: 1.5437 - val_loss: 1.5662
# Epoch 100/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5435
# Epoch 100: val_loss did not improve from 1.56282
# 29601/29601 [==============================] - 1s 19us/sample - loss: 1.5447 - val_loss: 1.5664
