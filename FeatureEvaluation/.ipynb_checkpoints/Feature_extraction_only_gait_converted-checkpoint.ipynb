# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([wlk_fre, wlk_fres_trace, double_support_time, pdps_new]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-07 00:13:38.183528: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
# rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

# for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
model_name = './checkpoints/Feature_extraction_only_gait.h5'

checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
# pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=0.35, start_epoch=5, end_epoch=50, frequency=1)
model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[checkpoint])
# Out:
# (29601, 4)
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 2023-11-07 00:14:09.872383: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:14:09.884266: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:14:09.884506: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:14:09.888964: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:14:09.889192: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:14:09.889360: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:14:09.960043: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:14:09.960255: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:14:09.960428: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 00:14:09.960572: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-07 00:14:09.960809: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-07 00:14:09.967842: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
#  1024/29601 [>.............................] - ETA: 14:09 - loss: 5.1108
# Epoch 1: val_loss improved from inf to 4.70890, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 4.9230 - val_loss: 4.7089
# Epoch 2/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 4.7421
# 2023-11-07 00:14:10.152683: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_3/kernel/v/Assign' id:365 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_3/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_3/kernel/v, training/Adam/dense_3/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-07 00:14:10.224886: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-07 00:14:10.288859: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:143 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 2: val_loss improved from 4.70890 to 4.16744, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 4.4922 - val_loss: 4.1674
# Epoch 3/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 4.2146
# Epoch 3: val_loss improved from 4.16744 to 3.30002, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 3.8063 - val_loss: 3.3000
# Epoch 4/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 3.4258
# Epoch 4: val_loss improved from 3.30002 to 2.50045, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 3.0010 - val_loss: 2.5004
# Epoch 5/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 2.7195
# Epoch 5: val_loss improved from 2.50045 to 2.13756, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 2.5046 - val_loss: 2.1376
# Epoch 6/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 2.3391
# Epoch 6: val_loss improved from 2.13756 to 1.90661, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 2.1820 - val_loss: 1.9066
# Epoch 7/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 2.0528
# Epoch 7: val_loss improved from 1.90661 to 1.70649, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.9240 - val_loss: 1.7065
# Epoch 8/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.8209
# Epoch 8: val_loss improved from 1.70649 to 1.60100, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.7190 - val_loss: 1.6010
# Epoch 9/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5901
# Epoch 9: val_loss improved from 1.60100 to 1.55020, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5941 - val_loss: 1.5502
# Epoch 10/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5931
# Epoch 10: val_loss improved from 1.55020 to 1.54462, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5590 - val_loss: 1.5446
# Epoch 11/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5336
# Epoch 11: val_loss improved from 1.54462 to 1.54149, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5494 - val_loss: 1.5415
# Epoch 12/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5652
# Epoch 12: val_loss improved from 1.54149 to 1.54023, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5460 - val_loss: 1.5402
# Epoch 13/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5487
# Epoch 13: val_loss improved from 1.54023 to 1.53936, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5445 - val_loss: 1.5394
# Epoch 14/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5354
# Epoch 14: val_loss improved from 1.53936 to 1.53865, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5440 - val_loss: 1.5387
# Epoch 15/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5622
# Epoch 15: val_loss improved from 1.53865 to 1.53791, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5411 - val_loss: 1.5379
# Epoch 16/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5646
# Epoch 16: val_loss improved from 1.53791 to 1.53723, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5419 - val_loss: 1.5372
# Epoch 17/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5472
# Epoch 17: val_loss improved from 1.53723 to 1.53560, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5398 - val_loss: 1.5356
# Epoch 18/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5577
# Epoch 18: val_loss improved from 1.53560 to 1.53374, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5390 - val_loss: 1.5337
# Epoch 19/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5382
# Epoch 19: val_loss did not improve from 1.53374
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5403 - val_loss: 1.5342
# Epoch 20/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5698
# Epoch 20: val_loss did not improve from 1.53374
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5411 - val_loss: 1.5345
# Epoch 21/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5240
# Epoch 21: val_loss improved from 1.53374 to 1.53233, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5379 - val_loss: 1.5323
# Epoch 22/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5429
# Epoch 22: val_loss improved from 1.53233 to 1.53113, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5387 - val_loss: 1.5311
# Epoch 23/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5506
# Epoch 23: val_loss improved from 1.53113 to 1.53028, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5371 - val_loss: 1.5303
# Epoch 24/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5071
# Epoch 24: val_loss improved from 1.53028 to 1.52990, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5363 - val_loss: 1.5299
# Epoch 25/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5476
# Epoch 25: val_loss improved from 1.52990 to 1.52766, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5361 - val_loss: 1.5277
# Epoch 26/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5142
# Epoch 26: val_loss did not improve from 1.52766
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5359 - val_loss: 1.5282
# Epoch 27/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5272
# Epoch 27: val_loss improved from 1.52766 to 1.52739, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5367 - val_loss: 1.5274
# Epoch 28/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5399
# Epoch 28: val_loss improved from 1.52739 to 1.52493, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5332 - val_loss: 1.5249
# Epoch 29/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4981
# Epoch 29: val_loss improved from 1.52493 to 1.52431, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5339 - val_loss: 1.5243
# Epoch 30/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5180
# Epoch 30: val_loss improved from 1.52431 to 1.52275, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5337 - val_loss: 1.5228
# Epoch 31/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5580
# Epoch 31: val_loss did not improve from 1.52275
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5338 - val_loss: 1.5231
# Epoch 32/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5300
# Epoch 32: val_loss improved from 1.52275 to 1.52162, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5328 - val_loss: 1.5216
# Epoch 33/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5383
# Epoch 33: val_loss did not improve from 1.52162
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5347 - val_loss: 1.5233
# Epoch 34/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5636
# Epoch 34: val_loss improved from 1.52162 to 1.51958, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5330 - val_loss: 1.5196
# Epoch 35/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5402
# Epoch 35: val_loss did not improve from 1.51958
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5325 - val_loss: 1.5197
# Epoch 36/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4898
# Epoch 36: val_loss improved from 1.51958 to 1.51817, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5321 - val_loss: 1.5182
# Epoch 37/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5184
# Epoch 37: val_loss did not improve from 1.51817
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5292 - val_loss: 1.5183
# Epoch 38/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5071
# Epoch 38: val_loss improved from 1.51817 to 1.51788, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5310 - val_loss: 1.5179
# Epoch 39/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5113
# Epoch 39: val_loss improved from 1.51788 to 1.51733, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5303 - val_loss: 1.5173
# Epoch 40/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5010
# Epoch 40: val_loss did not improve from 1.51733
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5290 - val_loss: 1.5174
# Epoch 41/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5521
# Epoch 41: val_loss improved from 1.51733 to 1.51733, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5286 - val_loss: 1.5173
# Epoch 42/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5609
# Epoch 42: val_loss improved from 1.51733 to 1.51644, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5300 - val_loss: 1.5164
# Epoch 43/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4537
# Epoch 43: val_loss did not improve from 1.51644
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5303 - val_loss: 1.5171
# Epoch 44/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4963
# Epoch 44: val_loss did not improve from 1.51644
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5278 - val_loss: 1.5165
# Epoch 45/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5692
# Epoch 45: val_loss improved from 1.51644 to 1.51611, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5286 - val_loss: 1.5161
# Epoch 46/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5507
# Epoch 46: val_loss did not improve from 1.51611
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5288 - val_loss: 1.5185
# Epoch 47/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5589
# Epoch 47: val_loss did not improve from 1.51611
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5285 - val_loss: 1.5171
# Epoch 48/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4872
# Epoch 48: val_loss improved from 1.51611 to 1.51610, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5306 - val_loss: 1.5161
# Epoch 49/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5386
# Epoch 49: val_loss improved from 1.51610 to 1.51575, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5297 - val_loss: 1.5158
# Epoch 50/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5619
# Epoch 50: val_loss did not improve from 1.51575
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5282 - val_loss: 1.5160
# Epoch 51/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5256
# Epoch 51: val_loss did not improve from 1.51575
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5292 - val_loss: 1.5178
# Epoch 52/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5180
# Epoch 52: val_loss improved from 1.51575 to 1.51559, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5292 - val_loss: 1.5156
# Epoch 53/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5318
# Epoch 53: val_loss improved from 1.51559 to 1.51547, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5289 - val_loss: 1.5155
# Epoch 54/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5549
# Epoch 54: val_loss did not improve from 1.51547
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5286 - val_loss: 1.5156
# Epoch 55/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5789
# Epoch 55: val_loss did not improve from 1.51547
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5280 - val_loss: 1.5161
# Epoch 56/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5381
# Epoch 56: val_loss did not improve from 1.51547
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5285 - val_loss: 1.5174
# Epoch 57/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5799
# Epoch 57: val_loss did not improve from 1.51547
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5268 - val_loss: 1.5157
# Epoch 58/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5223
# Epoch 58: val_loss did not improve from 1.51547
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5289 - val_loss: 1.5168
# Epoch 59/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4993
# Epoch 59: val_loss did not improve from 1.51547
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5289 - val_loss: 1.5156
# Epoch 60/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5277
# Epoch 60: val_loss improved from 1.51547 to 1.51512, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5275 - val_loss: 1.5151
# Epoch 61/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5095
# Epoch 61: val_loss improved from 1.51512 to 1.51496, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5276 - val_loss: 1.5150
# Epoch 62/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5437
# Epoch 62: val_loss improved from 1.51496 to 1.51495, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5281 - val_loss: 1.5150
# Epoch 63/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5170
# Epoch 63: val_loss improved from 1.51495 to 1.51445, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5258 - val_loss: 1.5145
# Epoch 64/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5038
# Epoch 64: val_loss did not improve from 1.51445
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5280 - val_loss: 1.5158
# Epoch 65/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5690
# Epoch 65: val_loss did not improve from 1.51445
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5267 - val_loss: 1.5150
# Epoch 66/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5376
# Epoch 66: val_loss did not improve from 1.51445
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5273 - val_loss: 1.5147
# Epoch 67/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5187
# Epoch 67: val_loss did not improve from 1.51445
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5257 - val_loss: 1.5146
# Epoch 68/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5486
# Epoch 68: val_loss did not improve from 1.51445
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5256 - val_loss: 1.5152
# Epoch 69/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5623
# Epoch 69: val_loss improved from 1.51445 to 1.51418, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5262 - val_loss: 1.5142
# Epoch 70/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5672
# Epoch 70: val_loss did not improve from 1.51418
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5284 - val_loss: 1.5176
# Epoch 71/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5487
# Epoch 71: val_loss did not improve from 1.51418
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5260 - val_loss: 1.5168
# Epoch 72/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5637
# Epoch 72: val_loss did not improve from 1.51418
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5253 - val_loss: 1.5143
# Epoch 73/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5216
# Epoch 73: val_loss did not improve from 1.51418
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5256 - val_loss: 1.5146
# Epoch 74/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5316
# Epoch 74: val_loss did not improve from 1.51418
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5265 - val_loss: 1.5147
# Epoch 75/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5105
# Epoch 75: val_loss did not improve from 1.51418
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5261 - val_loss: 1.5142
# Epoch 76/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5496
# Epoch 76: val_loss did not improve from 1.51418
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5274 - val_loss: 1.5142
# Epoch 77/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5742
# Epoch 77: val_loss improved from 1.51418 to 1.51396, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5257 - val_loss: 1.5140
# Epoch 78/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4930
# Epoch 78: val_loss did not improve from 1.51396
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5261 - val_loss: 1.5140
# Epoch 79/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5364
# Epoch 79: val_loss did not improve from 1.51396
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5258 - val_loss: 1.5141
# Epoch 80/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4876
# Epoch 80: val_loss did not improve from 1.51396
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5243 - val_loss: 1.5140
# Epoch 81/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5313
# Epoch 81: val_loss improved from 1.51396 to 1.51343, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5239 - val_loss: 1.5134
# Epoch 82/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5444
# Epoch 82: val_loss did not improve from 1.51343
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5270 - val_loss: 1.5137
# Epoch 83/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5644
# Epoch 83: val_loss improved from 1.51343 to 1.51320, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5253 - val_loss: 1.5132
# Epoch 84/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5171
# Epoch 84: val_loss did not improve from 1.51320
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5254 - val_loss: 1.5138
# Epoch 85/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5730
# Epoch 85: val_loss did not improve from 1.51320
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5251 - val_loss: 1.5134
# Epoch 86/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5349
# Epoch 86: val_loss did not improve from 1.51320
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5261 - val_loss: 1.5140
# Epoch 87/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5575
# Epoch 87: val_loss did not improve from 1.51320
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5260 - val_loss: 1.5138
# Epoch 88/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5282
# Epoch 88: val_loss did not improve from 1.51320
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5243 - val_loss: 1.5139
# Epoch 89/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5372
# Epoch 89: val_loss improved from 1.51320 to 1.51319, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5252 - val_loss: 1.5132
# Epoch 90/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5975
# Epoch 90: val_loss did not improve from 1.51319
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5255 - val_loss: 1.5144
# Epoch 91/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5074
# Epoch 91: val_loss improved from 1.51319 to 1.51285, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5236 - val_loss: 1.5129
# Epoch 92/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4926
# Epoch 92: val_loss did not improve from 1.51285
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5236 - val_loss: 1.5129
# Epoch 93/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5559
# Epoch 93: val_loss did not improve from 1.51285
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5242 - val_loss: 1.5129
# Epoch 94/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5093
# Epoch 94: val_loss did not improve from 1.51285
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5246 - val_loss: 1.5129
# Epoch 95/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4876
# Epoch 95: val_loss improved from 1.51285 to 1.51262, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5268 - val_loss: 1.5126
# Epoch 96/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5175
# Epoch 96: val_loss did not improve from 1.51262
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5251 - val_loss: 1.5128
# Epoch 97/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5173
# Epoch 97: val_loss did not improve from 1.51262
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5233 - val_loss: 1.5132
# Epoch 98/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5042
# Epoch 98: val_loss improved from 1.51262 to 1.51187, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5236 - val_loss: 1.5119
# Epoch 99/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5663
# Epoch 99: val_loss did not improve from 1.51187
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5241 - val_loss: 1.5123
# Epoch 100/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5175
# Epoch 100: val_loss did not improve from 1.51187
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5220 - val_loss: 1.5131
