# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([cwt_figs_all, fft_features, high_fre_compos, pitchs, low_fre_compos, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, feature, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, slope, lpcs, legendres,  ceps_features, real_hils, imag_hils, jitters, shimmers, jitter_rap, auto_corrs, hrs, zcrs]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-12-08 22:07:46.001672: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Adaptive_prune_model_remove_bio_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# 2023-12-08 22:08:19.927004: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:19.939333: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:19.939612: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:19.943610: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:19.943812: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:19.943982: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:20.021332: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:20.021536: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:20.021705: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:20.021846: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-12-08 22:08:20.022207: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-12-08 22:08:20.022584: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-08 22:08:20.200145: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:4 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-08 22:08:20.203268: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:5 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-08 22:08:20.272259: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:20.272557: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:20.272808: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:20.273090: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:20.273341: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 22:08:20.273522: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-12-08 22:08:20.273558: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 89)
# Train on 29601 samples, validate on 3694 samples
# 2023-12-08 22:08:25.202985: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_12/lstm_cell_12/recurrent_kernel/m/Assign' id:15243 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_12/lstm_cell_12/recurrent_kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_12/lstm_cell_12/recurrent_kernel/m, training/Adam/lstm_12/lstm_cell_12/recurrent_kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-12-08 22:08:28.802355: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-12-08 22:08:30.896585: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-08 22:08:30.911308: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 29601/29601 [==============================] - ETA: 0s - loss: 4.3803
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-12-08 22:08:47.751475: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:5915 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 2.60332, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 24s 800us/sample - loss: 4.3803 - val_loss: 2.6033
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 2.1088
# Epoch 2: val_loss improved from 2.60332 to 1.74015, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 618us/sample - loss: 2.1088 - val_loss: 1.7402
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6858
# Epoch 3: val_loss improved from 1.74015 to 1.58159, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 17s 580us/sample - loss: 1.6858 - val_loss: 1.5816
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5718
# Epoch 4: val_loss improved from 1.58159 to 1.53195, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 614us/sample - loss: 1.5718 - val_loss: 1.5320
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5431
# Epoch 5: val_loss improved from 1.53195 to 1.51084, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 616us/sample - loss: 1.5431 - val_loss: 1.5108
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5248
# Epoch 6: val_loss improved from 1.51084 to 1.50186, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 617us/sample - loss: 1.5248 - val_loss: 1.5019
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5190
# Epoch 7: val_loss improved from 1.50186 to 1.49454, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.5190 - val_loss: 1.4945
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5107
# Epoch 8: val_loss improved from 1.49454 to 1.49202, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 16s 547us/sample - loss: 1.5107 - val_loss: 1.4920
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5056
# Epoch 9: val_loss did not improve from 1.49202
# 29601/29601 [==============================] - 16s 537us/sample - loss: 1.5056 - val_loss: 1.4922
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5032
# Epoch 10: val_loss improved from 1.49202 to 1.48245, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 17s 580us/sample - loss: 1.5032 - val_loss: 1.4824
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5008
# Epoch 11: val_loss improved from 1.48245 to 1.47746, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.5008 - val_loss: 1.4775
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4953
# Epoch 12: val_loss improved from 1.47746 to 1.47670, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 16s 554us/sample - loss: 1.4953 - val_loss: 1.4767
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4958
# Epoch 13: val_loss improved from 1.47670 to 1.47404, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 610us/sample - loss: 1.4958 - val_loss: 1.4740
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4913
# Epoch 14: val_loss improved from 1.47404 to 1.46925, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 619us/sample - loss: 1.4913 - val_loss: 1.4692
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4847
# Epoch 15: val_loss did not improve from 1.46925
# 29601/29601 [==============================] - 16s 547us/sample - loss: 1.4847 - val_loss: 1.4729
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4848
# Epoch 16: val_loss did not improve from 1.46925
# 29601/29601 [==============================] - 16s 539us/sample - loss: 1.4848 - val_loss: 1.4701
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4798
# Epoch 17: val_loss improved from 1.46925 to 1.46422, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 16s 546us/sample - loss: 1.4798 - val_loss: 1.4642
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4782
# Epoch 18: val_loss improved from 1.46422 to 1.46211, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.4782 - val_loss: 1.4621
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4760
# Epoch 19: val_loss improved from 1.46211 to 1.46075, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 17s 559us/sample - loss: 1.4760 - val_loss: 1.4607
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4720
# Epoch 20: val_loss did not improve from 1.46075
# 29601/29601 [==============================] - 16s 537us/sample - loss: 1.4720 - val_loss: 1.4611
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4715
# Epoch 21: val_loss improved from 1.46075 to 1.45087, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 17s 576us/sample - loss: 1.4715 - val_loss: 1.4509
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4696
# Epoch 22: val_loss did not improve from 1.45087
# 29601/29601 [==============================] - 18s 608us/sample - loss: 1.4696 - val_loss: 1.4594
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4651
# Epoch 23: val_loss did not improve from 1.45087
# 29601/29601 [==============================] - 18s 604us/sample - loss: 1.4651 - val_loss: 1.4514
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4637
# Epoch 24: val_loss improved from 1.45087 to 1.44769, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 17s 587us/sample - loss: 1.4637 - val_loss: 1.4477
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4640
# Epoch 25: val_loss did not improve from 1.44769
# 29601/29601 [==============================] - 18s 614us/sample - loss: 1.4640 - val_loss: 1.4477
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4589
# Epoch 26: val_loss did not improve from 1.44769
# 29601/29601 [==============================] - 18s 609us/sample - loss: 1.4589 - val_loss: 1.4501
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4588
# Epoch 27: val_loss improved from 1.44769 to 1.44115, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.4588 - val_loss: 1.4412
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4574
# Epoch 28: val_loss did not improve from 1.44115
# 29601/29601 [==============================] - 18s 611us/sample - loss: 1.4574 - val_loss: 1.4478
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4550
# Epoch 29: val_loss improved from 1.44115 to 1.43813, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 616us/sample - loss: 1.4550 - val_loss: 1.4381
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4542
# Epoch 30: val_loss did not improve from 1.43813
# 29601/29601 [==============================] - 18s 613us/sample - loss: 1.4542 - val_loss: 1.4392
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4489
# Epoch 31: val_loss improved from 1.43813 to 1.43776, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 17s 576us/sample - loss: 1.4489 - val_loss: 1.4378
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4513
# Epoch 32: val_loss improved from 1.43776 to 1.43319, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 16s 533us/sample - loss: 1.4513 - val_loss: 1.4332
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4472
# Epoch 33: val_loss did not improve from 1.43319
# 29601/29601 [==============================] - 17s 562us/sample - loss: 1.4472 - val_loss: 1.4379
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4452
# Epoch 34: val_loss improved from 1.43319 to 1.42941, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 17s 575us/sample - loss: 1.4452 - val_loss: 1.4294
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4446
# Epoch 35: val_loss did not improve from 1.42941
# 29601/29601 [==============================] - 16s 538us/sample - loss: 1.4446 - val_loss: 1.4303
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4430
# Epoch 36: val_loss improved from 1.42941 to 1.42607, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 16s 537us/sample - loss: 1.4430 - val_loss: 1.4261
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4391
# Epoch 37: val_loss did not improve from 1.42607
# 29601/29601 [==============================] - 17s 560us/sample - loss: 1.4391 - val_loss: 1.4284
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4387
# Epoch 38: val_loss improved from 1.42607 to 1.42318, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 618us/sample - loss: 1.4387 - val_loss: 1.4232
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4352
# Epoch 39: val_loss improved from 1.42318 to 1.42147, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 616us/sample - loss: 1.4352 - val_loss: 1.4215
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4364
# Epoch 40: val_loss did not improve from 1.42147
# 29601/29601 [==============================] - 18s 618us/sample - loss: 1.4364 - val_loss: 1.4237
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4309
# Epoch 41: val_loss improved from 1.42147 to 1.42024, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.4309 - val_loss: 1.4202
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4321
# Epoch 42: val_loss did not improve from 1.42024
# 29601/29601 [==============================] - 16s 555us/sample - loss: 1.4321 - val_loss: 1.4214
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4300
# Epoch 43: val_loss improved from 1.42024 to 1.41675, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 619us/sample - loss: 1.4300 - val_loss: 1.4168
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4274
# Epoch 44: val_loss did not improve from 1.41675
# 29601/29601 [==============================] - 18s 612us/sample - loss: 1.4274 - val_loss: 1.4192
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4280
# Epoch 45: val_loss improved from 1.41675 to 1.41566, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 620us/sample - loss: 1.4280 - val_loss: 1.4157
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4232
# Epoch 46: val_loss did not improve from 1.41566
# 29601/29601 [==============================] - 16s 541us/sample - loss: 1.4232 - val_loss: 1.4164
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4246
# Epoch 47: val_loss improved from 1.41566 to 1.41335, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 17s 580us/sample - loss: 1.4246 - val_loss: 1.4134
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4245
# Epoch 48: val_loss did not improve from 1.41335
# 29601/29601 [==============================] - 16s 539us/sample - loss: 1.4245 - val_loss: 1.4173
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4250
# Epoch 49: val_loss did not improve from 1.41335
# 29601/29601 [==============================] - 16s 535us/sample - loss: 1.4250 - val_loss: 1.4155
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4222
# Epoch 50: val_loss improved from 1.41335 to 1.40993, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 16s 538us/sample - loss: 1.4222 - val_loss: 1.4099
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4214
# Epoch 51: val_loss improved from 1.40993 to 1.40928, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 16s 549us/sample - loss: 1.4214 - val_loss: 1.4093
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4187
# Epoch 52: val_loss improved from 1.40928 to 1.40878, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 16s 536us/sample - loss: 1.4187 - val_loss: 1.4088
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4165
# Epoch 53: val_loss did not improve from 1.40878
# 29601/29601 [==============================] - 16s 555us/sample - loss: 1.4165 - val_loss: 1.4096
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4175
# Epoch 54: val_loss did not improve from 1.40878
# 29601/29601 [==============================] - 16s 540us/sample - loss: 1.4175 - val_loss: 1.4128
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4169
# Epoch 55: val_loss improved from 1.40878 to 1.40628, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 16s 538us/sample - loss: 1.4169 - val_loss: 1.4063
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4140
# Epoch 56: val_loss did not improve from 1.40628
# 29601/29601 [==============================] - 16s 541us/sample - loss: 1.4140 - val_loss: 1.4079
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4142
# Epoch 57: val_loss did not improve from 1.40628
# 29601/29601 [==============================] - 17s 571us/sample - loss: 1.4142 - val_loss: 1.4151
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4119
# Epoch 58: val_loss did not improve from 1.40628
# 29601/29601 [==============================] - 18s 606us/sample - loss: 1.4119 - val_loss: 1.4126
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4095
# Epoch 59: val_loss improved from 1.40628 to 1.40482, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.4095 - val_loss: 1.4048
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4097
# Epoch 60: val_loss did not improve from 1.40482
# 29601/29601 [==============================] - 17s 573us/sample - loss: 1.4097 - val_loss: 1.4073
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4117
# Epoch 61: val_loss did not improve from 1.40482
# 29601/29601 [==============================] - 16s 553us/sample - loss: 1.4117 - val_loss: 1.4078
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4058
# Epoch 62: val_loss did not improve from 1.40482
# 29601/29601 [==============================] - 18s 616us/sample - loss: 1.4058 - val_loss: 1.4054
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4066
# Epoch 63: val_loss did not improve from 1.40482
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.4066 - val_loss: 1.4054
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4087
# Epoch 64: val_loss did not improve from 1.40482
# 29601/29601 [==============================] - 17s 563us/sample - loss: 1.4087 - val_loss: 1.4082
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4048
# Epoch 65: val_loss improved from 1.40482 to 1.40217, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 17s 591us/sample - loss: 1.4048 - val_loss: 1.4022
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4014
# Epoch 66: val_loss improved from 1.40217 to 1.40153, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 17s 569us/sample - loss: 1.4014 - val_loss: 1.4015
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4009
# Epoch 67: val_loss did not improve from 1.40153
# 29601/29601 [==============================] - 16s 533us/sample - loss: 1.4009 - val_loss: 1.4046
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4015
# Epoch 68: val_loss did not improve from 1.40153
# 29601/29601 [==============================] - 16s 536us/sample - loss: 1.4015 - val_loss: 1.4044
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4015
# Epoch 69: val_loss improved from 1.40153 to 1.39687, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.4015 - val_loss: 1.3969
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4008
# Epoch 70: val_loss did not improve from 1.39687
# 29601/29601 [==============================] - 16s 524us/sample - loss: 1.4008 - val_loss: 1.3981
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4001
# Epoch 71: val_loss did not improve from 1.39687
# 29601/29601 [==============================] - 17s 588us/sample - loss: 1.4001 - val_loss: 1.3974
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3991
# Epoch 72: val_loss did not improve from 1.39687
# 29601/29601 [==============================] - 17s 577us/sample - loss: 1.3991 - val_loss: 1.4020
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4001
# Epoch 73: val_loss did not improve from 1.39687
# 29601/29601 [==============================] - 16s 538us/sample - loss: 1.4001 - val_loss: 1.3994
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3959
# Epoch 74: val_loss did not improve from 1.39687
# 29601/29601 [==============================] - 16s 536us/sample - loss: 1.3959 - val_loss: 1.3988
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3938
# Epoch 75: val_loss improved from 1.39687 to 1.39339, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 16s 538us/sample - loss: 1.3938 - val_loss: 1.3934
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3932
# Epoch 76: val_loss did not improve from 1.39339
# 29601/29601 [==============================] - 16s 538us/sample - loss: 1.3932 - val_loss: 1.3969
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3940
# Epoch 77: val_loss did not improve from 1.39339
# 29601/29601 [==============================] - 18s 604us/sample - loss: 1.3940 - val_loss: 1.3957
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3927
# Epoch 78: val_loss improved from 1.39339 to 1.39186, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 16s 540us/sample - loss: 1.3927 - val_loss: 1.3919
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3935
# Epoch 79: val_loss did not improve from 1.39186
# 29601/29601 [==============================] - 16s 537us/sample - loss: 1.3935 - val_loss: 1.3961
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3908
# Epoch 80: val_loss did not improve from 1.39186
# 29601/29601 [==============================] - 16s 536us/sample - loss: 1.3908 - val_loss: 1.3970
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3885
# Epoch 81: val_loss did not improve from 1.39186
# 29601/29601 [==============================] - 16s 540us/sample - loss: 1.3885 - val_loss: 1.3963
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3888
# Epoch 82: val_loss did not improve from 1.39186
# 29601/29601 [==============================] - 16s 535us/sample - loss: 1.3888 - val_loss: 1.3948
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3874
# Epoch 83: val_loss did not improve from 1.39186
# 29601/29601 [==============================] - 16s 539us/sample - loss: 1.3874 - val_loss: 1.3919
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3884
# Epoch 84: val_loss did not improve from 1.39186
# 29601/29601 [==============================] - 16s 535us/sample - loss: 1.3884 - val_loss: 1.3933
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3897
# Epoch 85: val_loss improved from 1.39186 to 1.39178, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 16s 542us/sample - loss: 1.3897 - val_loss: 1.3918
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3845
# Epoch 86: val_loss did not improve from 1.39178
# 29601/29601 [==============================] - 16s 537us/sample - loss: 1.3845 - val_loss: 1.3934
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3830
# Epoch 87: val_loss did not improve from 1.39178
# 29601/29601 [==============================] - 16s 535us/sample - loss: 1.3830 - val_loss: 1.3937
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3827
# Epoch 88: val_loss did not improve from 1.39178
# 29601/29601 [==============================] - 16s 533us/sample - loss: 1.3827 - val_loss: 1.3928
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3856
# Epoch 89: val_loss did not improve from 1.39178
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.3856 - val_loss: 1.3938
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3829
# Epoch 90: val_loss did not improve from 1.39178
# 29601/29601 [==============================] - 17s 569us/sample - loss: 1.3829 - val_loss: 1.3934
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3810
# Epoch 91: val_loss improved from 1.39178 to 1.38673, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 16s 538us/sample - loss: 1.3810 - val_loss: 1.3867
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3825
# Epoch 92: val_loss did not improve from 1.38673
# 29601/29601 [==============================] - 16s 535us/sample - loss: 1.3825 - val_loss: 1.3915
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3811
# Epoch 93: val_loss did not improve from 1.38673
# 29601/29601 [==============================] - 16s 533us/sample - loss: 1.3811 - val_loss: 1.3915
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3813
# Epoch 94: val_loss did not improve from 1.38673
# 29601/29601 [==============================] - 16s 537us/sample - loss: 1.3813 - val_loss: 1.3910
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3800
# Epoch 95: val_loss did not improve from 1.38673
# 29601/29601 [==============================] - 18s 615us/sample - loss: 1.3800 - val_loss: 1.3875
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3786
# Epoch 96: val_loss did not improve from 1.38673
# 29601/29601 [==============================] - 18s 614us/sample - loss: 1.3786 - val_loss: 1.3912
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3790
# Epoch 97: val_loss improved from 1.38673 to 1.38572, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_0.h5
# 29601/29601 [==============================] - 18s 618us/sample - loss: 1.3790 - val_loss: 1.3857
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3752
# Epoch 98: val_loss did not improve from 1.38572
# 29601/29601 [==============================] - 18s 613us/sample - loss: 1.3752 - val_loss: 1.3876
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3775
# Epoch 99: val_loss did not improve from 1.38572
# 29601/29601 [==============================] - 18s 612us/sample - loss: 1.3775 - val_loss: 1.3893
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3740
# Epoch 100: val_loss did not improve from 1.38572
# 29601/29601 [==============================] - 18s 613us/sample - loss: 1.3740 - val_loss: 1.3869
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3730
# Epoch 1: val_loss improved from inf to 1.38932, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_1.h5
# 29601/29601 [==============================] - 18s 617us/sample - loss: 1.3730 - val_loss: 1.3893
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3769
# Epoch 2: val_loss improved from 1.38932 to 1.38787, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_1.h5
# 29601/29601 [==============================] - 18s 615us/sample - loss: 1.3769 - val_loss: 1.3879
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3746
# Epoch 3: val_loss did not improve from 1.38787
# 29601/29601 [==============================] - 16s 548us/sample - loss: 1.3746 - val_loss: 1.3912
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3725
# Epoch 4: val_loss did not improve from 1.38787
# 29601/29601 [==============================] - 17s 564us/sample - loss: 1.3725 - val_loss: 1.3933
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3724
# Epoch 5: val_loss improved from 1.38787 to 1.38667, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_1.h5
# 29601/29601 [==============================] - 18s 610us/sample - loss: 1.3724 - val_loss: 1.3867
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3689
# Epoch 6: val_loss improved from 1.38667 to 1.38508, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_1.h5
# 29601/29601 [==============================] - 18s 614us/sample - loss: 1.3689 - val_loss: 1.3851
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3697
# Epoch 7: val_loss improved from 1.38508 to 1.38400, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_1.h5
# 29601/29601 [==============================] - 16s 553us/sample - loss: 1.3697 - val_loss: 1.3840
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3671
# Epoch 8: val_loss did not improve from 1.38400
# 29601/29601 [==============================] - 17s 578us/sample - loss: 1.3671 - val_loss: 1.3886
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3705
# Epoch 9: val_loss did not improve from 1.38400
# 29601/29601 [==============================] - 18s 616us/sample - loss: 1.3705 - val_loss: 1.3897
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3668
# Epoch 10: val_loss improved from 1.38400 to 1.38361, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_1.h5
# 29601/29601 [==============================] - 19s 626us/sample - loss: 1.3668 - val_loss: 1.3836
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3699
# Epoch 11: val_loss did not improve from 1.38361
# 29601/29601 [==============================] - 16s 535us/sample - loss: 1.3699 - val_loss: 1.3922
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3662
# Epoch 12: val_loss did not improve from 1.38361
# 29601/29601 [==============================] - 16s 532us/sample - loss: 1.3662 - val_loss: 1.3861
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3653
# Epoch 13: val_loss did not improve from 1.38361
# 29601/29601 [==============================] - 16s 533us/sample - loss: 1.3653 - val_loss: 1.3877
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3675
# Epoch 14: val_loss did not improve from 1.38361
# 29601/29601 [==============================] - 16s 531us/sample - loss: 1.3675 - val_loss: 1.3876
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3661
# Epoch 15: val_loss did not improve from 1.38361
# 29601/29601 [==============================] - 16s 539us/sample - loss: 1.3661 - val_loss: 1.3851
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3670
# Epoch 16: val_loss did not improve from 1.38361
# 29601/29601 [==============================] - 16s 539us/sample - loss: 1.3670 - val_loss: 1.3908
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3628
# Epoch 17: val_loss did not improve from 1.38361
# 29601/29601 [==============================] - 16s 533us/sample - loss: 1.3628 - val_loss: 1.3874
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3634
# Epoch 18: val_loss did not improve from 1.38361
# 29601/29601 [==============================] - 16s 529us/sample - loss: 1.3634 - val_loss: 1.3869
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3656
# Epoch 19: val_loss did not improve from 1.38361
# 29601/29601 [==============================] - 16s 533us/sample - loss: 1.3656 - val_loss: 1.3879
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3637
# Epoch 20: val_loss did not improve from 1.38361
# 29601/29601 [==============================] - 16s 554us/sample - loss: 1.3637 - val_loss: 1.3876
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3654
# Epoch 21: val_loss improved from 1.38361 to 1.38322, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_1.h5
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.3654 - val_loss: 1.3832
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3636
# Epoch 22: val_loss did not improve from 1.38322
# 29601/29601 [==============================] - 16s 548us/sample - loss: 1.3636 - val_loss: 1.3840
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3619
# Epoch 23: val_loss improved from 1.38322 to 1.38009, saving model to ./checkpoints/Adaptive_prune_model_remove_bio_1.h5
# 29601/29601 [==============================] - 16s 537us/sample - loss: 1.3619 - val_loss: 1.3801
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3642
# Epoch 24: val_loss did not improve from 1.38009
# 29601/29601 [==============================] - 16s 531us/sample - loss: 1.3642 - val_loss: 1.3887
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3665
# Epoch 25: val_loss did not improve from 1.38009
# 29601/29601 [==============================] - 17s 584us/sample - loss: 1.3665 - val_loss: 1.3877
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3681
# Epoch 26: val_loss did not improve from 1.38009
# 29601/29601 [==============================] - 17s 561us/sample - loss: 1.3681 - val_loss: 1.3843
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3636
# Epoch 27: val_loss did not improve from 1.38009
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.3636 - val_loss: 1.3884
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3603
# Epoch 28: val_loss did not improve from 1.38009
# 29601/29601 [==============================] - 18s 614us/sample - loss: 1.3603 - val_loss: 1.3860
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3608
# Epoch 29: val_loss did not improve from 1.38009
# 29601/29601 [==============================] - 18s 614us/sample - loss: 1.3608 - val_loss: 1.3871
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3631
# Epoch 30: val_loss did not improve from 1.38009
# 29601/29601 [==============================] - 18s 616us/sample - loss: 1.3631 - val_loss: 1.3834
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3623
# Epoch 31: val_loss did not improve from 1.38009
# ...
# Epoch 31: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.2921 - val_loss: 1.3974
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2984
# Epoch 32: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 17s 575us/sample - loss: 1.2984 - val_loss: 1.3935
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2951
# Epoch 33: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.2951 - val_loss: 1.3945
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2924
# Epoch 34: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.2924 - val_loss: 1.3943
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2932
# Epoch 35: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 16s 536us/sample - loss: 1.2932 - val_loss: 1.3967
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2999
# Epoch 36: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 16s 552us/sample - loss: 1.2999 - val_loss: 1.3955
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3038
# Epoch 37: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 16s 528us/sample - loss: 1.3038 - val_loss: 1.4026
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3015
# Epoch 38: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.3015 - val_loss: 1.3970
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3052
# Epoch 39: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 17s 580us/sample - loss: 1.3052 - val_loss: 1.3960
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3069
# Epoch 40: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 17s 588us/sample - loss: 1.3069 - val_loss: 1.3955
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3080
# Epoch 41: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 16s 528us/sample - loss: 1.3080 - val_loss: 1.3986
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3055
# Epoch 42: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 17s 577us/sample - loss: 1.3055 - val_loss: 1.3970
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3137
# Epoch 43: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.3137 - val_loss: 1.3968
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3126
# Epoch 44: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 18s 597us/sample - loss: 1.3126 - val_loss: 1.3966
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3191
# Epoch 45: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 17s 576us/sample - loss: 1.3191 - val_loss: 1.3907
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3183
# Epoch 46: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 522us/sample - loss: 1.3183 - val_loss: 1.3995
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3190
# Epoch 47: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 519us/sample - loss: 1.3190 - val_loss: 1.3943
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3288
# Epoch 48: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 519us/sample - loss: 1.3288 - val_loss: 1.3914
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4460
# Epoch 49: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 16s 538us/sample - loss: 1.4460 - val_loss: 1.4033
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3740
# Epoch 50: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 520us/sample - loss: 1.3740 - val_loss: 1.4017
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3408
# Epoch 51: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 520us/sample - loss: 1.3408 - val_loss: 1.3913
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3428
# Epoch 52: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 520us/sample - loss: 1.3428 - val_loss: 1.3948
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3414
# Epoch 53: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 520us/sample - loss: 1.3414 - val_loss: 1.3998
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3376
# Epoch 54: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 520us/sample - loss: 1.3376 - val_loss: 1.3960
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3418
# Epoch 55: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 521us/sample - loss: 1.3418 - val_loss: 1.4003
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3367
# Epoch 56: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 518us/sample - loss: 1.3367 - val_loss: 1.3998
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3334
# Epoch 57: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 519us/sample - loss: 1.3334 - val_loss: 1.3956
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3334
# Epoch 58: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 17s 569us/sample - loss: 1.3334 - val_loss: 1.4003
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3294
# Epoch 59: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 16s 552us/sample - loss: 1.3294 - val_loss: 1.3985
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3299
# Epoch 60: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 521us/sample - loss: 1.3299 - val_loss: 1.3981
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3266
# Epoch 61: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 519us/sample - loss: 1.3266 - val_loss: 1.4010
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3284
# Epoch 62: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 17s 573us/sample - loss: 1.3284 - val_loss: 1.3950
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3223
# Epoch 63: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.3223 - val_loss: 1.4006
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3264
# Epoch 64: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 16s 546us/sample - loss: 1.3264 - val_loss: 1.3911
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3224
# Epoch 65: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 521us/sample - loss: 1.3224 - val_loss: 1.3967
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3188
# Epoch 66: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 519us/sample - loss: 1.3188 - val_loss: 1.3975
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3200
# Epoch 67: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 520us/sample - loss: 1.3200 - val_loss: 1.3968
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3194
# Epoch 68: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 520us/sample - loss: 1.3194 - val_loss: 1.4002
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3191
# Epoch 69: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 520us/sample - loss: 1.3191 - val_loss: 1.3974
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3193
# Epoch 70: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 519us/sample - loss: 1.3193 - val_loss: 1.4013
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3170
# Epoch 71: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 518us/sample - loss: 1.3170 - val_loss: 1.4015
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3162
# Epoch 72: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 519us/sample - loss: 1.3162 - val_loss: 1.3976
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3162
# Epoch 73: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 519us/sample - loss: 1.3162 - val_loss: 1.3946
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3131
# Epoch 74: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 517us/sample - loss: 1.3131 - val_loss: 1.3985
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3150
# Epoch 75: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 522us/sample - loss: 1.3150 - val_loss: 1.4054
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3119
# Epoch 76: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 523us/sample - loss: 1.3119 - val_loss: 1.3984
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3137
# Epoch 77: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 17s 574us/sample - loss: 1.3137 - val_loss: 1.3973
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3128
# Epoch 78: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 17s 563us/sample - loss: 1.3128 - val_loss: 1.3964
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3106
# Epoch 79: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.3106 - val_loss: 1.4013
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3091
# Epoch 80: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.3091 - val_loss: 1.3999
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3084
# Epoch 81: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 16s 527us/sample - loss: 1.3084 - val_loss: 1.4045
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3113
# Epoch 82: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 517us/sample - loss: 1.3113 - val_loss: 1.4053
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3102
# Epoch 83: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 519us/sample - loss: 1.3102 - val_loss: 1.3938
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3070
# Epoch 84: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 518us/sample - loss: 1.3070 - val_loss: 1.3959
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3072
# Epoch 85: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 520us/sample - loss: 1.3072 - val_loss: 1.3925
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3072
# Epoch 86: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 518us/sample - loss: 1.3072 - val_loss: 1.4023
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3075
# Epoch 87: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 520us/sample - loss: 1.3075 - val_loss: 1.3987
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3047
# Epoch 88: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 519us/sample - loss: 1.3047 - val_loss: 1.3982
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3052
# Epoch 89: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 519us/sample - loss: 1.3052 - val_loss: 1.3976
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3040
# Epoch 90: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 514us/sample - loss: 1.3040 - val_loss: 1.4009
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2992
# Epoch 91: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 519us/sample - loss: 1.2992 - val_loss: 1.4007
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3023
# Epoch 92: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 16s 526us/sample - loss: 1.3023 - val_loss: 1.3923
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3062
# Epoch 93: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 16s 553us/sample - loss: 1.3062 - val_loss: 1.3964
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3020
# Epoch 94: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 17s 588us/sample - loss: 1.3020 - val_loss: 1.4002
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3014
# Epoch 95: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 17s 565us/sample - loss: 1.3014 - val_loss: 1.3942
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3007
# Epoch 96: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 16s 524us/sample - loss: 1.3007 - val_loss: 1.3983
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2991
# Epoch 97: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 15s 518us/sample - loss: 1.2991 - val_loss: 1.3954
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3014
# Epoch 98: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 16s 540us/sample - loss: 1.3014 - val_loss: 1.3986
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3017
# Epoch 99: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.3017 - val_loss: 1.3963
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3011
# Epoch 100: val_loss did not improve from 1.38846
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.3011 - val_loss: 1.4016
