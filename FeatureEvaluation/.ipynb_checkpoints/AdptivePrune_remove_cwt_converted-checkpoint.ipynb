# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-07 05:34:59.671280: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Feature_extraction_remove_cwt_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-07 05:35:33.067259: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:33.082865: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:33.083165: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:33.087463: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:33.087743: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:33.087959: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:33.192488: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:33.192752: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:33.192972: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:33.193157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-07 05:35:33.195093: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 23)
# Train on 29601 samples, validate on 3694 samples
# 2023-11-07 05:35:39.787252: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:39.787633: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:39.787915: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:39.788422: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:39.788697: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 05:35:39.788915: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-07 05:35:39.788990: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-07 05:35:39.998939: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-07 05:35:40.699033: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_26/lstm_cell_26/kernel/v/Assign' id:16942 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_26/lstm_cell_26/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_26/lstm_cell_26/kernel/v, training/Adam/lstm_26/lstm_cell_26/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-11-07 05:35:51.706686: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 29601/29601 [==============================] - ETA: 0s - loss: 4.0786
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-07 05:36:20.932573: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:6248 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 2.65870, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 41s 1ms/sample - loss: 4.0786 - val_loss: 2.6587
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.9367
# Epoch 2: val_loss improved from 2.65870 to 1.64532, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.9367 - val_loss: 1.6453
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6386
# Epoch 3: val_loss improved from 1.64532 to 1.58560, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.6386 - val_loss: 1.5856
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5844
# Epoch 4: val_loss improved from 1.58560 to 1.55434, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.5844 - val_loss: 1.5543
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5587
# Epoch 5: val_loss improved from 1.55434 to 1.53028, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.5587 - val_loss: 1.5303
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5430
# Epoch 6: val_loss improved from 1.53028 to 1.51906, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.5430 - val_loss: 1.5191
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5327
# Epoch 7: val_loss improved from 1.51906 to 1.50111, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.5327 - val_loss: 1.5011
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5210
# Epoch 8: val_loss improved from 1.50111 to 1.49622, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.5210 - val_loss: 1.4962
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5157
# Epoch 9: val_loss improved from 1.49622 to 1.48790, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.5157 - val_loss: 1.4879
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5084
# Epoch 10: val_loss improved from 1.48790 to 1.48303, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.5084 - val_loss: 1.4830
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5048
# Epoch 11: val_loss improved from 1.48303 to 1.47603, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.5048 - val_loss: 1.4760
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5000
# Epoch 12: val_loss improved from 1.47603 to 1.47377, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.5000 - val_loss: 1.4738
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4939
# Epoch 13: val_loss did not improve from 1.47377
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4939 - val_loss: 1.4746
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4935
# Epoch 14: val_loss improved from 1.47377 to 1.47110, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4935 - val_loss: 1.4711
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4898
# Epoch 15: val_loss improved from 1.47110 to 1.46839, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4898 - val_loss: 1.4684
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4823
# Epoch 16: val_loss improved from 1.46839 to 1.46096, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4823 - val_loss: 1.4610
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4816
# Epoch 17: val_loss improved from 1.46096 to 1.45711, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4816 - val_loss: 1.4571
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4783
# Epoch 18: val_loss improved from 1.45711 to 1.45552, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4783 - val_loss: 1.4555
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4775
# Epoch 19: val_loss improved from 1.45552 to 1.45285, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4775 - val_loss: 1.4529
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4741
# Epoch 20: val_loss did not improve from 1.45285
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4741 - val_loss: 1.4534
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4737
# Epoch 21: val_loss improved from 1.45285 to 1.44680, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 31s 1ms/sample - loss: 1.4737 - val_loss: 1.4468
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4725
# Epoch 22: val_loss did not improve from 1.44680
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4725 - val_loss: 1.4534
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4669
# Epoch 23: val_loss improved from 1.44680 to 1.44540, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4669 - val_loss: 1.4454
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4653
# Epoch 24: val_loss improved from 1.44540 to 1.43784, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4653 - val_loss: 1.4378
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4627
# Epoch 25: val_loss improved from 1.43784 to 1.43705, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4627 - val_loss: 1.4370
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4594
# Epoch 26: val_loss improved from 1.43705 to 1.43701, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 991us/sample - loss: 1.4594 - val_loss: 1.4370
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4586
# Epoch 27: val_loss did not improve from 1.43701
# 29601/29601 [==============================] - 27s 916us/sample - loss: 1.4586 - val_loss: 1.4385
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4543
# Epoch 28: val_loss improved from 1.43701 to 1.43453, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 28s 935us/sample - loss: 1.4543 - val_loss: 1.4345
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4539
# Epoch 29: val_loss did not improve from 1.43453
# 29601/29601 [==============================] - 28s 949us/sample - loss: 1.4539 - val_loss: 1.4402
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4532
# Epoch 30: val_loss improved from 1.43453 to 1.42998, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 966us/sample - loss: 1.4532 - val_loss: 1.4300
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4499
# Epoch 31: val_loss improved from 1.42998 to 1.42959, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 28s 948us/sample - loss: 1.4499 - val_loss: 1.4296
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4513
# Epoch 32: val_loss improved from 1.42959 to 1.42907, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 28s 953us/sample - loss: 1.4513 - val_loss: 1.4291
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4508
# Epoch 33: val_loss improved from 1.42907 to 1.42501, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 28s 953us/sample - loss: 1.4508 - val_loss: 1.4250
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4457
# Epoch 34: val_loss improved from 1.42501 to 1.42194, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 28s 939us/sample - loss: 1.4457 - val_loss: 1.4219
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4440
# Epoch 35: val_loss did not improve from 1.42194
# 29601/29601 [==============================] - 28s 948us/sample - loss: 1.4440 - val_loss: 1.4306
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4422
# Epoch 36: val_loss did not improve from 1.42194
# 29601/29601 [==============================] - 28s 954us/sample - loss: 1.4422 - val_loss: 1.4241
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4407
# Epoch 37: val_loss improved from 1.42194 to 1.42017, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 976us/sample - loss: 1.4407 - val_loss: 1.4202
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4388
# Epoch 38: val_loss did not improve from 1.42017
# 29601/29601 [==============================] - 29s 964us/sample - loss: 1.4388 - val_loss: 1.4220
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4373
# Epoch 39: val_loss improved from 1.42017 to 1.41772, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 994us/sample - loss: 1.4373 - val_loss: 1.4177
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4364
# Epoch 40: val_loss did not improve from 1.41772
# 29601/29601 [==============================] - 29s 994us/sample - loss: 1.4364 - val_loss: 1.4196
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4325
# Epoch 41: val_loss improved from 1.41772 to 1.41475, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 990us/sample - loss: 1.4325 - val_loss: 1.4147
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4321
# Epoch 42: val_loss did not improve from 1.41475
# 29601/29601 [==============================] - 29s 990us/sample - loss: 1.4321 - val_loss: 1.4178
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4334
# Epoch 43: val_loss did not improve from 1.41475
# 29601/29601 [==============================] - 29s 978us/sample - loss: 1.4334 - val_loss: 1.4157
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4310
# Epoch 44: val_loss improved from 1.41475 to 1.41416, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 979us/sample - loss: 1.4310 - val_loss: 1.4142
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4280
# Epoch 45: val_loss improved from 1.41416 to 1.41184, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 992us/sample - loss: 1.4280 - val_loss: 1.4118
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4272
# Epoch 46: val_loss did not improve from 1.41184
# 29601/29601 [==============================] - 29s 996us/sample - loss: 1.4272 - val_loss: 1.4121
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4277
# Epoch 47: val_loss improved from 1.41184 to 1.41171, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4277 - val_loss: 1.4117
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4261
# Epoch 48: val_loss improved from 1.41171 to 1.40800, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 989us/sample - loss: 1.4261 - val_loss: 1.4080
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4234
# Epoch 49: val_loss did not improve from 1.40800
# 29601/29601 [==============================] - 29s 984us/sample - loss: 1.4234 - val_loss: 1.4090
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4233
# Epoch 50: val_loss did not improve from 1.40800
# 29601/29601 [==============================] - 29s 990us/sample - loss: 1.4233 - val_loss: 1.4107
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4231
# Epoch 51: val_loss did not improve from 1.40800
# 29601/29601 [==============================] - 29s 982us/sample - loss: 1.4231 - val_loss: 1.4119
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4218
# Epoch 52: val_loss did not improve from 1.40800
# 29601/29601 [==============================] - 29s 985us/sample - loss: 1.4218 - val_loss: 1.4124
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4223
# Epoch 53: val_loss improved from 1.40800 to 1.40590, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 978us/sample - loss: 1.4223 - val_loss: 1.4059
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4193
# Epoch 54: val_loss did not improve from 1.40590
# 29601/29601 [==============================] - 30s 998us/sample - loss: 1.4193 - val_loss: 1.4068
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4178
# Epoch 55: val_loss improved from 1.40590 to 1.40499, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 995us/sample - loss: 1.4178 - val_loss: 1.4050
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4183
# Epoch 56: val_loss improved from 1.40499 to 1.40274, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 985us/sample - loss: 1.4183 - val_loss: 1.4027
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4166
# Epoch 57: val_loss did not improve from 1.40274
# 29601/29601 [==============================] - 29s 986us/sample - loss: 1.4166 - val_loss: 1.4103
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4153
# Epoch 58: val_loss did not improve from 1.40274
# 29601/29601 [==============================] - 29s 982us/sample - loss: 1.4153 - val_loss: 1.4032
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4127
# Epoch 59: val_loss did not improve from 1.40274
# 29601/29601 [==============================] - 29s 971us/sample - loss: 1.4127 - val_loss: 1.4048
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4166
# Epoch 60: val_loss improved from 1.40274 to 1.40267, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 982us/sample - loss: 1.4166 - val_loss: 1.4027
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4140
# Epoch 61: val_loss did not improve from 1.40267
# 29601/29601 [==============================] - 29s 986us/sample - loss: 1.4140 - val_loss: 1.4044
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4113
# Epoch 62: val_loss did not improve from 1.40267
# 29601/29601 [==============================] - 29s 993us/sample - loss: 1.4113 - val_loss: 1.4038
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4076
# Epoch 63: val_loss did not improve from 1.40267
# 29601/29601 [==============================] - 29s 990us/sample - loss: 1.4076 - val_loss: 1.4030
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4087
# Epoch 64: val_loss did not improve from 1.40267
# 29601/29601 [==============================] - 29s 988us/sample - loss: 1.4087 - val_loss: 1.4035
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4085
# Epoch 65: val_loss improved from 1.40267 to 1.39966, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 993us/sample - loss: 1.4085 - val_loss: 1.3997
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4051
# Epoch 66: val_loss did not improve from 1.39966
# 29601/29601 [==============================] - 29s 978us/sample - loss: 1.4051 - val_loss: 1.4007
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4048
# Epoch 67: val_loss improved from 1.39966 to 1.39681, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 988us/sample - loss: 1.4048 - val_loss: 1.3968
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4049
# Epoch 68: val_loss did not improve from 1.39681
# 29601/29601 [==============================] - 29s 990us/sample - loss: 1.4049 - val_loss: 1.3995
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4053
# Epoch 69: val_loss improved from 1.39681 to 1.39623, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4053 - val_loss: 1.3962
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4014
# Epoch 70: val_loss did not improve from 1.39623
# 29601/29601 [==============================] - 29s 989us/sample - loss: 1.4014 - val_loss: 1.3981
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4032
# Epoch 71: val_loss improved from 1.39623 to 1.39390, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4032 - val_loss: 1.3939
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4004
# Epoch 72: val_loss did not improve from 1.39390
# 29601/29601 [==============================] - 29s 985us/sample - loss: 1.4004 - val_loss: 1.3955
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3993
# Epoch 73: val_loss improved from 1.39390 to 1.39213, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 975us/sample - loss: 1.3993 - val_loss: 1.3921
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4004
# Epoch 74: val_loss did not improve from 1.39213
# 29601/29601 [==============================] - 29s 978us/sample - loss: 1.4004 - val_loss: 1.3973
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4001
# Epoch 75: val_loss improved from 1.39213 to 1.39170, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.4001 - val_loss: 1.3917
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3972
# Epoch 76: val_loss did not improve from 1.39170
# 29601/29601 [==============================] - 29s 990us/sample - loss: 1.3972 - val_loss: 1.3949
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3951
# Epoch 77: val_loss did not improve from 1.39170
# 29601/29601 [==============================] - 29s 967us/sample - loss: 1.3951 - val_loss: 1.3955
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3954
# Epoch 78: val_loss improved from 1.39170 to 1.39168, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 28s 952us/sample - loss: 1.3954 - val_loss: 1.3917
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3948
# Epoch 79: val_loss improved from 1.39168 to 1.39045, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 24s 808us/sample - loss: 1.3948 - val_loss: 1.3904
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3935
# Epoch 80: val_loss did not improve from 1.39045
# 29601/29601 [==============================] - 28s 948us/sample - loss: 1.3935 - val_loss: 1.3920
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3924
# Epoch 81: val_loss improved from 1.39045 to 1.38958, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 977us/sample - loss: 1.3924 - val_loss: 1.3896
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3923
# Epoch 82: val_loss did not improve from 1.38958
# 29601/29601 [==============================] - 28s 944us/sample - loss: 1.3923 - val_loss: 1.3965
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3925
# Epoch 83: val_loss improved from 1.38958 to 1.38750, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 28s 963us/sample - loss: 1.3925 - val_loss: 1.3875
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3881
# Epoch 84: val_loss improved from 1.38750 to 1.38749, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 977us/sample - loss: 1.3881 - val_loss: 1.3875
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3897
# Epoch 85: val_loss improved from 1.38749 to 1.38489, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 28s 954us/sample - loss: 1.3897 - val_loss: 1.3849
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3874
# Epoch 86: val_loss did not improve from 1.38489
# 29601/29601 [==============================] - 28s 955us/sample - loss: 1.3874 - val_loss: 1.3923
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3873
# Epoch 87: val_loss did not improve from 1.38489
# 29601/29601 [==============================] - 28s 962us/sample - loss: 1.3873 - val_loss: 1.3866
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3831
# Epoch 88: val_loss improved from 1.38489 to 1.38260, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 29s 984us/sample - loss: 1.3831 - val_loss: 1.3826
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3841
# Epoch 89: val_loss did not improve from 1.38260
# 29601/29601 [==============================] - 28s 963us/sample - loss: 1.3841 - val_loss: 1.3866
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3838
# Epoch 90: val_loss did not improve from 1.38260
# 29601/29601 [==============================] - 28s 962us/sample - loss: 1.3838 - val_loss: 1.3843
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3851
# Epoch 91: val_loss did not improve from 1.38260
# 29601/29601 [==============================] - 28s 950us/sample - loss: 1.3851 - val_loss: 1.3839
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3823
# Epoch 92: val_loss did not improve from 1.38260
# 29601/29601 [==============================] - 28s 956us/sample - loss: 1.3823 - val_loss: 1.3845
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3795
# Epoch 93: val_loss improved from 1.38260 to 1.37989, saving model to ./checkpoints/Feature_extraction_remove_cwt_0.h5
# 29601/29601 [==============================] - 28s 945us/sample - loss: 1.3795 - val_loss: 1.3799
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3793
# Epoch 94: val_loss did not improve from 1.37989
# 29601/29601 [==============================] - 28s 942us/sample - loss: 1.3793 - val_loss: 1.3832
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3820
# Epoch 95: val_loss did not improve from 1.37989
# 29601/29601 [==============================] - 28s 947us/sample - loss: 1.3820 - val_loss: 1.3868
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3812
# Epoch 96: val_loss did not improve from 1.37989
# 29601/29601 [==============================] - 29s 964us/sample - loss: 1.3812 - val_loss: 1.3834
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3792
# Epoch 97: val_loss did not improve from 1.37989
# 29601/29601 [==============================] - 29s 965us/sample - loss: 1.3792 - val_loss: 1.3808
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3788
# Epoch 98: val_loss did not improve from 1.37989
# 29601/29601 [==============================] - 28s 944us/sample - loss: 1.3788 - val_loss: 1.3811
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3762
# Epoch 99: val_loss did not improve from 1.37989
# 29601/29601 [==============================] - 28s 937us/sample - loss: 1.3762 - val_loss: 1.3815
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3771
# Epoch 100: val_loss did not improve from 1.37989
# 29601/29601 [==============================] - 28s 957us/sample - loss: 1.3771 - val_loss: 1.3814
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3759
# Epoch 1: val_loss improved from inf to 1.38411, saving model to ./checkpoints/Feature_extraction_remove_cwt_1.h5
# 29601/29601 [==============================] - 28s 960us/sample - loss: 1.3759 - val_loss: 1.3841
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3770
# Epoch 2: val_loss improved from 1.38411 to 1.37996, saving model to ./checkpoints/Feature_extraction_remove_cwt_1.h5
# 29601/29601 [==============================] - 28s 952us/sample - loss: 1.3770 - val_loss: 1.3800
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3736
# Epoch 3: val_loss did not improve from 1.37996
# 29601/29601 [==============================] - 28s 941us/sample - loss: 1.3736 - val_loss: 1.3800
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3731
# Epoch 4: val_loss improved from 1.37996 to 1.37855, saving model to ./checkpoints/Feature_extraction_remove_cwt_1.h5
# 29601/29601 [==============================] - 29s 963us/sample - loss: 1.3731 - val_loss: 1.3785
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3712
# Epoch 5: val_loss did not improve from 1.37855
# 29601/29601 [==============================] - 28s 957us/sample - loss: 1.3712 - val_loss: 1.3800
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3711
# Epoch 6: val_loss improved from 1.37855 to 1.37778, saving model to ./checkpoints/Feature_extraction_remove_cwt_1.h5
# 29601/29601 [==============================] - 28s 957us/sample - loss: 1.3711 - val_loss: 1.3778
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3710
# Epoch 7: val_loss improved from 1.37778 to 1.37717, saving model to ./checkpoints/Feature_extraction_remove_cwt_1.h5
# 29601/29601 [==============================] - 28s 952us/sample - loss: 1.3710 - val_loss: 1.3772
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3697
# Epoch 8: val_loss did not improve from 1.37717
# 29601/29601 [==============================] - 28s 950us/sample - loss: 1.3697 - val_loss: 1.3772
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3699
# Epoch 9: val_loss did not improve from 1.37717
# 29601/29601 [==============================] - 28s 952us/sample - loss: 1.3699 - val_loss: 1.3808
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3689
# Epoch 10: val_loss improved from 1.37717 to 1.37220, saving model to ./checkpoints/Feature_extraction_remove_cwt_1.h5
# 29601/29601 [==============================] - 29s 963us/sample - loss: 1.3689 - val_loss: 1.3722
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3661
# Epoch 11: val_loss did not improve from 1.37220
# 29601/29601 [==============================] - 28s 943us/sample - loss: 1.3661 - val_loss: 1.3735
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3685
# Epoch 12: val_loss did not improve from 1.37220
# 29601/29601 [==============================] - 28s 942us/sample - loss: 1.3685 - val_loss: 1.3782
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3666
# Epoch 13: val_loss improved from 1.37220 to 1.37188, saving model to ./checkpoints/Feature_extraction_remove_cwt_1.h5
# 29601/29601 [==============================] - 28s 951us/sample - loss: 1.3666 - val_loss: 1.3719
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3677
# Epoch 14: val_loss did not improve from 1.37188
# 29601/29601 [==============================] - 28s 950us/sample - loss: 1.3677 - val_loss: 1.3721
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3636
# Epoch 15: val_loss did not improve from 1.37188
# 29601/29601 [==============================] - 29s 973us/sample - loss: 1.3636 - val_loss: 1.3768
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3609
# Epoch 16: val_loss did not improve from 1.37188
# 29601/29601 [==============================] - 28s 942us/sample - loss: 1.3609 - val_loss: 1.3819
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3645
# Epoch 17: val_loss did not improve from 1.37188
# 29601/29601 [==============================] - 28s 948us/sample - loss: 1.3645 - val_loss: 1.3755
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3629
# Epoch 18: val_loss did not improve from 1.37188
# 29601/29601 [==============================] - 28s 947us/sample - loss: 1.3629 - val_loss: 1.3803
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3642
# Epoch 19: val_loss improved from 1.37188 to 1.37172, saving model to ./checkpoints/Feature_extraction_remove_cwt_1.h5
# 29601/29601 [==============================] - 28s 952us/sample - loss: 1.3642 - val_loss: 1.3717
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3619
# Epoch 20: val_loss did not improve from 1.37172
# 29601/29601 [==============================] - 28s 961us/sample - loss: 1.3619 - val_loss: 1.3757
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3609
# Epoch 21: val_loss did not improve from 1.37172
# 29601/29601 [==============================] - 28s 949us/sample - loss: 1.3609 - val_loss: 1.3764
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3633
# Epoch 22: val_loss improved from 1.37172 to 1.37166, saving model to ./checkpoints/Feature_extraction_remove_cwt_1.h5
# 29601/29601 [==============================] - 29s 974us/sample - loss: 1.3633 - val_loss: 1.3717
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3634
# Epoch 23: val_loss did not improve from 1.37166
# 29601/29601 [==============================] - 28s 946us/sample - loss: 1.3634 - val_loss: 1.3720
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3617
# Epoch 24: val_loss improved from 1.37166 to 1.37138, saving model to ./checkpoints/Feature_extraction_remove_cwt_1.h5
# 29601/29601 [==============================] - 28s 956us/sample - loss: 1.3617 - val_loss: 1.3714
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3637
# Epoch 25: val_loss did not improve from 1.37138
# 29601/29601 [==============================] - 28s 946us/sample - loss: 1.3637 - val_loss: 1.3720
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3625
# Epoch 26: val_loss did not improve from 1.37138
# 29601/29601 [==============================] - 28s 954us/sample - loss: 1.3625 - val_loss: 1.3753
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3609
# Epoch 27: val_loss did not improve from 1.37138
# 29601/29601 [==============================] - 28s 957us/sample - loss: 1.3609 - val_loss: 1.3836
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3604
# Epoch 28: val_loss did not improve from 1.37138
# 29601/29601 [==============================] - 28s 932us/sample - loss: 1.3604 - val_loss: 1.3760
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3577
# Epoch 29: val_loss improved from 1.37138 to 1.36994, saving model to ./checkpoints/Feature_extraction_remove_cwt_1.h5
# 29601/29601 [==============================] - 28s 938us/sample - loss: 1.3577 - val_loss: 1.3699
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3575
# Epoch 30: val_loss did not improve from 1.36994
# 29601/29601 [==============================] - 28s 938us/sample - loss: 1.3575 - val_loss: 1.3731
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3569
# Epoch 31: val_loss did not improve from 1.36994
# 29601/29601 [==============================] - 28s 930us/sample - loss: 1.3569 - val_loss: 1.3732
# Epoch 32/100
# ...
# Epoch 31: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 657us/sample - loss: 1.2909 - val_loss: 1.3559
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2877
# Epoch 32: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 18s 620us/sample - loss: 1.2877 - val_loss: 1.3549
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2977
# Epoch 33: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 562us/sample - loss: 1.2977 - val_loss: 1.3518
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2935
# Epoch 34: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 639us/sample - loss: 1.2935 - val_loss: 1.3559
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2979
# Epoch 35: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 646us/sample - loss: 1.2979 - val_loss: 1.3520
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3011
# Epoch 36: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 644us/sample - loss: 1.3011 - val_loss: 1.3550
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2959
# Epoch 37: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 648us/sample - loss: 1.2959 - val_loss: 1.3550
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3015
# Epoch 38: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 638us/sample - loss: 1.3015 - val_loss: 1.3589
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3057
# Epoch 39: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.3057 - val_loss: 1.3523
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3102
# Epoch 40: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 642us/sample - loss: 1.3102 - val_loss: 1.3518
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3060
# Epoch 41: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 649us/sample - loss: 1.3060 - val_loss: 1.3590
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3105
# Epoch 42: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 650us/sample - loss: 1.3105 - val_loss: 1.3629
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3141
# Epoch 43: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 650us/sample - loss: 1.3141 - val_loss: 1.3574
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3106
# Epoch 44: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 648us/sample - loss: 1.3106 - val_loss: 1.3605
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3083
# Epoch 45: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 578us/sample - loss: 1.3083 - val_loss: 1.3537
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3144
# Epoch 46: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.3144 - val_loss: 1.3623
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3123
# Epoch 47: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.3123 - val_loss: 1.3570
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3165
# Epoch 48: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 566us/sample - loss: 1.3165 - val_loss: 1.3613
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3201
# Epoch 49: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 568us/sample - loss: 1.3201 - val_loss: 1.3720
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3269
# Epoch 50: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 16s 557us/sample - loss: 1.3269 - val_loss: 1.3605
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3356
# Epoch 51: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 18s 620us/sample - loss: 1.3356 - val_loss: 1.3541
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3370
# Epoch 52: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 587us/sample - loss: 1.3370 - val_loss: 1.3634
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3371
# Epoch 53: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 572us/sample - loss: 1.3371 - val_loss: 1.3635
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3291
# Epoch 54: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 564us/sample - loss: 1.3291 - val_loss: 1.3613
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3272
# Epoch 55: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 571us/sample - loss: 1.3272 - val_loss: 1.3619
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3267
# Epoch 56: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 570us/sample - loss: 1.3267 - val_loss: 1.3592
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3255
# Epoch 57: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 568us/sample - loss: 1.3255 - val_loss: 1.3582
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3227
# Epoch 58: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 567us/sample - loss: 1.3227 - val_loss: 1.3701
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3237
# Epoch 59: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.3237 - val_loss: 1.3599
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3207
# Epoch 60: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 651us/sample - loss: 1.3207 - val_loss: 1.3645
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3210
# Epoch 61: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 635us/sample - loss: 1.3210 - val_loss: 1.3603
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3202
# Epoch 62: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 566us/sample - loss: 1.3202 - val_loss: 1.3545
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3191
# Epoch 63: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 568us/sample - loss: 1.3191 - val_loss: 1.3595
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3187
# Epoch 64: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 569us/sample - loss: 1.3187 - val_loss: 1.3616
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3180
# Epoch 65: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 591us/sample - loss: 1.3180 - val_loss: 1.3553
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3181
# Epoch 66: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 567us/sample - loss: 1.3181 - val_loss: 1.3642
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3135
# Epoch 67: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 577us/sample - loss: 1.3135 - val_loss: 1.3591
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3165
# Epoch 68: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 570us/sample - loss: 1.3165 - val_loss: 1.3593
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3149
# Epoch 69: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 568us/sample - loss: 1.3149 - val_loss: 1.3595
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3149
# Epoch 70: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 629us/sample - loss: 1.3149 - val_loss: 1.3620
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3127
# Epoch 71: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 637us/sample - loss: 1.3127 - val_loss: 1.3549
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3136
# Epoch 72: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 569us/sample - loss: 1.3136 - val_loss: 1.3510
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3142
# Epoch 73: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.3142 - val_loss: 1.3541
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3126
# Epoch 74: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 18s 608us/sample - loss: 1.3126 - val_loss: 1.3581
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3123
# Epoch 75: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 648us/sample - loss: 1.3123 - val_loss: 1.3645
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3106
# Epoch 76: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.3106 - val_loss: 1.3633
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3095
# Epoch 77: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.3095 - val_loss: 1.3580
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3104
# Epoch 78: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.3104 - val_loss: 1.3603
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3086
# Epoch 79: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.3086 - val_loss: 1.3545
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3099
# Epoch 80: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.3099 - val_loss: 1.3557
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3084
# Epoch 81: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 634us/sample - loss: 1.3084 - val_loss: 1.3650
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3092
# Epoch 82: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 648us/sample - loss: 1.3092 - val_loss: 1.3582
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3087
# Epoch 83: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 583us/sample - loss: 1.3087 - val_loss: 1.3544
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3100
# Epoch 84: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 568us/sample - loss: 1.3100 - val_loss: 1.3520
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3082
# Epoch 85: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 559us/sample - loss: 1.3082 - val_loss: 1.3574
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3061
# Epoch 86: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 565us/sample - loss: 1.3061 - val_loss: 1.3529
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3054
# Epoch 87: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 560us/sample - loss: 1.3054 - val_loss: 1.3516
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3094
# Epoch 88: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 16s 556us/sample - loss: 1.3094 - val_loss: 1.3605
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3040
# Epoch 89: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 560us/sample - loss: 1.3040 - val_loss: 1.3602
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3075
# Epoch 90: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.3075 - val_loss: 1.3595
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3047
# Epoch 91: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 649us/sample - loss: 1.3047 - val_loss: 1.3531
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3042
# Epoch 92: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.3042 - val_loss: 1.3564
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3034
# Epoch 93: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 580us/sample - loss: 1.3034 - val_loss: 1.3541
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3039
# Epoch 94: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 19s 653us/sample - loss: 1.3039 - val_loss: 1.3567
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3007
# Epoch 95: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.3007 - val_loss: 1.3538
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3049
# Epoch 96: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 567us/sample - loss: 1.3049 - val_loss: 1.3595
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2999
# Epoch 97: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 579us/sample - loss: 1.2999 - val_loss: 1.3494
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3053
# Epoch 98: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 562us/sample - loss: 1.3053 - val_loss: 1.3513
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3003
# Epoch 99: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 564us/sample - loss: 1.3003 - val_loss: 1.3555
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3023
# Epoch 100: val_loss did not improve from 1.34760
# 29601/29601 [==============================] - 17s 560us/sample - loss: 1.3023 - val_loss: 1.3566
