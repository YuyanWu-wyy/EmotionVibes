# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-09 14:25:54.452606: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Feature_extraction_remove_spe_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# 2023-11-07 21:15:59.974272: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:15:59.986007: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:15:59.986287: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:15:59.990032: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:15:59.990229: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:15:59.990401: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:16:00.082167: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:16:00.082382: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:16:00.082619: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:16:00.082764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-07 21:16:00.083193: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-07 21:16:00.083623: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-07 21:16:00.260295: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:4 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-07 21:16:00.263136: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:5 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-07 21:16:00.326156: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:16:00.326418: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:16:00.326587: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:16:00.326791: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:16:00.326958: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-07 21:16:00.327093: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-07 21:16:00.327125: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 95)
# Train on 29601 samples, validate on 3694 samples
# 2023-11-07 21:16:02.601993: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_11/lstm_cell_11/kernel/v/Assign' id:7499 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_11/lstm_cell_11/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_11/lstm_cell_11/kernel/v, training/Adam/lstm_11/lstm_cell_11/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-11-07 21:16:03.641478: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-07 21:16:04.410849: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-07 21:16:04.504258: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 29601/29601 [==============================] - ETA: 0s - loss: 3.5724
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-07 21:16:18.794135: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:2780 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 2.16883, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 17s 587us/sample - loss: 3.5724 - val_loss: 2.1688
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.9349
# Epoch 2: val_loss improved from 2.16883 to 1.68137, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.9349 - val_loss: 1.6814
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6559
# Epoch 3: val_loss improved from 1.68137 to 1.57242, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 454us/sample - loss: 1.6559 - val_loss: 1.5724
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5777
# Epoch 4: val_loss improved from 1.57242 to 1.53008, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.5777 - val_loss: 1.5301
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5479
# Epoch 5: val_loss improved from 1.53008 to 1.50762, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.5479 - val_loss: 1.5076
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5295
# Epoch 6: val_loss improved from 1.50762 to 1.49626, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 455us/sample - loss: 1.5295 - val_loss: 1.4963
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5130
# Epoch 7: val_loss improved from 1.49626 to 1.47902, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 16s 535us/sample - loss: 1.5130 - val_loss: 1.4790
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5037
# Epoch 8: val_loss improved from 1.47902 to 1.47901, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 16s 537us/sample - loss: 1.5037 - val_loss: 1.4790
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4942
# Epoch 9: val_loss improved from 1.47901 to 1.46504, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 16s 537us/sample - loss: 1.4942 - val_loss: 1.4650
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4879
# Epoch 10: val_loss improved from 1.46504 to 1.45645, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 14s 485us/sample - loss: 1.4879 - val_loss: 1.4564
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4838
# Epoch 11: val_loss improved from 1.45645 to 1.44746, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 455us/sample - loss: 1.4838 - val_loss: 1.4475
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4781
# Epoch 12: val_loss improved from 1.44746 to 1.44177, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 15s 512us/sample - loss: 1.4781 - val_loss: 1.4418
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4712
# Epoch 13: val_loss improved from 1.44177 to 1.43719, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 14s 467us/sample - loss: 1.4712 - val_loss: 1.4372
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4629
# Epoch 14: val_loss did not improve from 1.43719
# 29601/29601 [==============================] - 13s 450us/sample - loss: 1.4629 - val_loss: 1.4440
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4602
# Epoch 15: val_loss did not improve from 1.43719
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.4602 - val_loss: 1.4373
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4564
# Epoch 16: val_loss improved from 1.43719 to 1.42952, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.4564 - val_loss: 1.4295
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4500
# Epoch 17: val_loss improved from 1.42952 to 1.42693, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 452us/sample - loss: 1.4500 - val_loss: 1.4269
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4471
# Epoch 18: val_loss improved from 1.42693 to 1.41998, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 450us/sample - loss: 1.4471 - val_loss: 1.4200
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4397
# Epoch 19: val_loss improved from 1.41998 to 1.41743, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.4397 - val_loss: 1.4174
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4382
# Epoch 20: val_loss did not improve from 1.41743
# 29601/29601 [==============================] - 14s 473us/sample - loss: 1.4382 - val_loss: 1.4238
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4386
# Epoch 21: val_loss improved from 1.41743 to 1.40879, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 16s 538us/sample - loss: 1.4386 - val_loss: 1.4088
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4312
# Epoch 22: val_loss did not improve from 1.40879
# 29601/29601 [==============================] - 14s 471us/sample - loss: 1.4312 - val_loss: 1.4116
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4286
# Epoch 23: val_loss improved from 1.40879 to 1.40647, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 16s 528us/sample - loss: 1.4286 - val_loss: 1.4065
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4279
# Epoch 24: val_loss improved from 1.40647 to 1.40230, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 16s 536us/sample - loss: 1.4279 - val_loss: 1.4023
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4234
# Epoch 25: val_loss did not improve from 1.40230
# 29601/29601 [==============================] - 16s 534us/sample - loss: 1.4234 - val_loss: 1.4071
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4200
# Epoch 26: val_loss did not improve from 1.40230
# 29601/29601 [==============================] - 16s 535us/sample - loss: 1.4200 - val_loss: 1.4036
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4177
# Epoch 27: val_loss improved from 1.40230 to 1.39616, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 16s 537us/sample - loss: 1.4177 - val_loss: 1.3962
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4164
# Epoch 28: val_loss did not improve from 1.39616
# 29601/29601 [==============================] - 16s 536us/sample - loss: 1.4164 - val_loss: 1.3987
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4131
# Epoch 29: val_loss improved from 1.39616 to 1.39433, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 16s 536us/sample - loss: 1.4131 - val_loss: 1.3943
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4103
# Epoch 30: val_loss did not improve from 1.39433
# 29601/29601 [==============================] - 16s 534us/sample - loss: 1.4103 - val_loss: 1.3970
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4091
# Epoch 31: val_loss did not improve from 1.39433
# 29601/29601 [==============================] - 16s 535us/sample - loss: 1.4091 - val_loss: 1.3953
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4056
# Epoch 32: val_loss improved from 1.39433 to 1.39041, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 15s 507us/sample - loss: 1.4056 - val_loss: 1.3904
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4050
# Epoch 33: val_loss improved from 1.39041 to 1.38773, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.4050 - val_loss: 1.3877
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4040
# Epoch 34: val_loss improved from 1.38773 to 1.38602, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.4040 - val_loss: 1.3860
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4049
# Epoch 35: val_loss did not improve from 1.38602
# 29601/29601 [==============================] - 14s 472us/sample - loss: 1.4049 - val_loss: 1.3865
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4001
# Epoch 36: val_loss improved from 1.38602 to 1.38494, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 15s 496us/sample - loss: 1.4001 - val_loss: 1.3849
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3988
# Epoch 37: val_loss did not improve from 1.38494
# 29601/29601 [==============================] - 13s 452us/sample - loss: 1.3988 - val_loss: 1.3891
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3992
# Epoch 38: val_loss improved from 1.38494 to 1.38108, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 14s 473us/sample - loss: 1.3992 - val_loss: 1.3811
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3957
# Epoch 39: val_loss improved from 1.38108 to 1.37944, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 14s 469us/sample - loss: 1.3957 - val_loss: 1.3794
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3939
# Epoch 40: val_loss did not improve from 1.37944
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.3939 - val_loss: 1.3891
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3924
# Epoch 41: val_loss did not improve from 1.37944
# 29601/29601 [==============================] - 13s 450us/sample - loss: 1.3924 - val_loss: 1.3847
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3930
# Epoch 42: val_loss did not improve from 1.37944
# 29601/29601 [==============================] - 13s 456us/sample - loss: 1.3930 - val_loss: 1.3826
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3915
# Epoch 43: val_loss did not improve from 1.37944
# 29601/29601 [==============================] - 16s 535us/sample - loss: 1.3915 - val_loss: 1.3801
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3887
# Epoch 44: val_loss did not improve from 1.37944
# 29601/29601 [==============================] - 16s 534us/sample - loss: 1.3887 - val_loss: 1.3834
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3888
# Epoch 45: val_loss improved from 1.37944 to 1.37474, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 15s 500us/sample - loss: 1.3888 - val_loss: 1.3747
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3860
# Epoch 46: val_loss did not improve from 1.37474
# 29601/29601 [==============================] - 13s 452us/sample - loss: 1.3860 - val_loss: 1.3776
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3827
# Epoch 47: val_loss did not improve from 1.37474
# 29601/29601 [==============================] - 13s 454us/sample - loss: 1.3827 - val_loss: 1.3754
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3866
# Epoch 48: val_loss did not improve from 1.37474
# 29601/29601 [==============================] - 15s 495us/sample - loss: 1.3866 - val_loss: 1.3775
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3827
# Epoch 49: val_loss did not improve from 1.37474
# 29601/29601 [==============================] - 14s 476us/sample - loss: 1.3827 - val_loss: 1.3775
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3809
# Epoch 50: val_loss did not improve from 1.37474
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.3809 - val_loss: 1.3769
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3807
# Epoch 51: val_loss did not improve from 1.37474
# 29601/29601 [==============================] - 13s 452us/sample - loss: 1.3807 - val_loss: 1.3792
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3796
# Epoch 52: val_loss did not improve from 1.37474
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.3796 - val_loss: 1.3755
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3787
# Epoch 53: val_loss did not improve from 1.37474
# 29601/29601 [==============================] - 13s 450us/sample - loss: 1.3787 - val_loss: 1.3777
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3764
# Epoch 54: val_loss improved from 1.37474 to 1.36951, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.3764 - val_loss: 1.3695
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3751
# Epoch 55: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 13s 450us/sample - loss: 1.3751 - val_loss: 1.3803
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3734
# Epoch 56: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 14s 485us/sample - loss: 1.3734 - val_loss: 1.3723
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3754
# Epoch 57: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 16s 538us/sample - loss: 1.3754 - val_loss: 1.3843
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3697
# Epoch 58: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 16s 533us/sample - loss: 1.3697 - val_loss: 1.3759
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3703
# Epoch 59: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 16s 532us/sample - loss: 1.3703 - val_loss: 1.3748
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3708
# Epoch 60: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 13s 452us/sample - loss: 1.3708 - val_loss: 1.3735
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3688
# Epoch 61: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 13s 455us/sample - loss: 1.3688 - val_loss: 1.3695
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3680
# Epoch 62: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 13s 448us/sample - loss: 1.3680 - val_loss: 1.3732
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3667
# Epoch 63: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 13s 447us/sample - loss: 1.3667 - val_loss: 1.3704
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3685
# Epoch 64: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 13s 446us/sample - loss: 1.3685 - val_loss: 1.3721
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3654
# Epoch 65: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 13s 446us/sample - loss: 1.3654 - val_loss: 1.3766
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3637
# Epoch 66: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 13s 442us/sample - loss: 1.3637 - val_loss: 1.3727
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3604
# Epoch 67: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 13s 442us/sample - loss: 1.3604 - val_loss: 1.3723
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3628
# Epoch 68: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 13s 443us/sample - loss: 1.3628 - val_loss: 1.3724
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3603
# Epoch 69: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 13s 443us/sample - loss: 1.3603 - val_loss: 1.3771
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3581
# Epoch 70: val_loss did not improve from 1.36951
# 29601/29601 [==============================] - 13s 443us/sample - loss: 1.3581 - val_loss: 1.3710
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3566
# Epoch 71: val_loss improved from 1.36951 to 1.36710, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 442us/sample - loss: 1.3566 - val_loss: 1.3671
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3575
# Epoch 72: val_loss did not improve from 1.36710
# 29601/29601 [==============================] - 13s 440us/sample - loss: 1.3575 - val_loss: 1.3682
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3567
# Epoch 73: val_loss did not improve from 1.36710
# 29601/29601 [==============================] - 13s 439us/sample - loss: 1.3567 - val_loss: 1.3682
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3547
# Epoch 74: val_loss improved from 1.36710 to 1.36631, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3547 - val_loss: 1.3663
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3538
# Epoch 75: val_loss improved from 1.36631 to 1.36528, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 443us/sample - loss: 1.3538 - val_loss: 1.3653
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3501
# Epoch 76: val_loss did not improve from 1.36528
# 29601/29601 [==============================] - 13s 441us/sample - loss: 1.3501 - val_loss: 1.3764
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3527
# Epoch 77: val_loss improved from 1.36528 to 1.36430, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 443us/sample - loss: 1.3527 - val_loss: 1.3643
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3518
# Epoch 78: val_loss improved from 1.36430 to 1.36407, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3518 - val_loss: 1.3641
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3487
# Epoch 79: val_loss did not improve from 1.36407
# 29601/29601 [==============================] - 13s 442us/sample - loss: 1.3487 - val_loss: 1.3670
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3496
# Epoch 80: val_loss did not improve from 1.36407
# 29601/29601 [==============================] - 13s 442us/sample - loss: 1.3496 - val_loss: 1.3704
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3500
# Epoch 81: val_loss did not improve from 1.36407
# 29601/29601 [==============================] - 13s 443us/sample - loss: 1.3500 - val_loss: 1.3749
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3464
# Epoch 82: val_loss did not improve from 1.36407
# 29601/29601 [==============================] - 13s 441us/sample - loss: 1.3464 - val_loss: 1.3664
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3485
# Epoch 83: val_loss improved from 1.36407 to 1.36280, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 445us/sample - loss: 1.3485 - val_loss: 1.3628
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3457
# Epoch 84: val_loss did not improve from 1.36280
# 29601/29601 [==============================] - 13s 442us/sample - loss: 1.3457 - val_loss: 1.3685
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3483
# Epoch 85: val_loss did not improve from 1.36280
# 29601/29601 [==============================] - 13s 443us/sample - loss: 1.3483 - val_loss: 1.3700
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3465
# Epoch 86: val_loss did not improve from 1.36280
# 29601/29601 [==============================] - 13s 441us/sample - loss: 1.3465 - val_loss: 1.3746
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3432
# Epoch 87: val_loss did not improve from 1.36280
# 29601/29601 [==============================] - 13s 441us/sample - loss: 1.3432 - val_loss: 1.3657
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3439
# Epoch 88: val_loss did not improve from 1.36280
# 29601/29601 [==============================] - 13s 442us/sample - loss: 1.3439 - val_loss: 1.3762
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3462
# Epoch 89: val_loss did not improve from 1.36280
# 29601/29601 [==============================] - 13s 442us/sample - loss: 1.3462 - val_loss: 1.3675
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3398
# Epoch 90: val_loss did not improve from 1.36280
# 29601/29601 [==============================] - 14s 463us/sample - loss: 1.3398 - val_loss: 1.3678
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3422
# Epoch 91: val_loss did not improve from 1.36280
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3422 - val_loss: 1.3701
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3396
# Epoch 92: val_loss did not improve from 1.36280
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3396 - val_loss: 1.3683
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3389
# Epoch 93: val_loss did not improve from 1.36280
# 29601/29601 [==============================] - 13s 445us/sample - loss: 1.3389 - val_loss: 1.3683
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3360
# Epoch 94: val_loss improved from 1.36280 to 1.36249, saving model to ./checkpoints/Feature_extraction_remove_spe_0.h5
# 29601/29601 [==============================] - 13s 447us/sample - loss: 1.3360 - val_loss: 1.3625
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3370
# Epoch 95: val_loss did not improve from 1.36249
# 29601/29601 [==============================] - 13s 443us/sample - loss: 1.3370 - val_loss: 1.3635
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3370
# Epoch 96: val_loss did not improve from 1.36249
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3370 - val_loss: 1.3628
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3372
# Epoch 97: val_loss did not improve from 1.36249
# 29601/29601 [==============================] - 13s 445us/sample - loss: 1.3372 - val_loss: 1.3640
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3360
# Epoch 98: val_loss did not improve from 1.36249
# 29601/29601 [==============================] - 13s 445us/sample - loss: 1.3360 - val_loss: 1.3628
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3333
# Epoch 99: val_loss did not improve from 1.36249
# 29601/29601 [==============================] - 13s 443us/sample - loss: 1.3333 - val_loss: 1.3685
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3332
# Epoch 100: val_loss did not improve from 1.36249
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3332 - val_loss: 1.3666
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3343
# Epoch 1: val_loss improved from inf to 1.38534, saving model to ./checkpoints/Feature_extraction_remove_spe_1.h5
# 29601/29601 [==============================] - 13s 456us/sample - loss: 1.3343 - val_loss: 1.3853
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3390
# Epoch 2: val_loss improved from 1.38534 to 1.36562, saving model to ./checkpoints/Feature_extraction_remove_spe_1.h5
# 29601/29601 [==============================] - 13s 447us/sample - loss: 1.3390 - val_loss: 1.3656
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3335
# Epoch 3: val_loss improved from 1.36562 to 1.36181, saving model to ./checkpoints/Feature_extraction_remove_spe_1.h5
# 29601/29601 [==============================] - 13s 446us/sample - loss: 1.3335 - val_loss: 1.3618
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3329
# Epoch 4: val_loss improved from 1.36181 to 1.35872, saving model to ./checkpoints/Feature_extraction_remove_spe_1.h5
# 29601/29601 [==============================] - 13s 446us/sample - loss: 1.3329 - val_loss: 1.3587
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3305
# Epoch 5: val_loss did not improve from 1.35872
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3305 - val_loss: 1.3728
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3327
# Epoch 6: val_loss did not improve from 1.35872
# 29601/29601 [==============================] - 13s 450us/sample - loss: 1.3327 - val_loss: 1.3659
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3289
# Epoch 7: val_loss improved from 1.35872 to 1.35469, saving model to ./checkpoints/Feature_extraction_remove_spe_1.h5
# 29601/29601 [==============================] - 14s 463us/sample - loss: 1.3289 - val_loss: 1.3547
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3275
# Epoch 8: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3275 - val_loss: 1.3590
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3259
# Epoch 9: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 445us/sample - loss: 1.3259 - val_loss: 1.3677
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3297
# Epoch 10: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3297 - val_loss: 1.3677
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3263
# Epoch 11: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 455us/sample - loss: 1.3263 - val_loss: 1.3684
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3288
# Epoch 12: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3288 - val_loss: 1.3704
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3264
# Epoch 13: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3264 - val_loss: 1.3688
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3280
# Epoch 14: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 445us/sample - loss: 1.3280 - val_loss: 1.3675
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3278
# Epoch 15: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 15s 495us/sample - loss: 1.3278 - val_loss: 1.3669
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3298
# Epoch 16: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 15s 501us/sample - loss: 1.3298 - val_loss: 1.3647
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3249
# Epoch 17: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3249 - val_loss: 1.3587
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3276
# Epoch 18: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 445us/sample - loss: 1.3276 - val_loss: 1.3661
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3274
# Epoch 19: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3274 - val_loss: 1.3712
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3274
# Epoch 20: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3274 - val_loss: 1.3644
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3254
# Epoch 21: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 444us/sample - loss: 1.3254 - val_loss: 1.3602
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3238
# Epoch 22: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 14s 487us/sample - loss: 1.3238 - val_loss: 1.3626
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3231
# Epoch 23: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 16s 527us/sample - loss: 1.3231 - val_loss: 1.3606
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3213
# Epoch 24: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 16s 525us/sample - loss: 1.3213 - val_loss: 1.3666
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3243
# Epoch 25: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 16s 537us/sample - loss: 1.3243 - val_loss: 1.3605
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3248
# Epoch 26: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 16s 545us/sample - loss: 1.3248 - val_loss: 1.3620
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3238
# Epoch 27: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 15s 493us/sample - loss: 1.3238 - val_loss: 1.3628
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3226
# Epoch 28: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 455us/sample - loss: 1.3226 - val_loss: 1.3568
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3235
# Epoch 29: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.3235 - val_loss: 1.3624
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3231
# Epoch 30: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 455us/sample - loss: 1.3231 - val_loss: 1.3589
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3224
# Epoch 31: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 455us/sample - loss: 1.3224 - val_loss: 1.3632
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3190
# Epoch 32: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 456us/sample - loss: 1.3190 - val_loss: 1.3595
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3185
# Epoch 33: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 14s 457us/sample - loss: 1.3185 - val_loss: 1.3583
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3194
# Epoch 34: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 456us/sample - loss: 1.3194 - val_loss: 1.3591
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3176
# Epoch 35: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 455us/sample - loss: 1.3176 - val_loss: 1.3602
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3220
# Epoch 36: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.3220 - val_loss: 1.3569
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3197
# Epoch 37: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 454us/sample - loss: 1.3197 - val_loss: 1.3570
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3204
# Epoch 38: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 452us/sample - loss: 1.3204 - val_loss: 1.3587
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3208
# Epoch 39: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.3208 - val_loss: 1.3565
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3198
# Epoch 40: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.3198 - val_loss: 1.3636
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3216
# Epoch 41: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.3216 - val_loss: 1.3621
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3191
# Epoch 42: val_loss did not improve from 1.35469
# 29601/29601 [==============================] - 13s 455us/sample - loss: 1.3191 - val_loss: 1.3683
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3423
# Epoch 43: val_loss improved from 1.35469 to 1.35203, saving model to ./checkpoints/Feature_extraction_remove_spe_1.h5
# 29601/29601 [==============================] - 14s 457us/sample - loss: 1.3423 - val_loss: 1.3520
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3231
# Epoch 44: val_loss did not improve from 1.35203
# 29601/29601 [==============================] - 13s 454us/sample - loss: 1.3231 - val_loss: 1.3602
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3169
# Epoch 45: val_loss did not improve from 1.35203
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.3169 - val_loss: 1.3637
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3166
# Epoch 46: val_loss did not improve from 1.35203
# 29601/29601 [==============================] - 13s 454us/sample - loss: 1.3166 - val_loss: 1.3597
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3174
# Epoch 47: val_loss did not improve from 1.35203
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.3174 - val_loss: 1.3601
# Epoch 48/100
# ...
# 29601/29601 [==============================] - 13s 456us/sample - loss: 1.2842 - val_loss: 1.3387
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2863
# Epoch 32: val_loss did not improve from 1.33217
# 29601/29601 [==============================] - 13s 453us/sample - loss: 1.2863 - val_loss: 1.3428
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2877
# Epoch 33: val_loss did not improve from 1.33217
# 29601/29601 [==============================] - 15s 494us/sample - loss: 1.2877 - val_loss: 1.3399
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2855
# Epoch 34: val_loss did not improve from 1.33217
# 29601/29601 [==============================] - 16s 531us/sample - loss: 1.2855 - val_loss: 1.3354
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2856
# Epoch 35: val_loss improved from 1.33217 to 1.32865, saving model to ./checkpoints/Feature_extraction_remove_spe_9.h5
# 29601/29601 [==============================] - 16s 534us/sample - loss: 1.2856 - val_loss: 1.3287
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2926
# Epoch 36: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 16s 536us/sample - loss: 1.2926 - val_loss: 1.3360
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2970
# Epoch 37: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 14s 484us/sample - loss: 1.2970 - val_loss: 1.3383
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2954
# Epoch 38: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 15s 515us/sample - loss: 1.2954 - val_loss: 1.3390
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2930
# Epoch 39: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 14s 457us/sample - loss: 1.2930 - val_loss: 1.3389
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2987
# Epoch 40: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.2987 - val_loss: 1.3339
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2950
# Epoch 41: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 13s 450us/sample - loss: 1.2950 - val_loss: 1.3356
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2977
# Epoch 42: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 13s 451us/sample - loss: 1.2977 - val_loss: 1.3407
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2993
# Epoch 43: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 13s 454us/sample - loss: 1.2993 - val_loss: 1.3417
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3020
# Epoch 44: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 14s 456us/sample - loss: 1.3020 - val_loss: 1.3364
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3024
# Epoch 45: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 13s 456us/sample - loss: 1.3024 - val_loss: 1.3322
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3047
# Epoch 46: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 13s 450us/sample - loss: 1.3047 - val_loss: 1.3373
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3034
# Epoch 47: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 13s 450us/sample - loss: 1.3034 - val_loss: 1.3439
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3053
# Epoch 48: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 14s 464us/sample - loss: 1.3053 - val_loss: 1.3402
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3098
# Epoch 49: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 16s 530us/sample - loss: 1.3098 - val_loss: 1.3426
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3072
# Epoch 50: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 15s 495us/sample - loss: 1.3072 - val_loss: 1.3409
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3095
# Epoch 51: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 15s 505us/sample - loss: 1.3095 - val_loss: 1.3394
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3137
# Epoch 52: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 14s 477us/sample - loss: 1.3137 - val_loss: 1.3382
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3140
# Epoch 53: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 16s 534us/sample - loss: 1.3140 - val_loss: 1.3416
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3140
# Epoch 54: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 16s 531us/sample - loss: 1.3140 - val_loss: 1.3430
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3144
# Epoch 55: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 16s 531us/sample - loss: 1.3144 - val_loss: 1.3490
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3096
# Epoch 56: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 17s 558us/sample - loss: 1.3096 - val_loss: 1.3431
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3096
# Epoch 57: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 725us/sample - loss: 1.3096 - val_loss: 1.3389
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3088
# Epoch 58: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 22s 731us/sample - loss: 1.3088 - val_loss: 1.3457
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3099
# Epoch 59: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 722us/sample - loss: 1.3099 - val_loss: 1.3458
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3080
# Epoch 60: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 720us/sample - loss: 1.3080 - val_loss: 1.3454
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3071
# Epoch 61: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 704us/sample - loss: 1.3071 - val_loss: 1.3413
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3069
# Epoch 62: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 703us/sample - loss: 1.3069 - val_loss: 1.3320
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3061
# Epoch 63: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 706us/sample - loss: 1.3061 - val_loss: 1.3441
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3010
# Epoch 64: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 724us/sample - loss: 1.3010 - val_loss: 1.3402
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3041
# Epoch 65: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 704us/sample - loss: 1.3041 - val_loss: 1.3392
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3052
# Epoch 66: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 715us/sample - loss: 1.3052 - val_loss: 1.3466
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3010
# Epoch 67: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 712us/sample - loss: 1.3010 - val_loss: 1.3418
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3013
# Epoch 68: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 20s 692us/sample - loss: 1.3013 - val_loss: 1.3416
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3003
# Epoch 69: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 706us/sample - loss: 1.3003 - val_loss: 1.3402
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2985
# Epoch 70: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 705us/sample - loss: 1.2985 - val_loss: 1.3481
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2965
# Epoch 71: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 700us/sample - loss: 1.2965 - val_loss: 1.3399
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3016
# Epoch 72: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 700us/sample - loss: 1.3016 - val_loss: 1.3409
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2997
# Epoch 73: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 709us/sample - loss: 1.2997 - val_loss: 1.3403
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2986
# Epoch 74: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 705us/sample - loss: 1.2986 - val_loss: 1.3361
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2957
# Epoch 75: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 716us/sample - loss: 1.2957 - val_loss: 1.3474
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2966
# Epoch 76: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 22s 727us/sample - loss: 1.2966 - val_loss: 1.3363
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2949
# Epoch 77: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 705us/sample - loss: 1.2949 - val_loss: 1.3393
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2967
# Epoch 78: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 724us/sample - loss: 1.2967 - val_loss: 1.3361
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2936
# Epoch 79: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 711us/sample - loss: 1.2936 - val_loss: 1.3410
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2925
# Epoch 80: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 695us/sample - loss: 1.2925 - val_loss: 1.3356
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2949
# Epoch 81: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 698us/sample - loss: 1.2949 - val_loss: 1.3428
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2921
# Epoch 82: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 725us/sample - loss: 1.2921 - val_loss: 1.3398
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2903
# Epoch 83: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 22s 733us/sample - loss: 1.2903 - val_loss: 1.3318
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2924
# Epoch 84: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 20s 689us/sample - loss: 1.2924 - val_loss: 1.3340
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2925
# Epoch 85: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 713us/sample - loss: 1.2925 - val_loss: 1.3361
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2923
# Epoch 86: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 721us/sample - loss: 1.2923 - val_loss: 1.3397
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2896
# Epoch 87: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 719us/sample - loss: 1.2896 - val_loss: 1.3396
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2894
# Epoch 88: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 723us/sample - loss: 1.2894 - val_loss: 1.3436
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2890
# Epoch 89: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 723us/sample - loss: 1.2890 - val_loss: 1.3434
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2901
# Epoch 90: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 22s 735us/sample - loss: 1.2901 - val_loss: 1.3470
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2918
# Epoch 91: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 708us/sample - loss: 1.2918 - val_loss: 1.3399
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2836
# Epoch 92: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 693us/sample - loss: 1.2836 - val_loss: 1.3393
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2854
# Epoch 93: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 698us/sample - loss: 1.2854 - val_loss: 1.3368
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2892
# Epoch 94: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 716us/sample - loss: 1.2892 - val_loss: 1.3398
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2884
# Epoch 95: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 725us/sample - loss: 1.2884 - val_loss: 1.3342
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2851
# Epoch 96: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 718us/sample - loss: 1.2851 - val_loss: 1.3399
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2856
# Epoch 97: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 708us/sample - loss: 1.2856 - val_loss: 1.3316
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2824
# Epoch 98: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 724us/sample - loss: 1.2824 - val_loss: 1.3426
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2863
# Epoch 99: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 706us/sample - loss: 1.2863 - val_loss: 1.3313
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2823
# Epoch 100: val_loss did not improve from 1.32865
# 29601/29601 [==============================] - 21s 700us/sample - loss: 1.2823 - val_loss: 1.3393

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_spe_0.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:26:58.209508: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.209729: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.209911: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.221177: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.221420: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.221601: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.221772: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.221935: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.222096: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.410098: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.410303: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.410472: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.410635: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.410786: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.410978: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.411130: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.411282: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.411433: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.418968: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.419155: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.419328: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.419495: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.419661: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.419828: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.419994: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.420139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-09 14:26:58.420549: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.420693: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-09 14:26:58.420970: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:58.421119: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-09 14:26:58.421324: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-09 14:26:59.196843: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.197088: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.197273: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.197449: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.197650: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.197819: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.197985: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.198157: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.198319: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.198560: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.198738: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.198913: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.199080: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.199218: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-09 14:26:59.199274: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.199405: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-09 14:26:59.199454: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:26:59.199587: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-09 14:26:59.199619: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-09 14:26:59.219926: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-09 14:26:59.267809: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_12/lstm_cell_12/bias/Assign' id:2197 op device:{requested: '', assigned: ''} def:{{{node lstm_12/lstm_cell_12/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_12/lstm_cell_12/bias, lstm_12/lstm_cell_12/bias/Initializer/concat)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:26:59.727526: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_7/lstm_cell_7/kernel/m/Assign' id:3179 op device:{requested: '', assigned: ''} def:{{{node lstm_7/lstm_cell_7/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_7/lstm_cell_7/kernel/m, lstm_7/lstm_cell_7/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-11-09 14:27:00.109405: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3/BiasAdd' id:2739 op device:{requested: '', assigned: ''} def:{{{node dense_3/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3/MatMul, dense_3/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:27:00.369086: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-09 14:27:00.377817: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# Test MAE:
# 1.3554099213756134
# 1.2819317355125082

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_spe_1.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:27:17.048592: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_9_1/lstm_cell_24/bias/Assign' id:5866 op device:{requested: '', assigned: ''} def:{{{node lstm_9_1/lstm_cell_24/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_9_1/lstm_cell_24/bias, lstm_9_1/lstm_cell_24/bias/Initializer/concat)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:27:17.587685: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_9_1/lstm_cell_24/bias/v/Assign' id:7681 op device:{requested: '', assigned: ''} def:{{{node lstm_9_1/lstm_cell_24/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_9_1/lstm_cell_24/bias/v, lstm_9_1/lstm_cell_24/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:27:18.057857: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_1/BiasAdd' id:6888 op device:{requested: '', assigned: ''} def:{{{node dense_3_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_1/MatMul, dense_3_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3394944600748875
# 1.2582069671655551

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_spe_2.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:27:40.073198: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_2_2/bias/Assign' id:11011 op device:{requested: '', assigned: ''} def:{{{node dense_2_2/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_2_2/bias, dense_2_2/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:27:40.732905: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_9_2/lstm_cell_39/bias/m/Assign' id:11517 op device:{requested: '', assigned: ''} def:{{{node lstm_9_2/lstm_cell_39/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_9_2/lstm_cell_39/bias/m, lstm_9_2/lstm_cell_39/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:27:41.308673: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_2/BiasAdd' id:11037 op device:{requested: '', assigned: ''} def:{{{node dense_3_2/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_2/MatMul, dense_3_2/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3399992800119176
# 1.2507125345248622

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_spe_3.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:27:59.918711: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1_3/bias/Assign' id:15139 op device:{requested: '', assigned: ''} def:{{{node dense_1_3/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_1_3/bias, dense_1_3/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:28:00.689453: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_17/lstm_cell_45/kernel/m/Assign' id:15521 op device:{requested: '', assigned: ''} def:{{{node lstm_17/lstm_cell_45/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_17/lstm_cell_45/kernel/m, lstm_17/lstm_cell_45/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:28:01.389007: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_3/BiasAdd' id:15186 op device:{requested: '', assigned: ''} def:{{{node dense_3_3/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_3/MatMul, dense_3_3/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3344770495690852
# 1.2463965280542095

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_spe_4.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:28:23.519765: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_3_4/lstm_cell_63/kernel/Assign' id:17324 op device:{requested: '', assigned: ''} def:{{{node lstm_3_4/lstm_cell_63/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_3_4/lstm_cell_63/kernel, lstm_3_4/lstm_cell_63/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:28:24.414559: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_3_4/lstm_cell_63/kernel/m/Assign' id:19715 op device:{requested: '', assigned: ''} def:{{{node lstm_3_4/lstm_cell_63/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_3_4/lstm_cell_63/kernel/m, lstm_3_4/lstm_cell_63/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:28:25.254256: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_4/BiasAdd' id:19335 op device:{requested: '', assigned: ''} def:{{{node dense_3_4/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_4/MatMul, dense_3_4/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3529567566534924
# 1.2588496400700417

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_spe_5.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:28:42.621932: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_11_5/lstm_cell_86/recurrent_kernel/Assign' id:22773 op device:{requested: '', assigned: ''} def:{{{node lstm_11_5/lstm_cell_86/recurrent_kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_11_5/lstm_cell_86/recurrent_kernel, lstm_11_5/lstm_cell_86/recurrent_kernel/Initializer/mul_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:28:43.662100: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_6_5/lstm_cell_81/bias/m/Assign' id:23919 op device:{requested: '', assigned: ''} def:{{{node lstm_6_5/lstm_cell_81/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_6_5/lstm_cell_81/bias/m, lstm_6_5/lstm_cell_81/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:28:44.656451: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_5/BiasAdd' id:23484 op device:{requested: '', assigned: ''} def:{{{node dense_3_5/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_5/MatMul, dense_3_5/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3493763124828588
# 1.2587406555811564

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_spe_6.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:29:01.822380: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_2_6/lstm_cell_92/kernel/Assign' id:25462 op device:{requested: '', assigned: ''} def:{{{node lstm_2_6/lstm_cell_92/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_2_6/lstm_cell_92/kernel, lstm_2_6/lstm_cell_92/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:29:03.022396: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_9_6/lstm_cell_99/bias/v/Assign' id:28426 op device:{requested: '', assigned: ''} def:{{{node lstm_9_6/lstm_cell_99/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_9_6/lstm_cell_99/bias/v, lstm_9_6/lstm_cell_99/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:29:04.170383: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_6/BiasAdd' id:27633 op device:{requested: '', assigned: ''} def:{{{node dense_3_6/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_6/MatMul, dense_3_6/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3506169605370928
# 1.26475041657204

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_spe_7.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:29:21.345002: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_21/lstm_cell_105/bias/Assign' id:29320 op device:{requested: '', assigned: ''} def:{{{node lstm_21/lstm_cell_105/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_21/lstm_cell_105/bias, lstm_21/lstm_cell_105/bias/Initializer/concat)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:29:22.721897: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_13_7/lstm_cell_118/bias/v/Assign' id:32635 op device:{requested: '', assigned: ''} def:{{{node lstm_13_7/lstm_cell_118/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_13_7/lstm_cell_118/bias/v, lstm_13_7/lstm_cell_118/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:29:24.047985: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_7/BiasAdd' id:31782 op device:{requested: '', assigned: ''} def:{{{node dense_3_7/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_7/MatMul, dense_3_7/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3504294535564334
# 1.25819238717502

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_spe_8.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:29:40.945495: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_2_8/kernel/Assign' id:35900 op device:{requested: '', assigned: ''} def:{{{node dense_2_8/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_2_8/kernel, dense_2_8/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:29:42.492428: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_6_8/lstm_cell_126/recurrent_kernel/v/Assign' id:36674 op device:{requested: '', assigned: ''} def:{{{node lstm_6_8/lstm_cell_126/recurrent_kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_6_8/lstm_cell_126/recurrent_kernel/v, lstm_6_8/lstm_cell_126/recurrent_kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:29:43.983456: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_8/BiasAdd' id:35931 op device:{requested: '', assigned: ''} def:{{{node dense_3_8/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_8/MatMul, dense_3_8/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3537677038732374
# 1.2655354033781874

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_spe_9.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:30:01.419393: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_2_9/bias/Assign' id:40054 op device:{requested: '', assigned: ''} def:{{{node dense_2_9/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_2_9/bias, dense_2_9/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:30:03.140564: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_9_9/lstm_cell_144/kernel/m/Assign' id:40550 op device:{requested: '', assigned: ''} def:{{{node lstm_9_9/lstm_cell_144/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_9_9/lstm_cell_144/kernel/m, lstm_9_9/lstm_cell_144/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:30:04.813943: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_9/BiasAdd' id:40080 op device:{requested: '', assigned: ''} def:{{{node dense_3_9/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_9/MatMul, dense_3_9/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.350605325893782
# 1.264379990293756
