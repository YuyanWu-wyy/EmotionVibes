# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-09 14:33:25.854068: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Feature_extraction_remove_gaitpara_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:34:29.726236: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.726456: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.726635: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.737902: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.738148: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.738327: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.738497: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.738660: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.738822: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.923464: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.923686: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.923868: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.924036: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.924193: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.924422: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.924579: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.924735: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.924887: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.932991: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.933180: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.933353: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.933519: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.933687: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.933848: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.934012: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.934157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-09 14:34:29.934464: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.934608: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-09 14:34:29.934860: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:29.934999: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-09 14:34:29.935317: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:34:30.888467: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.888702: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.888890: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.889071: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.889233: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.889393: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.889552: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.889713: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.889874: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.890102: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.890269: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.890433: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.890597: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.890730: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-09 14:34:30.890780: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.890977: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-09 14:34:30.891034: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:34:30.891168: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-09 14:34:30.891216: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-09 14:34:30.917634: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-09 14:34:30.972608: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_21/lstm_cell_21/kernel/Assign' id:3481 op device:{requested: '', assigned: ''} def:{{{node lstm_21/lstm_cell_21/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_21/lstm_cell_21/kernel, lstm_21/lstm_cell_21/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:34:31.109094: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:3634 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:34:31.142977: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:3635 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 81)
# Train on 29601 samples, validate on 3694 samples
# 2023-11-09 14:34:32.229385: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_1/kernel/v/Assign' id:6683 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_1/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_1/kernel/v, training/Adam/dense_1/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
#  6144/29601 [=====>........................] - ETA: 1s - loss: 4.9481
# 2023-11-09 14:34:32.554438: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 28672/29601 [============================>.] - ETA: 0s - loss: 3.6288
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-09 14:34:33.325485: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:6475 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 2.30102, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 47us/sample - loss: 3.5897 - val_loss: 2.3010
# Epoch 2/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 2.1190
# Epoch 2: val_loss improved from 2.30102 to 1.82407, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 2.1132 - val_loss: 1.8241
# Epoch 3/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.8179
# Epoch 3: val_loss improved from 1.82407 to 1.69027, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 25us/sample - loss: 1.8163 - val_loss: 1.6903
# Epoch 4/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.7307
# Epoch 4: val_loss improved from 1.69027 to 1.64202, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.7302 - val_loss: 1.6420
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6884
# Epoch 5: val_loss improved from 1.64202 to 1.61715, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.6884 - val_loss: 1.6171
# Epoch 6/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.6552
# Epoch 6: val_loss improved from 1.61715 to 1.59496, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.6552 - val_loss: 1.5950
# Epoch 7/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.6283
# Epoch 7: val_loss improved from 1.59496 to 1.58337, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.6292 - val_loss: 1.5834
# Epoch 8/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.6161
# Epoch 8: val_loss improved from 1.58337 to 1.58141, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.6130 - val_loss: 1.5814
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5978
# Epoch 9: val_loss improved from 1.58141 to 1.57282, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.5978 - val_loss: 1.5728
# Epoch 10/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.5821
# Epoch 10: val_loss improved from 1.57282 to 1.56354, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.5806 - val_loss: 1.5635
# Epoch 11/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.5737
# Epoch 11: val_loss improved from 1.56354 to 1.56223, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.5718 - val_loss: 1.5622
# Epoch 12/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5591
# Epoch 12: val_loss improved from 1.56223 to 1.54222, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.5594 - val_loss: 1.5422
# Epoch 13/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5506
# Epoch 13: val_loss did not improve from 1.54222
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.5503 - val_loss: 1.5451
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5414
# Epoch 14: val_loss did not improve from 1.54222
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.5414 - val_loss: 1.5501
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5323
# Epoch 15: val_loss improved from 1.54222 to 1.52824, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.5323 - val_loss: 1.5282
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5231
# Epoch 16: val_loss did not improve from 1.52824
# 29601/29601 [==============================] - 1s 26us/sample - loss: 1.5231 - val_loss: 1.5294
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5182
# Epoch 17: val_loss did not improve from 1.52824
# 29601/29601 [==============================] - 1s 26us/sample - loss: 1.5182 - val_loss: 1.5333
# Epoch 18/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.5168
# Epoch 18: val_loss improved from 1.52824 to 1.52060, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.5156 - val_loss: 1.5206
# Epoch 19/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.5076
# Epoch 19: val_loss improved from 1.52060 to 1.51406, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.5083 - val_loss: 1.5141
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5062
# Epoch 20: val_loss did not improve from 1.51406
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.5062 - val_loss: 1.5231
# Epoch 21/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.5000
# Epoch 21: val_loss improved from 1.51406 to 1.51284, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4989 - val_loss: 1.5128
# Epoch 22/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4976
# Epoch 22: val_loss improved from 1.51284 to 1.49988, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 29us/sample - loss: 1.4977 - val_loss: 1.4999
# Epoch 23/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4948
# Epoch 23: val_loss improved from 1.49988 to 1.49835, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4939 - val_loss: 1.4983
# Epoch 24/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4935
# Epoch 24: val_loss improved from 1.49835 to 1.49392, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4938 - val_loss: 1.4939
# Epoch 25/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4892
# Epoch 25: val_loss did not improve from 1.49392
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4887 - val_loss: 1.4953
# Epoch 26/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4883
# Epoch 26: val_loss did not improve from 1.49392
# 29601/29601 [==============================] - 1s 26us/sample - loss: 1.4896 - val_loss: 1.4940
# Epoch 27/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4866
# Epoch 27: val_loss improved from 1.49392 to 1.49346, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4864 - val_loss: 1.4935
# Epoch 28/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4861
# Epoch 28: val_loss improved from 1.49346 to 1.48938, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4857 - val_loss: 1.4894
# Epoch 29/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4837
# Epoch 29: val_loss did not improve from 1.48938
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4829 - val_loss: 1.4933
# Epoch 30/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4837
# Epoch 30: val_loss did not improve from 1.48938
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4818 - val_loss: 1.4908
# Epoch 31/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4796
# Epoch 31: val_loss did not improve from 1.48938
# 29601/29601 [==============================] - 1s 24us/sample - loss: 1.4807 - val_loss: 1.4919
# Epoch 32/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4790
# Epoch 32: val_loss improved from 1.48938 to 1.48317, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4803 - val_loss: 1.4832
# Epoch 33/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4774
# Epoch 33: val_loss did not improve from 1.48317
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4774 - val_loss: 1.4844
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4787
# Epoch 34: val_loss did not improve from 1.48317
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4787 - val_loss: 1.4842
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4805
# Epoch 35: val_loss improved from 1.48317 to 1.48274, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4805 - val_loss: 1.4827
# Epoch 36/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4779
# Epoch 36: val_loss did not improve from 1.48274
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4767 - val_loss: 1.4964
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4736
# Epoch 37: val_loss did not improve from 1.48274
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4736 - val_loss: 1.4861
# Epoch 38/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4691
# Epoch 38: val_loss improved from 1.48274 to 1.47865, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4718 - val_loss: 1.4786
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4722
# Epoch 39: val_loss improved from 1.47865 to 1.47653, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4722 - val_loss: 1.4765
# Epoch 40/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4717
# Epoch 40: val_loss did not improve from 1.47653
# 29601/29601 [==============================] - 1s 25us/sample - loss: 1.4721 - val_loss: 1.4797
# Epoch 41/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4682
# Epoch 41: val_loss improved from 1.47653 to 1.47595, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4685 - val_loss: 1.4760
# Epoch 42/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4690
# Epoch 42: val_loss improved from 1.47595 to 1.47246, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 29us/sample - loss: 1.4683 - val_loss: 1.4725
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4687
# Epoch 43: val_loss did not improve from 1.47246
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4687 - val_loss: 1.4727
# Epoch 44/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4673
# Epoch 44: val_loss improved from 1.47246 to 1.47012, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4669 - val_loss: 1.4701
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4665
# Epoch 45: val_loss improved from 1.47012 to 1.46864, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4665 - val_loss: 1.4686
# Epoch 46/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4653
# Epoch 46: val_loss improved from 1.46864 to 1.46672, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 25us/sample - loss: 1.4646 - val_loss: 1.4667
# Epoch 47/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4666
# Epoch 47: val_loss improved from 1.46672 to 1.46618, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4664 - val_loss: 1.4662
# Epoch 48/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4666
# Epoch 48: val_loss did not improve from 1.46618
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4662 - val_loss: 1.4756
# Epoch 49/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4654
# Epoch 49: val_loss improved from 1.46618 to 1.46230, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4631 - val_loss: 1.4623
# Epoch 50/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4599
# Epoch 50: val_loss did not improve from 1.46230
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4609 - val_loss: 1.4640
# Epoch 51/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4622
# Epoch 51: val_loss did not improve from 1.46230
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4627 - val_loss: 1.4715
# Epoch 52/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4629
# Epoch 52: val_loss improved from 1.46230 to 1.46108, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 26us/sample - loss: 1.4617 - val_loss: 1.4611
# Epoch 53/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4614
# Epoch 53: val_loss improved from 1.46108 to 1.45929, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4613 - val_loss: 1.4593
# Epoch 54/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4608
# Epoch 54: val_loss did not improve from 1.45929
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4607 - val_loss: 1.4604
# Epoch 55/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4596
# Epoch 55: val_loss did not improve from 1.45929
# 29601/29601 [==============================] - 1s 26us/sample - loss: 1.4606 - val_loss: 1.4658
# Epoch 56/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4586
# Epoch 56: val_loss did not improve from 1.45929
# 29601/29601 [==============================] - 1s 26us/sample - loss: 1.4581 - val_loss: 1.4614
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4578
# Epoch 57: val_loss did not improve from 1.45929
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4578 - val_loss: 1.4676
# Epoch 58/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4548
# Epoch 58: val_loss improved from 1.45929 to 1.45679, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 29us/sample - loss: 1.4537 - val_loss: 1.4568
# Epoch 59/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4564
# Epoch 59: val_loss did not improve from 1.45679
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4573 - val_loss: 1.4594
# Epoch 60/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4558
# Epoch 60: val_loss did not improve from 1.45679
# 29601/29601 [==============================] - 1s 26us/sample - loss: 1.4567 - val_loss: 1.4603
# Epoch 61/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4555
# Epoch 61: val_loss improved from 1.45679 to 1.45676, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4544 - val_loss: 1.4568
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4539
# Epoch 62: val_loss improved from 1.45676 to 1.45583, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4539 - val_loss: 1.4558
# Epoch 63/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4528
# Epoch 63: val_loss did not improve from 1.45583
# 29601/29601 [==============================] - 1s 25us/sample - loss: 1.4508 - val_loss: 1.4570
# Epoch 64/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4530
# Epoch 64: val_loss did not improve from 1.45583
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4524 - val_loss: 1.4570
# Epoch 65/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4507
# Epoch 65: val_loss improved from 1.45583 to 1.45163, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4507 - val_loss: 1.4516
# Epoch 66/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4486
# Epoch 66: val_loss did not improve from 1.45163
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4491 - val_loss: 1.4572
# Epoch 67/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4489
# Epoch 67: val_loss did not improve from 1.45163
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4506 - val_loss: 1.4544
# Epoch 68/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4483
# Epoch 68: val_loss did not improve from 1.45163
# 29601/29601 [==============================] - 1s 29us/sample - loss: 1.4487 - val_loss: 1.4538
# Epoch 69/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4465
# Epoch 69: val_loss did not improve from 1.45163
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4471 - val_loss: 1.4668
# Epoch 70/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4500
# Epoch 70: val_loss did not improve from 1.45163
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4511 - val_loss: 1.4527
# Epoch 71/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4498
# Epoch 71: val_loss improved from 1.45163 to 1.45009, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4492 - val_loss: 1.4501
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4477
# Epoch 72: val_loss did not improve from 1.45009
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4477 - val_loss: 1.4507
# Epoch 73/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4456
# Epoch 73: val_loss improved from 1.45009 to 1.44981, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4461 - val_loss: 1.4498
# Epoch 74/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4445
# Epoch 74: val_loss did not improve from 1.44981
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4444 - val_loss: 1.4508
# Epoch 75/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4432
# Epoch 75: val_loss improved from 1.44981 to 1.44804, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4420 - val_loss: 1.4480
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4455
# Epoch 76: val_loss did not improve from 1.44804
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4455 - val_loss: 1.4578
# Epoch 77/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4421
# Epoch 77: val_loss did not improve from 1.44804
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4411 - val_loss: 1.4509
# Epoch 78/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4413
# Epoch 78: val_loss did not improve from 1.44804
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4422 - val_loss: 1.4492
# Epoch 79/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4454
# Epoch 79: val_loss did not improve from 1.44804
# 29601/29601 [==============================] - 1s 26us/sample - loss: 1.4444 - val_loss: 1.4487
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4414
# Epoch 80: val_loss improved from 1.44804 to 1.44793, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4414 - val_loss: 1.4479
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4423
# Epoch 81: val_loss did not improve from 1.44793
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4423 - val_loss: 1.4498
# Epoch 82/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.4388
# Epoch 82: val_loss improved from 1.44793 to 1.44617, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 28us/sample - loss: 1.4391 - val_loss: 1.4462
# Epoch 83/100
# 27648/29601 [===========================>..] - ETA: 0s - loss: 1.4391
# Epoch 83: val_loss did not improve from 1.44617
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4398 - val_loss: 1.4481
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4398
# Epoch 84: val_loss improved from 1.44617 to 1.44534, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 1s 27us/sample - loss: 1.4398 - val_loss: 1.4453
# Epoch 85/100
# ...
# Epoch 69/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3941
# Epoch 69: val_loss did not improve from 1.42261
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3948 - val_loss: 1.4319
# Epoch 70/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3943
# Epoch 70: val_loss did not improve from 1.42261
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3956 - val_loss: 1.4245
# Epoch 71/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3932
# Epoch 71: val_loss did not improve from 1.42261
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3929 - val_loss: 1.4242
# Epoch 72/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3945
# Epoch 72: val_loss did not improve from 1.42261
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3943 - val_loss: 1.4290
# Epoch 73/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3916
# Epoch 73: val_loss did not improve from 1.42261
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3919 - val_loss: 1.4261
# Epoch 74/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3953
# Epoch 74: val_loss did not improve from 1.42261
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3948 - val_loss: 1.4243
# Epoch 75/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3942
# Epoch 75: val_loss did not improve from 1.42261
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3946 - val_loss: 1.4260
# Epoch 76/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3917
# Epoch 76: val_loss did not improve from 1.42261
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3902 - val_loss: 1.4260
# Epoch 77/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3956
# Epoch 77: val_loss did not improve from 1.42261
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3939 - val_loss: 1.4276
# Epoch 78/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3894
# Epoch 78: val_loss did not improve from 1.42261
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3903 - val_loss: 1.4243
# Epoch 79/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3943
# Epoch 79: val_loss did not improve from 1.42261
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3942 - val_loss: 1.4261
# Epoch 80/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3923
# Epoch 80: val_loss did not improve from 1.42261
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3931 - val_loss: 1.4249
# Epoch 81/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3920
# Epoch 81: val_loss improved from 1.42261 to 1.42172, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_2.h5
# 29601/29601 [==============================] - 1s 24us/sample - loss: 1.3927 - val_loss: 1.4217
# Epoch 82/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3934
# Epoch 82: val_loss improved from 1.42172 to 1.42111, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_2.h5
# 29601/29601 [==============================] - 1s 24us/sample - loss: 1.3939 - val_loss: 1.4211
# Epoch 83/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3937
# Epoch 83: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3927 - val_loss: 1.4235
# Epoch 84/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3896
# Epoch 84: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3908 - val_loss: 1.4269
# Epoch 85/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3898
# Epoch 85: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3897 - val_loss: 1.4276
# Epoch 86/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3939
# Epoch 86: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3931 - val_loss: 1.4226
# Epoch 87/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3925
# Epoch 87: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3909 - val_loss: 1.4233
# Epoch 88/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3877
# Epoch 88: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3878 - val_loss: 1.4259
# Epoch 89/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3869
# Epoch 89: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3875 - val_loss: 1.4265
# Epoch 90/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3898
# Epoch 90: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3892 - val_loss: 1.4219
# Epoch 91/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3880
# Epoch 91: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3882 - val_loss: 1.4260
# Epoch 92/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3903
# Epoch 92: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3901 - val_loss: 1.4252
# Epoch 93/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3868
# Epoch 93: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3882 - val_loss: 1.4235
# Epoch 94/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3895
# Epoch 94: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3894 - val_loss: 1.4225
# Epoch 95/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3932
# Epoch 95: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3928 - val_loss: 1.4346
# Epoch 96/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3887
# Epoch 96: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3892 - val_loss: 1.4245
# Epoch 97/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3870
# Epoch 97: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3885 - val_loss: 1.4300
# Epoch 98/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3855
# Epoch 98: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3866 - val_loss: 1.4274
# Epoch 99/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3849
# Epoch 99: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3849 - val_loss: 1.4278
# Epoch 100/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3890
# Epoch 100: val_loss did not improve from 1.42111
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3885 - val_loss: 1.4231
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3883
# Epoch 1: val_loss improved from inf to 1.42865, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_3.h5
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3882 - val_loss: 1.4286
# Epoch 2/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3889
# Epoch 2: val_loss improved from 1.42865 to 1.42649, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_3.h5
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3887 - val_loss: 1.4265
# Epoch 3/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3803
# Epoch 3: val_loss improved from 1.42649 to 1.42355, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_3.h5
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3829 - val_loss: 1.4235
# Epoch 4/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3886
# Epoch 4: val_loss improved from 1.42355 to 1.42221, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_3.h5
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3880 - val_loss: 1.4222
# Epoch 5/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3867
# Epoch 5: val_loss did not improve from 1.42221
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3855 - val_loss: 1.4249
# Epoch 6/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3875
# Epoch 6: val_loss did not improve from 1.42221
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3882 - val_loss: 1.4228
# Epoch 7/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3867
# Epoch 7: val_loss did not improve from 1.42221
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3861 - val_loss: 1.4287
# Epoch 8/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3868
# Epoch 8: val_loss did not improve from 1.42221
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3878 - val_loss: 1.4239
# Epoch 9/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3861
# Epoch 9: val_loss did not improve from 1.42221
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3867 - val_loss: 1.4236
# Epoch 10/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3903
# Epoch 10: val_loss did not improve from 1.42221
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3900 - val_loss: 1.4256
# Epoch 11/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3905
# Epoch 11: val_loss did not improve from 1.42221
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3897 - val_loss: 1.4240
# Epoch 12/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3875
# Epoch 12: val_loss did not improve from 1.42221
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3885 - val_loss: 1.4280
# Epoch 13/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3875
# Epoch 13: val_loss did not improve from 1.42221
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3869 - val_loss: 1.4235
# Epoch 14/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3914
# Epoch 14: val_loss did not improve from 1.42221
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3923 - val_loss: 1.4268
# Epoch 15/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3901
# Epoch 15: val_loss improved from 1.42221 to 1.41989, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_3.h5
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3900 - val_loss: 1.4199
# Epoch 16/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.3961
# Epoch 16: val_loss did not improve from 1.41989
# 29601/29601 [==============================] - 1s 23us/sample - loss: 1.3961 - val_loss: 1.4220
# Epoch 17/100
# 25600/29601 [========================>.....] - ETA: 0s - loss: 1.3906
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 100
#      98 checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
#      99 pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
# --> 100 model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
#
# File /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:856, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     853 self._check_call_args("fit")
#     855 func = self._select_training_loop(x)
# --> 856 return func.fit(
#     857     self,
#     858     x=x,
#     859     y=y,
#     860     batch_size=batch_size,
#     861     epochs=epochs,
#     862     verbose=verbose,
#     863     callbacks=callbacks,
#     864     validation_split=validation_split,
#     865     validation_data=validation_data,
#     866     shuffle=shuffle,
#     867     class_weight=class_weight,
#     868     sample_weight=sample_weight,
#     869     initial_epoch=initial_epoch,
#     870     steps_per_epoch=steps_per_epoch,
#     871     validation_steps=validation_steps,
#     872     validation_freq=validation_freq,
#     873     max_queue_size=max_queue_size,
#     874     workers=workers,
#     875     use_multiprocessing=use_multiprocessing,
#     876 )
#
# File /usr/lib/python3.11/site-packages/keras/engine/training_arrays_v1.py:734, in ArrayLikeTrainingLoop.fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     728         raise ValueError(
#     729             "`validation_steps` should not be specified if "
#     730             "`validation_data` is None."
#     731         )
#     732     val_x, val_y, val_sample_weights = None, None, None
# --> 734 return fit_loop(
#     735     model,
#     736     inputs=x,
#     737     targets=y,
#     738     sample_weights=sample_weights,
#     739     batch_size=batch_size,
#     740     epochs=epochs,
#     741     verbose=verbose,
#     742     callbacks=callbacks,
#     743     val_inputs=val_x,
#     744     val_targets=val_y,
#     745     val_sample_weights=val_sample_weights,
#     746     shuffle=shuffle,
#     747     initial_epoch=initial_epoch,
#     748     steps_per_epoch=steps_per_epoch,
#     749     validation_steps=validation_steps,
#     750     validation_freq=validation_freq,
#     751     steps_name="steps_per_epoch",
#     752 )
#
# File /usr/lib/python3.11/site-packages/keras/engine/training_arrays_v1.py:397, in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     394 try:
#     395     if ins and isinstance(ins[-1], int):
#     396         # Do not slice the training phase flag.
# --> 397         ins_batch = slice_arrays(ins[:-1], batch_ids) + [
#     398             ins[-1]
#     399         ]
#     400     else:
#     401         ins_batch = slice_arrays(ins, batch_ids)
#
# File /usr/lib/python3.11/site-packages/keras/utils/generic_utils.py:444, in slice_arrays(arrays, start, stop)
#     442         if hasattr(start, "shape"):
#     443             start = start.tolist()
# --> 444         return [None if x is None else x[start] for x in arrays]
#     445     return [
#     446         None
#     447         if x is None
#    (...)
#     451         for x in arrays
#     452     ]
#     453 else:
#
# File /usr/lib/python3.11/site-packages/keras/utils/generic_utils.py:444, in <listcomp>(.0)
#     442         if hasattr(start, "shape"):
#     443             start = start.tolist()
# --> 444         return [None if x is None else x[start] for x in arrays]
#     445     return [
#     446         None
#     447         if x is None
#    (...)
#     451         for x in arrays
#     452     ]
#     453 else:
#
# KeyboardInterrupt:

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_gaitpara_4.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:39:03.609874: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_15_1/lstm_cell_52/kernel/Assign' id:9617 op device:{requested: '', assigned: ''} def:{{{node lstm_15_1/lstm_cell_52/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_15_1/lstm_cell_52/kernel, lstm_15_1/lstm_cell_52/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:39:04.703934: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_34_1/lstm_cell_71/recurrent_kernel/v/Assign' id:14987 op device:{requested: '', assigned: ''} def:{{{node lstm_34_1/lstm_cell_71/recurrent_kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_34_1/lstm_cell_71/recurrent_kernel/v, lstm_34_1/lstm_cell_71/recurrent_kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-11-09 14:39:05.634630: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_1/BiasAdd' id:13230 op device:{requested: '', assigned: ''} def:{{{node dense_3_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_1/MatMul, dense_3_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:39:06.448399: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# Test MAE:
# 1.4032119890941328
# 1.2894378169069012

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_gaitpara_5.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:39:29.074340: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_14_2/lstm_cell_88/kernel/Assign' id:18688 op device:{requested: '', assigned: ''} def:{{{node lstm_14_2/lstm_cell_88/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_14_2/lstm_cell_88/kernel, lstm_14_2/lstm_cell_88/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:39:30.478069: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_38/lstm_cell_74/kernel/v/Assign' id:23703 op device:{requested: '', assigned: ''} def:{{{node lstm_38/lstm_cell_74/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_38/lstm_cell_74/kernel/v, lstm_38/lstm_cell_74/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:39:31.711604: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_2/BiasAdd' id:22461 op device:{requested: '', assigned: ''} def:{{{node dense_3_2/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_2/MatMul, dense_3_2/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3896389289725426
# 1.292267623804148

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_gaitpara_6.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:39:56.336335: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_36_3/lstm_cell_147/recurrent_kernel/Assign' id:31461 op device:{requested: '', assigned: ''} def:{{{node lstm_36_3/lstm_cell_147/recurrent_kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_36_3/lstm_cell_147/recurrent_kernel, lstm_36_3/lstm_cell_147/recurrent_kernel/Initializer/mul_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:39:58.095343: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_22_3/lstm_cell_133/kernel/v/Assign' id:33264 op device:{requested: '', assigned: ''} def:{{{node lstm_22_3/lstm_cell_133/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_22_3/lstm_cell_133/kernel/v, lstm_22_3/lstm_cell_133/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:39:59.704856: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_3/BiasAdd' id:31692 op device:{requested: '', assigned: ''} def:{{{node dense_3_3/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_3/MatMul, dense_3_3/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3872657465809304
# 1.2993788682141352

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_gaitpara_7.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:40:25.930458: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_17_4/lstm_cell_165/kernel/Assign' id:37630 op device:{requested: '', assigned: ''} def:{{{node lstm_17_4/lstm_cell_165/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_17_4/lstm_cell_165/kernel, lstm_17_4/lstm_cell_165/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:40:28.058559: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_30_4/lstm_cell_178/kernel/v/Assign' id:42615 op device:{requested: '', assigned: ''} def:{{{node lstm_30_4/lstm_cell_178/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_30_4/lstm_cell_178/kernel/v, lstm_30_4/lstm_cell_178/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:40:30.043658: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_4/BiasAdd' id:40923 op device:{requested: '', assigned: ''} def:{{{node dense_3_4/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_4/MatMul, dense_3_4/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3816535237820742
# 1.2802539650676321

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_gaitpara_8.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:40:54.197246: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_18_5/lstm_cell_203/kernel/Assign' id:47021 op device:{requested: '', assigned: ''} def:{{{node lstm_18_5/lstm_cell_203/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_18_5/lstm_cell_203/kernel, lstm_18_5/lstm_cell_203/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:40:56.734234: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_5_5/lstm_cell_190/kernel/v/Assign' id:51471 op device:{requested: '', assigned: ''} def:{{{node lstm_5_5/lstm_cell_190/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_5_5/lstm_cell_190/kernel/v, lstm_5_5/lstm_cell_190/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:40:59.118291: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_5/BiasAdd' id:50154 op device:{requested: '', assigned: ''} def:{{{node dense_3_5/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_5/MatMul, dense_3_5/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3924626200474473
# 1.2888696355341323

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_gaitpara_9.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:41:23.943859: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_8_6/lstm_cell_230/recurrent_kernel/Assign' id:54672 op device:{requested: '', assigned: ''} def:{{{node lstm_8_6/lstm_cell_230/recurrent_kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_8_6/lstm_cell_230/recurrent_kernel, lstm_8_6/lstm_cell_230/recurrent_kernel/Initializer/mul_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:41:26.860624: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_28_6/lstm_cell_250/bias/v/Assign' id:61057 op device:{requested: '', assigned: ''} def:{{{node lstm_28_6/lstm_cell_250/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_28_6/lstm_cell_250/bias/v, lstm_28_6/lstm_cell_250/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:41:29.617621: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_6/BiasAdd' id:59385 op device:{requested: '', assigned: ''} def:{{{node dense_3_6/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_6/MatMul, dense_3_6/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3840938726382774
# 1.2934857832189517
