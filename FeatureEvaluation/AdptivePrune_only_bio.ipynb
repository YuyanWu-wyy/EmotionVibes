# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([wlk_fre, wlk_fres_trace, double_support_time, pdps_new, energy_alls, log_energy_alls, smoothe_energy_alls, dur_time_1_alls, dur_time_2_alls]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-04 03:07:35.418299: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Adaptive_prune_model_only_bio_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# 2023-11-04 03:08:40.888978: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:40.889208: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:40.889395: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:40.901816: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:40.902253: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:40.902442: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:40.902617: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:40.902785: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:40.902952: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-04 03:08:41.114770: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.114989: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.115167: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.115554: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.115728: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.115893: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.116058: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.116219: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.116382: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.124443: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.124662: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.124858: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.125042: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.125404: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.125585: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.125760: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.125916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-04 03:08:41.126369: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.126528: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-04 03:08:41.127042: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:41.127196: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-04 03:08:41.127527: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-04 03:08:42.571261: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.571720: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.572150: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.572470: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.572769: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.573056: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.573336: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.573619: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.573906: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.574289: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.574585: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.574878: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.575176: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.575605: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-04 03:08:42.575736: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.575972: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-04 03:08:42.576092: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:08:42.576334: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-04 03:08:42.576432: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-04 03:08:42.622181: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-04 03:08:42.721018: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_20/lstm_cell_20/recurrent_kernel/Assign' id:3336 op device:{requested: '', assigned: ''} def:{{{node lstm_20/lstm_cell_20/recurrent_kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_20/lstm_cell_20/recurrent_kernel, lstm_20/lstm_cell_20/recurrent_kernel/Initializer/mul_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:08:42.961152: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:3634 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:08:43.025445: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:3635 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 95)
# Train on 29601 samples, validate on 3694 samples
# 2023-11-04 03:08:48.864751: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_3/lstm_cell_3/bias/v/Assign' id:17092 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_3/lstm_cell_3/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_3/lstm_cell_3/bias/v, training/Adam/lstm_3/lstm_cell_3/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-11-04 03:08:55.594469: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-04 03:08:59.738744: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-04 03:09:09.748159: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 957.00MiB (rounded to 1003487232)requested by op conv2d/Relu
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-11-04 03:09:09.748201: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2023-11-04 03:09:09.748213: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 299, Chunks in use: 299. 74.8KiB allocated for chunks. 74.8KiB in use in bin. 27.9KiB client-requested in use in bin.
# 2023-11-04 03:09:09.748220: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 2, Chunks in use: 2. 1.0KiB allocated for chunks. 1.0KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2023-11-04 03:09:09.748228: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 4, Chunks in use: 4. 5.0KiB allocated for chunks. 5.0KiB in use in bin. 4.4KiB client-requested in use in bin.
# 2023-11-04 03:09:09.748235: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-04 03:09:09.748242: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 912, Chunks in use: 912. 3.59MiB allocated for chunks. 3.59MiB in use in bin. 3.56MiB client-requested in use in bin.
# 2023-11-04 03:09:09.748249: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 3, Chunks in use: 3. 24.0KiB allocated for chunks. 24.0KiB in use in bin. 24.0KiB client-requested in use in bin.
# 2023-11-04 03:09:09.748257: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 11, Chunks in use: 11. 183.0KiB allocated for chunks. 183.0KiB in use in bin. 182.9KiB client-requested in use in bin.
# 2023-11-04 03:09:09.748265: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 2, Chunks in use: 2. 105.5KiB allocated for chunks. 105.5KiB in use in bin. 105.5KiB client-requested in use in bin.
# 2023-11-04 03:09:09.748275: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 2, Chunks in use: 1. 234.2KiB allocated for chunks. 124.0KiB in use in bin. 124.0KiB client-requested in use in bin.
# 2023-11-04 03:09:09.748283: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 20, Chunks in use: 20. 2.63MiB allocated for chunks. 2.63MiB in use in bin. 2.63MiB client-requested in use in bin.
# 2023-11-04 03:09:09.748289: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 2, Chunks in use: 2. 736.0KiB allocated for chunks. 736.0KiB in use in bin. 736.0KiB client-requested in use in bin.
# 2023-11-04 03:09:09.748297: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 8, Chunks in use: 7. 5.66MiB allocated for chunks. 4.72MiB in use in bin. 4.62MiB client-requested in use in bin.
# 2023-11-04 03:09:09.748304: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 1, Chunks in use: 1. 1.08MiB allocated for chunks. 1.08MiB in use in bin. 704.0KiB client-requested in use in bin.
# 2023-11-04 03:09:09.748310: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-04 03:09:09.748316: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-04 03:09:09.748323: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-04 03:09:09.748330: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 31.62MiB allocated for chunks. 31.62MiB in use in bin. 31.62MiB client-requested in use in bin.
# 2023-11-04 03:09:09.748339: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-04 03:09:09.748347: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-04 03:09:09.748356: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-04 03:09:09.748366: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 2, Chunks in use: 1. 1.25GiB allocated for chunks. 957.00MiB in use in bin. 957.00MiB client-requested in use in bin.
# 2023-11-04 03:09:09.748374: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 957.00MiB was 256.00MiB, Chunk State:
# 2023-11-04 03:09:09.748387: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 322.14MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 957.00MiB | Requested Size: 957.00MiB | in_use: 1 | bin_num: -1
# 2023-11-04 03:09:09.748396: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 1389428736
# 2023-11-04 03:09:09.748407: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8000000 of size 1280 next 1
# 2023-11-04 03:09:09.748416: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8000500 of size 256 next 2
# 2023-11-04 03:09:09.748424: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8000600 of size 256 next 3
# 2023-11-04 03:09:09.748433: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8000700 of size 256 next 4
# 2023-11-04 03:09:09.748442: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8000800 of size 256 next 5
# 2023-11-04 03:09:09.748450: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8000900 of size 256 next 6
# 2023-11-04 03:09:09.748460: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8000a00 of size 256 next 7
# 2023-11-04 03:09:09.748468: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8000b00 of size 256 next 8
# 2023-11-04 03:09:09.748475: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8000c00 of size 256 next 9
# 2023-11-04 03:09:09.748483: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8000d00 of size 256 next 10
# 2023-11-04 03:09:09.748492: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8000e00 of size 256 next 11
# 2023-11-04 03:09:09.748500: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8000f00 of size 256 next 12
# 2023-11-04 03:09:09.748507: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001000 of size 256 next 13
# 2023-11-04 03:09:09.748514: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001100 of size 256 next 14
# 2023-11-04 03:09:09.748520: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001200 of size 256 next 15
# 2023-11-04 03:09:09.748528: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001300 of size 256 next 16
# 2023-11-04 03:09:09.748726: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001400 of size 256 next 17
# 2023-11-04 03:09:09.748734: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001500 of size 256 next 18
# 2023-11-04 03:09:09.748743: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001600 of size 256 next 19
# 2023-11-04 03:09:09.748753: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001700 of size 256 next 20
# 2023-11-04 03:09:09.748762: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001800 of size 256 next 21
# 2023-11-04 03:09:09.748774: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001900 of size 256 next 22
# 2023-11-04 03:09:09.748784: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001a00 of size 256 next 23
# 2023-11-04 03:09:09.748794: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001b00 of size 256 next 24
# 2023-11-04 03:09:09.748804: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001c00 of size 256 next 25
# 2023-11-04 03:09:09.748815: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001d00 of size 256 next 26
# 2023-11-04 03:09:09.748828: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001e00 of size 256 next 27
# 2023-11-04 03:09:09.748839: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8001f00 of size 256 next 28
# 2023-11-04 03:09:09.748849: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002000 of size 256 next 29
# 2023-11-04 03:09:09.748858: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002100 of size 256 next 30
# 2023-11-04 03:09:09.748870: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002200 of size 256 next 31
# 2023-11-04 03:09:09.748879: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002300 of size 256 next 32
# 2023-11-04 03:09:09.748891: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002400 of size 256 next 33
# 2023-11-04 03:09:09.748899: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002500 of size 256 next 34
# 2023-11-04 03:09:09.748908: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002600 of size 256 next 35
# 2023-11-04 03:09:09.748917: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002700 of size 256 next 36
# 2023-11-04 03:09:09.748926: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002800 of size 256 next 37
# 2023-11-04 03:09:09.748935: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002900 of size 256 next 38
# 2023-11-04 03:09:09.748945: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002a00 of size 256 next 39
# 2023-11-04 03:09:09.748953: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002b00 of size 256 next 40
# 2023-11-04 03:09:09.748962: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002c00 of size 256 next 41
# 2023-11-04 03:09:09.748970: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002d00 of size 256 next 42
# 2023-11-04 03:09:09.748979: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002e00 of size 256 next 43
# 2023-11-04 03:09:09.748988: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8002f00 of size 256 next 44
# 2023-11-04 03:09:09.748997: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003000 of size 256 next 71
# 2023-11-04 03:09:09.749006: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003100 of size 256 next 46
# 2023-11-04 03:09:09.749015: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003200 of size 256 next 47
# 2023-11-04 03:09:09.749024: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003300 of size 256 next 66
# 2023-11-04 03:09:09.749034: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003400 of size 256 next 49
# 2023-11-04 03:09:09.749044: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003500 of size 256 next 50
# 2023-11-04 03:09:09.749056: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003600 of size 256 next 51
# 2023-11-04 03:09:09.749065: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003700 of size 256 next 52
# 2023-11-04 03:09:09.749075: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003800 of size 256 next 53
# 2023-11-04 03:09:09.749087: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003900 of size 256 next 54
# 2023-11-04 03:09:09.749098: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003a00 of size 256 next 55
# 2023-11-04 03:09:09.749108: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003b00 of size 256 next 56
# 2023-11-04 03:09:09.749120: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003c00 of size 256 next 57
# 2023-11-04 03:09:09.749130: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003d00 of size 256 next 58
# 2023-11-04 03:09:09.749142: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003e00 of size 256 next 59
# 2023-11-04 03:09:09.749153: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8003f00 of size 256 next 83
# 2023-11-04 03:09:09.749163: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004000 of size 256 next 88
# 2023-11-04 03:09:09.749175: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004100 of size 256 next 81
# 2023-11-04 03:09:09.749187: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004200 of size 256 next 75
# 2023-11-04 03:09:09.749197: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004300 of size 256 next 74
# 2023-11-04 03:09:09.749208: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004400 of size 256 next 60
# 2023-11-04 03:09:09.749219: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004500 of size 256 next 48
# 2023-11-04 03:09:09.749230: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004600 of size 256 next 73
# 2023-11-04 03:09:09.749239: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004700 of size 256 next 68
# 2023-11-04 03:09:09.749249: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004800 of size 256 next 69
# 2023-11-04 03:09:09.749260: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004900 of size 256 next 70
# 2023-11-04 03:09:09.749269: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004a00 of size 256 next 86
# 2023-11-04 03:09:09.749279: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004b00 of size 256 next 85
# 2023-11-04 03:09:09.749290: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004c00 of size 256 next 72
# 2023-11-04 03:09:09.749299: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004d00 of size 256 next 61
# 2023-11-04 03:09:09.749311: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004e00 of size 256 next 63
# 2023-11-04 03:09:09.749322: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8004f00 of size 256 next 76
# 2023-11-04 03:09:09.749332: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005000 of size 256 next 77
# 2023-11-04 03:09:09.749343: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005100 of size 256 next 78
# 2023-11-04 03:09:09.749358: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005200 of size 256 next 79
# 2023-11-04 03:09:09.749368: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005300 of size 256 next 80
# 2023-11-04 03:09:09.749379: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005400 of size 256 next 82
# 2023-11-04 03:09:09.749389: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005500 of size 256 next 89
# 2023-11-04 03:09:09.749399: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005600 of size 256 next 90
# 2023-11-04 03:09:09.749408: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005700 of size 256 next 84
# 2023-11-04 03:09:09.749418: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005800 of size 256 next 87
# 2023-11-04 03:09:09.749428: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005900 of size 256 next 62
# 2023-11-04 03:09:09.749437: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005a00 of size 256 next 45
# 2023-11-04 03:09:09.749449: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005b00 of size 256 next 64
# 2023-11-04 03:09:09.749460: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005c00 of size 256 next 65
# 2023-11-04 03:09:09.749471: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005d00 of size 256 next 67
# 2023-11-04 03:09:09.749481: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005e00 of size 256 next 91
# 2023-11-04 03:09:09.749493: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8005f00 of size 256 next 92
# 2023-11-04 03:09:09.749500: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8006000 of size 256 next 93
# 2023-11-04 03:09:09.749512: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8006100 of size 256 next 94
# 2023-11-04 03:09:09.749523: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8006200 of size 256 next 95
# 2023-11-04 03:09:09.749532: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8006300 of size 256 next 96
# 2023-11-04 03:09:09.749544: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8006400 of size 256 next 97
# 2023-11-04 03:09:09.749554: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8006500 of size 256 next 98
# 2023-11-04 03:09:09.749564: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8006600 of size 256 next 99
# 2023-11-04 03:09:09.749573: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8006700 of size 256 next 100
# 2023-11-04 03:09:09.749585: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8006800 of size 256 next 101
# 2023-11-04 03:09:09.749596: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8006900 of size 256 next 102
# 2023-11-04 03:09:09.749606: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8006a00 of size 256 next 103
# 2023-11-04 03:09:09.749617: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8006b00 of size 256 next 104
# 2023-11-04 03:09:09.749627: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8006c00 of size 1280 next 105
# 2023-11-04 03:09:09.749636: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8007100 of size 256 next 106
# 2023-11-04 03:09:09.749647: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8007200 of size 18432 next 107
# 2023-11-04 03:09:09.749657: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c800ba00 of size 256 next 108
# 2023-11-04 03:09:09.749667: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c800bb00 of size 512 next 109
# 2023-11-04 03:09:09.749676: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c800bd00 of size 256 next 110
# 2023-11-04 03:09:09.749688: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c800be00 of size 256 next 111
# 2023-11-04 03:09:09.749697: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c800bf00 of size 256 next 112
# 2023-11-04 03:09:09.749707: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c800c000 of size 256 next 113
# 2023-11-04 03:09:09.749717: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c800c100 of size 17920 next 114
# 2023-11-04 03:09:09.749729: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8010700 of size 256 next 115
# 2023-11-04 03:09:09.749738: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8010800 of size 54016 next 116
# 2023-11-04 03:09:09.749748: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c801db00 of size 256 next 117
# 2023-11-04 03:09:09.749757: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c801dc00 of size 8192 next 118
# 2023-11-04 03:09:09.749769: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c801fc00 of size 256 next 119
# 2023-11-04 03:09:09.749776: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c801fd00 of size 256 next 120
# 2023-11-04 03:09:09.749786: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c801fe00 of size 256 next 121
# 2023-11-04 03:09:09.749797: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c801ff00 of size 256 next 122
# 2023-11-04 03:09:09.749808: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020000 of size 256 next 123
# 2023-11-04 03:09:09.749818: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020100 of size 256 next 124
# 2023-11-04 03:09:09.749831: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020200 of size 256 next 125
# 2023-11-04 03:09:09.749848: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020300 of size 256 next 126
# 2023-11-04 03:09:09.749860: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020400 of size 256 next 127
# 2023-11-04 03:09:09.749871: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020500 of size 256 next 128
# 2023-11-04 03:09:09.749881: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020600 of size 256 next 129
# 2023-11-04 03:09:09.749894: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020700 of size 256 next 130
# 2023-11-04 03:09:09.749904: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020800 of size 256 next 131
# 2023-11-04 03:09:09.749916: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020900 of size 256 next 132
# 2023-11-04 03:09:09.749929: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020a00 of size 256 next 133
# 2023-11-04 03:09:09.749939: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020b00 of size 256 next 134
# 2023-11-04 03:09:09.749948: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020c00 of size 256 next 135
# 2023-11-04 03:09:09.749960: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020d00 of size 256 next 136
# 2023-11-04 03:09:09.749969: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020e00 of size 256 next 137
# 2023-11-04 03:09:09.749978: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8020f00 of size 256 next 138
# 2023-11-04 03:09:09.749986: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8021000 of size 256 next 139
# 2023-11-04 03:09:09.749997: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8021100 of size 256 next 140
# 2023-11-04 03:09:09.750010: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8021200 of size 256 next 141
# 2023-11-04 03:09:09.750023: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8021300 of size 256 next 142
# 2023-11-04 03:09:09.750034: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31c8021400 of size 256 next 143
# ...
# 2023-11-04 03:09:09.766696: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadbaf00 of size 4096 next 639
# 2023-11-04 03:09:09.766711: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadbbf00 of size 4096 next 640
# 2023-11-04 03:09:09.766725: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadbcf00 of size 4096 next 641
# 2023-11-04 03:09:09.766738: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadbdf00 of size 4096 next 642
# 2023-11-04 03:09:09.766752: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadbef00 of size 4096 next 643
# 2023-11-04 03:09:09.766766: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadbff00 of size 4096 next 644
# 2023-11-04 03:09:09.766780: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadc0f00 of size 4096 next 645
# 2023-11-04 03:09:09.766795: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadc1f00 of size 4096 next 646
# 2023-11-04 03:09:09.766806: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadc2f00 of size 4096 next 647
# 2023-11-04 03:09:09.766820: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadc3f00 of size 4096 next 648
# 2023-11-04 03:09:09.766835: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadc4f00 of size 4096 next 649
# 2023-11-04 03:09:09.766851: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadc5f00 of size 4096 next 650
# 2023-11-04 03:09:09.766868: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadc6f00 of size 4096 next 651
# 2023-11-04 03:09:09.766885: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadc7f00 of size 4096 next 652
# 2023-11-04 03:09:09.766901: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadc8f00 of size 4096 next 653
# 2023-11-04 03:09:09.766915: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadc9f00 of size 4096 next 654
# 2023-11-04 03:09:09.766929: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadcaf00 of size 4096 next 655
# 2023-11-04 03:09:09.766944: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadcbf00 of size 4096 next 656
# 2023-11-04 03:09:09.766957: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadccf00 of size 4096 next 657
# 2023-11-04 03:09:09.766972: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadcdf00 of size 4096 next 658
# 2023-11-04 03:09:09.766988: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadcef00 of size 4096 next 659
# 2023-11-04 03:09:09.767003: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadcff00 of size 4096 next 660
# 2023-11-04 03:09:09.767016: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadd0f00 of size 4096 next 661
# 2023-11-04 03:09:09.767029: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadd1f00 of size 4096 next 662
# 2023-11-04 03:09:09.767040: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadd2f00 of size 4096 next 663
# 2023-11-04 03:09:09.767052: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadd3f00 of size 4096 next 664
# 2023-11-04 03:09:09.767065: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadd4f00 of size 4096 next 665
# 2023-11-04 03:09:09.767080: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadd5f00 of size 4096 next 666
# 2023-11-04 03:09:09.767093: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadd6f00 of size 4096 next 667
# 2023-11-04 03:09:09.767107: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadd7f00 of size 4096 next 668
# 2023-11-04 03:09:09.767118: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadd8f00 of size 4096 next 669
# 2023-11-04 03:09:09.767132: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadd9f00 of size 4096 next 670
# 2023-11-04 03:09:09.767148: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31caddaf00 of size 4096 next 671
# 2023-11-04 03:09:09.767162: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31caddbf00 of size 4096 next 672
# 2023-11-04 03:09:09.767177: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31caddcf00 of size 4096 next 673
# 2023-11-04 03:09:09.767190: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadddf00 of size 4096 next 674
# 2023-11-04 03:09:09.767204: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31caddef00 of size 4096 next 675
# 2023-11-04 03:09:09.767215: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31caddff00 of size 4096 next 676
# 2023-11-04 03:09:09.767230: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cade0f00 of size 4096 next 677
# 2023-11-04 03:09:09.767244: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cade1f00 of size 4096 next 678
# 2023-11-04 03:09:09.767259: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cade2f00 of size 4096 next 679
# 2023-11-04 03:09:09.767276: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cade3f00 of size 4096 next 680
# 2023-11-04 03:09:09.767291: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cade4f00 of size 4096 next 681
# 2023-11-04 03:09:09.767305: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cade5f00 of size 4096 next 682
# 2023-11-04 03:09:09.767319: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cade6f00 of size 4096 next 683
# 2023-11-04 03:09:09.767336: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cade7f00 of size 4096 next 684
# 2023-11-04 03:09:09.767351: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cade8f00 of size 4096 next 685
# 2023-11-04 03:09:09.767365: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cade9f00 of size 4096 next 686
# 2023-11-04 03:09:09.767381: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadeaf00 of size 4096 next 687
# 2023-11-04 03:09:09.767396: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f31cadebf00 of size 1003487232 next 1267
# 2023-11-04 03:09:09.767413: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f3206aebf00 of size 337789184 next 18446744073709551615
# 2023-11-04 03:09:09.767427: I tensorflow/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2023-11-04 03:09:09.767448: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 299 Chunks of size 256 totalling 74.8KiB
# 2023-11-04 03:09:09.767464: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 512 totalling 1.0KiB
# 2023-11-04 03:09:09.767478: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 1280 totalling 5.0KiB
# 2023-11-04 03:09:09.767495: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 905 Chunks of size 4096 totalling 3.54MiB
# 2023-11-04 03:09:09.767510: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 7680 totalling 52.5KiB
# 2023-11-04 03:09:09.767525: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 8192 totalling 24.0KiB
# 2023-11-04 03:09:09.767539: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 16384 totalling 112.0KiB
# 2023-11-04 03:09:09.767553: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 17920 totalling 35.0KiB
# 2023-11-04 03:09:09.767566: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 18432 totalling 36.0KiB
# 2023-11-04 03:09:09.767580: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 54016 totalling 105.5KiB
# 2023-11-04 03:09:09.767596: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 126976 totalling 124.0KiB
# 2023-11-04 03:09:09.767611: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 19 Chunks of size 135168 totalling 2.45MiB
# 2023-11-04 03:09:09.767625: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 192512 totalling 188.0KiB
# 2023-11-04 03:09:09.767642: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 364544 totalling 356.0KiB
# 2023-11-04 03:09:09.767655: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 389120 totalling 380.0KiB
# 2023-11-04 03:09:09.767669: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 622592 totalling 608.0KiB
# 2023-11-04 03:09:09.767684: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 720896 totalling 4.12MiB
# 2023-11-04 03:09:09.767701: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1138432 totalling 1.08MiB
# 2023-11-04 03:09:09.767717: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 33161216 totalling 31.62MiB
# 2023-11-04 03:09:09.767734: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1003487232 totalling 957.00MiB
# 2023-11-04 03:09:09.767750: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 1001.87MiB
# 2023-11-04 03:09:09.767766: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 1389428736 memory_limit_: 1389428736 available bytes: 0 curr_region_allocation_bytes_: 2778857472
# 2023-11-04 03:09:09.767784: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      1389428736
# InUse:                      1050539520
# MaxInUse:                   1050539520
# NumAllocs:                        1436
# MaxAllocSize:               1003487232
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-11-04 03:09:09.767816: W tensorflow/tsl/framework/bfc_allocator.cc:497] ****************************************************************************________________________
# 2023-11-04 03:09:09.767862: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at conv_ops_fused_impl.h:568 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1024,32,44,174] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2023-11-04 03:09:09.767943: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 4236242970584339552
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[5], line 100
#      98 checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
#      99 pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
# --> 100 model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
#
# File /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:856, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     853 self._check_call_args("fit")
#     855 func = self._select_training_loop(x)
# --> 856 return func.fit(
#     857     self,
#     858     x=x,
#     859     y=y,
#     860     batch_size=batch_size,
#     861     epochs=epochs,
#     862     verbose=verbose,
#     863     callbacks=callbacks,
#     864     validation_split=validation_split,
#     865     validation_data=validation_data,
#     866     shuffle=shuffle,
#     867     class_weight=class_weight,
#     868     sample_weight=sample_weight,
#     869     initial_epoch=initial_epoch,
#     870     steps_per_epoch=steps_per_epoch,
#     871     validation_steps=validation_steps,
#     872     validation_freq=validation_freq,
#     873     max_queue_size=max_queue_size,
#     874     workers=workers,
#     875     use_multiprocessing=use_multiprocessing,
#     876 )
#
# File /usr/lib/python3.11/site-packages/keras/engine/training_arrays_v1.py:734, in ArrayLikeTrainingLoop.fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     728         raise ValueError(
#     729             "`validation_steps` should not be specified if "
#     730             "`validation_data` is None."
#     731         )
#     732     val_x, val_y, val_sample_weights = None, None, None
# --> 734 return fit_loop(
#     735     model,
#     736     inputs=x,
#     737     targets=y,
#     738     sample_weights=sample_weights,
#     739     batch_size=batch_size,
#     740     epochs=epochs,
#     741     verbose=verbose,
#     742     callbacks=callbacks,
#     743     val_inputs=val_x,
#     744     val_targets=val_y,
#     745     val_sample_weights=val_sample_weights,
#     746     shuffle=shuffle,
#     747     initial_epoch=initial_epoch,
#     748     steps_per_epoch=steps_per_epoch,
#     749     validation_steps=validation_steps,
#     750     validation_freq=validation_freq,
#     751     steps_name="steps_per_epoch",
#     752 )
#
# File /usr/lib/python3.11/site-packages/keras/engine/training_arrays_v1.py:421, in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     416 callbacks._call_batch_hook(
#     417     mode, "begin", batch_index, batch_logs
#     418 )
#     420 # Get outputs.
# --> 421 batch_outs = f(ins_batch)
#     422 if not isinstance(batch_outs, list):
#     423     batch_outs = [batch_outs]
#
# File /usr/lib/python3.11/site-packages/keras/backend.py:4608, in GraphExecutionFunction.__call__(self, inputs)
#    4598 if (
#    4599     self._callable_fn is None
#    4600     or feed_arrays != self._feed_arrays
#    (...)
#    4604     or session != self._session
#    4605 ):
#    4606     self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
# -> 4608 fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    4609 self._call_fetch_callbacks(fetched[-len(self._fetches) :])
#    4610 output_structure = tf.nest.pack_sequence_as(
#    4611     self._outputs_structure,
#    4612     fetched[: len(self.outputs)],
#    4613     expand_composites=True,
#    4614 )
#
# File /usr/lib/python3.11/site-packages/tensorflow/python/client/session.py:1482, in BaseSession._Callable.__call__(self, *args, **kwargs)
#    1480 try:
#    1481   run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# -> 1482   ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1483                                          self._handle, args,
#    1484                                          run_metadata_ptr)
#    1485   if run_metadata:
#    1486     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1024,32,44,174] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node conv2d/Relu}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[loss_1/mul/_1349]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
#   (1) RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1024,32,44,174] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node conv2d/Relu}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 0 successful operations.
# 0 derived errors ignored.
