# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([wlk_fre, wlk_fres_trace, double_support_time, pdps_new]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-09 13:43:02.353128: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    # concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(hidden_i)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
# rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]

# for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
model_name = './checkpoints/Feature_extraction_only_gait.h5'

checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
# pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=0.35, start_epoch=5, end_epoch=50, frequency=1)
model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[checkpoint])
# Out:
# (29601, 4)
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 2023-11-09 13:46:24.623036: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.623263: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.623445: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.634821: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.635074: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.635257: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.635428: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.635595: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.635759: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
#  1024/29601 [>.............................] - ETA: 28:06 - loss: 5.0517
# Epoch 1: val_loss improved from inf to 4.47301, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 2023-11-09 13:46:24.889318: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.889564: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.889777: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.889982: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.890176: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.890372: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.890560: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.890752: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.890933: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.898646: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.898858: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.899070: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.899267: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.899462: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.899642: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.899824: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.899986: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-09 13:46:24.900330: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.900486: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-09 13:46:24.900863: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 13:46:24.901016: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-09 13:46:24.901418: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-09 13:46:24.909178: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-09 13:46:24.934449: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_3/bias/v/Assign' id:412 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_3/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_3/bias/v, training/Adam/dense_3/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 13:46:25.007678: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-09 13:46:25.066275: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:185 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 29601/29601 [==============================] - 61s 2ms/sample - loss: 4.8094 - val_loss: 4.4730
# Epoch 2/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 4.5151
# Epoch 2: val_loss improved from 4.47301 to 3.51445, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 4.0789 - val_loss: 3.5144
# Epoch 3/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 3.5645
# Epoch 3: val_loss improved from 3.51445 to 2.51390, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 3.0962 - val_loss: 2.5139
# Epoch 4/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 2.6433
# Epoch 4: val_loss improved from 2.51390 to 2.07859, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 2.4260 - val_loss: 2.0786
# Epoch 5/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 2.2337
# Epoch 5: val_loss improved from 2.07859 to 1.86084, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 2.0797 - val_loss: 1.8608
# Epoch 6/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.9087
# Epoch 6: val_loss improved from 1.86084 to 1.71337, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.8442 - val_loss: 1.7134
# Epoch 7/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.7619
# Epoch 7: val_loss improved from 1.71337 to 1.63482, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.6914 - val_loss: 1.6348
# Epoch 8/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.6363
# Epoch 8: val_loss improved from 1.63482 to 1.58489, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.6104 - val_loss: 1.5849
# Epoch 9/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5571
# Epoch 9: val_loss improved from 1.58489 to 1.57213, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5766 - val_loss: 1.5721
# Epoch 10/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5863
# Epoch 10: val_loss improved from 1.57213 to 1.57141, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5668 - val_loss: 1.5714
# Epoch 11/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5526
# Epoch 11: val_loss improved from 1.57141 to 1.56931, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5638 - val_loss: 1.5693
# Epoch 12/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5639
# Epoch 12: val_loss improved from 1.56931 to 1.56709, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5629 - val_loss: 1.5671
# Epoch 13/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5822
# Epoch 13: val_loss improved from 1.56709 to 1.56609, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5616 - val_loss: 1.5661
# Epoch 14/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5693
# Epoch 14: val_loss improved from 1.56609 to 1.56485, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5586 - val_loss: 1.5649
# Epoch 15/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5700
# Epoch 15: val_loss improved from 1.56485 to 1.56433, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5587 - val_loss: 1.5643
# Epoch 16/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5940
# Epoch 16: val_loss improved from 1.56433 to 1.56389, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5574 - val_loss: 1.5639
# Epoch 17/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5678
# Epoch 17: val_loss improved from 1.56389 to 1.56233, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5565 - val_loss: 1.5623
# Epoch 18/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5595
# Epoch 18: val_loss improved from 1.56233 to 1.56173, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5557 - val_loss: 1.5617
# Epoch 19/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5584
# Epoch 19: val_loss improved from 1.56173 to 1.56084, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5552 - val_loss: 1.5608
# Epoch 20/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5755
# Epoch 20: val_loss improved from 1.56084 to 1.56044, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5548 - val_loss: 1.5604
# Epoch 21/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5248
# Epoch 21: val_loss did not improve from 1.56044
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5539 - val_loss: 1.5607
# Epoch 22/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5606
# Epoch 22: val_loss improved from 1.56044 to 1.55961, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5520 - val_loss: 1.5596
# Epoch 23/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5585
# Epoch 23: val_loss improved from 1.55961 to 1.55903, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5528 - val_loss: 1.5590
# Epoch 24/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5208
# Epoch 24: val_loss did not improve from 1.55903
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5521 - val_loss: 1.5592
# Epoch 25/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5594
# Epoch 25: val_loss improved from 1.55903 to 1.55720, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5517 - val_loss: 1.5572
# Epoch 26/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5335
# Epoch 26: val_loss improved from 1.55720 to 1.55645, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5512 - val_loss: 1.5564
# Epoch 27/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5472
# Epoch 27: val_loss improved from 1.55645 to 1.55571, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5495 - val_loss: 1.5557
# Epoch 28/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5556
# Epoch 28: val_loss improved from 1.55571 to 1.55418, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5489 - val_loss: 1.5542
# Epoch 29/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5158
# Epoch 29: val_loss improved from 1.55418 to 1.55351, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5489 - val_loss: 1.5535
# Epoch 30/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5204
# Epoch 30: val_loss improved from 1.55351 to 1.55250, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5479 - val_loss: 1.5525
# Epoch 31/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5529
# Epoch 31: val_loss improved from 1.55250 to 1.55169, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5461 - val_loss: 1.5517
# Epoch 32/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5423
# Epoch 32: val_loss improved from 1.55169 to 1.55038, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5455 - val_loss: 1.5504
# Epoch 33/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5472
# Epoch 33: val_loss improved from 1.55038 to 1.54864, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5448 - val_loss: 1.5486
# Epoch 34/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5659
# Epoch 34: val_loss improved from 1.54864 to 1.54781, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5454 - val_loss: 1.5478
# Epoch 35/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5653
# Epoch 35: val_loss improved from 1.54781 to 1.54581, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5441 - val_loss: 1.5458
# Epoch 36/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5112
# Epoch 36: val_loss improved from 1.54581 to 1.54504, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5436 - val_loss: 1.5450
# Epoch 37/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5363
# Epoch 37: val_loss improved from 1.54504 to 1.54500, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5425 - val_loss: 1.5450
# Epoch 38/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5239
# Epoch 38: val_loss improved from 1.54500 to 1.54416, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5419 - val_loss: 1.5442
# Epoch 39/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5301
# Epoch 39: val_loss improved from 1.54416 to 1.54210, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5408 - val_loss: 1.5421
# Epoch 40/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5121
# Epoch 40: val_loss improved from 1.54210 to 1.54089, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5407 - val_loss: 1.5409
# Epoch 41/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5644
# Epoch 41: val_loss improved from 1.54089 to 1.53954, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5368 - val_loss: 1.5395
# Epoch 42/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5463
# Epoch 42: val_loss improved from 1.53954 to 1.53808, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5359 - val_loss: 1.5381
# Epoch 43/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4709
# Epoch 43: val_loss improved from 1.53808 to 1.53545, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5363 - val_loss: 1.5354
# Epoch 44/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5069
# Epoch 44: val_loss improved from 1.53545 to 1.53283, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5355 - val_loss: 1.5328
# Epoch 45/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5682
# Epoch 45: val_loss did not improve from 1.53283
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5362 - val_loss: 1.5335
# Epoch 46/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5522
# Epoch 46: val_loss improved from 1.53283 to 1.53183, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5353 - val_loss: 1.5318
# Epoch 47/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5594
# Epoch 47: val_loss improved from 1.53183 to 1.53098, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5343 - val_loss: 1.5310
# Epoch 48/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4895
# Epoch 48: val_loss improved from 1.53098 to 1.53064, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5349 - val_loss: 1.5306
# Epoch 49/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5709
# Epoch 49: val_loss improved from 1.53064 to 1.52823, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5334 - val_loss: 1.5282
# Epoch 50/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5837
# Epoch 50: val_loss improved from 1.52823 to 1.52662, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5336 - val_loss: 1.5266
# Epoch 51/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5150
# Epoch 51: val_loss did not improve from 1.52662
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5315 - val_loss: 1.5267
# Epoch 52/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5191
# Epoch 52: val_loss improved from 1.52662 to 1.52560, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5318 - val_loss: 1.5256
# Epoch 53/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5215
# Epoch 53: val_loss improved from 1.52560 to 1.52497, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5316 - val_loss: 1.5250
# Epoch 54/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5609
# Epoch 54: val_loss improved from 1.52497 to 1.52427, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5319 - val_loss: 1.5243
# Epoch 55/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.6015
# Epoch 55: val_loss improved from 1.52427 to 1.52341, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5314 - val_loss: 1.5234
# Epoch 56/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5360
# Epoch 56: val_loss did not improve from 1.52341
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5294 - val_loss: 1.5252
# Epoch 57/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5873
# Epoch 57: val_loss improved from 1.52341 to 1.52251, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5309 - val_loss: 1.5225
# Epoch 58/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5272
# Epoch 58: val_loss improved from 1.52251 to 1.52201, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5298 - val_loss: 1.5220
# Epoch 59/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4897
# Epoch 59: val_loss improved from 1.52201 to 1.52110, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5279 - val_loss: 1.5211
# Epoch 60/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5201
# Epoch 60: val_loss improved from 1.52110 to 1.52073, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5294 - val_loss: 1.5207
# Epoch 61/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5192
# Epoch 61: val_loss improved from 1.52073 to 1.52048, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5283 - val_loss: 1.5205
# Epoch 62/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5357
# Epoch 62: val_loss improved from 1.52048 to 1.51914, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5284 - val_loss: 1.5191
# Epoch 63/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5004
# Epoch 63: val_loss improved from 1.51914 to 1.51887, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5282 - val_loss: 1.5189
# Epoch 64/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4988
# Epoch 64: val_loss did not improve from 1.51887
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5283 - val_loss: 1.5196
# Epoch 65/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5817
# Epoch 65: val_loss improved from 1.51887 to 1.51844, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5275 - val_loss: 1.5184
# Epoch 66/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5396
# Epoch 66: val_loss improved from 1.51844 to 1.51768, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5281 - val_loss: 1.5177
# Epoch 67/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5155
# Epoch 67: val_loss did not improve from 1.51768
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5276 - val_loss: 1.5177
# Epoch 68/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5477
# Epoch 68: val_loss did not improve from 1.51768
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5268 - val_loss: 1.5177
# Epoch 69/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5574
# Epoch 69: val_loss improved from 1.51768 to 1.51648, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5268 - val_loss: 1.5165
# Epoch 70/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5521
# Epoch 70: val_loss did not improve from 1.51648
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5268 - val_loss: 1.5175
# Epoch 71/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5374
# Epoch 71: val_loss did not improve from 1.51648
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5252 - val_loss: 1.5167
# Epoch 72/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5516
# Epoch 72: val_loss did not improve from 1.51648
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5247 - val_loss: 1.5169
# Epoch 73/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5008
# Epoch 73: val_loss improved from 1.51648 to 1.51522, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5259 - val_loss: 1.5152
# Epoch 74/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5282
# Epoch 74: val_loss improved from 1.51522 to 1.51487, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5244 - val_loss: 1.5149
# Epoch 75/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5061
# Epoch 75: val_loss did not improve from 1.51487
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5251 - val_loss: 1.5157
# Epoch 76/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5495
# Epoch 76: val_loss did not improve from 1.51487
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5262 - val_loss: 1.5151
# Epoch 77/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5795
# Epoch 77: val_loss improved from 1.51487 to 1.51444, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5243 - val_loss: 1.5144
# Epoch 78/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4969
# Epoch 78: val_loss improved from 1.51444 to 1.51417, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5245 - val_loss: 1.5142
# Epoch 79/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5372
# Epoch 79: val_loss did not improve from 1.51417
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5245 - val_loss: 1.5154
# Epoch 80/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4982
# Epoch 80: val_loss did not improve from 1.51417
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5250 - val_loss: 1.5146
# Epoch 81/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5413
# Epoch 81: val_loss improved from 1.51417 to 1.51388, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5235 - val_loss: 1.5139
# Epoch 82/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5437
# Epoch 82: val_loss improved from 1.51388 to 1.51371, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5222 - val_loss: 1.5137
# Epoch 83/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5673
# Epoch 83: val_loss improved from 1.51371 to 1.51328, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5246 - val_loss: 1.5133
# Epoch 84/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4987
# Epoch 84: val_loss did not improve from 1.51328
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5249 - val_loss: 1.5140
# Epoch 85/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5758
# Epoch 85: val_loss improved from 1.51328 to 1.51238, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5239 - val_loss: 1.5124
# Epoch 86/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5368
# Epoch 86: val_loss did not improve from 1.51238
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5248 - val_loss: 1.5134
# Epoch 87/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5442
# Epoch 87: val_loss improved from 1.51238 to 1.51234, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5238 - val_loss: 1.5123
# Epoch 88/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5349
# Epoch 88: val_loss improved from 1.51234 to 1.51211, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5230 - val_loss: 1.5121
# Epoch 89/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5300
# Epoch 89: val_loss did not improve from 1.51211
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5238 - val_loss: 1.5123
# Epoch 90/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5784
# Epoch 90: val_loss did not improve from 1.51211
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5232 - val_loss: 1.5133
# Epoch 91/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5136
# Epoch 91: val_loss did not improve from 1.51211
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5236 - val_loss: 1.5123
# Epoch 92/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4894
# Epoch 92: val_loss improved from 1.51211 to 1.51092, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 2us/sample - loss: 1.5235 - val_loss: 1.5109
# Epoch 93/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5548
# Epoch 93: val_loss did not improve from 1.51092
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5209 - val_loss: 1.5113
# Epoch 94/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5084
# Epoch 94: val_loss did not improve from 1.51092
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5202 - val_loss: 1.5111
# Epoch 95/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4777
# Epoch 95: val_loss did not improve from 1.51092
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5231 - val_loss: 1.5117
# Epoch 96/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4989
# Epoch 96: val_loss improved from 1.51092 to 1.51072, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5223 - val_loss: 1.5107
# Epoch 97/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5106
# Epoch 97: val_loss did not improve from 1.51072
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5208 - val_loss: 1.5126
# Epoch 98/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.4927
# Epoch 98: val_loss improved from 1.51072 to 1.51022, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5201 - val_loss: 1.5102
# Epoch 99/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5689
# Epoch 99: val_loss did not improve from 1.51022
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5227 - val_loss: 1.5109
# Epoch 100/100
#  1024/29601 [>.............................] - ETA: 0s - loss: 1.5150
# Epoch 100: val_loss improved from 1.51022 to 1.51014, saving model to ./checkpoints/Feature_extraction_only_gait.h5
# 29601/29601 [==============================] - 0s 1us/sample - loss: 1.5202 - val_loss: 1.5101

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_only_gait.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# 2023-11-09 13:47:16.338585: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_1/kernel/Assign' id:583 op device:{requested: '', assigned: ''} def:{{{node dense_3_1/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_3_1/kernel, dense_3_1/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 13:47:16.420240: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_1/bias/v/Assign' id:753 op device:{requested: '', assigned: ''} def:{{{node dense_3_1/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_3_1/bias/v, dense_3_1/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-11-09 13:47:16.525849: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_1/BiasAdd' id:593 op device:{requested: '', assigned: ''} def:{{{node dense_3_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_1/MatMul, dense_3_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.497721531271484
# 1.488900725355426

# %%
X_test_normalized_new
# Out:
# [array([[-1.46542912, -1.19004388, -0.86405372,  0.32247488],
#         [-0.08533848, -1.19004388,  0.29596859,  0.30331311],
#         [-0.93516173, -1.19004388, -0.59110729,  0.05958421],
#         ...,
#         [ 0.23508669,  0.3704255 ,  1.66070071, -0.26674251],
#         [-0.13584477,  0.3704255 , -1.06876354, -0.34205664],
#         [ 0.0075899 ,  0.3704255 ,  1.28539938, -0.34943858]])]

# %%
X_train_normalized_new[0].shape
# Out:
# (29601, 4)
