# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-09 14:43:43.158639: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Feature_extraction_remove_gaitpara_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:44:17.058984: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:17.070222: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:17.070470: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:17.073921: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:17.074116: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:17.074385: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:17.141513: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:17.141714: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:17.141882: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:17.142022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-09 14:44:17.142387: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-09 14:44:18.080926: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:18.081205: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:18.081406: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:18.081625: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:18.081809: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-09 14:44:18.081948: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-09 14:44:18.081981: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-09 14:44:18.103330: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-09 14:44:18.318255: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_19/lstm_cell_19/kernel/Assign' id:3151 op device:{requested: '', assigned: ''} def:{{{node lstm_19/lstm_cell_19/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_19/lstm_cell_19/kernel, lstm_19/lstm_cell_19/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:44:18.450042: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:3634 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-09 14:44:18.482788: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:3635 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 81)
# Train on 29601 samples, validate on 3694 samples
# 2023-11-09 14:44:22.932080: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_20/lstm_cell_20/bias/m/Assign' id:16704 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_20/lstm_cell_20/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_20/lstm_cell_20/bias/m, training/Adam/lstm_20/lstm_cell_20/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-11-09 14:44:26.692769: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-09 14:44:28.810499: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 2023-11-09 14:44:29.025900: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 29601/29601 [==============================] - ETA: 0s - loss: 3.2764
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-09 14:44:47.520866: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:6477 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 1.95713, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 26s 866us/sample - loss: 3.2764 - val_loss: 1.9571
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.8280
# Epoch 2: val_loss improved from 1.95713 to 1.61628, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.8280 - val_loss: 1.6163
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6228
# Epoch 3: val_loss improved from 1.61628 to 1.55814, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 610us/sample - loss: 1.6228 - val_loss: 1.5581
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5727
# Epoch 4: val_loss improved from 1.55814 to 1.53446, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.5727 - val_loss: 1.5345
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5468
# Epoch 5: val_loss improved from 1.53446 to 1.51667, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 604us/sample - loss: 1.5468 - val_loss: 1.5167
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5353
# Epoch 6: val_loss improved from 1.51667 to 1.51464, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.5353 - val_loss: 1.5146
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5275
# Epoch 7: val_loss improved from 1.51464 to 1.49988, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.5275 - val_loss: 1.4999
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5191
# Epoch 8: val_loss improved from 1.49988 to 1.49877, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.5191 - val_loss: 1.4988
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5104
# Epoch 9: val_loss improved from 1.49877 to 1.49288, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.5104 - val_loss: 1.4929
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5060
# Epoch 10: val_loss improved from 1.49288 to 1.48485, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.5060 - val_loss: 1.4848
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5040
# Epoch 11: val_loss improved from 1.48485 to 1.47698, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.5040 - val_loss: 1.4770
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4957
# Epoch 12: val_loss improved from 1.47698 to 1.47134, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.4957 - val_loss: 1.4713
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4923
# Epoch 13: val_loss improved from 1.47134 to 1.47019, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.4923 - val_loss: 1.4702
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4890
# Epoch 14: val_loss improved from 1.47019 to 1.46417, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.4890 - val_loss: 1.4642
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4840
# Epoch 15: val_loss did not improve from 1.46417
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.4840 - val_loss: 1.4667
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4791
# Epoch 16: val_loss improved from 1.46417 to 1.45668, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.4791 - val_loss: 1.4567
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4755
# Epoch 17: val_loss improved from 1.45668 to 1.45397, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 608us/sample - loss: 1.4755 - val_loss: 1.4540
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4707
# Epoch 18: val_loss improved from 1.45397 to 1.44399, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.4707 - val_loss: 1.4440
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4684
# Epoch 19: val_loss improved from 1.44399 to 1.44331, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 20s 684us/sample - loss: 1.4684 - val_loss: 1.4433
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4675
# Epoch 20: val_loss did not improve from 1.44331
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.4675 - val_loss: 1.4438
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4598
# Epoch 21: val_loss improved from 1.44331 to 1.43049, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 608us/sample - loss: 1.4598 - val_loss: 1.4305
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4584
# Epoch 22: val_loss did not improve from 1.43049
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.4584 - val_loss: 1.4357
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4573
# Epoch 23: val_loss improved from 1.43049 to 1.42806, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.4573 - val_loss: 1.4281
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4527
# Epoch 24: val_loss improved from 1.42806 to 1.42432, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.4527 - val_loss: 1.4243
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4518
# Epoch 25: val_loss did not improve from 1.42432
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.4518 - val_loss: 1.4279
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4481
# Epoch 26: val_loss did not improve from 1.42432
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.4481 - val_loss: 1.4249
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4492
# Epoch 27: val_loss improved from 1.42432 to 1.42119, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.4492 - val_loss: 1.4212
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4464
# Epoch 28: val_loss did not improve from 1.42119
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.4464 - val_loss: 1.4235
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4420
# Epoch 29: val_loss improved from 1.42119 to 1.41819, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.4420 - val_loss: 1.4182
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4394
# Epoch 30: val_loss did not improve from 1.41819
# 29601/29601 [==============================] - 18s 604us/sample - loss: 1.4394 - val_loss: 1.4230
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4395
# Epoch 31: val_loss improved from 1.41819 to 1.41718, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.4395 - val_loss: 1.4172
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4486
# Epoch 32: val_loss did not improve from 1.41718
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.4486 - val_loss: 1.4221
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4373
# Epoch 33: val_loss improved from 1.41718 to 1.41466, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.4373 - val_loss: 1.4147
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4347
# Epoch 34: val_loss improved from 1.41466 to 1.41168, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.4347 - val_loss: 1.4117
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4339
# Epoch 35: val_loss improved from 1.41168 to 1.41115, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.4339 - val_loss: 1.4111
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4328
# Epoch 36: val_loss did not improve from 1.41115
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.4328 - val_loss: 1.4127
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4307
# Epoch 37: val_loss improved from 1.41115 to 1.40877, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.4307 - val_loss: 1.4088
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4293
# Epoch 38: val_loss did not improve from 1.40877
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.4293 - val_loss: 1.4094
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4272
# Epoch 39: val_loss improved from 1.40877 to 1.40735, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 604us/sample - loss: 1.4272 - val_loss: 1.4074
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4284
# Epoch 40: val_loss did not improve from 1.40735
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.4284 - val_loss: 1.4087
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4258
# Epoch 41: val_loss improved from 1.40735 to 1.40298, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 606us/sample - loss: 1.4258 - val_loss: 1.4030
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4240
# Epoch 42: val_loss did not improve from 1.40298
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.4240 - val_loss: 1.4063
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4193
# Epoch 43: val_loss did not improve from 1.40298
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.4193 - val_loss: 1.4046
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4211
# Epoch 44: val_loss did not improve from 1.40298
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.4211 - val_loss: 1.4047
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4191
# Epoch 45: val_loss improved from 1.40298 to 1.40221, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.4191 - val_loss: 1.4022
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4174
# Epoch 46: val_loss did not improve from 1.40221
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.4174 - val_loss: 1.4062
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4168
# Epoch 47: val_loss did not improve from 1.40221
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.4168 - val_loss: 1.4069
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4152
# Epoch 48: val_loss improved from 1.40221 to 1.40092, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.4152 - val_loss: 1.4009
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4239
# Epoch 49: val_loss did not improve from 1.40092
# 29601/29601 [==============================] - 18s 597us/sample - loss: 1.4239 - val_loss: 1.4056
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4139
# Epoch 50: val_loss improved from 1.40092 to 1.39935, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.4139 - val_loss: 1.3993
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4111
# Epoch 51: val_loss improved from 1.39935 to 1.39856, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.4111 - val_loss: 1.3986
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4115
# Epoch 52: val_loss did not improve from 1.39856
# 29601/29601 [==============================] - 18s 597us/sample - loss: 1.4115 - val_loss: 1.3990
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4098
# Epoch 53: val_loss did not improve from 1.39856
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.4098 - val_loss: 1.3997
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4113
# Epoch 54: val_loss did not improve from 1.39856
# 29601/29601 [==============================] - 18s 597us/sample - loss: 1.4113 - val_loss: 1.4007
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4077
# Epoch 55: val_loss did not improve from 1.39856
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.4077 - val_loss: 1.4027
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4078
# Epoch 56: val_loss improved from 1.39856 to 1.39585, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.4078 - val_loss: 1.3959
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4067
# Epoch 57: val_loss did not improve from 1.39585
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.4067 - val_loss: 1.4024
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4058
# Epoch 58: val_loss did not improve from 1.39585
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.4058 - val_loss: 1.4018
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4037
# Epoch 59: val_loss improved from 1.39585 to 1.39474, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 609us/sample - loss: 1.4037 - val_loss: 1.3947
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4026
# Epoch 60: val_loss did not improve from 1.39474
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.4026 - val_loss: 1.3949
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4033
# Epoch 61: val_loss did not improve from 1.39474
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.4033 - val_loss: 1.3996
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4021
# Epoch 62: val_loss did not improve from 1.39474
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.4021 - val_loss: 1.3955
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4005
# Epoch 63: val_loss did not improve from 1.39474
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.4005 - val_loss: 1.3992
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3986
# Epoch 64: val_loss did not improve from 1.39474
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3986 - val_loss: 1.4008
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3972
# Epoch 65: val_loss did not improve from 1.39474
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3972 - val_loss: 1.3970
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3960
# Epoch 66: val_loss did not improve from 1.39474
# 29601/29601 [==============================] - 18s 597us/sample - loss: 1.3960 - val_loss: 1.3958
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3969
# Epoch 67: val_loss improved from 1.39474 to 1.39415, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.3969 - val_loss: 1.3941
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3928
# Epoch 68: val_loss did not improve from 1.39415
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.3928 - val_loss: 1.3978
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3936
# Epoch 69: val_loss did not improve from 1.39415
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3936 - val_loss: 1.3974
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3943
# Epoch 70: val_loss improved from 1.39415 to 1.39374, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 608us/sample - loss: 1.3943 - val_loss: 1.3937
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3931
# Epoch 71: val_loss did not improve from 1.39374
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3931 - val_loss: 1.3964
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3909
# Epoch 72: val_loss improved from 1.39374 to 1.39255, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.3909 - val_loss: 1.3925
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3877
# Epoch 73: val_loss did not improve from 1.39255
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.3877 - val_loss: 1.3963
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3898
# Epoch 74: val_loss did not improve from 1.39255
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.3898 - val_loss: 1.3931
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3871
# Epoch 75: val_loss improved from 1.39255 to 1.39013, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.3871 - val_loss: 1.3901
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3862
# Epoch 76: val_loss did not improve from 1.39013
# 29601/29601 [==============================] - 18s 621us/sample - loss: 1.3862 - val_loss: 1.3939
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3927
# Epoch 77: val_loss did not improve from 1.39013
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3927 - val_loss: 1.3989
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3880
# Epoch 78: val_loss did not improve from 1.39013
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.3880 - val_loss: 1.3934
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3858
# Epoch 79: val_loss did not improve from 1.39013
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.3858 - val_loss: 1.3920
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3824
# Epoch 80: val_loss did not improve from 1.39013
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3824 - val_loss: 1.3945
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3861
# Epoch 81: val_loss did not improve from 1.39013
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.3861 - val_loss: 1.3914
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3819
# Epoch 82: val_loss did not improve from 1.39013
# 29601/29601 [==============================] - 18s 597us/sample - loss: 1.3819 - val_loss: 1.3927
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3813
# Epoch 83: val_loss improved from 1.39013 to 1.38593, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.3813 - val_loss: 1.3859
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3799
# Epoch 84: val_loss did not improve from 1.38593
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3799 - val_loss: 1.3910
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3806
# Epoch 85: val_loss did not improve from 1.38593
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.3806 - val_loss: 1.3893
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3793
# Epoch 86: val_loss did not improve from 1.38593
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.3793 - val_loss: 1.3929
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3771
# Epoch 87: val_loss did not improve from 1.38593
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.3771 - val_loss: 1.3895
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3756
# Epoch 88: val_loss did not improve from 1.38593
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.3756 - val_loss: 1.3918
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3787
# Epoch 89: val_loss did not improve from 1.38593
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.3787 - val_loss: 1.3943
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3758
# Epoch 90: val_loss did not improve from 1.38593
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.3758 - val_loss: 1.3902
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3742
# Epoch 91: val_loss did not improve from 1.38593
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.3742 - val_loss: 1.3913
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3743
# Epoch 92: val_loss did not improve from 1.38593
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.3743 - val_loss: 1.3905
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3735
# Epoch 93: val_loss did not improve from 1.38593
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3735 - val_loss: 1.3901
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3706
# Epoch 94: val_loss did not improve from 1.38593
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3706 - val_loss: 1.3876
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3705
# Epoch 95: val_loss did not improve from 1.38593
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3705 - val_loss: 1.3874
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3725
# Epoch 96: val_loss did not improve from 1.38593
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3725 - val_loss: 1.3898
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3694
# Epoch 97: val_loss improved from 1.38593 to 1.38188, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_0.h5
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.3694 - val_loss: 1.3819
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3662
# Epoch 98: val_loss did not improve from 1.38188
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.3662 - val_loss: 1.3851
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3663
# Epoch 99: val_loss did not improve from 1.38188
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.3663 - val_loss: 1.3939
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3649
# Epoch 100: val_loss did not improve from 1.38188
# 29601/29601 [==============================] - 18s 604us/sample - loss: 1.3649 - val_loss: 1.3926
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3673
# Epoch 1: val_loss improved from inf to 1.39263, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_1.h5
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.3673 - val_loss: 1.3926
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3667
# Epoch 2: val_loss improved from 1.39263 to 1.38798, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_1.h5
# 29601/29601 [==============================] - 18s 612us/sample - loss: 1.3667 - val_loss: 1.3880
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3672
# Epoch 3: val_loss did not improve from 1.38798
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3672 - val_loss: 1.3910
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3605
# Epoch 4: val_loss did not improve from 1.38798
# 29601/29601 [==============================] - 18s 597us/sample - loss: 1.3605 - val_loss: 1.3924
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3609
# Epoch 5: val_loss improved from 1.38798 to 1.38661, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_1.h5
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3609 - val_loss: 1.3866
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3631
# Epoch 6: val_loss did not improve from 1.38661
# 29601/29601 [==============================] - 18s 597us/sample - loss: 1.3631 - val_loss: 1.3877
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3590
# Epoch 7: val_loss improved from 1.38661 to 1.38522, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_1.h5
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.3590 - val_loss: 1.3852
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3583
# Epoch 8: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3583 - val_loss: 1.3902
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3569
# Epoch 9: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 610us/sample - loss: 1.3569 - val_loss: 1.3952
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3605
# Epoch 10: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 622us/sample - loss: 1.3605 - val_loss: 1.3892
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3613
# Epoch 11: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3613 - val_loss: 1.3960
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3576
# Epoch 12: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3576 - val_loss: 1.3917
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3573
# Epoch 13: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3573 - val_loss: 1.3887
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3558
# Epoch 14: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.3558 - val_loss: 1.3925
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3564
# Epoch 15: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.3564 - val_loss: 1.3919
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3509
# Epoch 16: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.3509 - val_loss: 1.3921
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3540
# Epoch 17: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.3540 - val_loss: 1.3900
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3554
# Epoch 18: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3554 - val_loss: 1.3912
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3540
# Epoch 19: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 624us/sample - loss: 1.3540 - val_loss: 1.3919
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3522
# Epoch 20: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 606us/sample - loss: 1.3522 - val_loss: 1.3917
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3515
# Epoch 21: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3515 - val_loss: 1.3866
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3536
# Epoch 22: val_loss did not improve from 1.38522
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3536 - val_loss: 1.3861
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3512
# Epoch 23: val_loss improved from 1.38522 to 1.38512, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_1.h5
# 29601/29601 [==============================] - 18s 606us/sample - loss: 1.3512 - val_loss: 1.3851
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3498
# Epoch 24: val_loss did not improve from 1.38512
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3498 - val_loss: 1.3864
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3511
# Epoch 25: val_loss improved from 1.38512 to 1.38497, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_1.h5
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.3511 - val_loss: 1.3850
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3499
# Epoch 26: val_loss did not improve from 1.38497
# 29601/29601 [==============================] - 18s 608us/sample - loss: 1.3499 - val_loss: 1.3871
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3504
# ...
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2919
# Epoch 32: val_loss did not improve from 1.38449
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.2919 - val_loss: 1.3862
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2894
# Epoch 33: val_loss improved from 1.38449 to 1.38425, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_9.h5
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.2894 - val_loss: 1.3842
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2932
# Epoch 34: val_loss did not improve from 1.38425
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.2932 - val_loss: 1.3875
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2894
# Epoch 35: val_loss did not improve from 1.38425
# 29601/29601 [==============================] - 17s 584us/sample - loss: 1.2894 - val_loss: 1.3902
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2869
# Epoch 36: val_loss did not improve from 1.38425
# 29601/29601 [==============================] - 18s 593us/sample - loss: 1.2869 - val_loss: 1.3885
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2909
# Epoch 37: val_loss did not improve from 1.38425
# 29601/29601 [==============================] - 17s 591us/sample - loss: 1.2909 - val_loss: 1.3907
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2906
# Epoch 38: val_loss did not improve from 1.38425
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.2906 - val_loss: 1.3945
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2906
# Epoch 39: val_loss did not improve from 1.38425
# 29601/29601 [==============================] - 17s 580us/sample - loss: 1.2906 - val_loss: 1.3919
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2968
# Epoch 40: val_loss did not improve from 1.38425
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.2968 - val_loss: 1.3848
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2978
# Epoch 41: val_loss improved from 1.38425 to 1.38250, saving model to ./checkpoints/Feature_extraction_remove_gaitpara_9.h5
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.2978 - val_loss: 1.3825
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3058
# Epoch 42: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 582us/sample - loss: 1.3058 - val_loss: 1.3886
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3094
# Epoch 43: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 20s 666us/sample - loss: 1.3094 - val_loss: 1.3876
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3037
# Epoch 44: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 20s 673us/sample - loss: 1.3037 - val_loss: 1.3910
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3109
# Epoch 45: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.3109 - val_loss: 1.3884
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3144
# Epoch 46: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.3144 - val_loss: 1.3957
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3156
# Epoch 47: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.3156 - val_loss: 1.3890
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3177
# Epoch 48: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.3177 - val_loss: 1.3927
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3340
# Epoch 49: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 588us/sample - loss: 1.3340 - val_loss: 1.4028
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3330
# Epoch 50: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 584us/sample - loss: 1.3330 - val_loss: 1.4018
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3246
# Epoch 51: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.3246 - val_loss: 1.3970
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3463
# Epoch 52: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 583us/sample - loss: 1.3463 - val_loss: 1.3958
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3336
# Epoch 53: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 584us/sample - loss: 1.3336 - val_loss: 1.3958
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3317
# Epoch 54: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 587us/sample - loss: 1.3317 - val_loss: 1.3977
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3283
# Epoch 55: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 614us/sample - loss: 1.3283 - val_loss: 1.3951
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3346
# Epoch 56: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.3346 - val_loss: 1.3959
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3294
# Epoch 57: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.3294 - val_loss: 1.3959
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3274
# Epoch 58: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 583us/sample - loss: 1.3274 - val_loss: 1.3952
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3235
# Epoch 59: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.3235 - val_loss: 1.3957
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3256
# Epoch 60: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 584us/sample - loss: 1.3256 - val_loss: 1.4015
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3238
# Epoch 61: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 588us/sample - loss: 1.3238 - val_loss: 1.3965
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3234
# Epoch 62: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.3234 - val_loss: 1.3915
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3229
# Epoch 63: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 584us/sample - loss: 1.3229 - val_loss: 1.3947
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3235
# Epoch 64: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.3235 - val_loss: 1.3909
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3192
# Epoch 65: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.3192 - val_loss: 1.3911
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3180
# Epoch 66: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.3180 - val_loss: 1.3916
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3182
# Epoch 67: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 587us/sample - loss: 1.3182 - val_loss: 1.3931
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3221
# Epoch 68: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 588us/sample - loss: 1.3221 - val_loss: 1.3976
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3183
# Epoch 69: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 583us/sample - loss: 1.3183 - val_loss: 1.3898
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3178
# Epoch 70: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 587us/sample - loss: 1.3178 - val_loss: 1.3973
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3162
# Epoch 71: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 583us/sample - loss: 1.3162 - val_loss: 1.3888
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3159
# Epoch 72: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.3159 - val_loss: 1.3917
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3171
# Epoch 73: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.3171 - val_loss: 1.3946
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3164
# Epoch 74: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 590us/sample - loss: 1.3164 - val_loss: 1.3916
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3124
# Epoch 75: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.3124 - val_loss: 1.4052
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3105
# Epoch 76: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.3105 - val_loss: 1.3932
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3125
# Epoch 77: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.3125 - val_loss: 1.3934
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3124
# Epoch 78: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.3124 - val_loss: 1.3909
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3134
# Epoch 79: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.3134 - val_loss: 1.3934
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3102
# Epoch 80: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 588us/sample - loss: 1.3102 - val_loss: 1.3981
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3084
# Epoch 81: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.3084 - val_loss: 1.3935
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3094
# Epoch 82: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 590us/sample - loss: 1.3094 - val_loss: 1.3921
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3083
# Epoch 83: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.3083 - val_loss: 1.3872
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3083
# Epoch 84: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.3083 - val_loss: 1.3867
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3065
# Epoch 85: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 614us/sample - loss: 1.3065 - val_loss: 1.3875
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3046
# Epoch 86: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 20s 672us/sample - loss: 1.3046 - val_loss: 1.3963
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3065
# Epoch 87: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 20s 669us/sample - loss: 1.3065 - val_loss: 1.3911
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3067
# Epoch 88: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.3067 - val_loss: 1.3898
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3051
# Epoch 89: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.3051 - val_loss: 1.3885
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3056
# Epoch 90: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.3056 - val_loss: 1.3986
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3026
# Epoch 91: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.3026 - val_loss: 1.3896
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3034
# Epoch 92: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.3034 - val_loss: 1.3873
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3021
# Epoch 93: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 19s 636us/sample - loss: 1.3021 - val_loss: 1.3903
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3026
# Epoch 94: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 20s 666us/sample - loss: 1.3026 - val_loss: 1.3928
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3016
# Epoch 95: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 17s 590us/sample - loss: 1.3016 - val_loss: 1.3899
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3034
# Epoch 96: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 593us/sample - loss: 1.3034 - val_loss: 1.3851
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3055
# Epoch 97: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.3055 - val_loss: 1.3892
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3025
# Epoch 98: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 20s 671us/sample - loss: 1.3025 - val_loss: 1.3901
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2996
# Epoch 99: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 20s 667us/sample - loss: 1.2996 - val_loss: 1.3882
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3004
# Epoch 100: val_loss did not improve from 1.38250
# 29601/29601 [==============================] - 20s 667us/sample - loss: 1.3004 - val_loss: 1.3886
