# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([wlk_fre, wlk_fres_trace, double_support_time, pdps_new, energy_alls, log_energy_alls, smoothe_energy_alls, dur_time_1_alls, dur_time_2_alls, cwt_figs_all, fft_features, high_fre_compos, pitchs, low_fre_compos, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, feature]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-12-13 23:38:03.828998: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Adaptive_prune_model_remove_audio_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-08 20:17:50.691240: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.703573: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.704134: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.707880: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.716372: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.716550: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.773942: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.774139: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.774303: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.774440: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-12-08 20:17:50.774762: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-12-08 20:17:50.908702: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.908909: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.909080: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.909278: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.909446: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-08 20:17:50.909580: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-12-08 20:17:50.909607: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-12-08 20:17:50.912703: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-08 20:17:51.093392: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_2/lstm_cell_2/recurrent_kernel/Assign' id:366 op device:{requested: '', assigned: ''} def:{{{node lstm_2/lstm_cell_2/recurrent_kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_2/lstm_cell_2/recurrent_kernel, lstm_2/lstm_cell_2/recurrent_kernel/Initializer/mul_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-08 20:17:51.123755: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:499 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-08 20:17:51.130170: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:500 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 88)
# Train on 29601 samples, validate on 3694 samples
# 2023-12-08 20:17:52.171099: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_4/lstm_cell_4/recurrent_kernel/v/Assign' id:3908 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_4/lstm_cell_4/recurrent_kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_4/lstm_cell_4/recurrent_kernel/v, training/Adam/lstm_4/lstm_cell_4/recurrent_kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-12-08 20:17:52.608740: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-12-08 20:17:53.013050: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-08 20:17:53.021422: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 29601/29601 [==============================] - ETA: 0s - loss: 3.4553
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-12-08 20:18:00.530441: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:1470 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 2.19092, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 9s 308us/sample - loss: 3.4553 - val_loss: 2.1909
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.9507
# Epoch 2: val_loss improved from 2.19092 to 1.70582, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 224us/sample - loss: 1.9507 - val_loss: 1.7058
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6923
# Epoch 3: val_loss improved from 1.70582 to 1.59306, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 219us/sample - loss: 1.6923 - val_loss: 1.5931
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6015
# Epoch 4: val_loss improved from 1.59306 to 1.53023, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 213us/sample - loss: 1.6015 - val_loss: 1.5302
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5576
# Epoch 5: val_loss improved from 1.53023 to 1.50285, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 213us/sample - loss: 1.5576 - val_loss: 1.5028
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5370
# Epoch 6: val_loss improved from 1.50285 to 1.48993, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.5370 - val_loss: 1.4899
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5219
# Epoch 7: val_loss improved from 1.48993 to 1.47142, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 217us/sample - loss: 1.5219 - val_loss: 1.4714
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5096
# Epoch 8: val_loss did not improve from 1.47142
# 29601/29601 [==============================] - 7s 220us/sample - loss: 1.5096 - val_loss: 1.4725
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5000
# Epoch 9: val_loss improved from 1.47142 to 1.46425, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.5000 - val_loss: 1.4643
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4934
# Epoch 10: val_loss improved from 1.46425 to 1.45445, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 229us/sample - loss: 1.4934 - val_loss: 1.4545
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4846
# Epoch 11: val_loss improved from 1.45445 to 1.45231, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.4846 - val_loss: 1.4523
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4781
# Epoch 12: val_loss did not improve from 1.45231
# 29601/29601 [==============================] - 6s 207us/sample - loss: 1.4781 - val_loss: 1.4531
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4753
# Epoch 13: val_loss improved from 1.45231 to 1.43869, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.4753 - val_loss: 1.4387
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4703
# Epoch 14: val_loss did not improve from 1.43869
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.4703 - val_loss: 1.4530
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4659
# Epoch 15: val_loss improved from 1.43869 to 1.43338, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 215us/sample - loss: 1.4659 - val_loss: 1.4334
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4604
# Epoch 16: val_loss improved from 1.43338 to 1.43275, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.4604 - val_loss: 1.4328
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4578
# Epoch 17: val_loss did not improve from 1.43275
# 29601/29601 [==============================] - 6s 215us/sample - loss: 1.4578 - val_loss: 1.4347
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4494
# Epoch 18: val_loss improved from 1.43275 to 1.42930, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.4494 - val_loss: 1.4293
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4466
# Epoch 19: val_loss improved from 1.42930 to 1.42456, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.4466 - val_loss: 1.4246
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4439
# Epoch 20: val_loss did not improve from 1.42456
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.4439 - val_loss: 1.4361
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4425
# Epoch 21: val_loss did not improve from 1.42456
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.4425 - val_loss: 1.4272
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4445
# Epoch 22: val_loss improved from 1.42456 to 1.41801, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.4445 - val_loss: 1.4180
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4369
# Epoch 23: val_loss did not improve from 1.41801
# 29601/29601 [==============================] - 7s 233us/sample - loss: 1.4369 - val_loss: 1.4196
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4322
# Epoch 24: val_loss improved from 1.41801 to 1.41361, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 242us/sample - loss: 1.4322 - val_loss: 1.4136
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4316
# Epoch 25: val_loss did not improve from 1.41361
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.4316 - val_loss: 1.4156
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4273
# Epoch 26: val_loss did not improve from 1.41361
# 29601/29601 [==============================] - 7s 224us/sample - loss: 1.4273 - val_loss: 1.4184
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4262
# Epoch 27: val_loss improved from 1.41361 to 1.40977, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 231us/sample - loss: 1.4262 - val_loss: 1.4098
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4262
# Epoch 28: val_loss did not improve from 1.40977
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.4262 - val_loss: 1.4121
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4252
# Epoch 29: val_loss did not improve from 1.40977
# 29601/29601 [==============================] - 7s 242us/sample - loss: 1.4252 - val_loss: 1.4103
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4228
# Epoch 30: val_loss did not improve from 1.40977
# 29601/29601 [==============================] - 7s 220us/sample - loss: 1.4228 - val_loss: 1.4154
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4182
# Epoch 31: val_loss did not improve from 1.40977
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.4182 - val_loss: 1.4185
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4155
# Epoch 32: val_loss improved from 1.40977 to 1.40627, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.4155 - val_loss: 1.4063
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4178
# Epoch 33: val_loss did not improve from 1.40627
# 29601/29601 [==============================] - 6s 214us/sample - loss: 1.4178 - val_loss: 1.4088
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4171
# Epoch 34: val_loss did not improve from 1.40627
# 29601/29601 [==============================] - 6s 212us/sample - loss: 1.4171 - val_loss: 1.4095
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4105
# Epoch 35: val_loss did not improve from 1.40627
# 29601/29601 [==============================] - 6s 214us/sample - loss: 1.4105 - val_loss: 1.4088
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4102
# Epoch 36: val_loss did not improve from 1.40627
# 29601/29601 [==============================] - 6s 213us/sample - loss: 1.4102 - val_loss: 1.4320
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4071
# Epoch 37: val_loss did not improve from 1.40627
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.4071 - val_loss: 1.4099
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4081
# Epoch 38: val_loss did not improve from 1.40627
# 29601/29601 [==============================] - 6s 214us/sample - loss: 1.4081 - val_loss: 1.4111
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4029
# Epoch 39: val_loss improved from 1.40627 to 1.40461, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 238us/sample - loss: 1.4029 - val_loss: 1.4046
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4026
# Epoch 40: val_loss did not improve from 1.40461
# 29601/29601 [==============================] - 6s 215us/sample - loss: 1.4026 - val_loss: 1.4147
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4022
# Epoch 41: val_loss did not improve from 1.40461
# 29601/29601 [==============================] - 7s 224us/sample - loss: 1.4022 - val_loss: 1.4054
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3963
# Epoch 42: val_loss did not improve from 1.40461
# 29601/29601 [==============================] - 6s 213us/sample - loss: 1.3963 - val_loss: 1.4064
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3987
# Epoch 43: val_loss improved from 1.40461 to 1.40267, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 218us/sample - loss: 1.3987 - val_loss: 1.4027
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3943
# Epoch 44: val_loss improved from 1.40267 to 1.39959, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.3943 - val_loss: 1.3996
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3964
# Epoch 45: val_loss improved from 1.39959 to 1.39511, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3964 - val_loss: 1.3951
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3911
# Epoch 46: val_loss did not improve from 1.39511
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3911 - val_loss: 1.4082
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3892
# Epoch 47: val_loss did not improve from 1.39511
# 29601/29601 [==============================] - 6s 206us/sample - loss: 1.3892 - val_loss: 1.3989
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3940
# Epoch 48: val_loss did not improve from 1.39511
# 29601/29601 [==============================] - 6s 207us/sample - loss: 1.3940 - val_loss: 1.3978
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3878
# Epoch 49: val_loss did not improve from 1.39511
# 29601/29601 [==============================] - 6s 206us/sample - loss: 1.3878 - val_loss: 1.3988
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3857
# Epoch 50: val_loss improved from 1.39511 to 1.39091, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3857 - val_loss: 1.3909
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3874
# Epoch 51: val_loss did not improve from 1.39091
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.3874 - val_loss: 1.3977
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3845
# Epoch 52: val_loss did not improve from 1.39091
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3845 - val_loss: 1.3945
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3852
# Epoch 53: val_loss did not improve from 1.39091
# 29601/29601 [==============================] - 6s 216us/sample - loss: 1.3852 - val_loss: 1.3947
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3816
# Epoch 54: val_loss improved from 1.39091 to 1.39022, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 225us/sample - loss: 1.3816 - val_loss: 1.3902
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3802
# Epoch 55: val_loss did not improve from 1.39022
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.3802 - val_loss: 1.4002
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3805
# Epoch 56: val_loss did not improve from 1.39022
# 29601/29601 [==============================] - 7s 238us/sample - loss: 1.3805 - val_loss: 1.3928
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3819
# Epoch 57: val_loss did not improve from 1.39022
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3819 - val_loss: 1.4052
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3782
# Epoch 58: val_loss did not improve from 1.39022
# 29601/29601 [==============================] - 7s 231us/sample - loss: 1.3782 - val_loss: 1.3918
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3768
# Epoch 59: val_loss did not improve from 1.39022
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.3768 - val_loss: 1.3995
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3753
# Epoch 60: val_loss did not improve from 1.39022
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.3753 - val_loss: 1.3907
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3784
# Epoch 61: val_loss improved from 1.39022 to 1.38782, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.3784 - val_loss: 1.3878
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3778
# Epoch 62: val_loss improved from 1.38782 to 1.38442, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.3778 - val_loss: 1.3844
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3723
# Epoch 63: val_loss did not improve from 1.38442
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3723 - val_loss: 1.3896
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3743
# Epoch 64: val_loss did not improve from 1.38442
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.3743 - val_loss: 1.3881
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3741
# Epoch 65: val_loss did not improve from 1.38442
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3741 - val_loss: 1.3909
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3708
# Epoch 66: val_loss did not improve from 1.38442
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3708 - val_loss: 1.3866
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3688
# Epoch 67: val_loss did not improve from 1.38442
# 29601/29601 [==============================] - 7s 226us/sample - loss: 1.3688 - val_loss: 1.3913
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3727
# Epoch 68: val_loss did not improve from 1.38442
# 29601/29601 [==============================] - 7s 237us/sample - loss: 1.3727 - val_loss: 1.3876
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3702
# Epoch 69: val_loss did not improve from 1.38442
# 29601/29601 [==============================] - 7s 245us/sample - loss: 1.3702 - val_loss: 1.3952
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3701
# Epoch 70: val_loss improved from 1.38442 to 1.38179, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.3701 - val_loss: 1.3818
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3666
# Epoch 71: val_loss did not improve from 1.38179
# 29601/29601 [==============================] - 6s 214us/sample - loss: 1.3666 - val_loss: 1.3845
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3675
# Epoch 72: val_loss did not improve from 1.38179
# 29601/29601 [==============================] - 6s 212us/sample - loss: 1.3675 - val_loss: 1.3906
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3704
# Epoch 73: val_loss did not improve from 1.38179
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3704 - val_loss: 1.3906
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3662
# Epoch 74: val_loss did not improve from 1.38179
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3662 - val_loss: 1.3846
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3675
# Epoch 75: val_loss did not improve from 1.38179
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.3675 - val_loss: 1.3860
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3663
# Epoch 76: val_loss did not improve from 1.38179
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.3663 - val_loss: 1.3883
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3651
# Epoch 77: val_loss did not improve from 1.38179
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3651 - val_loss: 1.3864
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3628
# Epoch 78: val_loss improved from 1.38179 to 1.37916, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3628 - val_loss: 1.3792
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3635
# Epoch 79: val_loss did not improve from 1.37916
# 29601/29601 [==============================] - 7s 238us/sample - loss: 1.3635 - val_loss: 1.3795
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3631
# Epoch 80: val_loss did not improve from 1.37916
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3631 - val_loss: 1.3849
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3613
# Epoch 81: val_loss did not improve from 1.37916
# 29601/29601 [==============================] - 7s 226us/sample - loss: 1.3613 - val_loss: 1.3880
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3621
# Epoch 82: val_loss did not improve from 1.37916
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3621 - val_loss: 1.3828
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3592
# Epoch 83: val_loss did not improve from 1.37916
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3592 - val_loss: 1.3806
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3597
# Epoch 84: val_loss did not improve from 1.37916
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3597 - val_loss: 1.3901
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3591
# Epoch 85: val_loss did not improve from 1.37916
# 29601/29601 [==============================] - 6s 207us/sample - loss: 1.3591 - val_loss: 1.3827
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3576
# Epoch 86: val_loss did not improve from 1.37916
# 29601/29601 [==============================] - 6s 218us/sample - loss: 1.3576 - val_loss: 1.3902
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3573
# Epoch 87: val_loss did not improve from 1.37916
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3573 - val_loss: 1.3806
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3554
# Epoch 88: val_loss improved from 1.37916 to 1.37827, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 243us/sample - loss: 1.3554 - val_loss: 1.3783
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3569
# Epoch 89: val_loss did not improve from 1.37827
# 29601/29601 [==============================] - 6s 214us/sample - loss: 1.3569 - val_loss: 1.3862
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3536
# Epoch 90: val_loss improved from 1.37827 to 1.37803, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 6s 212us/sample - loss: 1.3536 - val_loss: 1.3780
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3537
# Epoch 91: val_loss did not improve from 1.37803
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3537 - val_loss: 1.3783
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3565
# Epoch 92: val_loss improved from 1.37803 to 1.37440, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 223us/sample - loss: 1.3565 - val_loss: 1.3744
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3535
# Epoch 93: val_loss did not improve from 1.37440
# 29601/29601 [==============================] - 7s 238us/sample - loss: 1.3535 - val_loss: 1.3813
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3550
# Epoch 94: val_loss did not improve from 1.37440
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.3550 - val_loss: 1.3752
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3519
# Epoch 95: val_loss did not improve from 1.37440
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3519 - val_loss: 1.3818
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3530
# Epoch 96: val_loss improved from 1.37440 to 1.37385, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_0.h5
# 29601/29601 [==============================] - 7s 226us/sample - loss: 1.3530 - val_loss: 1.3739
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3510
# Epoch 97: val_loss did not improve from 1.37385
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3510 - val_loss: 1.3785
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3490
# Epoch 98: val_loss did not improve from 1.37385
# 29601/29601 [==============================] - 7s 236us/sample - loss: 1.3490 - val_loss: 1.3769
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3493
# Epoch 99: val_loss did not improve from 1.37385
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.3493 - val_loss: 1.3777
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3494
# Epoch 100: val_loss did not improve from 1.37385
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3494 - val_loss: 1.3760
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3496
# Epoch 1: val_loss improved from inf to 1.39653, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_1.h5
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.3496 - val_loss: 1.3965
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3509
# Epoch 2: val_loss improved from 1.39653 to 1.37328, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_1.h5
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3509 - val_loss: 1.3733
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3487
# Epoch 3: val_loss improved from 1.37328 to 1.36936, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_1.h5
# 29601/29601 [==============================] - 7s 242us/sample - loss: 1.3487 - val_loss: 1.3694
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3450
# Epoch 4: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3450 - val_loss: 1.3709
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3443
# Epoch 5: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 7s 222us/sample - loss: 1.3443 - val_loss: 1.3857
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3465
# Epoch 6: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3465 - val_loss: 1.3756
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3478
# Epoch 7: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3478 - val_loss: 1.3697
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3448
# Epoch 8: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3448 - val_loss: 1.3763
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3445
# Epoch 9: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3445 - val_loss: 1.3763
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3449
# Epoch 10: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3449 - val_loss: 1.3696
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3446
# Epoch 11: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3446 - val_loss: 1.3808
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3442
# Epoch 12: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.3442 - val_loss: 1.3736
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3456
# Epoch 13: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 7s 238us/sample - loss: 1.3456 - val_loss: 1.3769
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3441
# Epoch 14: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3441 - val_loss: 1.3740
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3437
# Epoch 15: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3437 - val_loss: 1.3734
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3442
# Epoch 16: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 7s 231us/sample - loss: 1.3442 - val_loss: 1.3734
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3422
# Epoch 17: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 6s 219us/sample - loss: 1.3422 - val_loss: 1.3715
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3396
# Epoch 18: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 7s 226us/sample - loss: 1.3396 - val_loss: 1.3765
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3399
# Epoch 19: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3399 - val_loss: 1.3748
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3419
# Epoch 20: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3419 - val_loss: 1.3694
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3404
# Epoch 21: val_loss improved from 1.36936 to 1.36711, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_1.h5
# 29601/29601 [==============================] - 6s 213us/sample - loss: 1.3404 - val_loss: 1.3671
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3420
# Epoch 22: val_loss improved from 1.36711 to 1.36423, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_1.h5
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3420 - val_loss: 1.3642
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3403
# Epoch 23: val_loss did not improve from 1.36423
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3403 - val_loss: 1.3695
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3400
# Epoch 24: val_loss did not improve from 1.36423
# 29601/29601 [==============================] - 6s 212us/sample - loss: 1.3400 - val_loss: 1.3644
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3411
# Epoch 25: val_loss did not improve from 1.36423
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3411 - val_loss: 1.3715
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3411
# Epoch 26: val_loss did not improve from 1.36423
# 29601/29601 [==============================] - 7s 229us/sample - loss: 1.3411 - val_loss: 1.3726
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3405
# Epoch 27: val_loss did not improve from 1.36423
# 29601/29601 [==============================] - 7s 243us/sample - loss: 1.3405 - val_loss: 1.3687
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3405
# Epoch 28: val_loss did not improve from 1.36423
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.3405 - val_loss: 1.3670
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3379
# Epoch 29: val_loss did not improve from 1.36423
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.3379 - val_loss: 1.3644
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3407
# Epoch 30: val_loss improved from 1.36423 to 1.36377, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_1.h5
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.3407 - val_loss: 1.3638
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3393
# Epoch 31: val_loss did not improve from 1.36377
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.3393 - val_loss: 1.3675
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3369
# Epoch 32: val_loss did not improve from 1.36377
# 29601/29601 [==============================] - 7s 229us/sample - loss: 1.3369 - val_loss: 1.3660
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3387
# Epoch 33: val_loss did not improve from 1.36377
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3387 - val_loss: 1.3658
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3376
# Epoch 34: val_loss did not improve from 1.36377
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3376 - val_loss: 1.3650
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3375
# Epoch 35: val_loss did not improve from 1.36377
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.3375 - val_loss: 1.3650
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3355
# Epoch 36: val_loss did not improve from 1.36377
# 29601/29601 [==============================] - 6s 212us/sample - loss: 1.3355 - val_loss: 1.3648
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3367
# Epoch 37: val_loss did not improve from 1.36377
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3367 - val_loss: 1.3664
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3335
# Epoch 38: val_loss did not improve from 1.36377
# 29601/29601 [==============================] - 7s 244us/sample - loss: 1.3335 - val_loss: 1.3687
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3366
# Epoch 39: val_loss did not improve from 1.36377
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.3366 - val_loss: 1.3658
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3343
# Epoch 40: val_loss did not improve from 1.36377
# 29601/29601 [==============================] - 7s 247us/sample - loss: 1.3343 - val_loss: 1.3663
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3349
# Epoch 41: val_loss did not improve from 1.36377
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.3349 - val_loss: 1.3655
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3371
# Epoch 42: val_loss improved from 1.36377 to 1.36175, saving model to ./checkpoints/Adaptive_prune_model_remove_audio_1.h5
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.3371 - val_loss: 1.3617
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3364
# Epoch 43: val_loss did not improve from 1.36175
# 29601/29601 [==============================] - 7s 222us/sample - loss: 1.3364 - val_loss: 1.3629
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3391
# Epoch 44: val_loss did not improve from 1.36175
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3391 - val_loss: 1.3683
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3352
# Epoch 45: val_loss did not improve from 1.36175
# 29601/29601 [==============================] - 7s 234us/sample - loss: 1.3352 - val_loss: 1.3632
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3341
# Epoch 46: val_loss did not improve from 1.36175
# 29601/29601 [==============================] - 7s 238us/sample - loss: 1.3341 - val_loss: 1.3679
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3370
# Epoch 47: val_loss did not improve from 1.36175
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3370 - val_loss: 1.3674
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3363
# Epoch 48: val_loss did not improve from 1.36175
# 29601/29601 [==============================] - 7s 229us/sample - loss: 1.3363 - val_loss: 1.3665
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3332
# Epoch 49: val_loss did not improve from 1.36175
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.3332 - val_loss: 1.3659
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3335
# Epoch 50: val_loss did not improve from 1.36175
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3335 - val_loss: 1.3680
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3345
# Epoch 51: val_loss did not improve from 1.36175
# ...
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3148
# Epoch 31: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 213us/sample - loss: 1.3148 - val_loss: 1.3438
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3161
# Epoch 32: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3161 - val_loss: 1.3464
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3183
# Epoch 33: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3183 - val_loss: 1.3449
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3170
# Epoch 34: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3170 - val_loss: 1.3488
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3173
# Epoch 35: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3173 - val_loss: 1.3439
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3211
# Epoch 36: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3211 - val_loss: 1.3498
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3241
# Epoch 37: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3241 - val_loss: 1.3532
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3223
# Epoch 38: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3223 - val_loss: 1.3484
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3245
# Epoch 39: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 7s 227us/sample - loss: 1.3245 - val_loss: 1.3448
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3296
# Epoch 40: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.3296 - val_loss: 1.3424
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3231
# Epoch 41: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.3231 - val_loss: 1.3487
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3265
# Epoch 42: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 219us/sample - loss: 1.3265 - val_loss: 1.3485
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3265
# Epoch 43: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 207us/sample - loss: 1.3265 - val_loss: 1.3540
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3252
# Epoch 44: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3252 - val_loss: 1.3485
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3278
# Epoch 45: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3278 - val_loss: 1.3457
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3322
# Epoch 46: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.3322 - val_loss: 1.3554
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3316
# Epoch 47: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 207us/sample - loss: 1.3316 - val_loss: 1.3498
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3368
# Epoch 48: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 207us/sample - loss: 1.3368 - val_loss: 1.3513
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3363
# Epoch 49: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.3363 - val_loss: 1.3610
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3371
# Epoch 50: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3371 - val_loss: 1.3628
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3397
# Epoch 51: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3397 - val_loss: 1.3543
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3451
# Epoch 52: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3451 - val_loss: 1.3519
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3644
# Epoch 53: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.3644 - val_loss: 1.3639
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3555
# Epoch 54: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.3555 - val_loss: 1.3583
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3496
# Epoch 55: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3496 - val_loss: 1.3644
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3461
# Epoch 56: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 207us/sample - loss: 1.3461 - val_loss: 1.3553
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3447
# Epoch 57: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3447 - val_loss: 1.3515
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3414
# Epoch 58: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3414 - val_loss: 1.3550
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3411
# Epoch 59: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3411 - val_loss: 1.3516
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3399
# Epoch 60: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 207us/sample - loss: 1.3399 - val_loss: 1.3514
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3396
# Epoch 61: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3396 - val_loss: 1.3517
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3394
# Epoch 62: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.3394 - val_loss: 1.3433
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3402
# Epoch 63: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.3402 - val_loss: 1.3578
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3370
# Epoch 64: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 7s 240us/sample - loss: 1.3370 - val_loss: 1.3496
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3388
# Epoch 65: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 7s 239us/sample - loss: 1.3388 - val_loss: 1.3511
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3350
# Epoch 66: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3350 - val_loss: 1.3523
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3340
# Epoch 67: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3340 - val_loss: 1.3509
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3326
# Epoch 68: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3326 - val_loss: 1.3456
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3296
# Epoch 69: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 206us/sample - loss: 1.3296 - val_loss: 1.3500
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3294
# Epoch 70: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3294 - val_loss: 1.3547
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3320
# Epoch 71: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3320 - val_loss: 1.3493
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3337
# Epoch 72: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 207us/sample - loss: 1.3337 - val_loss: 1.3486
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3310
# Epoch 73: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3310 - val_loss: 1.3492
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3281
# Epoch 74: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 212us/sample - loss: 1.3281 - val_loss: 1.3533
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3259
# Epoch 75: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3259 - val_loss: 1.3525
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3256
# Epoch 76: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 213us/sample - loss: 1.3256 - val_loss: 1.3500
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3264
# Epoch 77: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3264 - val_loss: 1.3469
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3261
# Epoch 78: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3261 - val_loss: 1.3457
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3274
# Epoch 79: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 207us/sample - loss: 1.3274 - val_loss: 1.3474
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3227
# Epoch 80: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 207us/sample - loss: 1.3227 - val_loss: 1.3430
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3250
# Epoch 81: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3250 - val_loss: 1.3497
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3252
# Epoch 82: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3252 - val_loss: 1.3476
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3252
# Epoch 83: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 207us/sample - loss: 1.3252 - val_loss: 1.3430
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3238
# Epoch 84: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3238 - val_loss: 1.3452
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3220
# Epoch 85: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3220 - val_loss: 1.3457
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3252
# Epoch 86: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3252 - val_loss: 1.3479
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3220
# Epoch 87: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3220 - val_loss: 1.3400
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3211
# Epoch 88: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3211 - val_loss: 1.3471
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3221
# Epoch 89: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 7s 236us/sample - loss: 1.3221 - val_loss: 1.3416
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3196
# Epoch 90: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.3196 - val_loss: 1.3475
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3223
# Epoch 91: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3223 - val_loss: 1.3443
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3182
# Epoch 92: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 211us/sample - loss: 1.3182 - val_loss: 1.3420
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3192
# Epoch 93: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3192 - val_loss: 1.3399
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3202
# Epoch 94: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3202 - val_loss: 1.3531
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3162
# Epoch 95: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 209us/sample - loss: 1.3162 - val_loss: 1.3441
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3216
# Epoch 96: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 7s 233us/sample - loss: 1.3216 - val_loss: 1.3427
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3212
# Epoch 97: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 7s 241us/sample - loss: 1.3212 - val_loss: 1.3425
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3196
# Epoch 98: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 218us/sample - loss: 1.3196 - val_loss: 1.3420
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3217
# Epoch 99: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 210us/sample - loss: 1.3217 - val_loss: 1.3442
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3176
# Epoch 100: val_loss did not improve from 1.33979
# 29601/29601 [==============================] - 6s 208us/sample - loss: 1.3176 - val_loss: 1.3410

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_remove_audio_0.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:39:07.290658: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.290975: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.291157: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.302351: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.302602: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.302782: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.302954: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.303118: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.303281: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.470947: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.471173: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.471352: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.471520: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.471674: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.471828: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.471984: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.472138: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.472292: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.479962: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.480153: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.480330: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.480550: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.480728: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.480894: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.481062: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.481212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-12-13 23:39:07.481502: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.481654: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-12-13 23:39:07.481887: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.482032: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-12-13 23:39:07.482375: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-12-13 23:39:07.925596: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.925848: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.926036: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.926227: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.926400: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.926572: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.926742: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.926918: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.927092: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.927384: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.927560: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.927728: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.927896: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.928034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-12-13 23:39:07.928084: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.928218: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-12-13 23:39:07.928264: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-13 23:39:07.928402: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-12-13 23:39:07.928436: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-12-13 23:39:07.938419: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-12-13 23:39:07.970882: W tensorflow/c/c_api.cc:304] Operation '{name:'dense/bias/Assign' id:1333 op device:{requested: '', assigned: ''} def:{{{node dense/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense/bias, dense/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:08.252105: W tensorflow/c/c_api.cc:304] Operation '{name:'dense/kernel/v/Assign' id:1958 op device:{requested: '', assigned: ''} def:{{{node dense/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense/kernel/v, dense/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-12-13 23:39:08.501730: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3/BiasAdd' id:1419 op device:{requested: '', assigned: ''} def:{{{node dense_3/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3/MatMul, dense_3/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:08.646277: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-13 23:39:08.683768: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# Test MAE:
# 1.3595723050486155
# 1.2878155792801127

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_remove_audio_1.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:39:15.752012: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_2_1/lstm_cell_9/kernel/Assign' id:2827 op device:{requested: '', assigned: ''} def:{{{node lstm_2_1/lstm_cell_9/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_2_1/lstm_cell_9/kernel, lstm_2_1/lstm_cell_9/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:16.071902: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_1/kernel/v/Assign' id:4293 op device:{requested: '', assigned: ''} def:{{{node dense_3_1/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_3_1/kernel/v, dense_3_1/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:16.466880: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_1/BiasAdd' id:3720 op device:{requested: '', assigned: ''} def:{{{node dense_3_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_1/MatMul, dense_3_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3354661600852233
# 1.26148508547965

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_remove_audio_2.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:39:23.436251: W tensorflow/c/c_api.cc:304] Operation '{name:'conv2d_1_2/kernel/Assign' id:4666 op device:{requested: '', assigned: ''} def:{{{node conv2d_1_2/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](conv2d_1_2/kernel, conv2d_1_2/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:23.805840: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_6_2/lstm_cell_20/kernel/v/Assign' id:6543 op device:{requested: '', assigned: ''} def:{{{node lstm_6_2/lstm_cell_20/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_6_2/lstm_cell_20/kernel/v, lstm_6_2/lstm_cell_20/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:24.149386: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_2/BiasAdd' id:6021 op device:{requested: '', assigned: ''} def:{{{node dense_3_2/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_2/MatMul, dense_3_2/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.338734847487338
# 1.257223374210901

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_remove_audio_3.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:39:31.191921: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_3/bias/Assign' id:8317 op device:{requested: '', assigned: ''} def:{{{node dense_3_3/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_3_3/bias, dense_3_3/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:31.615881: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_6/kernel/v/Assign' id:8861 op device:{requested: '', assigned: ''} def:{{{node dense_6/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_6/kernel/v, dense_6/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:32.014816: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_3/BiasAdd' id:8322 op device:{requested: '', assigned: ''} def:{{{node dense_3_3/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_3/MatMul, dense_3_3/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.340222963570133
# 1.2629699849387974

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_remove_audio_4.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:39:39.108825: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_4_4/lstm_cell_32/bias/Assign' id:10081 op device:{requested: '', assigned: ''} def:{{{node lstm_4_4/lstm_cell_32/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_4_4/lstm_cell_32/bias, lstm_4_4/lstm_cell_32/bias/Initializer/concat)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:39.590154: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_2_4/lstm_cell_30/recurrent_kernel/v/Assign' id:11090 op device:{requested: '', assigned: ''} def:{{{node lstm_2_4/lstm_cell_30/recurrent_kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_2_4/lstm_cell_30/recurrent_kernel/v, lstm_2_4/lstm_cell_30/recurrent_kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:40.048615: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_4/BiasAdd' id:10623 op device:{requested: '', assigned: ''} def:{{{node dense_3_4/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_4/MatMul, dense_3_4/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3446701352411647
# 1.2670075908447933

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_remove_audio_5.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:39:47.224481: W tensorflow/c/c_api.cc:304] Operation '{name:'conv2d_8/bias/Assign' id:11536 op device:{requested: '', assigned: ''} def:{{{node conv2d_8/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](conv2d_8/bias, conv2d_8/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:47.767666: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_2_5/bias/m/Assign' id:13299 op device:{requested: '', assigned: ''} def:{{{node dense_2_5/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_2_5/bias/m, dense_2_5/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:48.286450: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_5/BiasAdd' id:12924 op device:{requested: '', assigned: ''} def:{{{node dense_3_5/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_5/MatMul, dense_3_5/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3480326365134683
# 1.2642797995153754

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_remove_audio_6.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:39:55.665669: W tensorflow/c/c_api.cc:304] Operation '{name:'conv2d_1_6/bias/Assign' id:13875 op device:{requested: '', assigned: ''} def:{{{node conv2d_1_6/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](conv2d_1_6/bias, conv2d_1_6/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:56.275350: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_5_6/lstm_cell_47/kernel/m/Assign' id:15539 op device:{requested: '', assigned: ''} def:{{{node lstm_5_6/lstm_cell_47/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_5_6/lstm_cell_47/kernel/m, lstm_5_6/lstm_cell_47/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:39:56.863902: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_6/BiasAdd' id:15225 op device:{requested: '', assigned: ''} def:{{{node dense_3_6/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_6/MatMul, dense_3_6/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3300302214096253
# 1.2509317270374607

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_remove_audio_7.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:40:04.309890: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_1_7/lstm_cell_50/bias/Assign' id:16502 op device:{requested: '', assigned: ''} def:{{{node lstm_1_7/lstm_cell_50/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_1_7/lstm_cell_50/bias, lstm_1_7/lstm_cell_50/bias/Initializer/concat)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:40:04.994546: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_4_7/lstm_cell_53/kernel/m/Assign' id:17825 op device:{requested: '', assigned: ''} def:{{{node lstm_4_7/lstm_cell_53/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_4_7/lstm_cell_53/kernel/m, lstm_4_7/lstm_cell_53/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:40:05.658894: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_7/BiasAdd' id:17526 op device:{requested: '', assigned: ''} def:{{{node dense_3_7/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_7/MatMul, dense_3_7/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3325884815653273
# 1.2523120801425676

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_remove_audio_8.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:40:13.111292: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_11/kernel/Assign' id:19736 op device:{requested: '', assigned: ''} def:{{{node dense_11/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_11/kernel, dense_11/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:40:13.874531: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_1_8/lstm_cell_57/recurrent_kernel/v/Assign' id:20279 op device:{requested: '', assigned: ''} def:{{{node lstm_1_8/lstm_cell_57/recurrent_kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_1_8/lstm_cell_57/recurrent_kernel/v, lstm_1_8/lstm_cell_57/recurrent_kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:40:14.612044: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_8/BiasAdd' id:19827 op device:{requested: '', assigned: ''} def:{{{node dense_3_8/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_8/MatMul, dense_3_8/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3325079776358746
# 1.24828245354316

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_model_remove_audio_9.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-13 23:40:21.946897: W tensorflow/c/c_api.cc:304] Operation '{name:'conv2d_12/kernel/Assign' id:20735 op device:{requested: '', assigned: ''} def:{{{node conv2d_12/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](conv2d_12/kernel, conv2d_12/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:40:22.789610: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_6_9/lstm_cell_69/bias/v/Assign' id:22660 op device:{requested: '', assigned: ''} def:{{{node lstm_6_9/lstm_cell_69/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_6_9/lstm_cell_69/bias/v, lstm_6_9/lstm_cell_69/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-13 23:40:23.613774: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_9/BiasAdd' id:22128 op device:{requested: '', assigned: ''} def:{{{node dense_3_9/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_9/MatMul, dense_3_9/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.328646129311836
# 1.2453553213270736
