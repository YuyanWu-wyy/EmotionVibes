# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-12-05 12:12:45.975405: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Feature_extraction_remove_fft_v2_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-04 23:56:02.280018: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:02.291599: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:02.291842: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:02.295476: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:02.295691: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:02.295860: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:02.353360: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:02.353567: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:02.353735: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:02.353875: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-12-04 23:56:02.354110: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-04 23:56:03.287794: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:03.288082: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:03.288316: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:03.288542: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:03.288724: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-04 23:56:03.288866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-12-04 23:56:03.288898: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-12-04 23:56:03.313103: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-12-04 23:56:03.528390: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_14/lstm_cell_14/kernel/Assign' id:2326 op device:{requested: '', assigned: ''} def:{{{node lstm_14/lstm_cell_14/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_14/lstm_cell_14/kernel, lstm_14/lstm_cell_14/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-04 23:56:03.661005: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:3634 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-04 23:56:03.694279: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:3635 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 95)
# Train on 29601 samples, validate on 3694 samples
# 2023-12-04 23:56:08.098617: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_14/lstm_cell_14/kernel/m/Assign' id:16181 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_14/lstm_cell_14/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_14/lstm_cell_14/kernel/m, training/Adam/lstm_14/lstm_cell_14/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-12-04 23:56:12.184541: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-12-04 23:56:14.399594: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-04 23:56:14.412775: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 29601/29601 [==============================] - ETA: 0s - loss: 3.1807
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-12-04 23:56:35.404705: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:6312 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 1.92262, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 28s 961us/sample - loss: 3.1807 - val_loss: 1.9226
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.7793
# Epoch 2: val_loss improved from 1.92262 to 1.62047, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 689us/sample - loss: 1.7793 - val_loss: 1.6205
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6037
# Epoch 3: val_loss improved from 1.62047 to 1.56844, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 690us/sample - loss: 1.6037 - val_loss: 1.5684
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5523
# Epoch 4: val_loss improved from 1.56844 to 1.53567, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 674us/sample - loss: 1.5523 - val_loss: 1.5357
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5263
# Epoch 5: val_loss improved from 1.53567 to 1.51209, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 681us/sample - loss: 1.5263 - val_loss: 1.5121
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5093
# Epoch 6: val_loss improved from 1.51209 to 1.49834, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 19s 637us/sample - loss: 1.5093 - val_loss: 1.4983
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4971
# Epoch 7: val_loss improved from 1.49834 to 1.48773, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 19s 639us/sample - loss: 1.4971 - val_loss: 1.4877
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4919
# Epoch 8: val_loss improved from 1.48773 to 1.47873, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 674us/sample - loss: 1.4919 - val_loss: 1.4787
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4819
# Epoch 9: val_loss improved from 1.47873 to 1.47109, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 686us/sample - loss: 1.4819 - val_loss: 1.4711
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4753
# Epoch 10: val_loss improved from 1.47109 to 1.46246, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 692us/sample - loss: 1.4753 - val_loss: 1.4625
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4675
# Epoch 11: val_loss improved from 1.46246 to 1.45622, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 688us/sample - loss: 1.4675 - val_loss: 1.4562
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4645
# Epoch 12: val_loss improved from 1.45622 to 1.44856, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 686us/sample - loss: 1.4645 - val_loss: 1.4486
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4557
# Epoch 13: val_loss improved from 1.44856 to 1.44536, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 19s 656us/sample - loss: 1.4557 - val_loss: 1.4454
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4552
# Epoch 14: val_loss improved from 1.44536 to 1.44210, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 19s 650us/sample - loss: 1.4552 - val_loss: 1.4421
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4478
# Epoch 15: val_loss improved from 1.44210 to 1.43796, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.4478 - val_loss: 1.4380
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4411
# Epoch 16: val_loss improved from 1.43796 to 1.42988, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 692us/sample - loss: 1.4411 - val_loss: 1.4299
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4381
# Epoch 17: val_loss improved from 1.42988 to 1.42450, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 686us/sample - loss: 1.4381 - val_loss: 1.4245
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4359
# Epoch 18: val_loss improved from 1.42450 to 1.42196, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 664us/sample - loss: 1.4359 - val_loss: 1.4220
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4316
# Epoch 19: val_loss improved from 1.42196 to 1.41834, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 690us/sample - loss: 1.4316 - val_loss: 1.4183
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4288
# Epoch 20: val_loss did not improve from 1.41834
# 29601/29601 [==============================] - 20s 683us/sample - loss: 1.4288 - val_loss: 1.4202
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4253
# Epoch 21: val_loss improved from 1.41834 to 1.40825, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 19s 642us/sample - loss: 1.4253 - val_loss: 1.4083
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4214
# Epoch 22: val_loss did not improve from 1.40825
# 29601/29601 [==============================] - 19s 645us/sample - loss: 1.4214 - val_loss: 1.4099
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4182
# Epoch 23: val_loss improved from 1.40825 to 1.40535, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 689us/sample - loss: 1.4182 - val_loss: 1.4053
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4136
# Epoch 24: val_loss improved from 1.40535 to 1.40481, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 19s 632us/sample - loss: 1.4136 - val_loss: 1.4048
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4094
# Epoch 25: val_loss improved from 1.40481 to 1.40038, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 666us/sample - loss: 1.4094 - val_loss: 1.4004
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4074
# Epoch 26: val_loss improved from 1.40038 to 1.39897, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 692us/sample - loss: 1.4074 - val_loss: 1.3990
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4089
# Epoch 27: val_loss improved from 1.39897 to 1.39574, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 690us/sample - loss: 1.4089 - val_loss: 1.3957
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4052
# Epoch 28: val_loss did not improve from 1.39574
# 29601/29601 [==============================] - 20s 687us/sample - loss: 1.4052 - val_loss: 1.3997
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4022
# Epoch 29: val_loss did not improve from 1.39574
# 29601/29601 [==============================] - 20s 685us/sample - loss: 1.4022 - val_loss: 1.3972
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3998
# Epoch 30: val_loss did not improve from 1.39574
# 29601/29601 [==============================] - 20s 684us/sample - loss: 1.3998 - val_loss: 1.3988
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3982
# Epoch 31: val_loss improved from 1.39574 to 1.39311, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 692us/sample - loss: 1.3982 - val_loss: 1.3931
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3970
# Epoch 32: val_loss improved from 1.39311 to 1.38703, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 692us/sample - loss: 1.3970 - val_loss: 1.3870
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3907
# Epoch 33: val_loss did not improve from 1.38703
# 29601/29601 [==============================] - 18s 616us/sample - loss: 1.3907 - val_loss: 1.3915
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3923
# Epoch 34: val_loss did not improve from 1.38703
# 29601/29601 [==============================] - 20s 682us/sample - loss: 1.3923 - val_loss: 1.3877
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3911
# Epoch 35: val_loss did not improve from 1.38703
# 29601/29601 [==============================] - 20s 687us/sample - loss: 1.3911 - val_loss: 1.3914
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3895
# Epoch 36: val_loss did not improve from 1.38703
# 29601/29601 [==============================] - 20s 682us/sample - loss: 1.3895 - val_loss: 1.3889
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3874
# Epoch 37: val_loss improved from 1.38703 to 1.38507, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 690us/sample - loss: 1.3874 - val_loss: 1.3851
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3857
# Epoch 38: val_loss improved from 1.38507 to 1.38381, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 691us/sample - loss: 1.3857 - val_loss: 1.3838
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3837
# Epoch 39: val_loss improved from 1.38381 to 1.38342, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 687us/sample - loss: 1.3837 - val_loss: 1.3834
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3806
# Epoch 40: val_loss did not improve from 1.38342
# 29601/29601 [==============================] - 20s 689us/sample - loss: 1.3806 - val_loss: 1.3883
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3777
# Epoch 41: val_loss improved from 1.38342 to 1.37696, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 21s 694us/sample - loss: 1.3777 - val_loss: 1.3770
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3782
# Epoch 42: val_loss improved from 1.37696 to 1.37630, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 684us/sample - loss: 1.3782 - val_loss: 1.3763
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3781
# Epoch 43: val_loss did not improve from 1.37630
# 29601/29601 [==============================] - 19s 637us/sample - loss: 1.3781 - val_loss: 1.3776
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3787
# Epoch 44: val_loss improved from 1.37630 to 1.37418, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 687us/sample - loss: 1.3787 - val_loss: 1.3742
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3755
# Epoch 45: val_loss did not improve from 1.37418
# 29601/29601 [==============================] - 20s 685us/sample - loss: 1.3755 - val_loss: 1.3756
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3694
# Epoch 46: val_loss did not improve from 1.37418
# 29601/29601 [==============================] - 18s 620us/sample - loss: 1.3694 - val_loss: 1.3771
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3689
# Epoch 47: val_loss improved from 1.37418 to 1.37134, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 18s 612us/sample - loss: 1.3689 - val_loss: 1.3713
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3705
# Epoch 48: val_loss did not improve from 1.37134
# 29601/29601 [==============================] - 20s 680us/sample - loss: 1.3705 - val_loss: 1.3722
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3686
# Epoch 49: val_loss did not improve from 1.37134
# 29601/29601 [==============================] - 20s 683us/sample - loss: 1.3686 - val_loss: 1.3718
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3683
# Epoch 50: val_loss improved from 1.37134 to 1.36936, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 19s 629us/sample - loss: 1.3683 - val_loss: 1.3694
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3681
# Epoch 51: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.3681 - val_loss: 1.3789
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3643
# Epoch 52: val_loss did not improve from 1.36936
# 29601/29601 [==============================] - 20s 672us/sample - loss: 1.3643 - val_loss: 1.3709
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3601
# Epoch 53: val_loss improved from 1.36936 to 1.36775, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.3601 - val_loss: 1.3677
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3597
# Epoch 54: val_loss improved from 1.36775 to 1.36750, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 18s 623us/sample - loss: 1.3597 - val_loss: 1.3675
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3621
# Epoch 55: val_loss did not improve from 1.36750
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.3621 - val_loss: 1.3731
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3578
# Epoch 56: val_loss improved from 1.36750 to 1.36018, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.3578 - val_loss: 1.3602
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3585
# Epoch 57: val_loss did not improve from 1.36018
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.3585 - val_loss: 1.3699
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3558
# Epoch 58: val_loss did not improve from 1.36018
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3558 - val_loss: 1.3667
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3543
# Epoch 59: val_loss improved from 1.36018 to 1.36007, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 19s 629us/sample - loss: 1.3543 - val_loss: 1.3601
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3527
# Epoch 60: val_loss did not improve from 1.36007
# 29601/29601 [==============================] - 20s 681us/sample - loss: 1.3527 - val_loss: 1.3634
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3542
# Epoch 61: val_loss did not improve from 1.36007
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.3542 - val_loss: 1.3651
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3529
# Epoch 62: val_loss did not improve from 1.36007
# 29601/29601 [==============================] - 18s 613us/sample - loss: 1.3529 - val_loss: 1.3655
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3524
# Epoch 63: val_loss did not improve from 1.36007
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.3524 - val_loss: 1.3677
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3482
# Epoch 64: val_loss did not improve from 1.36007
# 29601/29601 [==============================] - 20s 683us/sample - loss: 1.3482 - val_loss: 1.3620
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3468
# Epoch 65: val_loss did not improve from 1.36007
# 29601/29601 [==============================] - 20s 676us/sample - loss: 1.3468 - val_loss: 1.3677
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3451
# Epoch 66: val_loss improved from 1.36007 to 1.35882, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 18s 610us/sample - loss: 1.3451 - val_loss: 1.3588
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3456
# Epoch 67: val_loss did not improve from 1.35882
# 29601/29601 [==============================] - 20s 680us/sample - loss: 1.3456 - val_loss: 1.3607
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3430
# Epoch 68: val_loss did not improve from 1.35882
# 29601/29601 [==============================] - 19s 656us/sample - loss: 1.3430 - val_loss: 1.3639
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3447
# Epoch 69: val_loss did not improve from 1.35882
# 29601/29601 [==============================] - 20s 683us/sample - loss: 1.3447 - val_loss: 1.3679
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3432
# Epoch 70: val_loss improved from 1.35882 to 1.35462, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 19s 635us/sample - loss: 1.3432 - val_loss: 1.3546
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3426
# Epoch 71: val_loss did not improve from 1.35462
# 29601/29601 [==============================] - 20s 682us/sample - loss: 1.3426 - val_loss: 1.3618
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3427
# Epoch 72: val_loss did not improve from 1.35462
# 29601/29601 [==============================] - 20s 681us/sample - loss: 1.3427 - val_loss: 1.3633
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3405
# Epoch 73: val_loss did not improve from 1.35462
# 29601/29601 [==============================] - 20s 683us/sample - loss: 1.3405 - val_loss: 1.3605
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3372
# Epoch 74: val_loss did not improve from 1.35462
# 29601/29601 [==============================] - 20s 683us/sample - loss: 1.3372 - val_loss: 1.3556
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3358
# Epoch 75: val_loss did not improve from 1.35462
# 29601/29601 [==============================] - 20s 682us/sample - loss: 1.3358 - val_loss: 1.3601
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3357
# Epoch 76: val_loss did not improve from 1.35462
# 29601/29601 [==============================] - 20s 683us/sample - loss: 1.3357 - val_loss: 1.3622
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3356
# Epoch 77: val_loss improved from 1.35462 to 1.35369, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.3356 - val_loss: 1.3537
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3352
# Epoch 78: val_loss improved from 1.35369 to 1.35289, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 660us/sample - loss: 1.3352 - val_loss: 1.3529
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3324
# Epoch 79: val_loss did not improve from 1.35289
# 29601/29601 [==============================] - 20s 684us/sample - loss: 1.3324 - val_loss: 1.3536
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3338
# Epoch 80: val_loss did not improve from 1.35289
# 29601/29601 [==============================] - 19s 639us/sample - loss: 1.3338 - val_loss: 1.3543
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3306
# Epoch 81: val_loss improved from 1.35289 to 1.35249, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 19s 631us/sample - loss: 1.3306 - val_loss: 1.3525
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3293
# Epoch 82: val_loss did not improve from 1.35249
# 29601/29601 [==============================] - 18s 613us/sample - loss: 1.3293 - val_loss: 1.3573
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3270
# Epoch 83: val_loss did not improve from 1.35249
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.3270 - val_loss: 1.3526
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3283
# Epoch 84: val_loss did not improve from 1.35249
# 29601/29601 [==============================] - 18s 591us/sample - loss: 1.3283 - val_loss: 1.3561
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3268
# Epoch 85: val_loss did not improve from 1.35249
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.3268 - val_loss: 1.3578
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3269
# Epoch 86: val_loss did not improve from 1.35249
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.3269 - val_loss: 1.3610
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3222
# Epoch 87: val_loss improved from 1.35249 to 1.34958, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.3222 - val_loss: 1.3496
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3234
# Epoch 88: val_loss did not improve from 1.34958
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.3234 - val_loss: 1.3594
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3239
# Epoch 89: val_loss improved from 1.34958 to 1.34842, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.3239 - val_loss: 1.3484
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3209
# Epoch 90: val_loss did not improve from 1.34842
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.3209 - val_loss: 1.3556
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3210
# Epoch 91: val_loss did not improve from 1.34842
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.3210 - val_loss: 1.3568
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3196
# Epoch 92: val_loss did not improve from 1.34842
# 29601/29601 [==============================] - 17s 591us/sample - loss: 1.3196 - val_loss: 1.3510
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3188
# Epoch 93: val_loss did not improve from 1.34842
# 29601/29601 [==============================] - 18s 593us/sample - loss: 1.3188 - val_loss: 1.3498
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3204
# Epoch 94: val_loss did not improve from 1.34842
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.3204 - val_loss: 1.3494
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3186
# Epoch 95: val_loss improved from 1.34842 to 1.34645, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_0.h5
# 29601/29601 [==============================] - 20s 686us/sample - loss: 1.3186 - val_loss: 1.3465
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3166
# Epoch 96: val_loss did not improve from 1.34645
# 29601/29601 [==============================] - 19s 654us/sample - loss: 1.3166 - val_loss: 1.3587
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3160
# Epoch 97: val_loss did not improve from 1.34645
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.3160 - val_loss: 1.3534
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3147
# Epoch 98: val_loss did not improve from 1.34645
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.3147 - val_loss: 1.3470
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3108
# Epoch 99: val_loss did not improve from 1.34645
# 29601/29601 [==============================] - 19s 652us/sample - loss: 1.3108 - val_loss: 1.3518
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3103
# Epoch 100: val_loss did not improve from 1.34645
# 29601/29601 [==============================] - 20s 688us/sample - loss: 1.3103 - val_loss: 1.3504
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3134
# Epoch 1: val_loss improved from inf to 1.36512, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_1.h5
# 29601/29601 [==============================] - 20s 660us/sample - loss: 1.3134 - val_loss: 1.3651
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3153
# Epoch 2: val_loss did not improve from 1.36512
# 29601/29601 [==============================] - 19s 633us/sample - loss: 1.3153 - val_loss: 1.3675
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3136
# Epoch 3: val_loss improved from 1.36512 to 1.35770, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_1.h5
# 29601/29601 [==============================] - 18s 601us/sample - loss: 1.3136 - val_loss: 1.3577
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3072
# Epoch 4: val_loss improved from 1.35770 to 1.34830, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_1.h5
# 29601/29601 [==============================] - 20s 688us/sample - loss: 1.3072 - val_loss: 1.3483
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3085
# Epoch 5: val_loss did not improve from 1.34830
# 29601/29601 [==============================] - 20s 682us/sample - loss: 1.3085 - val_loss: 1.3524
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3065
# Epoch 6: val_loss did not improve from 1.34830
# 29601/29601 [==============================] - 20s 682us/sample - loss: 1.3065 - val_loss: 1.3515
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3067
# Epoch 7: val_loss improved from 1.34830 to 1.34616, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_1.h5
# 29601/29601 [==============================] - 20s 677us/sample - loss: 1.3067 - val_loss: 1.3462
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3056
# Epoch 8: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 19s 633us/sample - loss: 1.3056 - val_loss: 1.3536
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3041
# Epoch 9: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 18s 602us/sample - loss: 1.3041 - val_loss: 1.3534
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3052
# Epoch 10: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.3052 - val_loss: 1.3504
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3051
# Epoch 11: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 17s 588us/sample - loss: 1.3051 - val_loss: 1.3603
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3033
# Epoch 12: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.3033 - val_loss: 1.3566
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3039
# Epoch 13: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 18s 618us/sample - loss: 1.3039 - val_loss: 1.3506
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3047
# Epoch 14: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 17s 584us/sample - loss: 1.3047 - val_loss: 1.3574
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3020
# Epoch 15: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 17s 584us/sample - loss: 1.3020 - val_loss: 1.3495
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3017
# Epoch 16: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 17s 588us/sample - loss: 1.3017 - val_loss: 1.3486
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2994
# Epoch 17: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.2994 - val_loss: 1.3479
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3191
# Epoch 18: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 17s 585us/sample - loss: 1.3191 - val_loss: 1.3613
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3047
# Epoch 19: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.3047 - val_loss: 1.3513
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2994
# Epoch 20: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.2994 - val_loss: 1.3466
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3017
# Epoch 21: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.3017 - val_loss: 1.3470
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2992
# Epoch 22: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 20s 680us/sample - loss: 1.2992 - val_loss: 1.3485
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2966
# Epoch 23: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 20s 662us/sample - loss: 1.2966 - val_loss: 1.3488
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2986
# Epoch 24: val_loss did not improve from 1.34616
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.2986 - val_loss: 1.3519
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2967
# Epoch 25: val_loss improved from 1.34616 to 1.34222, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_1.h5
# 29601/29601 [==============================] - 17s 590us/sample - loss: 1.2967 - val_loss: 1.3422
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3298
# Epoch 26: val_loss improved from 1.34222 to 1.33999, saving model to ./checkpoints/Feature_extraction_remove_fft_v2_1.h5
# ...
# Epoch 31: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 562us/sample - loss: 1.2388 - val_loss: 1.3475
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2361
# Epoch 32: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 562us/sample - loss: 1.2361 - val_loss: 1.3441
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2328
# Epoch 33: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 563us/sample - loss: 1.2328 - val_loss: 1.3502
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2419
# Epoch 34: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 571us/sample - loss: 1.2419 - val_loss: 1.3437
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2418
# Epoch 35: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 667us/sample - loss: 1.2418 - val_loss: 1.3442
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2490
# Epoch 36: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 19s 656us/sample - loss: 1.2490 - val_loss: 1.3453
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2489
# Epoch 37: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 665us/sample - loss: 1.2489 - val_loss: 1.3517
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2523
# Epoch 38: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 666us/sample - loss: 1.2523 - val_loss: 1.3562
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2823
# Epoch 39: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 663us/sample - loss: 1.2823 - val_loss: 1.3634
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2698
# Epoch 40: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 659us/sample - loss: 1.2698 - val_loss: 1.3613
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2661
# Epoch 41: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 566us/sample - loss: 1.2661 - val_loss: 1.3577
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3045
# Epoch 42: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 563us/sample - loss: 1.3045 - val_loss: 1.3604
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2853
# Epoch 43: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 587us/sample - loss: 1.2853 - val_loss: 1.3640
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2778
# Epoch 44: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 575us/sample - loss: 1.2778 - val_loss: 1.3578
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2834
# Epoch 45: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 563us/sample - loss: 1.2834 - val_loss: 1.3544
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2805
# Epoch 46: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 563us/sample - loss: 1.2805 - val_loss: 1.3526
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2802
# Epoch 47: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.2802 - val_loss: 1.3578
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2813
# Epoch 48: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 566us/sample - loss: 1.2813 - val_loss: 1.3556
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2819
# Epoch 49: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 563us/sample - loss: 1.2819 - val_loss: 1.3677
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2834
# Epoch 50: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 562us/sample - loss: 1.2834 - val_loss: 1.3630
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2862
# Epoch 51: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 560us/sample - loss: 1.2862 - val_loss: 1.3562
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2903
# Epoch 52: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 562us/sample - loss: 1.2903 - val_loss: 1.3606
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2962
# Epoch 53: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 561us/sample - loss: 1.2962 - val_loss: 1.3680
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2949
# Epoch 54: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 561us/sample - loss: 1.2949 - val_loss: 1.3683
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2964
# Epoch 55: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 562us/sample - loss: 1.2964 - val_loss: 1.3578
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2945
# Epoch 56: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 563us/sample - loss: 1.2945 - val_loss: 1.3635
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2972
# Epoch 57: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 580us/sample - loss: 1.2972 - val_loss: 1.3551
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2946
# Epoch 58: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 18s 621us/sample - loss: 1.2946 - val_loss: 1.3541
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2935
# Epoch 59: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 574us/sample - loss: 1.2935 - val_loss: 1.3620
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2927
# Epoch 60: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 570us/sample - loss: 1.2927 - val_loss: 1.3651
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2924
# Epoch 61: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 578us/sample - loss: 1.2924 - val_loss: 1.3662
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2883
# Epoch 62: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 568us/sample - loss: 1.2883 - val_loss: 1.3608
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2865
# Epoch 63: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 575us/sample - loss: 1.2865 - val_loss: 1.3589
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2880
# Epoch 64: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 661us/sample - loss: 1.2880 - val_loss: 1.3559
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2835
# Epoch 65: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 18s 610us/sample - loss: 1.2835 - val_loss: 1.3595
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2838
# Epoch 66: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 564us/sample - loss: 1.2838 - val_loss: 1.3588
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2836
# Epoch 67: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 564us/sample - loss: 1.2836 - val_loss: 1.3591
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2830
# Epoch 68: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 563us/sample - loss: 1.2830 - val_loss: 1.3488
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2813
# Epoch 69: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 560us/sample - loss: 1.2813 - val_loss: 1.3586
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2786
# Epoch 70: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 19s 648us/sample - loss: 1.2786 - val_loss: 1.3611
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2790
# Epoch 71: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 19s 658us/sample - loss: 1.2790 - val_loss: 1.3540
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2797
# Epoch 72: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 19s 658us/sample - loss: 1.2797 - val_loss: 1.3596
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2769
# Epoch 73: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 19s 658us/sample - loss: 1.2769 - val_loss: 1.3560
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2741
# Epoch 74: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 660us/sample - loss: 1.2741 - val_loss: 1.3528
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2762
# Epoch 75: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 19s 658us/sample - loss: 1.2762 - val_loss: 1.3609
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2724
# Epoch 76: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 19s 658us/sample - loss: 1.2724 - val_loss: 1.3613
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2711
# Epoch 77: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 659us/sample - loss: 1.2711 - val_loss: 1.3604
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2727
# Epoch 78: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 661us/sample - loss: 1.2727 - val_loss: 1.3525
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2705
# Epoch 79: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 19s 659us/sample - loss: 1.2705 - val_loss: 1.3550
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2681
# Epoch 80: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 659us/sample - loss: 1.2681 - val_loss: 1.3572
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2699
# Epoch 81: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 659us/sample - loss: 1.2699 - val_loss: 1.3561
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2704
# Epoch 82: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 19s 658us/sample - loss: 1.2704 - val_loss: 1.3604
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2667
# Epoch 83: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 19s 658us/sample - loss: 1.2667 - val_loss: 1.3567
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2682
# Epoch 84: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 18s 616us/sample - loss: 1.2682 - val_loss: 1.3552
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2668
# Epoch 85: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 19s 658us/sample - loss: 1.2668 - val_loss: 1.3548
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2667
# Epoch 86: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 669us/sample - loss: 1.2667 - val_loss: 1.3601
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2661
# Epoch 87: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 661us/sample - loss: 1.2661 - val_loss: 1.3497
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2639
# Epoch 88: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 661us/sample - loss: 1.2639 - val_loss: 1.3537
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2625
# Epoch 89: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 661us/sample - loss: 1.2625 - val_loss: 1.3587
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2625
# Epoch 90: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 663us/sample - loss: 1.2625 - val_loss: 1.3599
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2632
# Epoch 91: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 20s 669us/sample - loss: 1.2632 - val_loss: 1.3526
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2641
# Epoch 92: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 19s 630us/sample - loss: 1.2641 - val_loss: 1.3538
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2655
# Epoch 93: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 567us/sample - loss: 1.2655 - val_loss: 1.3515
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2607
# Epoch 94: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 568us/sample - loss: 1.2607 - val_loss: 1.3610
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2594
# Epoch 95: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 571us/sample - loss: 1.2594 - val_loss: 1.3594
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2574
# Epoch 96: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 586us/sample - loss: 1.2574 - val_loss: 1.3558
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2576
# Epoch 97: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 569us/sample - loss: 1.2576 - val_loss: 1.3539
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2585
# Epoch 98: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 569us/sample - loss: 1.2585 - val_loss: 1.3573
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2547
# Epoch 99: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 570us/sample - loss: 1.2547 - val_loss: 1.3537
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2609
# Epoch 100: val_loss did not improve from 1.33822
# 29601/29601 [==============================] - 17s 568us/sample - loss: 1.2609 - val_loss: 1.3584

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_fft_v2_0.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-05 12:14:43.448795: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_26_2/lstm_cell_98/kernel/Assign' id:22513 op device:{requested: '', assigned: ''} def:{{{node lstm_26_2/lstm_cell_98/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_26_2/lstm_cell_98/kernel, lstm_26_2/lstm_cell_98/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-05 12:14:44.916767: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_33_2/lstm_cell_105/recurrent_kernel/v/Assign' id:25919 op device:{requested: '', assigned: ''} def:{{{node lstm_33_2/lstm_cell_105/recurrent_kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_33_2/lstm_cell_105/recurrent_kernel/v, lstm_33_2/lstm_cell_105/recurrent_kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-05 12:14:46.224482: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_2/BiasAdd' id:24204 op device:{requested: '', assigned: ''} def:{{{node dense_3_2/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_2/MatMul, dense_3_2/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3539732992649078
# 1.2736789346512853

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_fft_v2_1.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-05 12:13:49.885010: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:49.885229: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:49.885407: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:49.896798: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:49.897043: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:49.897298: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:49.897472: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:49.897634: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:49.897793: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.068900: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.069120: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.069349: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.069516: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.069669: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.069820: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.069970: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.070120: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.070269: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.077908: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.078096: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.078269: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.078441: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.078613: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.078775: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.078940: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.079086: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-12-05 12:13:50.079623: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.079768: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-12-05 12:13:50.080108: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:50.080249: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-12-05 12:13:50.080512: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-12-05 12:13:51.952799: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.953077: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.953269: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.953453: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.953631: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.953850: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.954029: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.954202: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.954376: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.954620: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.954798: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.954968: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.955136: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.955272: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-12-05 12:13:51.955324: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.955456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-12-05 12:13:51.955513: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-12-05 12:13:51.955648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-12-05 12:13:51.955705: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-12-05 12:13:52.003845: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-12-05 12:13:52.091602: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_3/lstm_cell_3/kernel/Assign' id:831 op device:{requested: '', assigned: ''} def:{{{node lstm_3/lstm_cell_3/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_3/lstm_cell_3/kernel, lstm_3/lstm_cell_3/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-05 12:13:53.016212: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_2/bias/v/Assign' id:7990 op device:{requested: '', assigned: ''} def:{{{node dense_2/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_2/bias/v, dense_2/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-12-05 12:13:53.754604: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3/BiasAdd' id:6204 op device:{requested: '', assigned: ''} def:{{{node dense_3/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3/MatMul, dense_3/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-05 12:13:54.313028: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-05 12:13:54.332375: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# Test MAE:
# 1.3416080209575856
# 1.2449892974980055

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Feature_extraction_remove_fft_v2_2.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-12-05 12:14:18.208625: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_18_1/lstm_cell_54/kernel/Assign' id:12231 op device:{requested: '', assigned: ''} def:{{{node lstm_18_1/lstm_cell_54/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_18_1/lstm_cell_54/kernel, lstm_18_1/lstm_cell_54/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-05 12:14:19.511141: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_11_1/lstm_cell_47/kernel/v/Assign' id:16584 op device:{requested: '', assigned: ''} def:{{{node lstm_11_1/lstm_cell_47/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_11_1/lstm_cell_47/kernel/v, lstm_11_1/lstm_cell_47/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-12-05 12:14:20.503630: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3_1/BiasAdd' id:15204 op device:{requested: '', assigned: ''} def:{{{node dense_3_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3_1/MatMul, dense_3_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.3489399804438666
# 1.2464593949441385
