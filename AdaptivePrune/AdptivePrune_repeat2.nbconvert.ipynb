# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-27 23:51:50.495934: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Adaptive_prune_model_r2_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-27 23:52:24.932791: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:24.944042: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:24.944283: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:24.947496: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:24.947681: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:24.947846: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:55.050952: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:55.052403: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:55.053043: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:55.053554: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-27 23:52:55.053819: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-27 23:52:55.991701: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:55.991948: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:55.992170: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:55.992381: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:55.992552: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-27 23:52:55.992690: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-27 23:52:55.992718: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-27 23:52:56.015202: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-27 23:52:56.291406: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_20/lstm_cell_20/bias/Assign' id:3345 op device:{requested: '', assigned: ''} def:{{{node lstm_20/lstm_cell_20/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_20/lstm_cell_20/bias, lstm_20/lstm_cell_20/bias/Initializer/concat)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-27 23:52:56.424798: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:3634 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-27 23:52:56.459959: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:3635 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 95)
# Train on 29601 samples, validate on 3694 samples
# 2023-11-27 23:53:00.943548: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/iter/Assign' id:16327 op device:{requested: '', assigned: ''} def:{{{node training/Adam/iter/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_INT64, validate_shape=false](training/Adam/iter, training/Adam/iter/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-11-27 23:53:05.149672: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-27 23:53:07.372903: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-27 23:53:07.384766: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 29601/29601 [==============================] - ETA: 0s - loss: 3.6265
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-27 23:53:26.472417: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:6477 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 2.01169, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 27s 913us/sample - loss: 3.6265 - val_loss: 2.0117
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.8844
# Epoch 2: val_loss improved from 2.01169 to 1.64103, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 21s 705us/sample - loss: 1.8844 - val_loss: 1.6410
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6247
# Epoch 3: val_loss improved from 1.64103 to 1.55663, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 19s 649us/sample - loss: 1.6247 - val_loss: 1.5566
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5490
# Epoch 4: val_loss improved from 1.55663 to 1.51537, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 21s 712us/sample - loss: 1.5490 - val_loss: 1.5154
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5168
# Epoch 5: val_loss improved from 1.51537 to 1.49650, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 20s 660us/sample - loss: 1.5168 - val_loss: 1.4965
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5003
# Epoch 6: val_loss improved from 1.49650 to 1.48278, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 19s 630us/sample - loss: 1.5003 - val_loss: 1.4828
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4880
# Epoch 7: val_loss improved from 1.48278 to 1.46791, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 18s 616us/sample - loss: 1.4880 - val_loss: 1.4679
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4787
# Epoch 8: val_loss improved from 1.46791 to 1.46009, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 20s 674us/sample - loss: 1.4787 - val_loss: 1.4601
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4709
# Epoch 9: val_loss improved from 1.46009 to 1.45609, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 20s 690us/sample - loss: 1.4709 - val_loss: 1.4561
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4636
# Epoch 10: val_loss improved from 1.45609 to 1.44838, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 19s 651us/sample - loss: 1.4636 - val_loss: 1.4484
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4526
# Epoch 11: val_loss improved from 1.44838 to 1.44255, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 18s 610us/sample - loss: 1.4526 - val_loss: 1.4425
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4529
# Epoch 12: val_loss improved from 1.44255 to 1.43916, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.4529 - val_loss: 1.4392
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4469
# Epoch 13: val_loss improved from 1.43916 to 1.43073, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 18s 609us/sample - loss: 1.4469 - val_loss: 1.4307
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4413
# Epoch 14: val_loss improved from 1.43073 to 1.42941, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.4413 - val_loss: 1.4294
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4386
# Epoch 15: val_loss did not improve from 1.42941
# 29601/29601 [==============================] - 18s 597us/sample - loss: 1.4386 - val_loss: 1.4369
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4325
# Epoch 16: val_loss improved from 1.42941 to 1.42340, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 18s 606us/sample - loss: 1.4325 - val_loss: 1.4234
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4314
# Epoch 17: val_loss improved from 1.42340 to 1.41811, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 18s 609us/sample - loss: 1.4314 - val_loss: 1.4181
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4280
# Epoch 18: val_loss improved from 1.41811 to 1.41476, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 21s 710us/sample - loss: 1.4280 - val_loss: 1.4148
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4221
# Epoch 19: val_loss improved from 1.41476 to 1.41077, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 20s 687us/sample - loss: 1.4221 - val_loss: 1.4108
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4209
# Epoch 20: val_loss did not improve from 1.41077
# 29601/29601 [==============================] - 20s 670us/sample - loss: 1.4209 - val_loss: 1.4135
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4186
# Epoch 21: val_loss improved from 1.41077 to 1.40276, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 21s 712us/sample - loss: 1.4186 - val_loss: 1.4028
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4176
# Epoch 22: val_loss did not improve from 1.40276
# 29601/29601 [==============================] - 20s 661us/sample - loss: 1.4176 - val_loss: 1.4055
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4150
# Epoch 23: val_loss did not improve from 1.40276
# 29601/29601 [==============================] - 20s 668us/sample - loss: 1.4150 - val_loss: 1.4047
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4129
# Epoch 24: val_loss improved from 1.40276 to 1.39958, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 21s 711us/sample - loss: 1.4129 - val_loss: 1.3996
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4093
# Epoch 25: val_loss did not improve from 1.39958
# 29601/29601 [==============================] - 20s 662us/sample - loss: 1.4093 - val_loss: 1.3997
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4044
# Epoch 26: val_loss did not improve from 1.39958
# 29601/29601 [==============================] - 21s 703us/sample - loss: 1.4044 - val_loss: 1.4004
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4071
# Epoch 27: val_loss improved from 1.39958 to 1.39331, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 21s 710us/sample - loss: 1.4071 - val_loss: 1.3933
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4026
# Epoch 28: val_loss did not improve from 1.39331
# 29601/29601 [==============================] - 21s 708us/sample - loss: 1.4026 - val_loss: 1.3995
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4003
# Epoch 29: val_loss did not improve from 1.39331
# 29601/29601 [==============================] - 20s 665us/sample - loss: 1.4003 - val_loss: 1.3950
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3988
# Epoch 30: val_loss improved from 1.39331 to 1.39201, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 19s 638us/sample - loss: 1.3988 - val_loss: 1.3920
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3952
# Epoch 31: val_loss did not improve from 1.39201
# 29601/29601 [==============================] - 19s 625us/sample - loss: 1.3952 - val_loss: 1.3936
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3954
# Epoch 32: val_loss improved from 1.39201 to 1.39061, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 19s 635us/sample - loss: 1.3954 - val_loss: 1.3906
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3933
# Epoch 33: val_loss improved from 1.39061 to 1.38684, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 19s 638us/sample - loss: 1.3933 - val_loss: 1.3868
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3912
# Epoch 34: val_loss did not improve from 1.38684
# 29601/29601 [==============================] - 19s 637us/sample - loss: 1.3912 - val_loss: 1.3902
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3893
# Epoch 35: val_loss did not improve from 1.38684
# 29601/29601 [==============================] - 20s 685us/sample - loss: 1.3893 - val_loss: 1.3896
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3897
# Epoch 36: val_loss did not improve from 1.38684
# 29601/29601 [==============================] - 19s 651us/sample - loss: 1.3897 - val_loss: 1.3882
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3891
# Epoch 37: val_loss did not improve from 1.38684
# 29601/29601 [==============================] - 20s 674us/sample - loss: 1.3891 - val_loss: 1.3880
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3859
# Epoch 38: val_loss improved from 1.38684 to 1.38022, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 21s 714us/sample - loss: 1.3859 - val_loss: 1.3802
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3804
# Epoch 39: val_loss did not improve from 1.38022
# 29601/29601 [==============================] - 21s 705us/sample - loss: 1.3804 - val_loss: 1.3811
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3812
# Epoch 40: val_loss did not improve from 1.38022
# 29601/29601 [==============================] - 21s 706us/sample - loss: 1.3812 - val_loss: 1.3842
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3810
# Epoch 41: val_loss did not improve from 1.38022
# 29601/29601 [==============================] - 21s 707us/sample - loss: 1.3810 - val_loss: 1.3813
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3771
# Epoch 42: val_loss improved from 1.38022 to 1.38005, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 21s 714us/sample - loss: 1.3771 - val_loss: 1.3800
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3790
# Epoch 43: val_loss did not improve from 1.38005
# 29601/29601 [==============================] - 19s 630us/sample - loss: 1.3790 - val_loss: 1.3827
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3776
# Epoch 44: val_loss improved from 1.38005 to 1.37869, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 19s 643us/sample - loss: 1.3776 - val_loss: 1.3787
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3772
# Epoch 45: val_loss improved from 1.37869 to 1.37538, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 20s 666us/sample - loss: 1.3772 - val_loss: 1.3754
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3711
# Epoch 46: val_loss did not improve from 1.37538
# 29601/29601 [==============================] - 20s 681us/sample - loss: 1.3711 - val_loss: 1.3814
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3695
# Epoch 47: val_loss did not improve from 1.37538
# 29601/29601 [==============================] - 19s 653us/sample - loss: 1.3695 - val_loss: 1.3774
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3725
# Epoch 48: val_loss did not improve from 1.37538
# 29601/29601 [==============================] - 20s 672us/sample - loss: 1.3725 - val_loss: 1.3762
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3688
# Epoch 49: val_loss improved from 1.37538 to 1.37408, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 20s 670us/sample - loss: 1.3688 - val_loss: 1.3741
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3685
# Epoch 50: val_loss improved from 1.37408 to 1.36719, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 18s 622us/sample - loss: 1.3685 - val_loss: 1.3672
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3644
# Epoch 51: val_loss did not improve from 1.36719
# 29601/29601 [==============================] - 19s 629us/sample - loss: 1.3644 - val_loss: 1.3749
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3668
# Epoch 52: val_loss did not improve from 1.36719
# 29601/29601 [==============================] - 20s 668us/sample - loss: 1.3668 - val_loss: 1.3763
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3607
# Epoch 53: val_loss did not improve from 1.36719
# 29601/29601 [==============================] - 21s 705us/sample - loss: 1.3607 - val_loss: 1.3708
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3610
# Epoch 54: val_loss improved from 1.36719 to 1.36717, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 21s 706us/sample - loss: 1.3610 - val_loss: 1.3672
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3621
# Epoch 55: val_loss did not improve from 1.36717
# 29601/29601 [==============================] - 21s 704us/sample - loss: 1.3621 - val_loss: 1.3694
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3606
# Epoch 56: val_loss did not improve from 1.36717
# 29601/29601 [==============================] - 21s 707us/sample - loss: 1.3606 - val_loss: 1.3704
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3587
# Epoch 57: val_loss did not improve from 1.36717
# 29601/29601 [==============================] - 20s 674us/sample - loss: 1.3587 - val_loss: 1.3703
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3576
# Epoch 58: val_loss did not improve from 1.36717
# 29601/29601 [==============================] - 20s 676us/sample - loss: 1.3576 - val_loss: 1.3707
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3557
# Epoch 59: val_loss did not improve from 1.36717
# 29601/29601 [==============================] - 20s 663us/sample - loss: 1.3557 - val_loss: 1.3694
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3556
# Epoch 60: val_loss improved from 1.36717 to 1.36442, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 19s 645us/sample - loss: 1.3556 - val_loss: 1.3644
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3538
# Epoch 61: val_loss did not improve from 1.36442
# 29601/29601 [==============================] - 21s 706us/sample - loss: 1.3538 - val_loss: 1.3689
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3557
# Epoch 62: val_loss did not improve from 1.36442
# 29601/29601 [==============================] - 20s 680us/sample - loss: 1.3557 - val_loss: 1.3651
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3517
# Epoch 63: val_loss did not improve from 1.36442
# 29601/29601 [==============================] - 20s 676us/sample - loss: 1.3517 - val_loss: 1.3710
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3506
# Epoch 64: val_loss did not improve from 1.36442
# 29601/29601 [==============================] - 18s 621us/sample - loss: 1.3506 - val_loss: 1.3689
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3493
# Epoch 65: val_loss did not improve from 1.36442
# 29601/29601 [==============================] - 18s 617us/sample - loss: 1.3493 - val_loss: 1.3658
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3464
# Epoch 66: val_loss improved from 1.36442 to 1.36283, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 18s 623us/sample - loss: 1.3464 - val_loss: 1.3628
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3465
# Epoch 67: val_loss improved from 1.36283 to 1.36041, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 19s 625us/sample - loss: 1.3465 - val_loss: 1.3604
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3438
# Epoch 68: val_loss did not improve from 1.36041
# 29601/29601 [==============================] - 20s 691us/sample - loss: 1.3438 - val_loss: 1.3638
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3446
# Epoch 69: val_loss did not improve from 1.36041
# 29601/29601 [==============================] - 18s 611us/sample - loss: 1.3446 - val_loss: 1.3627
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3451
# Epoch 70: val_loss did not improve from 1.36041
# 29601/29601 [==============================] - 18s 605us/sample - loss: 1.3451 - val_loss: 1.3623
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3412
# Epoch 71: val_loss did not improve from 1.36041
# 29601/29601 [==============================] - 21s 702us/sample - loss: 1.3412 - val_loss: 1.3626
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3404
# Epoch 72: val_loss did not improve from 1.36041
# 29601/29601 [==============================] - 21s 705us/sample - loss: 1.3404 - val_loss: 1.3658
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3404
# Epoch 73: val_loss did not improve from 1.36041
# 29601/29601 [==============================] - 20s 691us/sample - loss: 1.3404 - val_loss: 1.3615
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3383
# Epoch 74: val_loss did not improve from 1.36041
# 29601/29601 [==============================] - 21s 706us/sample - loss: 1.3383 - val_loss: 1.3624
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3388
# Epoch 75: val_loss improved from 1.36041 to 1.35473, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 21s 707us/sample - loss: 1.3388 - val_loss: 1.3547
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3385
# Epoch 76: val_loss did not improve from 1.35473
# 29601/29601 [==============================] - 20s 688us/sample - loss: 1.3385 - val_loss: 1.3655
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3363
# Epoch 77: val_loss did not improve from 1.35473
# 29601/29601 [==============================] - 20s 680us/sample - loss: 1.3363 - val_loss: 1.3658
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3372
# Epoch 78: val_loss did not improve from 1.35473
# 29601/29601 [==============================] - 20s 673us/sample - loss: 1.3372 - val_loss: 1.3603
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3365
# Epoch 79: val_loss did not improve from 1.35473
# 29601/29601 [==============================] - 19s 642us/sample - loss: 1.3365 - val_loss: 1.3602
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3355
# Epoch 80: val_loss did not improve from 1.35473
# 29601/29601 [==============================] - 20s 691us/sample - loss: 1.3355 - val_loss: 1.3587
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3329
# Epoch 81: val_loss did not improve from 1.35473
# 29601/29601 [==============================] - 19s 656us/sample - loss: 1.3329 - val_loss: 1.3580
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3326
# Epoch 82: val_loss did not improve from 1.35473
# 29601/29601 [==============================] - 21s 710us/sample - loss: 1.3326 - val_loss: 1.3553
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3311
# Epoch 83: val_loss improved from 1.35473 to 1.35462, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 21s 711us/sample - loss: 1.3311 - val_loss: 1.3546
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3321
# Epoch 84: val_loss did not improve from 1.35462
# 29601/29601 [==============================] - 19s 628us/sample - loss: 1.3321 - val_loss: 1.3599
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3276
# Epoch 85: val_loss did not improve from 1.35462
# 29601/29601 [==============================] - 19s 642us/sample - loss: 1.3276 - val_loss: 1.3547
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3285
# Epoch 86: val_loss did not improve from 1.35462
# 29601/29601 [==============================] - 21s 700us/sample - loss: 1.3285 - val_loss: 1.3662
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3282
# Epoch 87: val_loss improved from 1.35462 to 1.35371, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 20s 689us/sample - loss: 1.3282 - val_loss: 1.3537
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3288
# Epoch 88: val_loss did not improve from 1.35371
# 29601/29601 [==============================] - 19s 651us/sample - loss: 1.3288 - val_loss: 1.3592
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3298
# Epoch 89: val_loss did not improve from 1.35371
# 29601/29601 [==============================] - 20s 682us/sample - loss: 1.3298 - val_loss: 1.3578
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3222
# Epoch 90: val_loss did not improve from 1.35371
# 29601/29601 [==============================] - 19s 653us/sample - loss: 1.3222 - val_loss: 1.3560
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3223
# Epoch 91: val_loss did not improve from 1.35371
# 29601/29601 [==============================] - 19s 638us/sample - loss: 1.3223 - val_loss: 1.3572
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3265
# Epoch 92: val_loss did not improve from 1.35371
# 29601/29601 [==============================] - 20s 667us/sample - loss: 1.3265 - val_loss: 1.3546
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3234
# Epoch 93: val_loss improved from 1.35371 to 1.35270, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 21s 713us/sample - loss: 1.3234 - val_loss: 1.3527
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3214
# Epoch 94: val_loss did not improve from 1.35270
# 29601/29601 [==============================] - 20s 692us/sample - loss: 1.3214 - val_loss: 1.3562
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3179
# Epoch 95: val_loss did not improve from 1.35270
# 29601/29601 [==============================] - 21s 700us/sample - loss: 1.3179 - val_loss: 1.3555
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3202
# Epoch 96: val_loss did not improve from 1.35270
# 29601/29601 [==============================] - 20s 675us/sample - loss: 1.3202 - val_loss: 1.3590
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3186
# Epoch 97: val_loss improved from 1.35270 to 1.34890, saving model to ./checkpoints/Adaptive_prune_model_r2_0.h5
# 29601/29601 [==============================] - 19s 633us/sample - loss: 1.3186 - val_loss: 1.3489
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3168
# Epoch 98: val_loss did not improve from 1.34890
# 29601/29601 [==============================] - 18s 617us/sample - loss: 1.3168 - val_loss: 1.3523
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3137
# Epoch 99: val_loss did not improve from 1.34890
# 29601/29601 [==============================] - 18s 619us/sample - loss: 1.3137 - val_loss: 1.3533
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3140
# Epoch 100: val_loss did not improve from 1.34890
# 29601/29601 [==============================] - 18s 619us/sample - loss: 1.3140 - val_loss: 1.3519
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3133
# Epoch 1: val_loss improved from inf to 1.35930, saving model to ./checkpoints/Adaptive_prune_model_r2_1.h5
# 29601/29601 [==============================] - 18s 623us/sample - loss: 1.3133 - val_loss: 1.3593
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3187
# Epoch 2: val_loss improved from 1.35930 to 1.35070, saving model to ./checkpoints/Adaptive_prune_model_r2_1.h5
# 29601/29601 [==============================] - 18s 623us/sample - loss: 1.3187 - val_loss: 1.3507
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3163
# Epoch 3: val_loss did not improve from 1.35070
# 29601/29601 [==============================] - 18s 617us/sample - loss: 1.3163 - val_loss: 1.3511
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3115
# Epoch 4: val_loss improved from 1.35070 to 1.34700, saving model to ./checkpoints/Adaptive_prune_model_r2_1.h5
# 29601/29601 [==============================] - 18s 621us/sample - loss: 1.3115 - val_loss: 1.3470
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3084
# Epoch 5: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 18s 612us/sample - loss: 1.3084 - val_loss: 1.3559
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3114
# Epoch 6: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 19s 626us/sample - loss: 1.3114 - val_loss: 1.3518
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3107
# Epoch 7: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 20s 692us/sample - loss: 1.3107 - val_loss: 1.3471
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3107
# Epoch 8: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 21s 693us/sample - loss: 1.3107 - val_loss: 1.3498
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3085
# Epoch 9: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 20s 681us/sample - loss: 1.3085 - val_loss: 1.3530
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3077
# Epoch 10: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 18s 620us/sample - loss: 1.3077 - val_loss: 1.3475
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3066
# Epoch 11: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 19s 636us/sample - loss: 1.3066 - val_loss: 1.3545
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3029
# Epoch 12: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 19s 641us/sample - loss: 1.3029 - val_loss: 1.3550
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3070
# Epoch 13: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 18s 610us/sample - loss: 1.3070 - val_loss: 1.3503
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3066
# Epoch 14: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 18s 615us/sample - loss: 1.3066 - val_loss: 1.3484
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3073
# Epoch 15: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 18s 615us/sample - loss: 1.3073 - val_loss: 1.3485
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3043
# Epoch 16: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 18s 613us/sample - loss: 1.3043 - val_loss: 1.3493
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3040
# Epoch 17: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 18s 616us/sample - loss: 1.3040 - val_loss: 1.3473
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3026
# Epoch 18: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 20s 661us/sample - loss: 1.3026 - val_loss: 1.3521
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3009
# Epoch 19: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 18s 616us/sample - loss: 1.3009 - val_loss: 1.3532
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3010
# Epoch 20: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 18s 620us/sample - loss: 1.3010 - val_loss: 1.3508
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3004
# Epoch 21: val_loss did not improve from 1.34700
# 29601/29601 [==============================] - 18s 617us/sample - loss: 1.3004 - val_loss: 1.3501
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2994
# Epoch 22: val_loss improved from 1.34700 to 1.34509, saving model to ./checkpoints/Adaptive_prune_model_r2_1.h5
# 29601/29601 [==============================] - 18s 623us/sample - loss: 1.2994 - val_loss: 1.3451
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3012
# Epoch 23: val_loss improved from 1.34509 to 1.34440, saving model to ./checkpoints/Adaptive_prune_model_r2_1.h5
# 29601/29601 [==============================] - 18s 622us/sample - loss: 1.3012 - val_loss: 1.3444
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2968
# Epoch 24: val_loss did not improve from 1.34440
# 29601/29601 [==============================] - 18s 612us/sample - loss: 1.2968 - val_loss: 1.3473
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2978
# Epoch 25: val_loss did not improve from 1.34440
# 29601/29601 [==============================] - 21s 693us/sample - loss: 1.2978 - val_loss: 1.3515
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3060
# Epoch 26: val_loss improved from 1.34440 to 1.34299, saving model to ./checkpoints/Adaptive_prune_model_r2_1.h5
# 29601/29601 [==============================] - 21s 697us/sample - loss: 1.3060 - val_loss: 1.3430
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3021
# Epoch 27: val_loss did not improve from 1.34299
# 29601/29601 [==============================] - 21s 693us/sample - loss: 1.3021 - val_loss: 1.3532
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2983
# Epoch 28: val_loss did not improve from 1.34299
# 29601/29601 [==============================] - 21s 693us/sample - loss: 1.2983 - val_loss: 1.3578
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2983
# Epoch 29: val_loss did not improve from 1.34299
# 29601/29601 [==============================] - 21s 693us/sample - loss: 1.2983 - val_loss: 1.3449
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2968
# Epoch 30: val_loss did not improve from 1.34299
# 29601/29601 [==============================] - 21s 695us/sample - loss: 1.2968 - val_loss: 1.3466
# Epoch 31/100
# ...
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2304
# Epoch 32: val_loss improved from 1.34111 to 1.34080, saving model to ./checkpoints/Adaptive_prune_model_r2_9.h5
# 29601/29601 [==============================] - 28s 961us/sample - loss: 1.2304 - val_loss: 1.3408
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2320
# Epoch 33: val_loss did not improve from 1.34080
# 29601/29601 [==============================] - 27s 922us/sample - loss: 1.2320 - val_loss: 1.3440
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2480
# Epoch 34: val_loss improved from 1.34080 to 1.34038, saving model to ./checkpoints/Adaptive_prune_model_r2_9.h5
# 29601/29601 [==============================] - 27s 911us/sample - loss: 1.2480 - val_loss: 1.3404
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2420
# Epoch 35: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 30s 1ms/sample - loss: 1.2420 - val_loss: 1.3415
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2408
# Epoch 36: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 29s 970us/sample - loss: 1.2408 - val_loss: 1.3448
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2443
# Epoch 37: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 29s 988us/sample - loss: 1.2443 - val_loss: 1.3434
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2491
# Epoch 38: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 28s 932us/sample - loss: 1.2491 - val_loss: 1.3490
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2570
# Epoch 39: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 27s 914us/sample - loss: 1.2570 - val_loss: 1.3472
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2557
# Epoch 40: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 25s 851us/sample - loss: 1.2557 - val_loss: 1.3503
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2525
# Epoch 41: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 20s 669us/sample - loss: 1.2525 - val_loss: 1.3483
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2600
# Epoch 42: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 19s 646us/sample - loss: 1.2600 - val_loss: 1.3514
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2571
# Epoch 43: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 608us/sample - loss: 1.2571 - val_loss: 1.3437
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2595
# Epoch 44: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 17s 588us/sample - loss: 1.2595 - val_loss: 1.3475
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2597
# Epoch 45: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 20s 660us/sample - loss: 1.2597 - val_loss: 1.3508
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2682
# Epoch 46: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 597us/sample - loss: 1.2682 - val_loss: 1.3545
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2736
# Epoch 47: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.2736 - val_loss: 1.3434
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2786
# Epoch 48: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 20s 670us/sample - loss: 1.2786 - val_loss: 1.3499
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2816
# Epoch 49: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.2816 - val_loss: 1.3597
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2854
# Epoch 50: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.2854 - val_loss: 1.3608
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2896
# Epoch 51: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 20s 663us/sample - loss: 1.2896 - val_loss: 1.3555
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2917
# Epoch 52: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.2917 - val_loss: 1.3564
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2938
# Epoch 53: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.2938 - val_loss: 1.3525
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2897
# Epoch 54: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.2897 - val_loss: 1.3562
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2898
# Epoch 55: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.2898 - val_loss: 1.3507
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2850
# Epoch 56: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 17s 589us/sample - loss: 1.2850 - val_loss: 1.3542
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2810
# Epoch 57: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 592us/sample - loss: 1.2810 - val_loss: 1.3533
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2806
# Epoch 58: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.2806 - val_loss: 1.3556
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2791
# Epoch 59: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.2791 - val_loss: 1.3539
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2795
# Epoch 60: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.2795 - val_loss: 1.3574
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2801
# Epoch 61: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 20s 680us/sample - loss: 1.2801 - val_loss: 1.3555
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2736
# Epoch 62: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 20s 660us/sample - loss: 1.2736 - val_loss: 1.3550
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2739
# Epoch 63: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.2739 - val_loss: 1.3560
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2769
# Epoch 64: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.2769 - val_loss: 1.3586
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2712
# Epoch 65: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 624us/sample - loss: 1.2712 - val_loss: 1.3528
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2744
# Epoch 66: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.2744 - val_loss: 1.3558
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2674
# Epoch 67: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.2674 - val_loss: 1.3540
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2697
# Epoch 68: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.2697 - val_loss: 1.3506
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2666
# Epoch 69: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.2666 - val_loss: 1.3515
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2663
# Epoch 70: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.2663 - val_loss: 1.3582
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2655
# Epoch 71: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.2655 - val_loss: 1.3512
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2673
# Epoch 72: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.2673 - val_loss: 1.3488
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2685
# Epoch 73: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 600us/sample - loss: 1.2685 - val_loss: 1.3504
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2609
# Epoch 74: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.2609 - val_loss: 1.3537
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2630
# Epoch 75: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 19s 635us/sample - loss: 1.2630 - val_loss: 1.3680
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2589
# Epoch 76: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 20s 682us/sample - loss: 1.2589 - val_loss: 1.3542
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2593
# Epoch 77: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 20s 680us/sample - loss: 1.2593 - val_loss: 1.3567
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2570
# Epoch 78: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 20s 681us/sample - loss: 1.2570 - val_loss: 1.3606
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2588
# Epoch 79: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 19s 658us/sample - loss: 1.2588 - val_loss: 1.3572
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2581
# Epoch 80: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.2581 - val_loss: 1.3524
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2609
# Epoch 81: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.2609 - val_loss: 1.3657
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2572
# Epoch 82: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 613us/sample - loss: 1.2572 - val_loss: 1.3568
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2560
# Epoch 83: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.2560 - val_loss: 1.3477
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2545
# Epoch 84: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.2545 - val_loss: 1.3483
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2544
# Epoch 85: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 19s 657us/sample - loss: 1.2544 - val_loss: 1.3518
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2521
# Epoch 86: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 19s 650us/sample - loss: 1.2521 - val_loss: 1.3478
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2569
# Epoch 87: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.2569 - val_loss: 1.3490
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2539
# Epoch 88: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.2539 - val_loss: 1.3624
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2531
# Epoch 89: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.2531 - val_loss: 1.3599
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2518
# Epoch 90: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.2518 - val_loss: 1.3581
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2465
# Epoch 91: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 621us/sample - loss: 1.2465 - val_loss: 1.3552
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2491
# Epoch 92: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 19s 640us/sample - loss: 1.2491 - val_loss: 1.3445
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2521
# Epoch 93: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 609us/sample - loss: 1.2521 - val_loss: 1.3539
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2500
# Epoch 94: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 620us/sample - loss: 1.2500 - val_loss: 1.3564
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2451
# Epoch 95: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.2451 - val_loss: 1.3506
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2476
# Epoch 96: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.2476 - val_loss: 1.3507
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2482
# Epoch 97: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 596us/sample - loss: 1.2482 - val_loss: 1.3499
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2476
# Epoch 98: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 604us/sample - loss: 1.2476 - val_loss: 1.3511
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2504
# Epoch 99: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.2504 - val_loss: 1.3515
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2473
# Epoch 100: val_loss did not improve from 1.34038
# 29601/29601 [==============================] - 18s 597us/sample - loss: 1.2473 - val_loss: 1.3533
