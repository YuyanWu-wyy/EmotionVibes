# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-04 23:37:20.895869: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = Flatten()(input_i)
            hidden_i = Dense(256, activation='relu')(input_i)
            hidden_i = Dense(64, activation='relu')(input_i)
            hidden_i = Dense(32, activation='relu')(input_i)
            hidden_i = Flatten()(hidden_i)
            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Dense(64, activation='relu')(input_i)
            hidden_i = Dense(32, activation='relu')(input_i)
            # hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            # hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.2]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Adaptive_prune_dense_finegrain_model_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=32, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# (29601, 95)
# Train on 29601 samples, validate on 3694 samples
# 2023-11-04 03:56:47.191305: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:56:47.205939: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:56:47.206239: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:56:47.214116: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:56:47.214376: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:56:47.214598: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:56:47.312002: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:56:47.312389: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:56:47.312675: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:56:47.312902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-04 03:56:47.313818: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-04 03:56:47.409361: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-04 03:56:47.859494: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_58/bias/Assign' id:1327 op device:{requested: '', assigned: ''} def:{{{node dense_58/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_58/bias, dense_58/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
#   512/29601 [..............................] - ETA: 27s - loss: 2.3318
# 2023-11-04 03:56:49.415297: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5294
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-04 03:56:56.310239: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:1862 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_80_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 1.49053, saving model to ./checkpoints/Adaptive_prune_dense_finegrain_model_0.h5
# 29601/29601 [==============================] - 11s 387us/sample - loss: 1.5294 - val_loss: 1.4905
# Epoch 2/100
# 29376/29601 [============================>.] - ETA: 0s - loss: 1.4208
# Epoch 2: val_loss improved from 1.49053 to 1.41225, saving model to ./checkpoints/Adaptive_prune_dense_finegrain_model_0.h5
# 29601/29601 [==============================] - 7s 253us/sample - loss: 1.4208 - val_loss: 1.4122
# Epoch 3/100
# 29568/29601 [============================>.] - ETA: 0s - loss: 1.3781
# Epoch 3: val_loss improved from 1.41225 to 1.39333, saving model to ./checkpoints/Adaptive_prune_dense_finegrain_model_0.h5
# 29601/29601 [==============================] - 7s 252us/sample - loss: 1.3783 - val_loss: 1.3933
# Epoch 4/100
# 29440/29601 [============================>.] - ETA: 0s - loss: 1.3476
# Epoch 4: val_loss did not improve from 1.39333
# 29601/29601 [==============================] - 8s 256us/sample - loss: 1.3477 - val_loss: 1.3981
# Epoch 5/100
# 29440/29601 [============================>.] - ETA: 0s - loss: 1.3198
# Epoch 5: val_loss did not improve from 1.39333
# 29601/29601 [==============================] - 7s 249us/sample - loss: 1.3199 - val_loss: 1.4006
# Epoch 6/100
# 29472/29601 [============================>.] - ETA: 0s - loss: 1.3008
# Epoch 6: val_loss improved from 1.39333 to 1.37377, saving model to ./checkpoints/Adaptive_prune_dense_finegrain_model_0.h5
# 29601/29601 [==============================] - 8s 257us/sample - loss: 1.3007 - val_loss: 1.3738
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2785
# Epoch 7: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 8s 254us/sample - loss: 1.2785 - val_loss: 1.3880
# Epoch 8/100
# 29504/29601 [============================>.] - ETA: 0s - loss: 1.2583
# Epoch 8: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 252us/sample - loss: 1.2583 - val_loss: 1.4201
# Epoch 9/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 1.2408
# Epoch 9: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 251us/sample - loss: 1.2414 - val_loss: 1.3774
# Epoch 10/100
# 29568/29601 [============================>.] - ETA: 0s - loss: 1.2239
# Epoch 10: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 251us/sample - loss: 1.2239 - val_loss: 1.3813
# Epoch 11/100
# 29440/29601 [============================>.] - ETA: 0s - loss: 1.2088
# Epoch 11: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 251us/sample - loss: 1.2086 - val_loss: 1.3966
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1967
# Epoch 12: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 250us/sample - loss: 1.1967 - val_loss: 1.4255
# Epoch 13/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 1.1875
# Epoch 13: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 252us/sample - loss: 1.1872 - val_loss: 1.4024
# Epoch 14/100
# 29440/29601 [============================>.] - ETA: 0s - loss: 1.1745
# Epoch 14: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 8s 255us/sample - loss: 1.1739 - val_loss: 1.3856
# Epoch 15/100
# 29472/29601 [============================>.] - ETA: 0s - loss: 1.1604
# Epoch 15: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 253us/sample - loss: 1.1605 - val_loss: 1.3782
# Epoch 16/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 1.1454
# Epoch 16: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 248us/sample - loss: 1.1454 - val_loss: 1.3862
# Epoch 17/100
# 29440/29601 [============================>.] - ETA: 0s - loss: 1.1369
# Epoch 17: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 251us/sample - loss: 1.1369 - val_loss: 1.4187
# Epoch 18/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 1.1305
# Epoch 18: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 245us/sample - loss: 1.1308 - val_loss: 1.3869
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1203
# Epoch 19: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 252us/sample - loss: 1.1203 - val_loss: 1.3975
# Epoch 20/100
# 29472/29601 [============================>.] - ETA: 0s - loss: 1.1107
# Epoch 20: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 248us/sample - loss: 1.1108 - val_loss: 1.3895
# Epoch 21/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 1.0986
# Epoch 21: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 247us/sample - loss: 1.0986 - val_loss: 1.4759
# Epoch 22/100
# 29472/29601 [============================>.] - ETA: 0s - loss: 1.0963
# Epoch 22: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 8s 254us/sample - loss: 1.0967 - val_loss: 1.4094
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0846
# Epoch 23: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 251us/sample - loss: 1.0846 - val_loss: 1.4096
# Epoch 24/100
# 29504/29601 [============================>.] - ETA: 0s - loss: 1.0899
# Epoch 24: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 247us/sample - loss: 1.0900 - val_loss: 1.3903
# Epoch 25/100
# 29472/29601 [============================>.] - ETA: 0s - loss: 1.0772
# Epoch 25: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 8s 254us/sample - loss: 1.0770 - val_loss: 1.3893
# Epoch 26/100
# 29568/29601 [============================>.] - ETA: 0s - loss: 1.0624
# Epoch 26: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 250us/sample - loss: 1.0624 - val_loss: 1.4002
# Epoch 27/100
# 29504/29601 [============================>.] - ETA: 0s - loss: 1.0622
# Epoch 27: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 248us/sample - loss: 1.0621 - val_loss: 1.3920
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0542
# Epoch 28: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 248us/sample - loss: 1.0542 - val_loss: 1.3868
# Epoch 29/100
# 29440/29601 [============================>.] - ETA: 0s - loss: 1.0528
# Epoch 29: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 250us/sample - loss: 1.0536 - val_loss: 1.3985
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0445
# Epoch 30: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 244us/sample - loss: 1.0445 - val_loss: 1.3966
# Epoch 31/100
# 29600/29601 [============================>.] - ETA: 0s - loss: 1.0383
# Epoch 31: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 8s 256us/sample - loss: 1.0383 - val_loss: 1.4055
# Epoch 32/100
# 29472/29601 [============================>.] - ETA: 0s - loss: 1.0343
# Epoch 32: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 253us/sample - loss: 1.0347 - val_loss: 1.4106
# Epoch 33/100
# 29568/29601 [============================>.] - ETA: 0s - loss: 1.0277
# Epoch 33: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 249us/sample - loss: 1.0278 - val_loss: 1.3837
# Epoch 34/100
# 29600/29601 [============================>.] - ETA: 0s - loss: 1.0226
# Epoch 34: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 252us/sample - loss: 1.0226 - val_loss: 1.3885
# Epoch 35/100
# 29600/29601 [============================>.] - ETA: 0s - loss: 1.0197
# Epoch 35: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 232us/sample - loss: 1.0197 - val_loss: 1.3994
# Epoch 36/100
# 29600/29601 [============================>.] - ETA: 0s - loss: 1.0173
# Epoch 36: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 221us/sample - loss: 1.0172 - val_loss: 1.4101
# Epoch 37/100
# 29408/29601 [============================>.] - ETA: 0s - loss: 1.0101
# Epoch 37: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 221us/sample - loss: 1.0103 - val_loss: 1.3951
# Epoch 38/100
# 29600/29601 [============================>.] - ETA: 0s - loss: 1.0085
# Epoch 38: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 219us/sample - loss: 1.0085 - val_loss: 1.4086
# Epoch 39/100
# 29600/29601 [============================>.] - ETA: 0s - loss: 1.0046
# Epoch 39: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 222us/sample - loss: 1.0046 - val_loss: 1.3932
# Epoch 40/100
# 29568/29601 [============================>.] - ETA: 0s - loss: 0.9972
# Epoch 40: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 220us/sample - loss: 0.9971 - val_loss: 1.3880
# Epoch 41/100
# 29568/29601 [============================>.] - ETA: 0s - loss: 0.9970
# Epoch 41: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 221us/sample - loss: 0.9970 - val_loss: 1.4009
# Epoch 42/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 0.9899
# Epoch 42: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 232us/sample - loss: 0.9900 - val_loss: 1.4017
# Epoch 43/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 0.9893
# Epoch 43: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 236us/sample - loss: 0.9895 - val_loss: 1.4075
# Epoch 44/100
# 29312/29601 [============================>.] - ETA: 0s - loss: 0.9883
# Epoch 44: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 232us/sample - loss: 0.9890 - val_loss: 1.4407
# Epoch 45/100
# 29504/29601 [============================>.] - ETA: 0s - loss: 0.9837
# Epoch 45: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 207us/sample - loss: 0.9835 - val_loss: 1.3961
# Epoch 46/100
# 29472/29601 [============================>.] - ETA: 0s - loss: 0.9804
# Epoch 46: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 229us/sample - loss: 0.9809 - val_loss: 1.4002
# Epoch 47/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 0.9807
# Epoch 47: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 240us/sample - loss: 0.9806 - val_loss: 1.4040
# Epoch 48/100
# 29312/29601 [============================>.] - ETA: 0s - loss: 0.9781
# Epoch 48: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 211us/sample - loss: 0.9780 - val_loss: 1.4344
# Epoch 49/100
# 29504/29601 [============================>.] - ETA: 0s - loss: 0.9766
# Epoch 49: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 189us/sample - loss: 0.9764 - val_loss: 1.4216
# Epoch 50/100
# 29472/29601 [============================>.] - ETA: 0s - loss: 0.9787
# Epoch 50: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 202us/sample - loss: 0.9787 - val_loss: 1.4033
# Epoch 51/100
# 29408/29601 [============================>.] - ETA: 0s - loss: 0.9718
# Epoch 51: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 234us/sample - loss: 0.9722 - val_loss: 1.4078
# Epoch 52/100
# 29568/29601 [============================>.] - ETA: 0s - loss: 0.9681
# Epoch 52: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 246us/sample - loss: 0.9681 - val_loss: 1.4016
# Epoch 53/100
# 29440/29601 [============================>.] - ETA: 0s - loss: 0.9649
# Epoch 53: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 207us/sample - loss: 0.9647 - val_loss: 1.4057
# Epoch 54/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 0.9612
# Epoch 54: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 209us/sample - loss: 0.9615 - val_loss: 1.4254
# Epoch 55/100
# 29504/29601 [============================>.] - ETA: 0s - loss: 0.9588
# Epoch 55: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 213us/sample - loss: 0.9595 - val_loss: 1.3922
# Epoch 56/100
# 29440/29601 [============================>.] - ETA: 0s - loss: 0.9520
# Epoch 56: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 219us/sample - loss: 0.9525 - val_loss: 1.4193
# Epoch 57/100
# 29568/29601 [============================>.] - ETA: 0s - loss: 0.9511
# Epoch 57: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 209us/sample - loss: 0.9510 - val_loss: 1.4135
# Epoch 58/100
# 29600/29601 [============================>.] - ETA: 0s - loss: 0.9438
# Epoch 58: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 230us/sample - loss: 0.9438 - val_loss: 1.4144
# Epoch 59/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 0.9379
# Epoch 59: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 233us/sample - loss: 0.9377 - val_loss: 1.3928
# Epoch 60/100
# 29600/29601 [============================>.] - ETA: 0s - loss: 0.9356
# Epoch 60: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 239us/sample - loss: 0.9356 - val_loss: 1.4205
# Epoch 61/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 0.9339
# Epoch 61: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 237us/sample - loss: 0.9337 - val_loss: 1.4122
# Epoch 62/100
# 29440/29601 [============================>.] - ETA: 0s - loss: 0.9289
# Epoch 62: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 231us/sample - loss: 0.9292 - val_loss: 1.4098
# Epoch 63/100
# 29440/29601 [============================>.] - ETA: 0s - loss: 0.9308
# Epoch 63: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 229us/sample - loss: 0.9311 - val_loss: 1.4417
# Epoch 64/100
# 29504/29601 [============================>.] - ETA: 0s - loss: 0.9194
# Epoch 64: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 219us/sample - loss: 0.9195 - val_loss: 1.4106
# Epoch 65/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 0.9195
# Epoch 65: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 202us/sample - loss: 0.9197 - val_loss: 1.4271
# Epoch 66/100
# 29568/29601 [============================>.] - ETA: 0s - loss: 0.9201
# Epoch 66: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 217us/sample - loss: 0.9201 - val_loss: 1.4212
# Epoch 67/100
# 29376/29601 [============================>.] - ETA: 0s - loss: 0.9116
# Epoch 67: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 223us/sample - loss: 0.9117 - val_loss: 1.4124
# Epoch 68/100
# 29440/29601 [============================>.] - ETA: 0s - loss: 0.9134
# Epoch 68: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 228us/sample - loss: 0.9138 - val_loss: 1.4172
# Epoch 69/100
# 29440/29601 [============================>.] - ETA: 0s - loss: 0.9061
# Epoch 69: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 209us/sample - loss: 0.9062 - val_loss: 1.4073
# Epoch 70/100
# 29504/29601 [============================>.] - ETA: 0s - loss: 0.9007
# Epoch 70: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 218us/sample - loss: 0.9008 - val_loss: 1.4283
# Epoch 71/100
# 29504/29601 [============================>.] - ETA: 0s - loss: 0.9065
# Epoch 71: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 213us/sample - loss: 0.9064 - val_loss: 1.4218
# Epoch 72/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 0.8972
# Epoch 72: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 222us/sample - loss: 0.8974 - val_loss: 1.4285
# Epoch 73/100
# 29600/29601 [============================>.] - ETA: 0s - loss: 0.9002
# Epoch 73: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 223us/sample - loss: 0.9002 - val_loss: 1.4432
# Epoch 74/100
# 29408/29601 [============================>.] - ETA: 0s - loss: 0.8916
# Epoch 74: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 219us/sample - loss: 0.8914 - val_loss: 1.4180
# Epoch 75/100
# 29568/29601 [============================>.] - ETA: 0s - loss: 0.8911
# Epoch 75: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 239us/sample - loss: 0.8910 - val_loss: 1.4231
# Epoch 76/100
# 29408/29601 [============================>.] - ETA: 0s - loss: 0.8897
# Epoch 76: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 247us/sample - loss: 0.8900 - val_loss: 1.4397
# Epoch 77/100
# 29472/29601 [============================>.] - ETA: 0s - loss: 0.8875
# Epoch 77: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 7s 230us/sample - loss: 0.8873 - val_loss: 1.4426
# Epoch 78/100
# 29312/29601 [============================>.] - ETA: 0s - loss: 0.8858
# Epoch 78: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 208us/sample - loss: 0.8856 - val_loss: 1.4290
# Epoch 79/100
# 29408/29601 [============================>.] - ETA: 0s - loss: 0.8824
# Epoch 79: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 197us/sample - loss: 0.8819 - val_loss: 1.4277
# Epoch 80/100
# 29408/29601 [============================>.] - ETA: 0s - loss: 0.8773
# Epoch 80: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 213us/sample - loss: 0.8774 - val_loss: 1.4237
# Epoch 81/100
# 29568/29601 [============================>.] - ETA: 0s - loss: 0.8784
# Epoch 81: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 204us/sample - loss: 0.8781 - val_loss: 1.4474
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8728
# Epoch 82: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 205us/sample - loss: 0.8728 - val_loss: 1.4335
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8746
# Epoch 83: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 191us/sample - loss: 0.8746 - val_loss: 1.4414
# Epoch 84/100
# 29600/29601 [============================>.] - ETA: 0s - loss: 0.8691
# Epoch 84: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 196us/sample - loss: 0.8691 - val_loss: 1.4395
# Epoch 85/100
# 29408/29601 [============================>.] - ETA: 0s - loss: 0.8716
# Epoch 85: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 211us/sample - loss: 0.8718 - val_loss: 1.4544
# Epoch 86/100
# 29376/29601 [============================>.] - ETA: 0s - loss: 0.8675
# Epoch 86: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 201us/sample - loss: 0.8677 - val_loss: 1.4263
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8630
# Epoch 87: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 192us/sample - loss: 0.8630 - val_loss: 1.4388
# Epoch 88/100
# 29472/29601 [============================>.] - ETA: 0s - loss: 0.8654
# Epoch 88: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 193us/sample - loss: 0.8654 - val_loss: 1.4360
# Epoch 89/100
# 29376/29601 [============================>.] - ETA: 0s - loss: 0.8597
# Epoch 89: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 208us/sample - loss: 0.8599 - val_loss: 1.4278
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8577
# Epoch 90: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 210us/sample - loss: 0.8577 - val_loss: 1.4394
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8584
# Epoch 91: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 191us/sample - loss: 0.8584 - val_loss: 1.4356
# Epoch 92/100
# 29536/29601 [============================>.] - ETA: 0s - loss: 0.8568
# Epoch 92: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 215us/sample - loss: 0.8569 - val_loss: 1.4460
# Epoch 93/100
# 29600/29601 [============================>.] - ETA: 0s - loss: 0.8503
# Epoch 93: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 209us/sample - loss: 0.8503 - val_loss: 1.4451
# Epoch 94/100
# 29600/29601 [============================>.] - ETA: 0s - loss: 0.8513
# Epoch 94: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 189us/sample - loss: 0.8513 - val_loss: 1.4245
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8446
# Epoch 95: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 201us/sample - loss: 0.8446 - val_loss: 1.4525
# Epoch 96/100
# 29408/29601 [============================>.] - ETA: 0s - loss: 0.8444
# Epoch 96: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 200us/sample - loss: 0.8446 - val_loss: 1.4413
# Epoch 97/100
# 29376/29601 [============================>.] - ETA: 0s - loss: 0.8457
# Epoch 97: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 202us/sample - loss: 0.8455 - val_loss: 1.4440
# Epoch 98/100
# 29440/29601 [============================>.] - ETA: 0s - loss: 0.8446
# Epoch 98: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 200us/sample - loss: 0.8448 - val_loss: 1.4551
# Epoch 99/100
# 29504/29601 [============================>.] - ETA: 0s - loss: 0.8433
# Epoch 99: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 198us/sample - loss: 0.8433 - val_loss: 1.4480
# Epoch 100/100
# 29504/29601 [============================>.] - ETA: 0s - loss: 0.8387
# Epoch 100: val_loss did not improve from 1.37377
# 29601/29601 [==============================] - 6s 212us/sample - loss: 0.8389 - val_loss: 1.4499

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_dense_finegrain_model_0.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 2023-11-04 23:37:55.099611: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:37:55.110872: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:37:55.111114: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:37:55.114143: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:37:55.114334: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:37:55.114634: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:37:55.187474: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:37:55.187690: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:37:55.187921: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:37:55.188070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-04 23:37:55.188423: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-04 23:37:55.206199: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-04 23:37:55.410164: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_60/bias/Assign' id:686 op device:{requested: '', assigned: ''} def:{{{node dense_60/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_60/bias, dense_60/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 23:37:55.966378: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_58/kernel/v/Assign' id:2184 op device:{requested: '', assigned: ''} def:{{{node dense_58/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_58/kernel/v, dense_58/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-11-04 23:37:56.421829: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_80/BiasAdd' id:963 op device:{requested: '', assigned: ''} def:{{{node dense_80/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_80/MatMul, dense_80/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 23:37:56.514119: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Test MAE:
# 1.3649052195190676
# 1.2677840061558103
