# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-06 15:56:49.070287: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.35]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Adaptive_prune_fine_grain_model_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=32, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-04 23:43:49.857354: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:49.869311: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:49.869539: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:49.872676: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:49.877225: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:49.877421: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:49.959478: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:49.959680: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:49.959851: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:49.959992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-04 23:43:49.960208: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-04 23:43:50.874201: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:50.874420: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:50.874677: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:50.874887: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:50.875060: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:43:50.875199: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-04 23:43:50.875226: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-04 23:43:50.897203: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-04 23:43:51.181580: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_19/lstm_cell_19/bias/Assign' id:3180 op device:{requested: '', assigned: ''} def:{{{node lstm_19/lstm_cell_19/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_19/lstm_cell_19/bias, lstm_19/lstm_cell_19/bias/Initializer/concat)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 23:43:51.316949: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:3634 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 23:43:51.351493: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:3635 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 95)
# Train on 29601 samples, validate on 3694 samples
# 2023-11-04 23:43:55.731847: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_21/lstm_cell_21/kernel/m/Assign' id:16709 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_21/lstm_cell_21/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_21/lstm_cell_21/kernel/m, training/Adam/lstm_21/lstm_cell_21/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-11-04 23:43:59.487003: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-04 23:44:01.573813: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-04 23:44:01.588743: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 29601/29601 [==============================] - ETA: 0s - loss: 1.6086
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-04 23:52:41.864094: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:6477 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 1.48013, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 547s 18ms/sample - loss: 1.6086 - val_loss: 1.4801
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4790
# Epoch 2: val_loss improved from 1.48013 to 1.43635, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 548s 19ms/sample - loss: 1.4790 - val_loss: 1.4363
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4472
# Epoch 3: val_loss improved from 1.43635 to 1.40806, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 546s 18ms/sample - loss: 1.4472 - val_loss: 1.4081
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4311
# Epoch 4: val_loss improved from 1.40806 to 1.39348, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 567s 19ms/sample - loss: 1.4311 - val_loss: 1.3935
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4157
# Epoch 5: val_loss did not improve from 1.39348
# 29601/29601 [==============================] - 560s 19ms/sample - loss: 1.4157 - val_loss: 1.4065
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4072
# Epoch 6: val_loss improved from 1.39348 to 1.38585, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 553s 19ms/sample - loss: 1.4072 - val_loss: 1.3858
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3966
# Epoch 7: val_loss improved from 1.38585 to 1.38034, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 543s 18ms/sample - loss: 1.3966 - val_loss: 1.3803
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3893
# Epoch 8: val_loss improved from 1.38034 to 1.38031, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 532s 18ms/sample - loss: 1.3893 - val_loss: 1.3803
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3851
# Epoch 9: val_loss improved from 1.38031 to 1.37545, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 522s 18ms/sample - loss: 1.3851 - val_loss: 1.3754
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3790
# Epoch 10: val_loss improved from 1.37545 to 1.36342, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 533s 18ms/sample - loss: 1.3790 - val_loss: 1.3634
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3774
# Epoch 11: val_loss did not improve from 1.36342
# 29601/29601 [==============================] - 558s 19ms/sample - loss: 1.3774 - val_loss: 1.3745
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3721
# Epoch 12: val_loss did not improve from 1.36342
# 29601/29601 [==============================] - 561s 19ms/sample - loss: 1.3721 - val_loss: 1.3696
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3657
# Epoch 13: val_loss did not improve from 1.36342
# 29601/29601 [==============================] - 545s 18ms/sample - loss: 1.3657 - val_loss: 1.3947
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3615
# Epoch 14: val_loss improved from 1.36342 to 1.35435, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 562s 19ms/sample - loss: 1.3615 - val_loss: 1.3544
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3570
# Epoch 15: val_loss did not improve from 1.35435
# 29601/29601 [==============================] - 538s 18ms/sample - loss: 1.3570 - val_loss: 1.3595
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3501
# Epoch 16: val_loss did not improve from 1.35435
# 29601/29601 [==============================] - 545s 18ms/sample - loss: 1.3501 - val_loss: 1.3728
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3467
# Epoch 17: val_loss did not improve from 1.35435
# 29601/29601 [==============================] - 533s 18ms/sample - loss: 1.3467 - val_loss: 1.3607
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3424
# Epoch 18: val_loss improved from 1.35435 to 1.34468, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 548s 19ms/sample - loss: 1.3424 - val_loss: 1.3447
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3429
# Epoch 19: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 559s 19ms/sample - loss: 1.3429 - val_loss: 1.3740
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3403
# Epoch 20: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 549s 19ms/sample - loss: 1.3403 - val_loss: 1.3480
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3359
# Epoch 21: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 547s 18ms/sample - loss: 1.3359 - val_loss: 1.3725
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3367
# Epoch 22: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 533s 18ms/sample - loss: 1.3367 - val_loss: 1.3712
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3363
# Epoch 23: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 545s 18ms/sample - loss: 1.3363 - val_loss: 1.3734
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3346
# Epoch 24: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 551s 19ms/sample - loss: 1.3346 - val_loss: 1.3640
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3288
# Epoch 25: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 551s 19ms/sample - loss: 1.3288 - val_loss: 1.3583
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3261
# Epoch 26: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 552s 19ms/sample - loss: 1.3261 - val_loss: 1.3542
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3231
# Epoch 27: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 544s 18ms/sample - loss: 1.3231 - val_loss: 1.3531
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3202
# Epoch 28: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 552s 19ms/sample - loss: 1.3202 - val_loss: 1.3582
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3225
# Epoch 29: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 541s 18ms/sample - loss: 1.3225 - val_loss: 1.3590
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3189
# Epoch 30: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 551s 19ms/sample - loss: 1.3189 - val_loss: 1.3579
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3179
# Epoch 31: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 784s 26ms/sample - loss: 1.3179 - val_loss: 1.3562
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3124
# Epoch 32: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 828s 28ms/sample - loss: 1.3124 - val_loss: 1.3523
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3152
# Epoch 33: val_loss did not improve from 1.34468
# 29601/29601 [==============================] - 841s 28ms/sample - loss: 1.3152 - val_loss: 1.3591
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3115
# Epoch 34: val_loss improved from 1.34468 to 1.34114, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 829s 28ms/sample - loss: 1.3115 - val_loss: 1.3411
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3095
# Epoch 35: val_loss did not improve from 1.34114
# 29601/29601 [==============================] - 833s 28ms/sample - loss: 1.3095 - val_loss: 1.3421
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3094
# Epoch 36: val_loss did not improve from 1.34114
# 29601/29601 [==============================] - 832s 28ms/sample - loss: 1.3094 - val_loss: 1.3551
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3102
# Epoch 37: val_loss improved from 1.34114 to 1.33955, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 815s 28ms/sample - loss: 1.3102 - val_loss: 1.3396
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3070
# Epoch 38: val_loss did not improve from 1.33955
# 29601/29601 [==============================] - 819s 28ms/sample - loss: 1.3070 - val_loss: 1.3555
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3049
# Epoch 39: val_loss did not improve from 1.33955
# 29601/29601 [==============================] - 822s 28ms/sample - loss: 1.3049 - val_loss: 1.3484
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3074
# Epoch 40: val_loss improved from 1.33955 to 1.33828, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 826s 28ms/sample - loss: 1.3074 - val_loss: 1.3383
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3025
# Epoch 41: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 855s 29ms/sample - loss: 1.3025 - val_loss: 1.3450
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3033
# Epoch 42: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 868s 29ms/sample - loss: 1.3033 - val_loss: 1.3507
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2998
# Epoch 43: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 887s 30ms/sample - loss: 1.2998 - val_loss: 1.3469
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3015
# Epoch 44: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 840s 28ms/sample - loss: 1.3015 - val_loss: 1.3498
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2985
# Epoch 45: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 831s 28ms/sample - loss: 1.2985 - val_loss: 1.3558
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3002
# Epoch 46: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 827s 28ms/sample - loss: 1.3002 - val_loss: 1.3423
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3006
# Epoch 47: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 892s 30ms/sample - loss: 1.3006 - val_loss: 1.3498
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2977
# Epoch 48: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 901s 30ms/sample - loss: 1.2977 - val_loss: 1.3506
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2990
# Epoch 49: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 852s 29ms/sample - loss: 1.2990 - val_loss: 1.3467
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2973
# Epoch 50: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 854s 29ms/sample - loss: 1.2973 - val_loss: 1.3423
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2970
# Epoch 51: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 829s 28ms/sample - loss: 1.2970 - val_loss: 1.3496
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2965
# Epoch 52: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 833s 28ms/sample - loss: 1.2965 - val_loss: 1.3477
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2930
# Epoch 53: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 831s 28ms/sample - loss: 1.2930 - val_loss: 1.3461
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2911
# Epoch 54: val_loss did not improve from 1.33828
# 29601/29601 [==============================] - 830s 28ms/sample - loss: 1.2911 - val_loss: 1.3457
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2917
# Epoch 55: val_loss improved from 1.33828 to 1.33044, saving model to ./checkpoints/Adaptive_prune_fine_grain_model_0.h5
# 29601/29601 [==============================] - 832s 28ms/sample - loss: 1.2917 - val_loss: 1.3304
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2894
# Epoch 56: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 833s 28ms/sample - loss: 1.2894 - val_loss: 1.3440
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2878
# Epoch 57: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 833s 28ms/sample - loss: 1.2878 - val_loss: 1.3470
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2870
# Epoch 58: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 832s 28ms/sample - loss: 1.2870 - val_loss: 1.3394
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2854
# Epoch 59: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 562s 19ms/sample - loss: 1.2854 - val_loss: 1.3377
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2822
# Epoch 60: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 543s 18ms/sample - loss: 1.2822 - val_loss: 1.3484
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2844
# Epoch 61: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 544s 18ms/sample - loss: 1.2844 - val_loss: 1.3480
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2794
# Epoch 62: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 529s 18ms/sample - loss: 1.2794 - val_loss: 1.3403
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2789
# Epoch 63: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 523s 18ms/sample - loss: 1.2789 - val_loss: 1.3467
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2769
# Epoch 64: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 521s 18ms/sample - loss: 1.2769 - val_loss: 1.3525
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2780
# Epoch 65: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 551s 19ms/sample - loss: 1.2780 - val_loss: 1.3396
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2773
# Epoch 66: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 572s 19ms/sample - loss: 1.2773 - val_loss: 1.3555
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2739
# Epoch 67: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 546s 18ms/sample - loss: 1.2739 - val_loss: 1.3590
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2722
# Epoch 68: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 548s 19ms/sample - loss: 1.2722 - val_loss: 1.3523
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2715
# Epoch 69: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 535s 18ms/sample - loss: 1.2715 - val_loss: 1.3391
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2680
# Epoch 70: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 525s 18ms/sample - loss: 1.2680 - val_loss: 1.3575
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2694
# Epoch 71: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 513s 17ms/sample - loss: 1.2694 - val_loss: 1.3405
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2654
# Epoch 72: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 538s 18ms/sample - loss: 1.2654 - val_loss: 1.3411
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2679
# Epoch 73: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 549s 19ms/sample - loss: 1.2679 - val_loss: 1.3684
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2678
# Epoch 74: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 553s 19ms/sample - loss: 1.2678 - val_loss: 1.3461
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2661
# Epoch 75: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 556s 19ms/sample - loss: 1.2661 - val_loss: 1.3429
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2677
# Epoch 76: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 542s 18ms/sample - loss: 1.2677 - val_loss: 1.3427
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2626
# Epoch 77: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 525s 18ms/sample - loss: 1.2626 - val_loss: 1.3455
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2622
# Epoch 78: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 522s 18ms/sample - loss: 1.2622 - val_loss: 1.3540
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2590
# Epoch 79: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 525s 18ms/sample - loss: 1.2590 - val_loss: 1.3404
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2611
# Epoch 80: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 509s 17ms/sample - loss: 1.2611 - val_loss: 1.3490
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2577
# Epoch 81: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 534s 18ms/sample - loss: 1.2577 - val_loss: 1.3534
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2560
# Epoch 82: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 562s 19ms/sample - loss: 1.2560 - val_loss: 1.3434
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2529
# Epoch 83: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 529s 18ms/sample - loss: 1.2529 - val_loss: 1.3587
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2557
# Epoch 84: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 535s 18ms/sample - loss: 1.2557 - val_loss: 1.3385
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2547
# Epoch 85: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 541s 18ms/sample - loss: 1.2547 - val_loss: 1.3464
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2535
# Epoch 86: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 552s 19ms/sample - loss: 1.2535 - val_loss: 1.3477
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2546
# Epoch 87: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 542s 18ms/sample - loss: 1.2546 - val_loss: 1.3479
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2538
# Epoch 88: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 564s 19ms/sample - loss: 1.2538 - val_loss: 1.3458
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2512
# Epoch 89: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 528s 18ms/sample - loss: 1.2512 - val_loss: 1.3517
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2476
# Epoch 90: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 555s 19ms/sample - loss: 1.2476 - val_loss: 1.3526
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2477
# Epoch 91: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 542s 18ms/sample - loss: 1.2477 - val_loss: 1.3364
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2485
# Epoch 92: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 523s 18ms/sample - loss: 1.2485 - val_loss: 1.3528
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2476
# Epoch 93: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 541s 18ms/sample - loss: 1.2476 - val_loss: 1.3467
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2457
# Epoch 94: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 544s 18ms/sample - loss: 1.2457 - val_loss: 1.3455
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2448
# Epoch 95: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 549s 19ms/sample - loss: 1.2448 - val_loss: 1.3419
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2453
# Epoch 96: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 561s 19ms/sample - loss: 1.2453 - val_loss: 1.3418
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2472
# Epoch 97: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 558s 19ms/sample - loss: 1.2472 - val_loss: 1.3571
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2408
# Epoch 98: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 542s 18ms/sample - loss: 1.2408 - val_loss: 1.3418
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2473
# Epoch 99: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 547s 18ms/sample - loss: 1.2473 - val_loss: 1.3569
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2417
# Epoch 100: val_loss did not improve from 1.33044
# 29601/29601 [==============================] - 550s 19ms/sample - loss: 1.2417 - val_loss: 1.3464

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_fine_grain_model_0.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-06 15:57:53.005000: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.005224: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.005405: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.016971: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.017218: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.017399: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.017569: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.017733: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.017895: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.193743: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.193948: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.194115: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.194277: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.194435: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.194589: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.194739: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.194892: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.195044: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.202651: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.202862: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.203053: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.203222: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.203391: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.203560: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.203723: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.203868: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-06 15:57:53.204310: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.204456: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-06 15:57:53.204691: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:53.204839: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-06 15:57:53.205172: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-06 15:57:55.096551: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.096787: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.096973: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.097156: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.097336: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.097503: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.097670: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.097841: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.098005: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.098236: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.098404: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.098566: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.098729: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.098863: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-06 15:57:55.098913: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.099043: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-06 15:57:55.099092: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:57:55.099223: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-06 15:57:55.099278: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-06 15:57:55.148493: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-06 15:57:55.239107: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_1/kernel/Assign' id:6317 op device:{requested: '', assigned: ''} def:{{{node dense_1/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_1/kernel, dense_1/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-06 15:57:56.184422: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_28/lstm_cell_28/recurrent_kernel/m/Assign' id:7393 op device:{requested: '', assigned: ''} def:{{{node lstm_28/lstm_cell_28/recurrent_kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_28/lstm_cell_28/recurrent_kernel/m, lstm_28/lstm_cell_28/recurrent_kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-11-06 15:57:56.946396: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3/BiasAdd' id:6369 op device:{requested: '', assigned: ''} def:{{{node dense_3/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3/MatMul, dense_3/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-06 15:57:57.516276: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-06 15:57:57.688515: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# Test MAE:
# 1.3282755759765312
# 1.2571836356592025
