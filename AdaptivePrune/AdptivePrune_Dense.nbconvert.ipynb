# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-04 03:44:28.829241: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = Flatten()(input_i)
            hidden_i = Dense(256, activation='relu')(input_i)
            hidden_i = Dense(64, activation='relu')(input_i)
            hidden_i = Dense(32, activation='relu')(input_i)
            hidden_i = Flatten()(hidden_i)
            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Dense(64, activation='relu')(input_i)
            hidden_i = Dense(32, activation='relu')(input_i)
            # hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            # hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Adaptive_prune_dense_model_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val), callbacks=[pruning_callback, checkpoint])
# Out:
# (29601, 95)
# Train on 29601 samples, validate on 3694 samples
# 2023-11-04 03:13:26.472695: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:13:26.489538: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:13:26.499423: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:13:26.506551: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:13:26.507692: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:13:26.508212: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:13:26.618789: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:13:26.619184: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:13:26.619489: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:13:26.619757: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-04 03:13:26.620462: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-04 03:13:26.720702: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-04 03:13:27.153943: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/dense_5/bias/v/Assign' id:2720 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_5/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_5/bias/v, training/Adam/dense_5/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
#  3072/29601 [==>...........................] - ETA: 4s - loss: 3.5369
# 2023-11-04 03:13:28.916887: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 29601/29601 [==============================] - ETA: 0s - loss: 1.9346
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-04 03:13:30.208805: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:1862 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_80_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 1.58655, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 6s 198us/sample - loss: 1.9346 - val_loss: 1.5866
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5229
# Epoch 2: val_loss improved from 1.58655 to 1.52221, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.5229 - val_loss: 1.5222
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4785
# Epoch 3: val_loss improved from 1.52221 to 1.48496, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.4785 - val_loss: 1.4850
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4495
# Epoch 4: val_loss improved from 1.48496 to 1.46491, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.4495 - val_loss: 1.4649
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4247
# Epoch 5: val_loss improved from 1.46491 to 1.45745, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.4247 - val_loss: 1.4575
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4054
# Epoch 6: val_loss improved from 1.45745 to 1.43475, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 54us/sample - loss: 1.4054 - val_loss: 1.4348
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3826
# Epoch 7: val_loss improved from 1.43475 to 1.42577, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.3826 - val_loss: 1.4258
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3685
# Epoch 8: val_loss improved from 1.42577 to 1.41497, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.3685 - val_loss: 1.4150
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3503
# Epoch 9: val_loss improved from 1.41497 to 1.40980, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 51us/sample - loss: 1.3503 - val_loss: 1.4098
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3343
# Epoch 10: val_loss improved from 1.40980 to 1.40441, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 51us/sample - loss: 1.3343 - val_loss: 1.4044
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3232
# Epoch 11: val_loss did not improve from 1.40441
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.3232 - val_loss: 1.4051
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3114
# Epoch 12: val_loss improved from 1.40441 to 1.39970, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.3114 - val_loss: 1.3997
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2943
# Epoch 13: val_loss improved from 1.39970 to 1.39705, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.2943 - val_loss: 1.3971
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2916
# Epoch 14: val_loss improved from 1.39705 to 1.39462, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 51us/sample - loss: 1.2916 - val_loss: 1.3946
# Epoch 15/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.2690
# Epoch 15: val_loss improved from 1.39462 to 1.38970, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 51us/sample - loss: 1.2707 - val_loss: 1.3897
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2651
# Epoch 16: val_loss did not improve from 1.38970
# 29601/29601 [==============================] - 1s 50us/sample - loss: 1.2651 - val_loss: 1.3998
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2576
# Epoch 17: val_loss did not improve from 1.38970
# 29601/29601 [==============================] - 1s 47us/sample - loss: 1.2576 - val_loss: 1.3969
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2435
# Epoch 18: val_loss improved from 1.38970 to 1.38732, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 1s 50us/sample - loss: 1.2435 - val_loss: 1.3873
# Epoch 19/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.2338
# Epoch 19: val_loss did not improve from 1.38732
# 29601/29601 [==============================] - 1s 47us/sample - loss: 1.2345 - val_loss: 1.3940
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2307
# Epoch 20: val_loss improved from 1.38732 to 1.38428, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.2307 - val_loss: 1.3843
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2157
# Epoch 21: val_loss did not improve from 1.38428
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.2157 - val_loss: 1.3901
# Epoch 22/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.2074
# Epoch 22: val_loss did not improve from 1.38428
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.2080 - val_loss: 1.4068
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2025
# Epoch 23: val_loss did not improve from 1.38428
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.2025 - val_loss: 1.3922
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1948
# Epoch 24: val_loss did not improve from 1.38428
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.1948 - val_loss: 1.3920
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1928
# Epoch 25: val_loss did not improve from 1.38428
# 29601/29601 [==============================] - 1s 50us/sample - loss: 1.1928 - val_loss: 1.3859
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1850
# Epoch 26: val_loss did not improve from 1.38428
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.1850 - val_loss: 1.3924
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1687
# Epoch 27: val_loss did not improve from 1.38428
# 29601/29601 [==============================] - 1s 46us/sample - loss: 1.1687 - val_loss: 1.3960
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1624
# Epoch 28: val_loss did not improve from 1.38428
# 29601/29601 [==============================] - 1s 49us/sample - loss: 1.1624 - val_loss: 1.3881
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1553
# Epoch 29: val_loss did not improve from 1.38428
# 29601/29601 [==============================] - 1s 49us/sample - loss: 1.1553 - val_loss: 1.3867
# Epoch 30/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.1479
# Epoch 30: val_loss did not improve from 1.38428
# 29601/29601 [==============================] - 2s 51us/sample - loss: 1.1480 - val_loss: 1.3984
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1368
# Epoch 31: val_loss did not improve from 1.38428
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.1368 - val_loss: 1.3936
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1342
# Epoch 32: val_loss improved from 1.38428 to 1.38387, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 52us/sample - loss: 1.1342 - val_loss: 1.3839
# Epoch 33/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.1288
# Epoch 33: val_loss did not improve from 1.38387
# 29601/29601 [==============================] - 1s 47us/sample - loss: 1.1281 - val_loss: 1.3956
# Epoch 34/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.1226
# Epoch 34: val_loss improved from 1.38387 to 1.37964, saving model to ./checkpoints/Adaptive_prune_dense_model_0.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 1.1221 - val_loss: 1.3796
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1204
# Epoch 35: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 1.1204 - val_loss: 1.3983
# Epoch 36/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.1095
# Epoch 36: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.1081 - val_loss: 1.3993
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1100
# Epoch 37: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.1100 - val_loss: 1.3846
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1017
# Epoch 38: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.1017 - val_loss: 1.4017
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0989
# Epoch 39: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 46us/sample - loss: 1.0989 - val_loss: 1.4029
# Epoch 40/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.0920
# Epoch 40: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 1.0935 - val_loss: 1.4055
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0820
# Epoch 41: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.0820 - val_loss: 1.3944
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0805
# Epoch 42: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.0805 - val_loss: 1.3937
# Epoch 43/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.0765
# Epoch 43: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 1.0772 - val_loss: 1.4021
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0679
# Epoch 44: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 1.0679 - val_loss: 1.3971
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0642
# Epoch 45: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 1.0642 - val_loss: 1.3986
# Epoch 46/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.0564
# Epoch 46: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.0567 - val_loss: 1.3948
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0557
# Epoch 47: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 50us/sample - loss: 1.0557 - val_loss: 1.4085
# Epoch 48/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.0529
# Epoch 48: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.0525 - val_loss: 1.4063
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0463
# Epoch 49: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 2s 51us/sample - loss: 1.0463 - val_loss: 1.4023
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0443
# Epoch 50: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 1.0443 - val_loss: 1.4037
# Epoch 51/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.0392
# Epoch 51: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 1.0401 - val_loss: 1.4221
# Epoch 52/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.0393
# Epoch 52: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 1.0391 - val_loss: 1.4028
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0236
# Epoch 53: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.0236 - val_loss: 1.4037
# Epoch 54/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.0231
# Epoch 54: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 1.0237 - val_loss: 1.4053
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0225
# Epoch 55: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 1.0225 - val_loss: 1.4004
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0157
# Epoch 56: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 1.0157 - val_loss: 1.4197
# Epoch 57/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.0194
# Epoch 57: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 46us/sample - loss: 1.0173 - val_loss: 1.4236
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0072
# Epoch 58: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.0072 - val_loss: 1.4088
# Epoch 59/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 1.0065
# Epoch 59: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 1.0076 - val_loss: 1.4042
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0021
# Epoch 60: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 1.0021 - val_loss: 1.4129
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0012
# Epoch 61: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 46us/sample - loss: 1.0012 - val_loss: 1.4168
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9945
# Epoch 62: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.9945 - val_loss: 1.4242
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9924
# Epoch 63: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.9924 - val_loss: 1.4133
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9841
# Epoch 64: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9841 - val_loss: 1.4176
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9867
# Epoch 65: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.9867 - val_loss: 1.4099
# Epoch 66/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.9763
# Epoch 66: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 50us/sample - loss: 0.9775 - val_loss: 1.4162
# Epoch 67/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.9707
# Epoch 67: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9724 - val_loss: 1.4199
# Epoch 68/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.9746
# Epoch 68: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.9763 - val_loss: 1.4166
# Epoch 69/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.9746
# Epoch 69: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.9747 - val_loss: 1.4225
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9725
# Epoch 70: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.9725 - val_loss: 1.4306
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9685
# Epoch 71: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.9685 - val_loss: 1.4200
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9596
# Epoch 72: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 2s 51us/sample - loss: 0.9596 - val_loss: 1.4165
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9555
# Epoch 73: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 50us/sample - loss: 0.9555 - val_loss: 1.4171
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9518
# Epoch 74: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.9518 - val_loss: 1.4200
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9521
# Epoch 75: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 50us/sample - loss: 0.9521 - val_loss: 1.4219
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9517
# Epoch 76: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.9517 - val_loss: 1.4175
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9473
# Epoch 77: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.9473 - val_loss: 1.4183
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9469
# Epoch 78: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.9469 - val_loss: 1.4268
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9415
# Epoch 79: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.9415 - val_loss: 1.4154
# Epoch 80/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.9367
# Epoch 80: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.9374 - val_loss: 1.4161
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9330
# Epoch 81: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.9330 - val_loss: 1.4223
# Epoch 82/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.9353
# Epoch 82: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.9364 - val_loss: 1.4203
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9275
# Epoch 83: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 43us/sample - loss: 0.9275 - val_loss: 1.4225
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9355
# Epoch 84: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9355 - val_loss: 1.4149
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9262
# Epoch 85: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9262 - val_loss: 1.4219
# Epoch 86/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.9214
# Epoch 86: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9208 - val_loss: 1.4302
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9218
# Epoch 87: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9218 - val_loss: 1.4226
# Epoch 88/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.9189
# Epoch 88: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9199 - val_loss: 1.4243
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9178
# Epoch 89: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.9178 - val_loss: 1.4191
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9133
# Epoch 90: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9133 - val_loss: 1.4152
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9094
# Epoch 91: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9094 - val_loss: 1.4238
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9099
# Epoch 92: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9099 - val_loss: 1.4248
# Epoch 93/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.9108
# Epoch 93: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9107 - val_loss: 1.4361
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9059
# Epoch 94: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9059 - val_loss: 1.4174
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9029
# Epoch 95: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9029 - val_loss: 1.4302
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9066
# Epoch 96: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.9066 - val_loss: 1.4240
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8925
# Epoch 97: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8925 - val_loss: 1.4267
# Epoch 98/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8978
# Epoch 98: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8970 - val_loss: 1.4234
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8955
# Epoch 99: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8955 - val_loss: 1.4331
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8926
# Epoch 100: val_loss did not improve from 1.37964
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8926 - val_loss: 1.4200
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8971
# Epoch 1: val_loss improved from inf to 1.43302, saving model to ./checkpoints/Adaptive_prune_dense_model_1.h5
# 29601/29601 [==============================] - 2s 54us/sample - loss: 0.8971 - val_loss: 1.4330
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8925
# Epoch 2: val_loss improved from 1.43302 to 1.42767, saving model to ./checkpoints/Adaptive_prune_dense_model_1.h5
# 29601/29601 [==============================] - 2s 53us/sample - loss: 0.8925 - val_loss: 1.4277
# Epoch 3/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8852
# Epoch 3: val_loss improved from 1.42767 to 1.41653, saving model to ./checkpoints/Adaptive_prune_dense_model_1.h5
# 29601/29601 [==============================] - 2s 52us/sample - loss: 0.8869 - val_loss: 1.4165
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8809
# Epoch 4: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8809 - val_loss: 1.4292
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8831
# Epoch 5: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.8831 - val_loss: 1.4282
# Epoch 6/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8805
# Epoch 6: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 51us/sample - loss: 0.8807 - val_loss: 1.4367
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8842
# Epoch 7: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8842 - val_loss: 1.4224
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8790
# Epoch 8: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 50us/sample - loss: 0.8790 - val_loss: 1.4264
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8850
# Epoch 9: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8850 - val_loss: 1.4225
# Epoch 10/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8848
# Epoch 10: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8849 - val_loss: 1.4288
# Epoch 11/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8878
# Epoch 11: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.8866 - val_loss: 1.4509
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8816
# Epoch 12: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.8816 - val_loss: 1.4273
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8794
# Epoch 13: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.8794 - val_loss: 1.4264
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8769
# Epoch 14: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 43us/sample - loss: 0.8769 - val_loss: 1.4397
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8758
# Epoch 15: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 44us/sample - loss: 0.8758 - val_loss: 1.4323
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8778
# Epoch 16: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 44us/sample - loss: 0.8778 - val_loss: 1.4349
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8791
# Epoch 17: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 43us/sample - loss: 0.8791 - val_loss: 1.4361
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9025
# Epoch 18: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.9025 - val_loss: 1.4226
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8883
# Epoch 19: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 43us/sample - loss: 0.8883 - val_loss: 1.4212
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8858
# Epoch 20: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8858 - val_loss: 1.4319
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8773
# Epoch 21: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 44us/sample - loss: 0.8773 - val_loss: 1.4342
# Epoch 22/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8750
# Epoch 22: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8759 - val_loss: 1.4415
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8803
# Epoch 23: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.8803 - val_loss: 1.4355
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8810
# Epoch 24: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.8810 - val_loss: 1.4374
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8958
# Epoch 25: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 44us/sample - loss: 0.8958 - val_loss: 1.4320
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8784
# Epoch 26: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.8784 - val_loss: 1.4355
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8740
# Epoch 27: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8740 - val_loss: 1.4422
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8777
# Epoch 28: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.8777 - val_loss: 1.4313
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8749
# Epoch 29: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.8749 - val_loss: 1.4313
# Epoch 30/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8766
# Epoch 30: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8778 - val_loss: 1.4334
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8920
# Epoch 31: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8920 - val_loss: 1.4452
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8764
# Epoch 32: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 52us/sample - loss: 0.8764 - val_loss: 1.4356
# Epoch 33/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8731
# Epoch 33: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8738 - val_loss: 1.4413
# Epoch 34/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8778
# Epoch 34: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.8782 - val_loss: 1.4388
# Epoch 35/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8723
# Epoch 35: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 52us/sample - loss: 0.8723 - val_loss: 1.4409
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8720
# Epoch 36: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8720 - val_loss: 1.4432
# Epoch 37/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8698
# Epoch 37: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8698 - val_loss: 1.4368
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8678
# Epoch 38: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 44us/sample - loss: 0.8678 - val_loss: 1.4332
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8621
# Epoch 39: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8621 - val_loss: 1.4408
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8693
# Epoch 40: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8693 - val_loss: 1.4461
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8669
# Epoch 41: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8669 - val_loss: 1.4418
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8584
# Epoch 42: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8584 - val_loss: 1.4454
# Epoch 43/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8644
# Epoch 43: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 54us/sample - loss: 0.8641 - val_loss: 1.4433
# Epoch 44/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8629
# Epoch 44: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 50us/sample - loss: 0.8628 - val_loss: 1.4348
# Epoch 45/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8684
# Epoch 45: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8683 - val_loss: 1.4446
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8604
# Epoch 46: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.8604 - val_loss: 1.4536
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8601
# Epoch 47: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 44us/sample - loss: 0.8601 - val_loss: 1.4442
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8665
# Epoch 48: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.8665 - val_loss: 1.4440
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8577
# Epoch 49: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 50us/sample - loss: 0.8577 - val_loss: 1.4542
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8551
# Epoch 50: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8551 - val_loss: 1.4385
# Epoch 51/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8538
# Epoch 51: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8540 - val_loss: 1.4418
# Epoch 52/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8579
# Epoch 52: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 51us/sample - loss: 0.8573 - val_loss: 1.4434
# Epoch 53/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8579
# Epoch 53: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8579 - val_loss: 1.4414
# Epoch 54/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8495
# Epoch 54: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 54us/sample - loss: 0.8506 - val_loss: 1.4407
# Epoch 55/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8483
# Epoch 55: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8484 - val_loss: 1.4341
# Epoch 56/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8426
# Epoch 56: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8434 - val_loss: 1.4409
# Epoch 57/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8457
# Epoch 57: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.8456 - val_loss: 1.4378
# Epoch 58/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8427
# Epoch 58: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8422 - val_loss: 1.4382
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8344
# Epoch 59: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 50us/sample - loss: 0.8344 - val_loss: 1.4504
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8352
# Epoch 60: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 51us/sample - loss: 0.8352 - val_loss: 1.4405
# Epoch 61/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8365
# Epoch 61: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 51us/sample - loss: 0.8371 - val_loss: 1.4511
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8303
# Epoch 62: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8303 - val_loss: 1.4432
# Epoch 63/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8273
# Epoch 63: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8282 - val_loss: 1.4407
# Epoch 64/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8267
# Epoch 64: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8266 - val_loss: 1.4362
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8287
# Epoch 65: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8287 - val_loss: 1.4429
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8291
# Epoch 66: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.8291 - val_loss: 1.4465
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8225
# Epoch 67: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.8225 - val_loss: 1.4503
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8218
# Epoch 68: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8218 - val_loss: 1.4396
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8188
# Epoch 69: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8188 - val_loss: 1.4455
# Epoch 70/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8119
# Epoch 70: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8122 - val_loss: 1.4582
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8145
# Epoch 71: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 53us/sample - loss: 0.8145 - val_loss: 1.4429
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8158
# Epoch 72: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8158 - val_loss: 1.4498
# Epoch 73/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8149
# Epoch 73: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 51us/sample - loss: 0.8157 - val_loss: 1.4410
# Epoch 74/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8065
# Epoch 74: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 51us/sample - loss: 0.8072 - val_loss: 1.4483
# Epoch 75/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8070
# Epoch 75: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 55us/sample - loss: 0.8071 - val_loss: 1.4489
# Epoch 76/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8089
# Epoch 76: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 52us/sample - loss: 0.8093 - val_loss: 1.4539
# Epoch 77/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8105
# Epoch 77: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 51us/sample - loss: 0.8114 - val_loss: 1.4535
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8051
# Epoch 78: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8051 - val_loss: 1.4527
# Epoch 79/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8069
# Epoch 79: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 53us/sample - loss: 0.8069 - val_loss: 1.4468
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.7994
# Epoch 80: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 2s 51us/sample - loss: 0.7994 - val_loss: 1.4441
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8011
# Epoch 81: val_loss did not improve from 1.41653
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.8011 - val_loss: 1.4510
# Epoch 82/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8022
# Epoch 82: val_loss did not improve from 1.41653
# ...
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.7936 - val_loss: 1.4310
# Epoch 31/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.7990
# Epoch 31: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.7987 - val_loss: 1.4279
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.7999
# Epoch 32: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 50us/sample - loss: 0.7999 - val_loss: 1.4358
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8080
# Epoch 33: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.8080 - val_loss: 1.4282
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8251
# Epoch 34: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8251 - val_loss: 1.4304
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8177
# Epoch 35: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8177 - val_loss: 1.4350
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8186
# Epoch 36: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8186 - val_loss: 1.4331
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8413
# Epoch 37: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8413 - val_loss: 1.4324
# Epoch 38/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8332
# Epoch 38: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8321 - val_loss: 1.4453
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8389
# Epoch 39: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8389 - val_loss: 1.4385
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8465
# Epoch 40: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8465 - val_loss: 1.4361
# Epoch 41/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8746
# Epoch 41: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8748 - val_loss: 1.4525
# Epoch 42/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8626
# Epoch 42: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8625 - val_loss: 1.4606
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9149
# Epoch 43: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.9149 - val_loss: 1.4466
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8786
# Epoch 44: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8786 - val_loss: 1.4451
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8811
# Epoch 45: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8811 - val_loss: 1.4383
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8903
# Epoch 46: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8903 - val_loss: 1.4405
# Epoch 47/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.9113
# Epoch 47: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9096 - val_loss: 1.4464
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9390
# Epoch 48: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9390 - val_loss: 1.4406
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9295
# Epoch 49: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9295 - val_loss: 1.4469
# Epoch 50/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.9367
# Epoch 50: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9351 - val_loss: 1.4481
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0169
# Epoch 51: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 49us/sample - loss: 1.0169 - val_loss: 1.4567
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9753
# Epoch 52: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9753 - val_loss: 1.4436
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9659
# Epoch 53: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9659 - val_loss: 1.4474
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9628
# Epoch 54: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.9628 - val_loss: 1.4476
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9649
# Epoch 55: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.9649 - val_loss: 1.4488
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9789
# Epoch 56: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9789 - val_loss: 1.4366
# Epoch 57/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.9582
# Epoch 57: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.9584 - val_loss: 1.4486
# Epoch 58/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.9579
# Epoch 58: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9558 - val_loss: 1.4410
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9438
# Epoch 59: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.9438 - val_loss: 1.4487
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9485
# Epoch 60: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.9485 - val_loss: 1.4651
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9389
# Epoch 61: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.9389 - val_loss: 1.4549
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9367
# Epoch 62: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9367 - val_loss: 1.4525
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9254
# Epoch 63: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.9254 - val_loss: 1.4546
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9188
# Epoch 64: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 44us/sample - loss: 0.9188 - val_loss: 1.4499
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9204
# Epoch 65: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9204 - val_loss: 1.4572
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9223
# Epoch 66: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.9223 - val_loss: 1.4472
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9178
# Epoch 67: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9178 - val_loss: 1.4600
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9133
# Epoch 68: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.9133 - val_loss: 1.4655
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9094
# Epoch 69: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9094 - val_loss: 1.4594
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9067
# Epoch 70: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9067 - val_loss: 1.4573
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9043
# Epoch 71: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.9043 - val_loss: 1.4569
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8997
# Epoch 72: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8997 - val_loss: 1.4601
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8999
# Epoch 73: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8999 - val_loss: 1.4613
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8970
# Epoch 74: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8970 - val_loss: 1.4629
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8984
# Epoch 75: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 43us/sample - loss: 0.8984 - val_loss: 1.4599
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8935
# Epoch 76: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8935 - val_loss: 1.4582
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8906
# Epoch 77: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8906 - val_loss: 1.4633
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8869
# Epoch 78: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8869 - val_loss: 1.4630
# Epoch 79/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8845
# Epoch 79: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8844 - val_loss: 1.4613
# Epoch 80/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8846
# Epoch 80: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.8842 - val_loss: 1.4660
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8815
# Epoch 81: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8815 - val_loss: 1.4699
# Epoch 82/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8743
# Epoch 82: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8755 - val_loss: 1.4703
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8773
# Epoch 83: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8773 - val_loss: 1.4594
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8736
# Epoch 84: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 45us/sample - loss: 0.8736 - val_loss: 1.4684
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8719
# Epoch 85: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.8719 - val_loss: 1.4704
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8734
# Epoch 86: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8734 - val_loss: 1.4639
# Epoch 87/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8691
# Epoch 87: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8690 - val_loss: 1.4746
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8688
# Epoch 88: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.8688 - val_loss: 1.4672
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8675
# Epoch 89: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.8675 - val_loss: 1.4680
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8657
# Epoch 90: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8657 - val_loss: 1.4703
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8628
# Epoch 91: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8628 - val_loss: 1.4739
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8622
# Epoch 92: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 48us/sample - loss: 0.8622 - val_loss: 1.4680
# Epoch 93/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8585
# Epoch 93: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 2s 53us/sample - loss: 0.8574 - val_loss: 1.4764
# Epoch 94/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8599
# Epoch 94: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8601 - val_loss: 1.4646
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8586
# Epoch 95: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8586 - val_loss: 1.4685
# Epoch 96/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8544
# Epoch 96: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8552 - val_loss: 1.4648
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8531
# Epoch 97: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 49us/sample - loss: 0.8531 - val_loss: 1.4603
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8497
# Epoch 98: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 43us/sample - loss: 0.8497 - val_loss: 1.4683
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.8618
# Epoch 99: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 46us/sample - loss: 0.8618 - val_loss: 1.4659
# Epoch 100/100
# 28672/29601 [============================>.] - ETA: 0s - loss: 0.8507
# Epoch 100: val_loss did not improve from 1.42757
# 29601/29601 [==============================] - 1s 47us/sample - loss: 0.8507 - val_loss: 1.4717

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_dense_model_0.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 2023-11-04 03:45:05.761319: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:45:05.777818: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:45:05.778116: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:45:05.782866: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:45:05.783158: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:45:05.783396: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:45:05.880887: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:45:05.881284: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:45:05.881598: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 03:45:05.882071: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-04 03:45:05.882739: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-04 03:45:05.911983: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-04 03:45:06.215345: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_78/kernel/Assign' id:911 op device:{requested: '', assigned: ''} def:{{{node dense_78/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_78/kernel, dense_78/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:45:07.076508: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_19/bias/v/Assign' id:1975 op device:{requested: '', assigned: ''} def:{{{node dense_19/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_19/bias/v, dense_19/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-11-04 03:45:07.824954: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_80/BiasAdd' id:963 op device:{requested: '', assigned: ''} def:{{{node dense_80/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_80/MatMul, dense_80/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:45:07.975734: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Test MAE:
# 1.3719426088577917
# 1.2441651629784347

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_dense_model_1.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# 2023-11-04 03:45:09.186495: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_11_1/kernel/Assign' id:3221 op device:{requested: '', assigned: ''} def:{{{node dense_11_1/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_11_1/kernel, dense_11_1/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:45:10.349515: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_76_1/kernel/m/Assign' id:4815 op device:{requested: '', assigned: ''} def:{{{node dense_76_1/kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_76_1/kernel/m, dense_76_1/kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:45:11.226083: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_80_1/BiasAdd' id:3986 op device:{requested: '', assigned: ''} def:{{{node dense_80_1/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_80_1/MatMul, dense_80_1/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.4110520942429159
# 1.2327690685451225

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_dense_model_2.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# 2023-11-04 03:45:21.116781: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_21_2/bias/Assign' id:6354 op device:{requested: '', assigned: ''} def:{{{node dense_21_2/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_21_2/bias, dense_21_2/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:45:22.264365: W tensorflow/c/c_api.cc:304] Operation '{name:'beta_1_2/Assign' id:7374 op device:{requested: '', assigned: ''} def:{{{node beta_1_2/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](beta_1_2, beta_1_2/Initializer/initial_value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:45:23.246946: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_80_2/BiasAdd' id:7009 op device:{requested: '', assigned: ''} def:{{{node dense_80_2/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_80_2/MatMul, dense_80_2/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.428608871415796
# 1.2261066408990657

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_dense_model_3.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# 2023-11-04 03:45:34.551052: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_35_3/bias/Assign' id:9524 op device:{requested: '', assigned: ''} def:{{{node dense_35_3/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_35_3/bias, dense_35_3/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:45:35.836225: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_60_3/bias/m/Assign' id:10770 op device:{requested: '', assigned: ''} def:{{{node dense_60_3/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_60_3/bias/m, dense_60_3/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:45:36.990741: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_80_3/BiasAdd' id:10032 op device:{requested: '', assigned: ''} def:{{{node dense_80_3/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_80_3/MatMul, dense_80_3/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.4089637975309484
# 1.2128446582065817

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_dense_model_4.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# 2023-11-04 03:45:45.984964: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_66_4/kernel/Assign' id:12838 op device:{requested: '', assigned: ''} def:{{{node dense_66_4/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_66_4/kernel, dense_66_4/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:45:47.668715: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_5_4/bias/v/Assign' id:13983 op device:{requested: '', assigned: ''} def:{{{node dense_5_4/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_5_4/bias/v, dense_5_4/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:45:49.027086: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_80_4/BiasAdd' id:13055 op device:{requested: '', assigned: ''} def:{{{node dense_80_4/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_80_4/MatMul, dense_80_4/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.4193130549455553
# 1.2244037452639114

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_dense_model_5.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# 2023-11-04 03:45:55.624438: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_77_5/kernel/Assign' id:15987 op device:{requested: '', assigned: ''} def:{{{node dense_77_5/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_77_5/kernel, dense_77_5/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:45:57.281366: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_5_5/kernel/v/Assign' id:17001 op device:{requested: '', assigned: ''} def:{{{node dense_5_5/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_5_5/kernel/v, dense_5_5/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:45:58.822414: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_80_5/BiasAdd' id:16078 op device:{requested: '', assigned: ''} def:{{{node dense_80_5/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_80_5/MatMul, dense_80_5/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.4369150523046064
# 1.2627226896270578

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_dense_model_6.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# 2023-11-04 03:51:10.844416: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_56_6/bias/Assign' id:18784 op device:{requested: '', assigned: ''} def:{{{node dense_56_6/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_56_6/bias, dense_56_6/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:51:12.688954: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_70_6/bias/v/Assign' id:20399 op device:{requested: '', assigned: ''} def:{{{node dense_70_6/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_70_6/bias/v, dense_70_6/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:51:14.449525: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_80_6/BiasAdd' id:19101 op device:{requested: '', assigned: ''} def:{{{node dense_80_6/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_80_6/MatMul, dense_80_6/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.411238588104844
# 1.2275115714104046

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_dense_model_7.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# 2023-11-04 03:51:25.715392: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_76_7/kernel/Assign' id:22012 op device:{requested: '', assigned: ''} def:{{{node dense_76_7/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_76_7/kernel, dense_76_7/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:51:27.667140: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_27_7/bias/v/Assign' id:23184 op device:{requested: '', assigned: ''} def:{{{node dense_27_7/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_27_7/bias/v, dense_27_7/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:51:29.559611: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_80_7/BiasAdd' id:22124 op device:{requested: '', assigned: ''} def:{{{node dense_80_7/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_80_7/MatMul, dense_80_7/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.437614444799669
# 1.2407840615337336

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_dense_model_8.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# 2023-11-04 03:51:42.096925: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_31_8/kernel/Assign' id:24592 op device:{requested: '', assigned: ''} def:{{{node dense_31_8/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_31_8/kernel, dense_31_8/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:51:44.464935: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_7_8/bias/v/Assign' id:26087 op device:{requested: '', assigned: ''} def:{{{node dense_7_8/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_7_8/bias/v, dense_7_8/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:51:46.529248: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_80_8/BiasAdd' id:25147 op device:{requested: '', assigned: ''} def:{{{node dense_80_8/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_80_8/MatMul, dense_80_8/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.4062970277736202
# 1.2369141732604758

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Adaptive_prune_dense_model_9.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num )

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# 2023-11-04 03:51:56.277785: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_37_9/kernel/Assign' id:27678 op device:{requested: '', assigned: ''} def:{{{node dense_37_9/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_37_9/kernel, dense_37_9/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:51:58.664348: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_66_9/kernel/v/Assign' id:29439 op device:{requested: '', assigned: ''} def:{{{node dense_66_9/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_66_9/kernel/v, dense_66_9/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 03:52:00.966255: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_80_9/BiasAdd' id:28170 op device:{requested: '', assigned: ''} def:{{{node dense_80_9/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_80_9/MatMul, dense_80_9/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Test MAE:
# 1.41924418139091
# 1.2303955093170833
