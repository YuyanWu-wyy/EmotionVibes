# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-06 15:51:58.979053: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer = Dense(2)(h)
    model = Model(inputs=input_layers, outputs=output_layer)
    model.compile(loss='mean_absolute_error', optimizer='adam')
    return model

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
# rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
# for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
model_name = './checkpoints/Baseline_allfeature_model_'+str(idx)+'.h5'
idx = idx+1
checkpoint = ModelCheckpoint(model_name, monitor='val_loss', mode='min', save_best_only=True, verbose=1)
pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=0.35, start_epoch=5, end_epoch=50, frequency=1)
model.fit(X_train_normalized_new, y_train, epochs=num_epochs, batch_size=32, validation_data=(X_val_normalized_new, y_val), callbacks=[checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-04 23:52:35.576803: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:35.588251: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:35.588516: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:35.591798: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:35.591977: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:35.592133: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:35.671991: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:35.672190: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:35.672354: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:35.672492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-04 23:52:35.672732: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-04 23:52:36.599018: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:36.599245: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:36.599418: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:36.599623: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:36.599793: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-04 23:52:36.599930: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-04 23:52:36.599958: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-04 23:52:36.621596: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-04 23:52:36.836671: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_15/lstm_cell_15/kernel/Assign' id:2491 op device:{requested: '', assigned: ''} def:{{{node lstm_15/lstm_cell_15/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_15/lstm_cell_15/kernel, lstm_15/lstm_cell_15/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 23:52:36.968947: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:3634 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 23:52:37.001760: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:3635 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 95)
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 2023-11-04 23:52:41.378490: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_17/lstm_cell_17/recurrent_kernel/m/Assign' id:16654 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_17/lstm_cell_17/recurrent_kernel/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_17/lstm_cell_17/recurrent_kernel/m, training/Adam/lstm_17/lstm_cell_17/recurrent_kernel/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-04 23:52:42.626335: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-04 23:52:44.685026: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 2023-11-04 23:52:44.800596: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 29601/29601 [==============================] - ETA: 0s - loss: 1.5979
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-05 00:01:19.989764: W tensorflow/c/c_api.cc:304] Operation '{name:'loss_1/mul' id:6477 op device:{requested: '', assigned: ''} def:{{{node loss_1/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss_1/mul/x, loss_1/dense_3_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_loss improved from inf to 1.48477, saving model to ./checkpoints/Baseline_allfeature_model_0.h5
# 29601/29601 [==============================] - 548s 19ms/sample - loss: 1.5979 - val_loss: 1.4848
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4746
# Epoch 2: val_loss improved from 1.48477 to 1.44908, saving model to ./checkpoints/Baseline_allfeature_model_0.h5
# 29601/29601 [==============================] - 567s 19ms/sample - loss: 1.4746 - val_loss: 1.4491
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4476
# Epoch 3: val_loss improved from 1.44908 to 1.40453, saving model to ./checkpoints/Baseline_allfeature_model_0.h5
# 29601/29601 [==============================] - 542s 18ms/sample - loss: 1.4476 - val_loss: 1.4045
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4304
# Epoch 4: val_loss did not improve from 1.40453
# 29601/29601 [==============================] - 560s 19ms/sample - loss: 1.4304 - val_loss: 1.4095
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4167
# Epoch 5: val_loss did not improve from 1.40453
# 29601/29601 [==============================] - 570s 19ms/sample - loss: 1.4167 - val_loss: 1.4062
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4084
# Epoch 6: val_loss improved from 1.40453 to 1.39559, saving model to ./checkpoints/Baseline_allfeature_model_0.h5
# 29601/29601 [==============================] - 573s 19ms/sample - loss: 1.4084 - val_loss: 1.3956
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.4000
# Epoch 7: val_loss improved from 1.39559 to 1.37901, saving model to ./checkpoints/Baseline_allfeature_model_0.h5
# 29601/29601 [==============================] - 581s 20ms/sample - loss: 1.4000 - val_loss: 1.3790
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3915
# Epoch 8: val_loss did not improve from 1.37901
# 29601/29601 [==============================] - 575s 19ms/sample - loss: 1.3915 - val_loss: 1.4014
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3873
# Epoch 9: val_loss did not improve from 1.37901
# 29601/29601 [==============================] - 555s 19ms/sample - loss: 1.3873 - val_loss: 1.3921
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3786
# Epoch 10: val_loss improved from 1.37901 to 1.36430, saving model to ./checkpoints/Baseline_allfeature_model_0.h5
# 29601/29601 [==============================] - 564s 19ms/sample - loss: 1.3786 - val_loss: 1.3643
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3729
# Epoch 11: val_loss did not improve from 1.36430
# 29601/29601 [==============================] - 552s 19ms/sample - loss: 1.3729 - val_loss: 1.3832
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3721
# Epoch 12: val_loss did not improve from 1.36430
# 29601/29601 [==============================] - 572s 19ms/sample - loss: 1.3721 - val_loss: 1.3961
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3654
# Epoch 13: val_loss did not improve from 1.36430
# 29601/29601 [==============================] - 570s 19ms/sample - loss: 1.3654 - val_loss: 1.3754
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3625
# Epoch 14: val_loss improved from 1.36430 to 1.35520, saving model to ./checkpoints/Baseline_allfeature_model_0.h5
# 29601/29601 [==============================] - 572s 19ms/sample - loss: 1.3625 - val_loss: 1.3552
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3541
# Epoch 15: val_loss did not improve from 1.35520
# 29601/29601 [==============================] - 558s 19ms/sample - loss: 1.3541 - val_loss: 1.3590
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3498
# Epoch 16: val_loss did not improve from 1.35520
# 29601/29601 [==============================] - 564s 19ms/sample - loss: 1.3498 - val_loss: 1.3795
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3464
# Epoch 17: val_loss did not improve from 1.35520
# 29601/29601 [==============================] - 579s 20ms/sample - loss: 1.3464 - val_loss: 1.3800
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3424
# Epoch 18: val_loss did not improve from 1.35520
# 29601/29601 [==============================] - 558s 19ms/sample - loss: 1.3424 - val_loss: 1.3595
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3399
# Epoch 19: val_loss did not improve from 1.35520
# 29601/29601 [==============================] - 561s 19ms/sample - loss: 1.3399 - val_loss: 1.3624
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3365
# Epoch 20: val_loss improved from 1.35520 to 1.34959, saving model to ./checkpoints/Baseline_allfeature_model_0.h5
# 29601/29601 [==============================] - 562s 19ms/sample - loss: 1.3365 - val_loss: 1.3496
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3349
# Epoch 21: val_loss did not improve from 1.34959
# 29601/29601 [==============================] - 535s 18ms/sample - loss: 1.3349 - val_loss: 1.3592
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3297
# Epoch 22: val_loss did not improve from 1.34959
# 29601/29601 [==============================] - 539s 18ms/sample - loss: 1.3297 - val_loss: 1.3651
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3248
# Epoch 23: val_loss improved from 1.34959 to 1.34413, saving model to ./checkpoints/Baseline_allfeature_model_0.h5
# 29601/29601 [==============================] - 540s 18ms/sample - loss: 1.3248 - val_loss: 1.3441
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3211
# Epoch 24: val_loss did not improve from 1.34413
# 29601/29601 [==============================] - 559s 19ms/sample - loss: 1.3211 - val_loss: 1.3708
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3186
# Epoch 25: val_loss did not improve from 1.34413
# 29601/29601 [==============================] - 541s 18ms/sample - loss: 1.3186 - val_loss: 1.3568
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3131
# Epoch 26: val_loss did not improve from 1.34413
# 29601/29601 [==============================] - 545s 18ms/sample - loss: 1.3131 - val_loss: 1.3739
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3125
# Epoch 27: val_loss did not improve from 1.34413
# 29601/29601 [==============================] - 553s 19ms/sample - loss: 1.3125 - val_loss: 1.3520
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3073
# Epoch 28: val_loss did not improve from 1.34413
# 29601/29601 [==============================] - 557s 19ms/sample - loss: 1.3073 - val_loss: 1.3501
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3070
# Epoch 29: val_loss did not improve from 1.34413
# 29601/29601 [==============================] - 673s 23ms/sample - loss: 1.3070 - val_loss: 1.3736
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3040
# Epoch 30: val_loss improved from 1.34413 to 1.33731, saving model to ./checkpoints/Baseline_allfeature_model_0.h5
# 29601/29601 [==============================] - 859s 29ms/sample - loss: 1.3040 - val_loss: 1.3373
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3014
# Epoch 31: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 862s 29ms/sample - loss: 1.3014 - val_loss: 1.3525
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2981
# Epoch 32: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 862s 29ms/sample - loss: 1.2981 - val_loss: 1.3440
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2956
# Epoch 33: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 862s 29ms/sample - loss: 1.2956 - val_loss: 1.3376
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2941
# Epoch 34: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 858s 29ms/sample - loss: 1.2941 - val_loss: 1.3490
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2885
# Epoch 35: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 854s 29ms/sample - loss: 1.2885 - val_loss: 1.3564
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2881
# Epoch 36: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 858s 29ms/sample - loss: 1.2881 - val_loss: 1.3597
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2882
# Epoch 37: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 854s 29ms/sample - loss: 1.2882 - val_loss: 1.3395
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2841
# Epoch 38: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 860s 29ms/sample - loss: 1.2841 - val_loss: 1.3439
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2827
# Epoch 39: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 878s 30ms/sample - loss: 1.2827 - val_loss: 1.3473
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2764
# Epoch 40: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 889s 30ms/sample - loss: 1.2764 - val_loss: 1.3404
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2763
# Epoch 41: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 904s 31ms/sample - loss: 1.2763 - val_loss: 1.3410
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2766
# Epoch 42: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 867s 29ms/sample - loss: 1.2766 - val_loss: 1.3424
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2727
# Epoch 43: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 854s 29ms/sample - loss: 1.2727 - val_loss: 1.3512
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2728
# Epoch 44: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 849s 29ms/sample - loss: 1.2728 - val_loss: 1.3475
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2638
# Epoch 45: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 913s 31ms/sample - loss: 1.2638 - val_loss: 1.3449
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2633
# Epoch 46: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 913s 31ms/sample - loss: 1.2633 - val_loss: 1.3382
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2638
# Epoch 47: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 872s 29ms/sample - loss: 1.2638 - val_loss: 1.3497
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2615
# Epoch 48: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 870s 29ms/sample - loss: 1.2615 - val_loss: 1.3446
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2635
# Epoch 49: val_loss did not improve from 1.33731
# 29601/29601 [==============================] - 847s 29ms/sample - loss: 1.2635 - val_loss: 1.3388
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2597
# Epoch 50: val_loss improved from 1.33731 to 1.33318, saving model to ./checkpoints/Baseline_allfeature_model_0.h5
# 29601/29601 [==============================] - 849s 29ms/sample - loss: 1.2597 - val_loss: 1.3332
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2570
# Epoch 51: val_loss improved from 1.33318 to 1.33200, saving model to ./checkpoints/Baseline_allfeature_model_0.h5
# 29601/29601 [==============================] - 845s 29ms/sample - loss: 1.2570 - val_loss: 1.3320
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2568
# Epoch 52: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 847s 29ms/sample - loss: 1.2568 - val_loss: 1.3473
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2550
# Epoch 53: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 849s 29ms/sample - loss: 1.2550 - val_loss: 1.3656
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2530
# Epoch 54: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 848s 29ms/sample - loss: 1.2530 - val_loss: 1.3369
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2497
# Epoch 55: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 858s 29ms/sample - loss: 1.2497 - val_loss: 1.3494
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2509
# Epoch 56: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 786s 27ms/sample - loss: 1.2509 - val_loss: 1.3338
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2490
# Epoch 57: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 549s 19ms/sample - loss: 1.2490 - val_loss: 1.3542
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2451
# Epoch 58: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 539s 18ms/sample - loss: 1.2451 - val_loss: 1.3471
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2479
# Epoch 59: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 535s 18ms/sample - loss: 1.2479 - val_loss: 1.3484
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2408
# Epoch 60: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 527s 18ms/sample - loss: 1.2408 - val_loss: 1.3338
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2421
# Epoch 61: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 541s 18ms/sample - loss: 1.2421 - val_loss: 1.3540
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2437
# Epoch 62: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 552s 19ms/sample - loss: 1.2437 - val_loss: 1.3431
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2386
# Epoch 63: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 559s 19ms/sample - loss: 1.2386 - val_loss: 1.3477
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2366
# Epoch 64: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 542s 18ms/sample - loss: 1.2366 - val_loss: 1.3562
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2397
# Epoch 65: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 550s 19ms/sample - loss: 1.2397 - val_loss: 1.3494
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2329
# Epoch 66: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 563s 19ms/sample - loss: 1.2329 - val_loss: 1.3496
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2315
# Epoch 67: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 546s 18ms/sample - loss: 1.2315 - val_loss: 1.3491
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2307
# Epoch 68: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 568s 19ms/sample - loss: 1.2307 - val_loss: 1.3438
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2312
# Epoch 69: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 557s 19ms/sample - loss: 1.2312 - val_loss: 1.3529
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2299
# Epoch 70: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 540s 18ms/sample - loss: 1.2299 - val_loss: 1.3519
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2291
# Epoch 71: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 538s 18ms/sample - loss: 1.2291 - val_loss: 1.3498
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2293
# Epoch 72: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 555s 19ms/sample - loss: 1.2293 - val_loss: 1.3451
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2283
# Epoch 73: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 538s 18ms/sample - loss: 1.2283 - val_loss: 1.3573
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2268
# Epoch 74: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 555s 19ms/sample - loss: 1.2268 - val_loss: 1.3336
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2252
# Epoch 75: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 534s 18ms/sample - loss: 1.2252 - val_loss: 1.3457
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2249
# Epoch 76: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 529s 18ms/sample - loss: 1.2249 - val_loss: 1.3484
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2165
# Epoch 77: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 541s 18ms/sample - loss: 1.2165 - val_loss: 1.3623
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2199
# Epoch 78: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 521s 18ms/sample - loss: 1.2199 - val_loss: 1.3496
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2192
# Epoch 79: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 539s 18ms/sample - loss: 1.2192 - val_loss: 1.3405
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2180
# Epoch 80: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 554s 19ms/sample - loss: 1.2180 - val_loss: 1.3476
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2200
# Epoch 81: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 552s 19ms/sample - loss: 1.2200 - val_loss: 1.3498
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2154
# Epoch 82: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 552s 19ms/sample - loss: 1.2154 - val_loss: 1.3527
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2178
# Epoch 83: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 561s 19ms/sample - loss: 1.2178 - val_loss: 1.3584
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2160
# Epoch 84: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 560s 19ms/sample - loss: 1.2160 - val_loss: 1.3446
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2115
# Epoch 85: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 546s 18ms/sample - loss: 1.2115 - val_loss: 1.3488
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2109
# Epoch 86: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 562s 19ms/sample - loss: 1.2109 - val_loss: 1.3543
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2120
# Epoch 87: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 537s 18ms/sample - loss: 1.2120 - val_loss: 1.3520
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2096
# Epoch 88: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 521s 18ms/sample - loss: 1.2096 - val_loss: 1.3569
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2095
# Epoch 89: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 533s 18ms/sample - loss: 1.2095 - val_loss: 1.3524
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2105
# Epoch 90: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 543s 18ms/sample - loss: 1.2105 - val_loss: 1.3493
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2093
# Epoch 91: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 537s 18ms/sample - loss: 1.2093 - val_loss: 1.3474
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2082
# Epoch 92: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 532s 18ms/sample - loss: 1.2082 - val_loss: 1.3510
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2083
# Epoch 93: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 532s 18ms/sample - loss: 1.2083 - val_loss: 1.3624
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2049
# Epoch 94: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 555s 19ms/sample - loss: 1.2049 - val_loss: 1.3611
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2079
# Epoch 95: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 552s 19ms/sample - loss: 1.2079 - val_loss: 1.3508
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2016
# Epoch 96: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 533s 18ms/sample - loss: 1.2016 - val_loss: 1.3499
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2012
# Epoch 97: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 569s 19ms/sample - loss: 1.2012 - val_loss: 1.3668
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2005
# Epoch 98: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 541s 18ms/sample - loss: 1.2005 - val_loss: 1.3537
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1972
# Epoch 99: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 500s 17ms/sample - loss: 1.1972 - val_loss: 1.3549
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1966
# Epoch 100: val_loss did not improve from 1.33200
# 29601/29601 [==============================] - 501s 17ms/sample - loss: 1.1966 - val_loss: 1.3564

# %%
## Evaluation on test data
import tensorflow as tf
model = tf.keras.models.load_model("./checkpoints/Baseline_allfeature_model_0.h5")
from feature_emotion import feature_extract, split_data, label_unique_tuples
trace_wlk_num = label_unique_tuples(people_nums_all, walk_nums_all, trace_nums_all)
trace_wlk_num = np.array(trace_wlk_num)

y_pred = model.predict(X_test_normalized_new)
print('Test MAE:')
err = np.mean(np.abs(y_pred - y_test))
print(err)
## Evaluation: trace median vote
trace_num_test = trace_wlk_num[test_idx]
u = np.unique(trace_num_test)
pred_trace = np.empty((0, 2))
gt_trace = np.empty((0, 2))
for i in u:
  trace_idx = np.where(trace_num_test == i)[0]
  y_pred_trace = y_pred[trace_idx,:]
  pred = np.mean(y_pred_trace, axis = 0)
  pred_trace = np.vstack((pred_trace, pred))
  gt_t = y_test[trace_idx[0],:]
  gt_trace = np.vstack((gt_trace, gt_t))
print(np.mean(np.abs(pred_trace-gt_trace)))
# Out:
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/ops/init_ops.py:94: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-06 15:53:02.911629: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:02.911849: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:02.912032: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:02.923321: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:02.923566: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:02.923750: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:02.923924: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:02.924089: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:02.924256: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.119596: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.119846: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.120016: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.120181: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.120333: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.120486: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.120639: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.120792: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.120944: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.128719: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.128910: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.129087: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.129257: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.129427: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.129595: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.129796: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.129945: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-06 15:53:03.130276: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.130422: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-06 15:53:03.130791: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:03.130937: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-06 15:53:03.131158: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-06 15:53:05.031554: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.031863: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.032074: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.032314: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.032521: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.032721: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.032917: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.033171: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.033362: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.033623: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.033825: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.034003: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.034179: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.034317: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1325 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-11-06 15:53:05.034375: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.034507: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46608 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-06 15:53:05.034565: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 15:53:05.034699: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46608 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-06 15:53:05.034757: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-06 15:53:05.084260: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-06 15:53:05.176743: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_33/lstm_cell_33/bias/Assign' id:5667 op device:{requested: '', assigned: ''} def:{{{node lstm_33/lstm_cell_33/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_33/lstm_cell_33/bias, lstm_33/lstm_cell_33/bias/Initializer/concat)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-06 15:53:06.143543: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_21/lstm_cell_21/bias/v/Assign' id:7936 op device:{requested: '', assigned: ''} def:{{{node lstm_21/lstm_cell_21/bias/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_21/lstm_cell_21/bias/v, lstm_21/lstm_cell_21/bias/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-11-06 15:53:06.907799: W tensorflow/c/c_api.cc:304] Operation '{name:'dense_3/BiasAdd' id:6369 op device:{requested: '', assigned: ''} def:{{{node dense_3/BiasAdd}} = BiasAdd[T=DT_FLOAT, _has_manual_control_dependencies=true, data_format="NHWC"](dense_3/MatMul, dense_3/BiasAdd/ReadVariableOp)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-06 15:53:07.477736: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-06 15:53:07.709296: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# Test MAE:
# 1.344978088578757
# 1.2513632334165974
