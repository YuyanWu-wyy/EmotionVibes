# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]
# Out:
# 2023-11-06 16:59:54.259164: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.2 when it was built against 1.14.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# WARNING:tensorflow:From /usr/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
def new_label_gen(old_labels):
    new_labels = np.zeros((old_labels.shape[0],))
    
    # Define classes based on conditions
    new_labels[np.logical_and(old_labels[:, 0] <= 5, old_labels[:, 1] < 5)] = 0
    new_labels[np.logical_and(old_labels[:, 0] > 5, old_labels[:, 1] < 5)] = 1
    new_labels[np.logical_and(old_labels[:, 0] <= 5, old_labels[:, 1] >= 5)] = 2
    new_labels[np.logical_and(old_labels[:, 0] > 5, old_labels[:, 1] >= 5)] = 3
    
    # If you need one-hot encoded labels for the classification output
    one_hot_new_labels = np.eye(4)[new_labels.astype(int)]
    return one_hot_new_labels
y_train_class = new_label_gen(y_train)
y_val_class = new_label_gen(y_val)
y_test_class = new_label_gen(y_test)

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer_classification = Dense(4, activation='softmax', name='classification_output')(h)
    model = Model(inputs=input_layers, outputs=output_layer_classification)
    
    # compile the model with categorical_crossentropy loss function
    model.compile(optimizer='adam', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    return model

# %%
from sklearn.utils import class_weight
# Compute class weights
y_labels = np.argmax(y_train_class, axis=1)
class_weights = class_weight.compute_class_weight(class_weight ='balanced', classes =np.unique(y_labels), y=y_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
# model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Adaptive_prune_model_classify_nobalance_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_acc', mode='max', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(x=X_train_normalized_new, y=y_train_class, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val_class), callbacks=[pruning_callback, checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-06 17:00:28.110942: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:28.122202: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:28.122443: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:28.127417: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:28.127605: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:28.127771: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:28.192096: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:28.192296: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:28.192459: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:28.192632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1033 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-06 17:00:28.193028: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-06 17:00:29.115101: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:29.115330: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:29.115502: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:29.115702: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:29.115870: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:00:29.116069: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1033 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:41:00.0, compute capability: 8.6
# 2023-11-06 17:00:29.116103: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-06 17:00:29.138683: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-06 17:00:29.189013: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_20/lstm_cell_20/bias/Assign' id:3345 op device:{requested: '', assigned: ''} def:{{{node lstm_20/lstm_cell_20/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_20/lstm_cell_20/bias, lstm_20/lstm_cell_20/bias/Initializer/concat)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-06 17:00:29.319634: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:3634 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-06 17:00:29.352800: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:3635 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 95)
# Train on 29601 samples, validate on 3694 samples
# 2023-11-06 17:00:33.702790: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/conv2d/kernel/v/Assign' id:17013 op device:{requested: '', assigned: ''} def:{{{node training/Adam/conv2d/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/conv2d/kernel/v, training/Adam/conv2d/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-11-06 17:00:37.601288: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-06 17:00:39.736037: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-11-06 17:00:49.810623: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 957.00MiB (rounded to 1003487232)requested by op conv2d/Relu
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-11-06 17:00:49.810975: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2023-11-06 17:00:49.810997: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 323, Chunks in use: 322. 80.8KiB allocated for chunks. 80.5KiB in use in bin. 27.5KiB client-requested in use in bin.
# 2023-11-06 17:00:49.811012: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 4, Chunks in use: 4. 2.0KiB allocated for chunks. 2.0KiB in use in bin. 2.0KiB client-requested in use in bin.
# 2023-11-06 17:00:49.811026: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 3, Chunks in use: 3. 3.8KiB allocated for chunks. 3.8KiB in use in bin. 3.3KiB client-requested in use in bin.
# 2023-11-06 17:00:49.811039: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-06 17:00:49.811052: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 3019, Chunks in use: 3019. 11.85MiB allocated for chunks. 11.85MiB in use in bin. 11.79MiB client-requested in use in bin.
# 2023-11-06 17:00:49.811065: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 3, Chunks in use: 3. 24.0KiB allocated for chunks. 24.0KiB in use in bin. 24.0KiB client-requested in use in bin.
# 2023-11-06 17:00:49.811077: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 21176, Chunks in use: 21175. 331.03MiB allocated for chunks. 331.02MiB in use in bin. 330.87MiB client-requested in use in bin.
# 2023-11-06 17:00:49.811089: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 2, Chunks in use: 2. 105.5KiB allocated for chunks. 105.5KiB in use in bin. 105.5KiB client-requested in use in bin.
# 2023-11-06 17:00:49.811099: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-06 17:00:49.811111: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 1, Chunks in use: 1. 188.0KiB allocated for chunks. 188.0KiB in use in bin. 188.0KiB client-requested in use in bin.
# 2023-11-06 17:00:49.811122: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 2, Chunks in use: 2. 876.0KiB allocated for chunks. 876.0KiB in use in bin. 876.0KiB client-requested in use in bin.
# 2023-11-06 17:00:49.811134: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 23, Chunks in use: 23. 11.86MiB allocated for chunks. 11.86MiB in use in bin. 11.86MiB client-requested in use in bin.
# 2023-11-06 17:00:49.811148: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 2, Chunks in use: 2. 2.97MiB allocated for chunks. 2.97MiB in use in bin. 2.97MiB client-requested in use in bin.
# 2023-11-06 17:00:49.811160: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 10, Chunks in use: 10. 26.38MiB allocated for chunks. 26.38MiB in use in bin. 26.38MiB client-requested in use in bin.
# 2023-11-06 17:00:49.811172: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 1, Chunks in use: 1. 5.48MiB allocated for chunks. 5.48MiB in use in bin. 5.48MiB client-requested in use in bin.
# 2023-11-06 17:00:49.811182: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-06 17:00:49.811193: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 31.62MiB allocated for chunks. 31.62MiB in use in bin. 31.62MiB client-requested in use in bin.
# 2023-11-06 17:00:49.811204: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-06 17:00:49.811214: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-06 17:00:49.811224: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-06 17:00:49.811234: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 1, Chunks in use: 0. 611.42MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-06 17:00:49.811246: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 957.00MiB was 256.00MiB, Chunk State:
# 2023-11-06 17:00:49.811264: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 611.42MiB | Requested Size: 264B | in_use: 0 | bin_num: 20, prev:   Size: 528.0KiB | Requested Size: 528.0KiB | in_use: 1 | bin_num: -1
# 2023-11-06 17:00:49.811278: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 1084096512
# 2023-11-06 17:00:49.811292: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da000000 of size 1280 next 1
# 2023-11-06 17:00:49.811304: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da000500 of size 256 next 2
# 2023-11-06 17:00:49.811317: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da000600 of size 256 next 3
# 2023-11-06 17:00:49.811328: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da000700 of size 256 next 4
# 2023-11-06 17:00:49.811340: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da000800 of size 256 next 5
# 2023-11-06 17:00:49.811351: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da000900 of size 256 next 6
# 2023-11-06 17:00:49.811361: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da000a00 of size 256 next 7
# 2023-11-06 17:00:49.811374: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da000b00 of size 256 next 8
# 2023-11-06 17:00:49.811387: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da000c00 of size 256 next 9
# 2023-11-06 17:00:49.811400: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da000d00 of size 256 next 10
# 2023-11-06 17:00:49.811411: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da000e00 of size 256 next 11
# 2023-11-06 17:00:49.811424: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da000f00 of size 256 next 12
# 2023-11-06 17:00:49.811435: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001000 of size 256 next 13
# 2023-11-06 17:00:49.811447: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001100 of size 256 next 14
# 2023-11-06 17:00:49.811458: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001200 of size 256 next 15
# 2023-11-06 17:00:49.811470: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001300 of size 256 next 16
# 2023-11-06 17:00:49.811483: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001400 of size 256 next 17
# 2023-11-06 17:00:49.811497: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001500 of size 256 next 18
# 2023-11-06 17:00:49.811510: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001600 of size 256 next 19
# 2023-11-06 17:00:49.811524: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001700 of size 256 next 20
# 2023-11-06 17:00:49.811535: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001800 of size 256 next 21
# 2023-11-06 17:00:49.811549: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001900 of size 256 next 22
# 2023-11-06 17:00:49.811561: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001a00 of size 256 next 23
# 2023-11-06 17:00:49.811573: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001b00 of size 256 next 24
# 2023-11-06 17:00:49.811588: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001c00 of size 256 next 25
# 2023-11-06 17:00:49.811599: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001d00 of size 256 next 26
# 2023-11-06 17:00:49.811613: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001e00 of size 256 next 27
# 2023-11-06 17:00:49.811627: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da001f00 of size 256 next 28
# 2023-11-06 17:00:49.811641: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002000 of size 256 next 29
# 2023-11-06 17:00:49.811654: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002100 of size 256 next 30
# 2023-11-06 17:00:49.811668: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002200 of size 256 next 31
# 2023-11-06 17:00:49.811681: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002300 of size 256 next 32
# 2023-11-06 17:00:49.811695: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002400 of size 256 next 33
# 2023-11-06 17:00:49.811708: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002500 of size 256 next 34
# 2023-11-06 17:00:49.811719: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002600 of size 256 next 35
# 2023-11-06 17:00:49.811733: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002700 of size 256 next 36
# 2023-11-06 17:00:49.811745: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002800 of size 256 next 42
# 2023-11-06 17:00:49.811758: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002900 of size 256 next 41
# 2023-11-06 17:00:49.811771: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002a00 of size 256 next 68
# 2023-11-06 17:00:49.811783: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002b00 of size 256 next 69
# 2023-11-06 17:00:49.811795: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002c00 of size 256 next 40
# 2023-11-06 17:00:49.811807: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002d00 of size 256 next 39
# 2023-11-06 17:00:49.811818: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002e00 of size 256 next 43
# 2023-11-06 17:00:49.811831: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da002f00 of size 256 next 44
# 2023-11-06 17:00:49.811842: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003000 of size 256 next 45
# 2023-11-06 17:00:49.811855: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003100 of size 256 next 46
# 2023-11-06 17:00:49.811868: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003200 of size 256 next 49
# 2023-11-06 17:00:49.811879: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003300 of size 256 next 48
# 2023-11-06 17:00:49.811891: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003400 of size 256 next 47
# 2023-11-06 17:00:49.811904: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003500 of size 256 next 50
# 2023-11-06 17:00:49.811917: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003600 of size 256 next 51
# 2023-11-06 17:00:49.811929: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003700 of size 256 next 52
# 2023-11-06 17:00:49.811942: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003800 of size 256 next 53
# 2023-11-06 17:00:49.811955: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003900 of size 256 next 54
# 2023-11-06 17:00:49.811967: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003a00 of size 256 next 55
# 2023-11-06 17:00:49.811980: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003b00 of size 256 next 56
# 2023-11-06 17:00:49.811991: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003c00 of size 256 next 57
# 2023-11-06 17:00:49.812003: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003d00 of size 256 next 58
# 2023-11-06 17:00:49.812016: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003e00 of size 256 next 59
# 2023-11-06 17:00:49.812027: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da003f00 of size 256 next 60
# 2023-11-06 17:00:49.812040: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004000 of size 256 next 61
# 2023-11-06 17:00:49.812052: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004100 of size 256 next 62
# 2023-11-06 17:00:49.812064: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004200 of size 256 next 63
# 2023-11-06 17:00:49.812076: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004300 of size 256 next 64
# 2023-11-06 17:00:49.812087: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004400 of size 256 next 65
# 2023-11-06 17:00:49.812100: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004500 of size 256 next 66
# 2023-11-06 17:00:49.812110: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004600 of size 256 next 67
# 2023-11-06 17:00:49.812123: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004700 of size 256 next 76
# 2023-11-06 17:00:49.812135: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004800 of size 256 next 79
# 2023-11-06 17:00:49.812147: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004900 of size 256 next 80
# 2023-11-06 17:00:49.812160: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004a00 of size 256 next 78
# 2023-11-06 17:00:49.812171: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004b00 of size 256 next 77
# 2023-11-06 17:00:49.812184: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004c00 of size 256 next 75
# 2023-11-06 17:00:49.812197: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004d00 of size 256 next 74
# 2023-11-06 17:00:49.812210: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004e00 of size 256 next 73
# 2023-11-06 17:00:49.812221: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da004f00 of size 256 next 83
# 2023-11-06 17:00:49.812233: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005000 of size 256 next 72
# 2023-11-06 17:00:49.812245: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005100 of size 256 next 37
# 2023-11-06 17:00:49.812257: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005200 of size 256 next 70
# 2023-11-06 17:00:49.812269: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005300 of size 256 next 84
# 2023-11-06 17:00:49.812282: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005400 of size 256 next 81
# 2023-11-06 17:00:49.812293: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005500 of size 256 next 82
# 2023-11-06 17:00:49.812306: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005600 of size 256 next 38
# 2023-11-06 17:00:49.812318: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005700 of size 256 next 85
# 2023-11-06 17:00:49.812331: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005800 of size 256 next 71
# 2023-11-06 17:00:49.812342: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005900 of size 256 next 86
# 2023-11-06 17:00:49.812354: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005a00 of size 256 next 87
# 2023-11-06 17:00:49.812367: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005b00 of size 256 next 88
# 2023-11-06 17:00:49.812380: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005c00 of size 256 next 89
# 2023-11-06 17:00:49.812393: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005d00 of size 256 next 90
# 2023-11-06 17:00:49.812406: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005e00 of size 256 next 91
# 2023-11-06 17:00:49.812417: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da005f00 of size 256 next 92
# 2023-11-06 17:00:49.812428: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006000 of size 256 next 93
# 2023-11-06 17:00:49.812440: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006100 of size 256 next 94
# 2023-11-06 17:00:49.812453: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006200 of size 256 next 95
# 2023-11-06 17:00:49.812466: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006300 of size 256 next 96
# 2023-11-06 17:00:49.812478: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006400 of size 256 next 97
# 2023-11-06 17:00:49.812491: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006500 of size 256 next 98
# 2023-11-06 17:00:49.812503: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006600 of size 256 next 99
# 2023-11-06 17:00:49.812514: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006700 of size 256 next 100
# 2023-11-06 17:00:49.812527: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006800 of size 256 next 101
# 2023-11-06 17:00:49.812540: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006900 of size 256 next 102
# 2023-11-06 17:00:49.812552: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006a00 of size 256 next 103
# 2023-11-06 17:00:49.812564: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006b00 of size 256 next 104
# 2023-11-06 17:00:49.812639: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006c00 of size 256 next 105
# 2023-11-06 17:00:49.812670: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006d00 of size 256 next 106
# 2023-11-06 17:00:49.812683: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da006e00 of size 512 next 107
# 2023-11-06 17:00:49.812696: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da007000 of size 256 next 108
# 2023-11-06 17:00:49.812708: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da007100 of size 1280 next 109
# 2023-11-06 17:00:49.812722: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da007600 of size 256 next 110
# 2023-11-06 17:00:49.812735: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da007700 of size 18432 next 111
# 2023-11-06 17:00:49.812747: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da00bf00 of size 256 next 112
# 2023-11-06 17:00:49.812759: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da00c000 of size 512 next 113
# 2023-11-06 17:00:49.812770: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da00c200 of size 256 next 114
# 2023-11-06 17:00:49.812783: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da00c300 of size 256 next 115
# 2023-11-06 17:00:49.812796: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da00c400 of size 256 next 116
# 2023-11-06 17:00:49.812808: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da00c500 of size 256 next 117
# 2023-11-06 17:00:49.812820: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da00c600 of size 17920 next 118
# 2023-11-06 17:00:49.812833: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da010c00 of size 256 next 119
# 2023-11-06 17:00:49.812844: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da010d00 of size 54016 next 120
# 2023-11-06 17:00:49.812856: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da01e000 of size 256 next 121
# 2023-11-06 17:00:49.812869: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da01e100 of size 8192 next 122
# 2023-11-06 17:00:49.812880: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020100 of size 256 next 123
# 2023-11-06 17:00:49.812891: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020200 of size 256 next 124
# 2023-11-06 17:00:49.812903: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020300 of size 256 next 125
# 2023-11-06 17:00:49.812916: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020400 of size 256 next 126
# 2023-11-06 17:00:49.812928: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020500 of size 256 next 127
# 2023-11-06 17:00:49.812940: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020600 of size 256 next 128
# 2023-11-06 17:00:49.812951: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020700 of size 256 next 129
# 2023-11-06 17:00:49.812963: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020800 of size 256 next 130
# 2023-11-06 17:00:49.812975: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020900 of size 256 next 131
# 2023-11-06 17:00:49.812987: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020a00 of size 256 next 132
# 2023-11-06 17:00:49.813000: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020b00 of size 256 next 133
# 2023-11-06 17:00:49.813012: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020c00 of size 256 next 134
# 2023-11-06 17:00:49.813023: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020d00 of size 256 next 135
# 2023-11-06 17:00:49.813036: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020e00 of size 256 next 136
# 2023-11-06 17:00:49.813049: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da020f00 of size 256 next 137
# 2023-11-06 17:00:49.813061: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021000 of size 256 next 138
# 2023-11-06 17:00:49.813074: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021100 of size 256 next 139
# 2023-11-06 17:00:49.813084: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021200 of size 256 next 140
# 2023-11-06 17:00:49.813096: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021300 of size 256 next 141
# 2023-11-06 17:00:49.813108: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021400 of size 256 next 142
# 2023-11-06 17:00:49.813120: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021500 of size 256 next 143
# 2023-11-06 17:00:49.813133: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021600 of size 256 next 144
# 2023-11-06 17:00:49.813145: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021700 of size 256 next 145
# 2023-11-06 17:00:49.813156: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021800 of size 256 next 146
# 2023-11-06 17:00:49.813169: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021900 of size 256 next 147
# 2023-11-06 17:00:49.813182: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021a00 of size 256 next 148
# 2023-11-06 17:00:49.813195: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021b00 of size 256 next 149
# 2023-11-06 17:00:49.813208: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021c00 of size 256 next 150
# 2023-11-06 17:00:49.813218: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021d00 of size 256 next 151
# 2023-11-06 17:00:49.813229: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021e00 of size 256 next 152
# 2023-11-06 17:00:49.813239: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da021f00 of size 256 next 153
# 2023-11-06 17:00:49.813252: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022000 of size 256 next 154
# 2023-11-06 17:00:49.813263: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022100 of size 256 next 155
# 2023-11-06 17:00:49.813274: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022200 of size 256 next 156
# 2023-11-06 17:00:49.813286: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022300 of size 256 next 157
# 2023-11-06 17:00:49.813298: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022400 of size 256 next 158
# 2023-11-06 17:00:49.813310: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022500 of size 256 next 159
# 2023-11-06 17:00:49.813323: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022600 of size 256 next 160
# 2023-11-06 17:00:49.813336: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022700 of size 256 next 161
# 2023-11-06 17:00:49.813346: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022800 of size 256 next 162
# 2023-11-06 17:00:49.813357: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022900 of size 256 next 163
# 2023-11-06 17:00:49.813370: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022a00 of size 256 next 164
# 2023-11-06 17:00:49.813382: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022b00 of size 256 next 165
# 2023-11-06 17:00:49.813393: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022c00 of size 256 next 166
# 2023-11-06 17:00:49.813405: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022d00 of size 256 next 167
# 2023-11-06 17:00:49.813416: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022e00 of size 256 next 168
# 2023-11-06 17:00:49.813429: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da022f00 of size 256 next 169
# 2023-11-06 17:00:49.813442: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023000 of size 256 next 170
# 2023-11-06 17:00:49.813453: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023100 of size 256 next 171
# 2023-11-06 17:00:49.813466: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023200 of size 256 next 172
# 2023-11-06 17:00:49.813477: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023300 of size 256 next 173
# 2023-11-06 17:00:49.813490: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023400 of size 256 next 174
# 2023-11-06 17:00:49.813503: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023500 of size 256 next 175
# 2023-11-06 17:00:49.813515: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023600 of size 256 next 176
# 2023-11-06 17:00:49.813526: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023700 of size 256 next 177
# 2023-11-06 17:00:49.813538: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023800 of size 256 next 178
# 2023-11-06 17:00:49.813549: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023900 of size 256 next 179
# 2023-11-06 17:00:49.813562: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023a00 of size 256 next 180
# 2023-11-06 17:00:49.813574: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023b00 of size 256 next 181
# 2023-11-06 17:00:49.813585: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023c00 of size 256 next 182
# 2023-11-06 17:00:49.813598: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023d00 of size 256 next 183
# 2023-11-06 17:00:49.813609: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023e00 of size 256 next 184
# 2023-11-06 17:00:49.813622: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da023f00 of size 256 next 185
# 2023-11-06 17:00:49.813635: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024000 of size 256 next 186
# 2023-11-06 17:00:49.813646: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024100 of size 256 next 187
# 2023-11-06 17:00:49.813659: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024200 of size 256 next 188
# 2023-11-06 17:00:49.813671: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024300 of size 256 next 189
# 2023-11-06 17:00:49.813684: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024400 of size 256 next 190
# 2023-11-06 17:00:49.813697: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024500 of size 256 next 191
# 2023-11-06 17:00:49.813708: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024600 of size 256 next 192
# 2023-11-06 17:00:49.813721: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024700 of size 256 next 193
# 2023-11-06 17:00:49.813733: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024800 of size 256 next 194
# 2023-11-06 17:00:49.813743: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024900 of size 256 next 195
# 2023-11-06 17:00:49.813755: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024a00 of size 256 next 196
# 2023-11-06 17:00:49.813767: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024b00 of size 256 next 197
# 2023-11-06 17:00:49.813779: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024c00 of size 256 next 198
# 2023-11-06 17:00:49.813791: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024d00 of size 256 next 199
# 2023-11-06 17:00:49.813803: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024e00 of size 256 next 200
# 2023-11-06 17:00:49.813816: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da024f00 of size 256 next 201
# 2023-11-06 17:00:49.813828: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025000 of size 256 next 202
# 2023-11-06 17:00:49.813840: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025100 of size 256 next 203
# 2023-11-06 17:00:49.813853: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025200 of size 256 next 204
# 2023-11-06 17:00:49.813864: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025300 of size 256 next 205
# 2023-11-06 17:00:49.813877: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025400 of size 256 next 206
# 2023-11-06 17:00:49.813889: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025500 of size 256 next 207
# 2023-11-06 17:00:49.813900: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025600 of size 256 next 208
# 2023-11-06 17:00:49.813912: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025700 of size 256 next 209
# 2023-11-06 17:00:49.813924: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025800 of size 256 next 210
# 2023-11-06 17:00:49.813937: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025900 of size 256 next 211
# 2023-11-06 17:00:49.813949: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025a00 of size 256 next 212
# 2023-11-06 17:00:49.813962: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025b00 of size 256 next 213
# 2023-11-06 17:00:49.813972: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025c00 of size 256 next 214
# 2023-11-06 17:00:49.813983: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025d00 of size 256 next 215
# 2023-11-06 17:00:49.813996: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025e00 of size 256 next 216
# 2023-11-06 17:00:49.814008: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da025f00 of size 256 next 217
# 2023-11-06 17:00:49.814019: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026000 of size 256 next 218
# 2023-11-06 17:00:49.814031: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026100 of size 256 next 219
# 2023-11-06 17:00:49.814043: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026200 of size 256 next 220
# 2023-11-06 17:00:49.814056: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026300 of size 256 next 221
# 2023-11-06 17:00:49.814068: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026400 of size 256 next 222
# 2023-11-06 17:00:49.814079: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026500 of size 256 next 223
# 2023-11-06 17:00:49.814092: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026600 of size 256 next 224
# 2023-11-06 17:00:49.814102: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026700 of size 256 next 225
# 2023-11-06 17:00:49.814115: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026800 of size 256 next 226
# 2023-11-06 17:00:49.814128: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026900 of size 256 next 227
# 2023-11-06 17:00:49.814139: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026a00 of size 256 next 228
# 2023-11-06 17:00:49.814152: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026b00 of size 256 next 229
# 2023-11-06 17:00:49.814165: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026c00 of size 256 next 230
# 2023-11-06 17:00:49.814178: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62da026d00 of size 256 next 231
# ...
# 2023-11-06 17:00:50.249445: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebc84900 of size 16384 next 15908
# 2023-11-06 17:00:50.249454: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebc88900 of size 16384 next 15916
# 2023-11-06 17:00:50.249465: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebc8c900 of size 16384 next 15917
# 2023-11-06 17:00:50.249475: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebc90900 of size 16384 next 15918
# 2023-11-06 17:00:50.249487: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebc94900 of size 16384 next 15912
# 2023-11-06 17:00:50.249497: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebc98900 of size 16384 next 15913
# 2023-11-06 17:00:50.249508: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebc9c900 of size 16384 next 15914
# 2023-11-06 17:00:50.249517: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebca0900 of size 16384 next 15915
# 2023-11-06 17:00:50.249529: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebca4900 of size 16384 next 15923
# 2023-11-06 17:00:50.249539: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebca8900 of size 16384 next 15924
# 2023-11-06 17:00:50.249550: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcac900 of size 16384 next 15925
# 2023-11-06 17:00:50.249559: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcb0900 of size 16384 next 15919
# 2023-11-06 17:00:50.249571: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcb4900 of size 16384 next 15920
# 2023-11-06 17:00:50.249581: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcb8900 of size 16384 next 15921
# 2023-11-06 17:00:50.249592: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcbc900 of size 16384 next 15922
# 2023-11-06 17:00:50.249601: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcc0900 of size 16384 next 15930
# 2023-11-06 17:00:50.249613: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcc4900 of size 16384 next 15931
# 2023-11-06 17:00:50.249623: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcc8900 of size 16384 next 15932
# 2023-11-06 17:00:50.249635: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebccc900 of size 16384 next 15926
# 2023-11-06 17:00:50.249644: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcd0900 of size 16384 next 15927
# 2023-11-06 17:00:50.249655: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcd4900 of size 16384 next 15928
# 2023-11-06 17:00:50.249665: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcd8900 of size 16384 next 15929
# 2023-11-06 17:00:50.249677: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcdc900 of size 16384 next 15937
# 2023-11-06 17:00:50.249687: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebce0900 of size 16384 next 15938
# 2023-11-06 17:00:50.249698: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebce4900 of size 16384 next 15939
# 2023-11-06 17:00:50.249707: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebce8900 of size 16384 next 15933
# 2023-11-06 17:00:50.249719: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcec900 of size 16384 next 15934
# 2023-11-06 17:00:50.249728: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcf0900 of size 16384 next 15935
# 2023-11-06 17:00:50.249739: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcf4900 of size 16384 next 15936
# 2023-11-06 17:00:50.249748: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcf8900 of size 16384 next 15944
# 2023-11-06 17:00:50.249760: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebcfc900 of size 16384 next 15945
# 2023-11-06 17:00:50.249770: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd00900 of size 16384 next 15946
# 2023-11-06 17:00:50.249782: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd04900 of size 16384 next 15940
# 2023-11-06 17:00:50.249792: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd08900 of size 16384 next 15941
# 2023-11-06 17:00:50.249803: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd0c900 of size 16384 next 15942
# 2023-11-06 17:00:50.249812: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd10900 of size 16384 next 15943
# 2023-11-06 17:00:50.249824: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd14900 of size 16384 next 15951
# 2023-11-06 17:00:50.249834: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd18900 of size 16384 next 15952
# 2023-11-06 17:00:50.249844: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd1c900 of size 16384 next 15953
# 2023-11-06 17:00:50.249853: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd20900 of size 16384 next 15947
# 2023-11-06 17:00:50.249865: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd24900 of size 16384 next 15948
# 2023-11-06 17:00:50.249875: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd28900 of size 16384 next 15949
# 2023-11-06 17:00:50.249887: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd2c900 of size 16384 next 15950
# 2023-11-06 17:00:50.249896: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd30900 of size 16384 next 15958
# 2023-11-06 17:00:50.249907: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd34900 of size 16384 next 15959
# 2023-11-06 17:00:50.249917: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd38900 of size 16384 next 15960
# 2023-11-06 17:00:50.249928: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd3c900 of size 16384 next 15954
# 2023-11-06 17:00:50.249937: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd40900 of size 16384 next 15955
# 2023-11-06 17:00:50.249948: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd44900 of size 16384 next 15956
# 2023-11-06 17:00:50.249958: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd48900 of size 16384 next 15957
# 2023-11-06 17:00:50.249969: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd4c900 of size 16384 next 15965
# 2023-11-06 17:00:50.249978: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd50900 of size 16384 next 15966
# 2023-11-06 17:00:50.249989: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd54900 of size 16384 next 15967
# 2023-11-06 17:00:50.249999: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd58900 of size 16384 next 15961
# 2023-11-06 17:00:50.250011: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd5c900 of size 16384 next 15962
# 2023-11-06 17:00:50.250020: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd60900 of size 16384 next 15963
# 2023-11-06 17:00:50.250031: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd64900 of size 16384 next 15964
# 2023-11-06 17:00:50.250041: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd68900 of size 16384 next 15972
# 2023-11-06 17:00:50.250053: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd6c900 of size 16384 next 15973
# 2023-11-06 17:00:50.250062: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd70900 of size 16384 next 15974
# 2023-11-06 17:00:50.250073: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd74900 of size 16384 next 15968
# 2023-11-06 17:00:50.250083: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd78900 of size 16384 next 15969
# 2023-11-06 17:00:50.250094: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd7c900 of size 16384 next 15970
# 2023-11-06 17:00:50.250103: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd80900 of size 16384 next 15971
# 2023-11-06 17:00:50.250114: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd84900 of size 16384 next 15979
# 2023-11-06 17:00:50.250125: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd88900 of size 16384 next 15980
# 2023-11-06 17:00:50.250136: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd8c900 of size 16384 next 15981
# 2023-11-06 17:00:50.250145: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd90900 of size 16384 next 15975
# 2023-11-06 17:00:50.250156: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd94900 of size 16384 next 15976
# 2023-11-06 17:00:50.250167: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd98900 of size 16384 next 15977
# 2023-11-06 17:00:50.250178: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebd9c900 of size 16384 next 15978
# 2023-11-06 17:00:50.250187: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebda0900 of size 16384 next 15986
# 2023-11-06 17:00:50.250198: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebda4900 of size 16384 next 15987
# 2023-11-06 17:00:50.250208: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebda8900 of size 16384 next 15988
# 2023-11-06 17:00:50.250219: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebdac900 of size 16384 next 15982
# 2023-11-06 17:00:50.250228: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebdb0900 of size 16384 next 15983
# 2023-11-06 17:00:50.250239: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebdb4900 of size 16384 next 15984
# 2023-11-06 17:00:50.250250: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f62ebdb8900 of size 16384 next 15985
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[7], line 100
#      98 checkpoint = ModelCheckpoint(model_name, monitor='val_acc', mode='max', save_best_only=True, verbose=1)
#      99 pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
# --> 100 model.fit(x=X_train_normalized_new, y=y_train_class, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val_class), callbacks=[pruning_callback, checkpoint])
#
# File /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:856, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     853 self._check_call_args("fit")
#     855 func = self._select_training_loop(x)
# --> 856 return func.fit(
#     857     self,
#     858     x=x,
#     859     y=y,
#     860     batch_size=batch_size,
#     861     epochs=epochs,
#     862     verbose=verbose,
#     863     callbacks=callbacks,
#     864     validation_split=validation_split,
#     865     validation_data=validation_data,
#     866     shuffle=shuffle,
#     867     class_weight=class_weight,
#     868     sample_weight=sample_weight,
#     869     initial_epoch=initial_epoch,
#     870     steps_per_epoch=steps_per_epoch,
#     871     validation_steps=validation_steps,
#     872     validation_freq=validation_freq,
#     873     max_queue_size=max_queue_size,
#     874     workers=workers,
#     875     use_multiprocessing=use_multiprocessing,
#     876 )
#
# File /usr/lib/python3.11/site-packages/keras/engine/training_arrays_v1.py:734, in ArrayLikeTrainingLoop.fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     728         raise ValueError(
#     729             "`validation_steps` should not be specified if "
#     730             "`validation_data` is None."
#     731         )
#     732     val_x, val_y, val_sample_weights = None, None, None
# --> 734 return fit_loop(
#     735     model,
#     736     inputs=x,
#     737     targets=y,
#     738     sample_weights=sample_weights,
#     739     batch_size=batch_size,
#     740     epochs=epochs,
#     741     verbose=verbose,
#     742     callbacks=callbacks,
#     743     val_inputs=val_x,
#     744     val_targets=val_y,
#     745     val_sample_weights=val_sample_weights,
#     746     shuffle=shuffle,
#     747     initial_epoch=initial_epoch,
#     748     steps_per_epoch=steps_per_epoch,
#     749     validation_steps=validation_steps,
#     750     validation_freq=validation_freq,
#     751     steps_name="steps_per_epoch",
#     752 )
#
# File /usr/lib/python3.11/site-packages/keras/engine/training_arrays_v1.py:421, in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     416 callbacks._call_batch_hook(
#     417     mode, "begin", batch_index, batch_logs
#     418 )
#     420 # Get outputs.
# --> 421 batch_outs = f(ins_batch)
#     422 if not isinstance(batch_outs, list):
#     423     batch_outs = [batch_outs]
#
# File /usr/lib/python3.11/site-packages/keras/backend.py:4608, in GraphExecutionFunction.__call__(self, inputs)
#    4598 if (
#    4599     self._callable_fn is None
#    4600     or feed_arrays != self._feed_arrays
#    (...)
#    4604     or session != self._session
#    4605 ):
#    4606     self._make_callable(feed_arrays, feed_symbols, symbol_vals, session)
# -> 4608 fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    4609 self._call_fetch_callbacks(fetched[-len(self._fetches) :])
#    4610 output_structure = tf.nest.pack_sequence_as(
#    4611     self._outputs_structure,
#    4612     fetched[: len(self.outputs)],
#    4613     expand_composites=True,
#    4614 )
#
# File /usr/lib/python3.11/site-packages/tensorflow/python/client/session.py:1482, in BaseSession._Callable.__call__(self, *args, **kwargs)
#    1480 try:
#    1481   run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
# -> 1482   ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1483                                          self._handle, args,
#    1484                                          run_metadata_ptr)
#    1485   if run_metadata:
#    1486     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1024,44,174,32] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node conv2d/Relu}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[loss/mul/_1355]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
#   (1) RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1024,44,174,32] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node conv2d/Relu}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 0 successful operations.
# 0 derived errors ignored.
