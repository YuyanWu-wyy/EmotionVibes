# %%
## The Baseline Method only use simple gait parameter feature, it only includes 2 dense layers
import scipy.io
import numpy as np
import random

## We delete people's data with low feedback score and remove people who kicked off the sensors during walking'
## So 20 people in total.
person_nums = [1,2,4,5,6,8,9,10,11,12,13,17,19,21,22,25,26,27,28,29]

from feature_emotion import feature_extract, split_data, label_unique_tuples
gts, sensor_nums, walk_nums, trace_nums, people_nums, spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features = feature_extract(person_nums)

walk_nums_all = np.squeeze(walk_nums)
trace_nums_all = np.squeeze(trace_nums)
people_nums_all = np.squeeze(people_nums)

## 0: train, 1: validation 2: test
flag_tr_val_te = split_data(walk_nums_all, trace_nums_all, people_nums_all)

# %%
## Data Normalization before training ans testing
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, LSTM
from sklearn.preprocessing import StandardScaler
scalers = []
X_train_normalized = []
X_val_normalized = []
X_test_normalized = []
train_idx = np.where(flag_tr_val_te ==0)[0]
np.random.shuffle(train_idx)
val_idx = np.where(flag_tr_val_te ==1)[0]
test_idx = np.where(flag_tr_val_te ==2)[0]

for i, feature in enumerate([spe_centr, delta_spe_centr, spe_crest, delta_spe_crest, spe_decrease, delta_spe_decrease, spe_entropy, delta_spe_entropy, spe_flatness, delta_spe_flatness, spe_flux, delta_spe_flux, spe_kurtosis, delta_spe_kurtosis, spe_skewness, delta_spe_skewness, spe_rfp, delta_spe_rfp, spe_slope, delta_spe_slope, spe_spread, delta_spe_spread, wlk_fre, wlk_fres_trace, cwt_figs_all, cwt_sum_all_0, cwt_sum_all_1, cwt_sum_all_2, cwt_sum_all_3, high_fre_compos, pitchs, low_fre_compos, auto_corrs, real_hils, imag_hils, dur_time_1_alls, dur_time_2_alls, jitters, shimmers, jitter_rap, hrs, feature, slope, zcrs, fft_features, energy_alls, log_energy_alls, smoothe_energy_alls, legendres, double_support_time, pdps_new, lpcs, ceps_features]):
    scaler = StandardScaler()
    if len(feature.shape)==2:
        X_train_i = feature[train_idx,:]
        X_val_i = feature[val_idx,:]
        X_test_i = feature[test_idx,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i)
        X_val_normalized_i = scaler.transform(X_val_i)
        X_test_normalized_i = scaler.transform(X_test_i)
        scalers.append(scaler)
    else:
        X_train_i = feature[train_idx,:,:]
        X_val_i = feature[val_idx,:,:]
        X_test_i = feature[test_idx,:,:]
        X_train_normalized_i = scaler.fit_transform(X_train_i.reshape(X_train_i.shape[0], -1)).reshape(X_train_i.shape)
        X_val_normalized_i = scaler.transform(X_val_i.reshape(X_val_i.shape[0], -1)).reshape(X_val_i.shape)
        X_test_normalized_i = scaler.transform(X_test_i.reshape(X_test_i.shape[0], -1)).reshape(X_test_i.shape)
        scalers.append(scaler)
    X_train_normalized.append(X_train_normalized_i)
    X_val_normalized.append(X_val_normalized_i)
    X_test_normalized.append(X_test_normalized_i)
y_train = gts[train_idx,:]
y_val = gts[val_idx,:]
y_test = gts[test_idx,:]

# %%
def new_label_gen(old_labels):
    new_labels = np.zeros((old_labels.shape[0],))
    
    # Define classes based on conditions
    new_labels[np.logical_and(old_labels[:, 0] <= 5, old_labels[:, 1] < 5)] = 0
    new_labels[np.logical_and(old_labels[:, 0] > 5, old_labels[:, 1] < 5)] = 1
    new_labels[np.logical_and(old_labels[:, 0] <= 5, old_labels[:, 1] >= 5)] = 2
    new_labels[np.logical_and(old_labels[:, 0] > 5, old_labels[:, 1] >= 5)] = 3
    
    # If you need one-hot encoded labels for the classification output
    one_hot_new_labels = np.eye(4)[new_labels.astype(int)]
    return one_hot_new_labels
y_train_class = new_label_gen(y_train)
y_val_class = new_label_gen(y_val)
y_test_class = new_label_gen(y_test)

# %%
X_train_normalized_new = []
combined_feature = np.empty((len(X_train_normalized[0]),0))
for feature in X_train_normalized:
    if len(feature.shape) == 3:
        X_train_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_train_normalized_new.append(feature)
X_train_normalized_new.append(combined_feature)

X_val_normalized_new = []
combined_feature = np.empty((len(X_val_normalized[0]),0))
for feature in X_val_normalized:
    if len(feature.shape) == 3:
        X_val_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_val_normalized_new.append(feature)
X_val_normalized_new.append(combined_feature)

X_test_normalized_new = []
combined_feature = np.empty((len(X_test_normalized[0]),0))
for feature in X_test_normalized:
    if len(feature.shape) == 3:
        X_test_normalized_new.append(feature)
    elif feature.shape[1] <20:
        combined_feature = np.hstack((combined_feature, feature))
    else:
        X_test_normalized_new.append(feature)
X_test_normalized_new.append(combined_feature)

# %%
## Build the baseline model for emotion recognition with dropout layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, concatenate, SimpleRNN, LSTM, Conv2D, Flatten, MaxPooling2D, GRU, AveragePooling2D, Dropout, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import StandardScaler
def individual_model(features_list):
    input_layers = []
    hidden_layers = []
    combined_feature = np.empty((len(features_list[0]),0))
    for i, feature in enumerate(features_list):
        
        if len(feature.shape) == 3:
            input_i = Input(shape=(feature.shape[1], feature.shape[2]))
            input_layers.append(input_i)

            hidden_i = input_i[:,:,:,None]
            hidden_i = Conv2D(32, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(16, 3, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((3, 3))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(8, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Conv2D(4, 1, activation='relu')(hidden_i)
            hidden_i = AveragePooling2D((2, 2))(hidden_i)
            hidden_i = Dropout(0.5)(hidden_i)
            hidden_i = Flatten()(hidden_i)

            hidden_layers.append(hidden_i)
        elif feature.shape[1] <20:
            combined_feature = np.hstack((combined_feature, feature))
            
        else:  # For series features
            input_i = Input(shape=(feature.shape[1],))
            input_layers.append(input_i)
            hidden_i = Lambda(lambda x: x[:, :, None])(input_i)  # Add a new dimension
            hidden_i = LSTM(4)(hidden_i)
            hidden_layers.append(hidden_i)
    input_i = Input(shape=(combined_feature.shape[1],))
    input_layers.append(input_i)
    dense_num = np.max((1, int(combined_feature.shape[1]/2)))
    hidden_i = Dense(dense_num, activation='relu')(input_i)
    hidden_layers.append(hidden_i)
    print(combined_feature.shape)
    concat_layer = concatenate(hidden_layers)
    h = Dropout(0.2)(concat_layer)
    h = Dense(64, activation='relu')(h)
    h = Dense(32, activation='relu')(h)
    output_layer_classification = Dense(4, activation='softmax', name='classification_output')(h)
    model = Model(inputs=input_layers, outputs=output_layer_classification)
    
    # compile the model with categorical_crossentropy loss function
    model.compile(optimizer='adam', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    return model

# %%
from sklearn.utils import class_weight
# Compute class weights
y_labels = np.argmax(y_train_class, axis=1)
class_weights = class_weight.compute_class_weight(class_weight ='balanced', classes =np.unique(y_labels), y=y_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

import tensorflow as tf
from tensorflow.keras.callbacks import Callback
import numpy as np

class PruningCallback(tf.keras.callbacks.Callback):
    def __init__(self, initial_pruning_factor=0.1, final_pruning_factor=0.5, start_epoch=0, end_epoch=None, frequency=1):
        super(PruningCallback, self).__init__()
        self.initial_pruning_factor = initial_pruning_factor
        self.final_pruning_factor = final_pruning_factor
        self.start_epoch = start_epoch
        self.end_epoch = end_epoch if end_epoch is not None else np.inf
        self.frequency = frequency
        self.pruned_weights = {}
        self.layer_importance = {}

    def get_pruning_factor(self, epoch):
        if epoch < self.start_epoch:
            return 0
        if epoch > self.end_epoch:
            return self.final_pruning_factor
        return self.initial_pruning_factor + (self.final_pruning_factor - self.initial_pruning_factor) * (epoch - self.start_epoch) / (self.end_epoch - self.start_epoch)

    def on_train_begin(self, logs=None):
        total_weight_magnitude = 0
        for layer in self.model.layers:
            if hasattr(layer, 'get_weights'):
                weights = layer.get_weights()
                layer_norm = sum(np.linalg.norm(w) for w in weights)
                total_weight_magnitude += layer_norm
                self.layer_importance[layer.name] = layer_norm
    
        # Normalize the layer importance values so they sum up to 1
        for layer_name in self.layer_importance:
            self.layer_importance[layer_name] /= total_weight_magnitude
    # def on_train_begin(self, logs=None):
    #     total_weight_magnitude = sum([np.linalg.norm(layer.get_weights()) for layer in self.model.layers if hasattr(layer, 'get_weights')])
    #     for layer in self.model.layers:
    #         if hasattr(layer, 'get_weights'):
    #             self.layer_importance[layer.name] = np.linalg.norm(layer.get_weights()) / total_weight_magnitude

    def get_layer_pruning_factor(self, layer_name, global_pruning_factor):
        if layer_name in self.layer_importance:
            importance = self.layer_importance[layer_name]
            adjusted_pruning_factor = global_pruning_factor * (1 - importance)
            return min(adjusted_pruning_factor, 1)  # Ensure the pruning factor is not greater than 1
        return global_pruning_factor
    def prune_weights(self, layer, global_pruning_factor):
        
        weights = layer.get_weights()
        layer_name = layer.name
        pruning_factor = self.get_layer_pruning_factor(layer_name, global_pruning_factor)

        if layer_name not in self.pruned_weights:
            self.pruned_weights[layer_name] = [np.zeros_like(w, dtype=bool) for w in weights]
        
        for i in range(len(weights)):
            weight = weights[i]
            # print(weight.shape)
            # print(weight.size)
            if weight.ndim > 1:  # Only prune dense or convolutional layers
                unpruned_weights = np.logical_not(self.pruned_weights[layer_name][i])
                num_unpruned = np.sum(unpruned_weights)
                num_pruning = min(num_unpruned, int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i]))
                num_pruning = int(weight.size * pruning_factor) - np.sum(self.pruned_weights[layer_name][i])
                if num_pruning > 0:
                    unpruned_flat_indices = np.flatnonzero(unpruned_weights)
                    abs_unpruned_weights = np.abs(weight[unpruned_weights])
                    pruning_flat_indices = np.argpartition(abs_unpruned_weights, num_pruning)[:num_pruning]
                    
                    indices = np.unravel_index(pruning_flat_indices, weight.shape)
                    self.pruned_weights[layer_name][i][indices] = True

                weights[i] = weights[i]*(~self.pruned_weights[layer_name][i])
                
        layer.set_weights(weights)

    def on_epoch_end(self, epoch, logs=None):
        if (epoch - self.start_epoch) % self.frequency != 0:
            return

        pruning_factor = self.get_pruning_factor(epoch)
        for layer in self.model.layers:
            if isinstance(layer, (tf.keras.layers.Dense, tf.keras.layers.Conv2D)):
                self.prune_weights(layer, pruning_factor)
model = individual_model(X_train_normalized)
# model.compile(loss='mean_absolute_error', optimizer='adam')
num_epochs = 100
rates = [0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
idx = 0
for r in rates:
# Gradually prune weights in dense and convolutional layers from 10% to 50% over the course of training, starting from epoch 0.
    model_name = './checkpoints/Adaptive_prune_model_classify_nobalance_'+str(idx)+'.h5'
    idx = idx+1
    checkpoint = ModelCheckpoint(model_name, monitor='val_acc', mode='max', save_best_only=True, verbose=1)
    pruning_callback = PruningCallback(initial_pruning_factor=0.01, final_pruning_factor=r, start_epoch=5, end_epoch=50, frequency=1)
    model.fit(x=X_train_normalized_new, y=y_train_class, epochs=num_epochs, batch_size=1024, validation_data=(X_val_normalized_new, y_val_class), callbacks=[pruning_callback, checkpoint])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-06 17:04:11.972843: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:11.985539: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:11.985781: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:11.989865: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:11.997471: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:11.998258: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:12.063411: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:12.063616: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:12.063784: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:12.063926: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-06 17:04:12.064158: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2023-11-06 17:04:12.982185: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:12.982420: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:12.982641: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:12.982857: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:12.983028: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-06 17:04:12.983168: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46608 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:2d:00.0, compute capability: 8.6
# 2023-11-06 17:04:12.983199: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2023-11-06 17:04:13.004518: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2023-11-06 17:04:13.283259: W tensorflow/c/c_api.cc:304] Operation '{name:'lstm_21/lstm_cell_21/kernel/Assign' id:3481 op device:{requested: '', assigned: ''} def:{{{node lstm_21/lstm_cell_21/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](lstm_21/lstm_cell_21/kernel, lstm_21/lstm_cell_21/kernel/Initializer/random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-06 17:04:13.414501: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_1' id:3634 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_1}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 0 0 0...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-11-06 17:04:13.447667: W tensorflow/c/c_api.cc:304] Operation '{name:'strided_slice/stack_2' id:3635 op device:{requested: '', assigned: ''} def:{{{node strided_slice/stack_2}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [4] values: 1 1 1...>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# (29601, 95)
# Train on 29601 samples, validate on 3694 samples
# 2023-11-06 17:04:17.779604: W tensorflow/c/c_api.cc:304] Operation '{name:'training/Adam/lstm_25/lstm_cell_25/kernel/v/Assign' id:17430 op device:{requested: '', assigned: ''} def:{{{node training/Adam/lstm_25/lstm_cell_25/kernel/v/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/lstm_25/lstm_cell_25/kernel/v, training/Adam/lstm_25/lstm_cell_25/kernel/v/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1/100
# 2023-11-06 17:04:21.662058: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape indropout/cond/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-06 17:04:23.769544: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8902
# 2023-11-06 17:04:23.985621: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 29601/29601 [==============================] - ETA: 0s - loss: 1.3549 - acc: 0.3604
# /usr/lib/python3.11/site-packages/keras/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2023-11-06 17:04:42.911312: W tensorflow/c/c_api.cc:304] Operation '{name:'loss/mul' id:6516 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/classification_output_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Epoch 1: val_acc improved from -inf to 0.39957, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 26s 885us/sample - loss: 1.3549 - acc: 0.3604 - val_loss: 1.3047 - val_acc: 0.3996
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2615 - acc: 0.4430
# Epoch 2: val_acc improved from 0.39957 to 0.41825, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 18s 621us/sample - loss: 1.2615 - acc: 0.4430 - val_loss: 1.2615 - val_acc: 0.4182
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2343 - acc: 0.4539
# Epoch 3: val_acc improved from 0.41825 to 0.43259, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 18s 617us/sample - loss: 1.2343 - acc: 0.4539 - val_loss: 1.2418 - val_acc: 0.4326
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2182 - acc: 0.4647
# Epoch 4: val_acc improved from 0.43259 to 0.43774, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 20s 691us/sample - loss: 1.2182 - acc: 0.4647 - val_loss: 1.2349 - val_acc: 0.4377
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.2070 - acc: 0.4686
# Epoch 5: val_acc improved from 0.43774 to 0.43855, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 21s 710us/sample - loss: 1.2070 - acc: 0.4686 - val_loss: 1.2229 - val_acc: 0.4385
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1963 - acc: 0.4730
# Epoch 6: val_acc improved from 0.43855 to 0.44532, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 21s 712us/sample - loss: 1.1963 - acc: 0.4730 - val_loss: 1.2141 - val_acc: 0.4453
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1884 - acc: 0.4749
# Epoch 7: val_acc improved from 0.44532 to 0.45100, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 19s 653us/sample - loss: 1.1884 - acc: 0.4749 - val_loss: 1.2086 - val_acc: 0.4510
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1784 - acc: 0.4796
# Epoch 8: val_acc improved from 0.45100 to 0.45236, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 18s 607us/sample - loss: 1.1784 - acc: 0.4796 - val_loss: 1.2024 - val_acc: 0.4524
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1726 - acc: 0.4817
# Epoch 9: val_acc did not improve from 0.45236
# 29601/29601 [==============================] - 18s 622us/sample - loss: 1.1726 - acc: 0.4817 - val_loss: 1.1945 - val_acc: 0.4518
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1669 - acc: 0.4814
# Epoch 10: val_acc improved from 0.45236 to 0.45479, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 19s 651us/sample - loss: 1.1669 - acc: 0.4814 - val_loss: 1.1882 - val_acc: 0.4548
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1597 - acc: 0.4845
# Epoch 11: val_acc did not improve from 0.45479
# 29601/29601 [==============================] - 20s 684us/sample - loss: 1.1597 - acc: 0.4845 - val_loss: 1.1838 - val_acc: 0.4545
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1552 - acc: 0.4888
# Epoch 12: val_acc did not improve from 0.45479
# 29601/29601 [==============================] - 19s 637us/sample - loss: 1.1552 - acc: 0.4888 - val_loss: 1.1785 - val_acc: 0.4529
# Epoch 13/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1498 - acc: 0.4915
# Epoch 13: val_acc improved from 0.45479 to 0.45831, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 20s 661us/sample - loss: 1.1498 - acc: 0.4915 - val_loss: 1.1741 - val_acc: 0.4583
# Epoch 14/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1473 - acc: 0.4915
# Epoch 14: val_acc improved from 0.45831 to 0.46318, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 19s 655us/sample - loss: 1.1473 - acc: 0.4915 - val_loss: 1.1705 - val_acc: 0.4632
# Epoch 15/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1414 - acc: 0.4931
# Epoch 15: val_acc did not improve from 0.46318
# 29601/29601 [==============================] - 19s 658us/sample - loss: 1.1414 - acc: 0.4931 - val_loss: 1.1688 - val_acc: 0.4578
# Epoch 16/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1363 - acc: 0.4965
# Epoch 16: val_acc did not improve from 0.46318
# 29601/29601 [==============================] - 21s 710us/sample - loss: 1.1363 - acc: 0.4965 - val_loss: 1.1661 - val_acc: 0.4591
# Epoch 17/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1326 - acc: 0.4969
# Epoch 17: val_acc did not improve from 0.46318
# 29601/29601 [==============================] - 21s 704us/sample - loss: 1.1326 - acc: 0.4969 - val_loss: 1.1644 - val_acc: 0.4632
# Epoch 18/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1272 - acc: 0.4988
# Epoch 18: val_acc improved from 0.46318 to 0.46643, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 21s 702us/sample - loss: 1.1272 - acc: 0.4988 - val_loss: 1.1601 - val_acc: 0.4664
# Epoch 19/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1219 - acc: 0.5027
# Epoch 19: val_acc improved from 0.46643 to 0.46914, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 20s 683us/sample - loss: 1.1219 - acc: 0.5027 - val_loss: 1.1550 - val_acc: 0.4691
# Epoch 20/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1189 - acc: 0.5020
# Epoch 20: val_acc did not improve from 0.46914
# 29601/29601 [==============================] - 20s 673us/sample - loss: 1.1189 - acc: 0.5020 - val_loss: 1.1552 - val_acc: 0.4662
# Epoch 21/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1161 - acc: 0.5042
# Epoch 21: val_acc did not improve from 0.46914
# 29601/29601 [==============================] - 21s 707us/sample - loss: 1.1161 - acc: 0.5042 - val_loss: 1.1509 - val_acc: 0.4656
# Epoch 22/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1135 - acc: 0.5070
# Epoch 22: val_acc improved from 0.46914 to 0.46995, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 20s 667us/sample - loss: 1.1135 - acc: 0.5070 - val_loss: 1.1573 - val_acc: 0.4700
# Epoch 23/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1098 - acc: 0.5071
# Epoch 23: val_acc improved from 0.46995 to 0.47185, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 19s 646us/sample - loss: 1.1098 - acc: 0.5071 - val_loss: 1.1494 - val_acc: 0.4718
# Epoch 24/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1055 - acc: 0.5081
# Epoch 24: val_acc did not improve from 0.47185
# 29601/29601 [==============================] - 20s 663us/sample - loss: 1.1055 - acc: 0.5081 - val_loss: 1.1489 - val_acc: 0.4710
# Epoch 25/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.1042 - acc: 0.5101
# Epoch 25: val_acc did not improve from 0.47185
# 29601/29601 [==============================] - 19s 629us/sample - loss: 1.1042 - acc: 0.5101 - val_loss: 1.1440 - val_acc: 0.4713
# Epoch 26/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0990 - acc: 0.5121
# Epoch 26: val_acc improved from 0.47185 to 0.47482, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 21s 713us/sample - loss: 1.0990 - acc: 0.5121 - val_loss: 1.1462 - val_acc: 0.4748
# Epoch 27/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0956 - acc: 0.5155
# Epoch 27: val_acc did not improve from 0.47482
# 29601/29601 [==============================] - 21s 693us/sample - loss: 1.0956 - acc: 0.5155 - val_loss: 1.1434 - val_acc: 0.4748
# Epoch 28/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0939 - acc: 0.5131
# Epoch 28: val_acc did not improve from 0.47482
# 29601/29601 [==============================] - 21s 706us/sample - loss: 1.0939 - acc: 0.5131 - val_loss: 1.1435 - val_acc: 0.4743
# Epoch 29/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0909 - acc: 0.5183
# Epoch 29: val_acc did not improve from 0.47482
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.0909 - acc: 0.5183 - val_loss: 1.1452 - val_acc: 0.4716
# Epoch 30/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0881 - acc: 0.5181
# Epoch 30: val_acc did not improve from 0.47482
# 29601/29601 [==============================] - 20s 664us/sample - loss: 1.0881 - acc: 0.5181 - val_loss: 1.1505 - val_acc: 0.4737
# Epoch 31/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0860 - acc: 0.5225
# Epoch 31: val_acc improved from 0.47482 to 0.47591, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 21s 698us/sample - loss: 1.0860 - acc: 0.5225 - val_loss: 1.1376 - val_acc: 0.4759
# Epoch 32/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0865 - acc: 0.5192
# Epoch 32: val_acc did not improve from 0.47591
# 29601/29601 [==============================] - 18s 623us/sample - loss: 1.0865 - acc: 0.5192 - val_loss: 1.1428 - val_acc: 0.4740
# Epoch 33/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0824 - acc: 0.5238
# Epoch 33: val_acc did not improve from 0.47591
# 29601/29601 [==============================] - 19s 631us/sample - loss: 1.0824 - acc: 0.5238 - val_loss: 1.1398 - val_acc: 0.4729
# Epoch 34/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0819 - acc: 0.5224
# Epoch 34: val_acc improved from 0.47591 to 0.47618, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 19s 646us/sample - loss: 1.0819 - acc: 0.5224 - val_loss: 1.1357 - val_acc: 0.4762
# Epoch 35/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0766 - acc: 0.5248
# Epoch 35: val_acc did not improve from 0.47618
# 29601/29601 [==============================] - 19s 628us/sample - loss: 1.0766 - acc: 0.5248 - val_loss: 1.1397 - val_acc: 0.4705
# Epoch 36/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0725 - acc: 0.5268
# Epoch 36: val_acc did not improve from 0.47618
# 29601/29601 [==============================] - 19s 625us/sample - loss: 1.0725 - acc: 0.5268 - val_loss: 1.1387 - val_acc: 0.4740
# Epoch 37/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0716 - acc: 0.5281
# Epoch 37: val_acc improved from 0.47618 to 0.48836, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_0.h5
# 29601/29601 [==============================] - 19s 631us/sample - loss: 1.0716 - acc: 0.5281 - val_loss: 1.1345 - val_acc: 0.4884
# Epoch 38/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0679 - acc: 0.5268
# Epoch 38: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 626us/sample - loss: 1.0679 - acc: 0.5268 - val_loss: 1.1403 - val_acc: 0.4764
# Epoch 39/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0700 - acc: 0.5272
# Epoch 39: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 626us/sample - loss: 1.0700 - acc: 0.5272 - val_loss: 1.1340 - val_acc: 0.4832
# Epoch 40/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0683 - acc: 0.5318
# Epoch 40: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.0683 - acc: 0.5318 - val_loss: 1.1363 - val_acc: 0.4808
# Epoch 41/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0643 - acc: 0.5310
# Epoch 41: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 700us/sample - loss: 1.0643 - acc: 0.5310 - val_loss: 1.1328 - val_acc: 0.4835
# Epoch 42/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0602 - acc: 0.5330
# Epoch 42: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 20s 678us/sample - loss: 1.0602 - acc: 0.5330 - val_loss: 1.1373 - val_acc: 0.4794
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0609 - acc: 0.5321
# Epoch 43: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 644us/sample - loss: 1.0609 - acc: 0.5321 - val_loss: 1.1370 - val_acc: 0.4816
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0550 - acc: 0.5371
# Epoch 44: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 636us/sample - loss: 1.0550 - acc: 0.5371 - val_loss: 1.1389 - val_acc: 0.4794
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0583 - acc: 0.5319
# Epoch 45: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 646us/sample - loss: 1.0583 - acc: 0.5319 - val_loss: 1.1364 - val_acc: 0.4862
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0528 - acc: 0.5349
# Epoch 46: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 640us/sample - loss: 1.0528 - acc: 0.5349 - val_loss: 1.1342 - val_acc: 0.4819
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0515 - acc: 0.5359
# Epoch 47: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 638us/sample - loss: 1.0515 - acc: 0.5359 - val_loss: 1.1353 - val_acc: 0.4854
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0511 - acc: 0.5350
# Epoch 48: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 703us/sample - loss: 1.0511 - acc: 0.5350 - val_loss: 1.1376 - val_acc: 0.4792
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0497 - acc: 0.5394
# Epoch 49: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 700us/sample - loss: 1.0497 - acc: 0.5394 - val_loss: 1.1370 - val_acc: 0.4808
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0478 - acc: 0.5392
# Epoch 50: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 653us/sample - loss: 1.0478 - acc: 0.5392 - val_loss: 1.1396 - val_acc: 0.4792
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0444 - acc: 0.5424
# Epoch 51: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 632us/sample - loss: 1.0444 - acc: 0.5424 - val_loss: 1.1403 - val_acc: 0.4759
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0434 - acc: 0.5433
# Epoch 52: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 658us/sample - loss: 1.0434 - acc: 0.5433 - val_loss: 1.1358 - val_acc: 0.4838
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0412 - acc: 0.5427
# Epoch 53: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 20s 690us/sample - loss: 1.0412 - acc: 0.5427 - val_loss: 1.1343 - val_acc: 0.4821
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0367 - acc: 0.5462
# Epoch 54: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 20s 675us/sample - loss: 1.0367 - acc: 0.5462 - val_loss: 1.1393 - val_acc: 0.4778
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0354 - acc: 0.5462
# Epoch 55: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 641us/sample - loss: 1.0354 - acc: 0.5462 - val_loss: 1.1370 - val_acc: 0.4746
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0371 - acc: 0.5449
# Epoch 56: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 647us/sample - loss: 1.0371 - acc: 0.5449 - val_loss: 1.1349 - val_acc: 0.4802
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0329 - acc: 0.5465
# Epoch 57: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 627us/sample - loss: 1.0329 - acc: 0.5465 - val_loss: 1.1408 - val_acc: 0.4789
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0326 - acc: 0.5472
# Epoch 58: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 631us/sample - loss: 1.0326 - acc: 0.5472 - val_loss: 1.1369 - val_acc: 0.4764
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0284 - acc: 0.5471
# Epoch 59: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 20s 685us/sample - loss: 1.0284 - acc: 0.5471 - val_loss: 1.1386 - val_acc: 0.4716
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0296 - acc: 0.5464
# Epoch 60: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 657us/sample - loss: 1.0296 - acc: 0.5464 - val_loss: 1.1377 - val_acc: 0.4732
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0297 - acc: 0.5511
# Epoch 61: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 699us/sample - loss: 1.0297 - acc: 0.5511 - val_loss: 1.1472 - val_acc: 0.4748
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0280 - acc: 0.5529
# Epoch 62: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 633us/sample - loss: 1.0280 - acc: 0.5529 - val_loss: 1.1420 - val_acc: 0.4743
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0279 - acc: 0.5483
# Epoch 63: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 653us/sample - loss: 1.0279 - acc: 0.5483 - val_loss: 1.1350 - val_acc: 0.4783
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0240 - acc: 0.5522
# Epoch 64: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 707us/sample - loss: 1.0240 - acc: 0.5522 - val_loss: 1.1473 - val_acc: 0.4713
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0222 - acc: 0.5540
# Epoch 65: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 703us/sample - loss: 1.0222 - acc: 0.5540 - val_loss: 1.1371 - val_acc: 0.4813
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0207 - acc: 0.5538
# Epoch 66: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 708us/sample - loss: 1.0207 - acc: 0.5538 - val_loss: 1.1419 - val_acc: 0.4770
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0155 - acc: 0.5574
# Epoch 67: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 707us/sample - loss: 1.0155 - acc: 0.5574 - val_loss: 1.1391 - val_acc: 0.4767
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0156 - acc: 0.5566
# Epoch 68: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 658us/sample - loss: 1.0156 - acc: 0.5566 - val_loss: 1.1448 - val_acc: 0.4732
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0148 - acc: 0.5564
# Epoch 69: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 702us/sample - loss: 1.0148 - acc: 0.5564 - val_loss: 1.1373 - val_acc: 0.4846
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0145 - acc: 0.5570
# Epoch 70: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 630us/sample - loss: 1.0145 - acc: 0.5570 - val_loss: 1.1423 - val_acc: 0.4743
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0118 - acc: 0.5592
# Epoch 71: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 20s 668us/sample - loss: 1.0118 - acc: 0.5592 - val_loss: 1.1401 - val_acc: 0.4786
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0111 - acc: 0.5586
# Epoch 72: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 704us/sample - loss: 1.0111 - acc: 0.5586 - val_loss: 1.1417 - val_acc: 0.4792
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0100 - acc: 0.5592
# Epoch 73: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 20s 674us/sample - loss: 1.0100 - acc: 0.5592 - val_loss: 1.1399 - val_acc: 0.4746
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0067 - acc: 0.5592
# Epoch 74: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 626us/sample - loss: 1.0067 - acc: 0.5592 - val_loss: 1.1416 - val_acc: 0.4762
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0070 - acc: 0.5601
# Epoch 75: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 628us/sample - loss: 1.0070 - acc: 0.5601 - val_loss: 1.1414 - val_acc: 0.4832
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0069 - acc: 0.5595
# Epoch 76: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 20s 664us/sample - loss: 1.0069 - acc: 0.5595 - val_loss: 1.1419 - val_acc: 0.4827
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0011 - acc: 0.5616
# Epoch 77: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 20s 670us/sample - loss: 1.0011 - acc: 0.5616 - val_loss: 1.1531 - val_acc: 0.4802
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0034 - acc: 0.5638
# Epoch 78: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 703us/sample - loss: 1.0034 - acc: 0.5638 - val_loss: 1.1468 - val_acc: 0.4773
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9989 - acc: 0.5669
# Epoch 79: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 633us/sample - loss: 0.9989 - acc: 0.5669 - val_loss: 1.1466 - val_acc: 0.4816
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9982 - acc: 0.5681
# Epoch 80: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 18s 609us/sample - loss: 0.9982 - acc: 0.5681 - val_loss: 1.1454 - val_acc: 0.4792
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9983 - acc: 0.5656
# Epoch 81: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 20s 664us/sample - loss: 0.9983 - acc: 0.5656 - val_loss: 1.1510 - val_acc: 0.4748
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9951 - acc: 0.5675
# Epoch 82: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 643us/sample - loss: 0.9951 - acc: 0.5675 - val_loss: 1.1480 - val_acc: 0.4824
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9969 - acc: 0.5661
# Epoch 83: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 18s 624us/sample - loss: 0.9969 - acc: 0.5661 - val_loss: 1.1469 - val_acc: 0.4762
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9969 - acc: 0.5635
# Epoch 84: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 627us/sample - loss: 0.9969 - acc: 0.5635 - val_loss: 1.1506 - val_acc: 0.4832
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9946 - acc: 0.5664
# Epoch 85: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 18s 622us/sample - loss: 0.9946 - acc: 0.5664 - val_loss: 1.1480 - val_acc: 0.4819
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9927 - acc: 0.5678
# Epoch 86: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 629us/sample - loss: 0.9927 - acc: 0.5678 - val_loss: 1.1562 - val_acc: 0.4732
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9900 - acc: 0.5670
# Epoch 87: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 18s 615us/sample - loss: 0.9900 - acc: 0.5670 - val_loss: 1.1486 - val_acc: 0.4770
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9888 - acc: 0.5713
# Epoch 88: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 696us/sample - loss: 0.9888 - acc: 0.5713 - val_loss: 1.1470 - val_acc: 0.4786
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9887 - acc: 0.5687
# Epoch 89: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 695us/sample - loss: 0.9887 - acc: 0.5687 - val_loss: 1.1458 - val_acc: 0.4767
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9870 - acc: 0.5688
# Epoch 90: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 703us/sample - loss: 0.9870 - acc: 0.5688 - val_loss: 1.1553 - val_acc: 0.4767
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9884 - acc: 0.5663
# Epoch 91: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 19s 641us/sample - loss: 0.9884 - acc: 0.5663 - val_loss: 1.1486 - val_acc: 0.4854
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9858 - acc: 0.5709
# Epoch 92: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 708us/sample - loss: 0.9858 - acc: 0.5709 - val_loss: 1.1564 - val_acc: 0.4764
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9858 - acc: 0.5682
# Epoch 93: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 707us/sample - loss: 0.9858 - acc: 0.5682 - val_loss: 1.1520 - val_acc: 0.4789
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9805 - acc: 0.5700
# Epoch 94: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 704us/sample - loss: 0.9805 - acc: 0.5700 - val_loss: 1.1536 - val_acc: 0.4756
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9854 - acc: 0.5700
# Epoch 95: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 706us/sample - loss: 0.9854 - acc: 0.5700 - val_loss: 1.1519 - val_acc: 0.4800
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9792 - acc: 0.5733
# Epoch 96: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 704us/sample - loss: 0.9792 - acc: 0.5733 - val_loss: 1.1566 - val_acc: 0.4718
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9772 - acc: 0.5730
# Epoch 97: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 694us/sample - loss: 0.9772 - acc: 0.5730 - val_loss: 1.1549 - val_acc: 0.4813
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9763 - acc: 0.5746
# Epoch 98: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 21s 704us/sample - loss: 0.9763 - acc: 0.5746 - val_loss: 1.1574 - val_acc: 0.4800
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9772 - acc: 0.5747
# Epoch 99: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 20s 681us/sample - loss: 0.9772 - acc: 0.5747 - val_loss: 1.1518 - val_acc: 0.4827
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9778 - acc: 0.5733
# Epoch 100: val_acc did not improve from 0.48836
# 29601/29601 [==============================] - 18s 600us/sample - loss: 0.9778 - acc: 0.5733 - val_loss: 1.1514 - val_acc: 0.4840
# Train on 29601 samples, validate on 3694 samples
# Epoch 1/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9732 - acc: 0.5760
# Epoch 1: val_acc improved from -inf to 0.47699, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_1.h5
# 29601/29601 [==============================] - 20s 684us/sample - loss: 0.9732 - acc: 0.5760 - val_loss: 1.1521 - val_acc: 0.4770
# Epoch 2/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9761 - acc: 0.5739
# Epoch 2: val_acc improved from 0.47699 to 0.48024, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_1.h5
# 29601/29601 [==============================] - 21s 708us/sample - loss: 0.9761 - acc: 0.5739 - val_loss: 1.1533 - val_acc: 0.4802
# Epoch 3/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9751 - acc: 0.5761
# Epoch 3: val_acc improved from 0.48024 to 0.48349, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_1.h5
# 29601/29601 [==============================] - 21s 705us/sample - loss: 0.9751 - acc: 0.5761 - val_loss: 1.1543 - val_acc: 0.4835
# Epoch 4/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9696 - acc: 0.5769
# Epoch 4: val_acc did not improve from 0.48349
# 29601/29601 [==============================] - 21s 704us/sample - loss: 0.9696 - acc: 0.5769 - val_loss: 1.1536 - val_acc: 0.4824
# Epoch 5/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9691 - acc: 0.5800
# Epoch 5: val_acc did not improve from 0.48349
# 29601/29601 [==============================] - 20s 679us/sample - loss: 0.9691 - acc: 0.5800 - val_loss: 1.1602 - val_acc: 0.4829
# Epoch 6/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9675 - acc: 0.5808
# Epoch 6: val_acc did not improve from 0.48349
# 29601/29601 [==============================] - 19s 627us/sample - loss: 0.9675 - acc: 0.5808 - val_loss: 1.1642 - val_acc: 0.4797
# Epoch 7/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9684 - acc: 0.5783
# Epoch 7: val_acc improved from 0.48349 to 0.48809, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_1.h5
# 29601/29601 [==============================] - 18s 624us/sample - loss: 0.9684 - acc: 0.5783 - val_loss: 1.1581 - val_acc: 0.4881
# Epoch 8/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9665 - acc: 0.5827
# Epoch 8: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 617us/sample - loss: 0.9665 - acc: 0.5827 - val_loss: 1.1653 - val_acc: 0.4829
# Epoch 9/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9697 - acc: 0.5780
# Epoch 9: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 617us/sample - loss: 0.9697 - acc: 0.5780 - val_loss: 1.1660 - val_acc: 0.4813
# Epoch 10/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9662 - acc: 0.5793
# Epoch 10: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 619us/sample - loss: 0.9662 - acc: 0.5793 - val_loss: 1.1641 - val_acc: 0.4792
# Epoch 11/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9661 - acc: 0.5825
# Epoch 11: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 621us/sample - loss: 0.9661 - acc: 0.5825 - val_loss: 1.1752 - val_acc: 0.4743
# Epoch 12/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9676 - acc: 0.5800
# Epoch 12: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 617us/sample - loss: 0.9676 - acc: 0.5800 - val_loss: 1.1613 - val_acc: 0.4805
# Epoch 13/100
# ...
# Epoch 43/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9914 - acc: 0.5706
# Epoch 43: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 19s 651us/sample - loss: 0.9914 - acc: 0.5706 - val_loss: 1.1535 - val_acc: 0.4732
# Epoch 44/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0029 - acc: 0.5637
# Epoch 44: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 593us/sample - loss: 1.0029 - acc: 0.5637 - val_loss: 1.1571 - val_acc: 0.4797
# Epoch 45/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0154 - acc: 0.5545
# Epoch 45: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 17s 591us/sample - loss: 1.0154 - acc: 0.5545 - val_loss: 1.1494 - val_acc: 0.4843
# Epoch 46/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0103 - acc: 0.5639
# Epoch 46: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 595us/sample - loss: 1.0103 - acc: 0.5639 - val_loss: 1.1585 - val_acc: 0.4854
# Epoch 47/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0129 - acc: 0.5580
# Epoch 47: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.0129 - acc: 0.5580 - val_loss: 1.1536 - val_acc: 0.4854
# Epoch 48/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0128 - acc: 0.5603
# Epoch 48: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 20s 679us/sample - loss: 1.0128 - acc: 0.5603 - val_loss: 1.1502 - val_acc: 0.4792
# Epoch 49/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0148 - acc: 0.5546
# Epoch 49: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 21s 695us/sample - loss: 1.0148 - acc: 0.5546 - val_loss: 1.1510 - val_acc: 0.4800
# Epoch 50/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0191 - acc: 0.5535
# Epoch 50: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 21s 695us/sample - loss: 1.0191 - acc: 0.5535 - val_loss: 1.1584 - val_acc: 0.4789
# Epoch 51/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0222 - acc: 0.5569
# Epoch 51: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 21s 694us/sample - loss: 1.0222 - acc: 0.5569 - val_loss: 1.1556 - val_acc: 0.4819
# Epoch 52/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0268 - acc: 0.5497
# Epoch 52: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 19s 639us/sample - loss: 1.0268 - acc: 0.5497 - val_loss: 1.1510 - val_acc: 0.4802
# Epoch 53/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0267 - acc: 0.5519
# Epoch 53: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 599us/sample - loss: 1.0267 - acc: 0.5519 - val_loss: 1.1571 - val_acc: 0.4805
# Epoch 54/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0306 - acc: 0.5468
# Epoch 54: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 593us/sample - loss: 1.0306 - acc: 0.5468 - val_loss: 1.1564 - val_acc: 0.4813
# Epoch 55/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0268 - acc: 0.5501
# Epoch 55: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 623us/sample - loss: 1.0268 - acc: 0.5501 - val_loss: 1.1614 - val_acc: 0.4789
# Epoch 56/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0280 - acc: 0.5516
# Epoch 56: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 19s 634us/sample - loss: 1.0280 - acc: 0.5516 - val_loss: 1.1600 - val_acc: 0.4805
# Epoch 57/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0270 - acc: 0.5503
# Epoch 57: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 598us/sample - loss: 1.0270 - acc: 0.5503 - val_loss: 1.1542 - val_acc: 0.4786
# Epoch 58/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0242 - acc: 0.5537
# Epoch 58: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 594us/sample - loss: 1.0242 - acc: 0.5537 - val_loss: 1.1567 - val_acc: 0.4778
# Epoch 59/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0230 - acc: 0.5503
# Epoch 59: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 609us/sample - loss: 1.0230 - acc: 0.5503 - val_loss: 1.1487 - val_acc: 0.4811
# Epoch 60/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0179 - acc: 0.5552
# Epoch 60: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 20s 690us/sample - loss: 1.0179 - acc: 0.5552 - val_loss: 1.1651 - val_acc: 0.4746
# Epoch 61/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0220 - acc: 0.5538
# Epoch 61: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 623us/sample - loss: 1.0220 - acc: 0.5538 - val_loss: 1.1661 - val_acc: 0.4710
# Epoch 62/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0170 - acc: 0.5556
# Epoch 62: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 19s 651us/sample - loss: 1.0170 - acc: 0.5556 - val_loss: 1.1541 - val_acc: 0.4846
# Epoch 63/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0167 - acc: 0.5583
# Epoch 63: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 604us/sample - loss: 1.0167 - acc: 0.5583 - val_loss: 1.1598 - val_acc: 0.4775
# Epoch 64/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0143 - acc: 0.5557
# Epoch 64: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 603us/sample - loss: 1.0143 - acc: 0.5557 - val_loss: 1.1567 - val_acc: 0.4832
# Epoch 65/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0106 - acc: 0.5565
# Epoch 65: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 19s 649us/sample - loss: 1.0106 - acc: 0.5565 - val_loss: 1.1526 - val_acc: 0.4846
# Epoch 66/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0126 - acc: 0.5585
# Epoch 66: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 613us/sample - loss: 1.0126 - acc: 0.5585 - val_loss: 1.1579 - val_acc: 0.4775
# Epoch 67/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0113 - acc: 0.5547
# Epoch 67: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 19s 646us/sample - loss: 1.0113 - acc: 0.5547 - val_loss: 1.1602 - val_acc: 0.4802
# Epoch 68/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0109 - acc: 0.5575
# Epoch 68: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 20s 666us/sample - loss: 1.0109 - acc: 0.5575 - val_loss: 1.1569 - val_acc: 0.4821
# Epoch 69/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0102 - acc: 0.5592
# Epoch 69: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 621us/sample - loss: 1.0102 - acc: 0.5592 - val_loss: 1.1522 - val_acc: 0.4792
# Epoch 70/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0146 - acc: 0.5568
# Epoch 70: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 614us/sample - loss: 1.0146 - acc: 0.5568 - val_loss: 1.1562 - val_acc: 0.4781
# Epoch 71/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0112 - acc: 0.5572
# Epoch 71: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 624us/sample - loss: 1.0112 - acc: 0.5572 - val_loss: 1.1528 - val_acc: 0.4775
# Epoch 72/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0090 - acc: 0.5602
# Epoch 72: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 19s 651us/sample - loss: 1.0090 - acc: 0.5602 - val_loss: 1.1581 - val_acc: 0.4789
# Epoch 73/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0089 - acc: 0.5577
# Epoch 73: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 21s 699us/sample - loss: 1.0089 - acc: 0.5577 - val_loss: 1.1576 - val_acc: 0.4792
# Epoch 74/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0199 - acc: 0.5504
# Epoch 74: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 21s 697us/sample - loss: 1.0199 - acc: 0.5504 - val_loss: 1.1529 - val_acc: 0.4767
# Epoch 75/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0102 - acc: 0.5577
# Epoch 75: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 618us/sample - loss: 1.0102 - acc: 0.5577 - val_loss: 1.1496 - val_acc: 0.4873
# Epoch 76/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0066 - acc: 0.5595
# Epoch 76: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 20s 684us/sample - loss: 1.0066 - acc: 0.5595 - val_loss: 1.1573 - val_acc: 0.4740
# Epoch 77/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0040 - acc: 0.5621
# Epoch 77: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 20s 691us/sample - loss: 1.0040 - acc: 0.5621 - val_loss: 1.1489 - val_acc: 0.4829
# Epoch 78/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0041 - acc: 0.5634
# Epoch 78: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 21s 697us/sample - loss: 1.0041 - acc: 0.5634 - val_loss: 1.1527 - val_acc: 0.4851
# Epoch 79/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0012 - acc: 0.5672
# Epoch 79: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 20s 692us/sample - loss: 1.0012 - acc: 0.5672 - val_loss: 1.1532 - val_acc: 0.4867
# Epoch 80/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0030 - acc: 0.5632
# Epoch 80: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 21s 695us/sample - loss: 1.0030 - acc: 0.5632 - val_loss: 1.1522 - val_acc: 0.4832
# Epoch 81/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0015 - acc: 0.5639
# Epoch 81: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 21s 694us/sample - loss: 1.0015 - acc: 0.5639 - val_loss: 1.1551 - val_acc: 0.4835
# Epoch 82/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9984 - acc: 0.5676
# Epoch 82: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 19s 628us/sample - loss: 0.9984 - acc: 0.5676 - val_loss: 1.1571 - val_acc: 0.4748
# Epoch 83/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9955 - acc: 0.5677
# Epoch 83: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 19s 632us/sample - loss: 0.9955 - acc: 0.5677 - val_loss: 1.1585 - val_acc: 0.4835
# Epoch 84/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9971 - acc: 0.5643
# Epoch 84: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 20s 672us/sample - loss: 0.9971 - acc: 0.5643 - val_loss: 1.1529 - val_acc: 0.4840
# Epoch 85/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9935 - acc: 0.5663
# Epoch 85: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 19s 651us/sample - loss: 0.9935 - acc: 0.5663 - val_loss: 1.1507 - val_acc: 0.4819
# Epoch 86/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9929 - acc: 0.5690
# Epoch 86: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 20s 671us/sample - loss: 0.9929 - acc: 0.5690 - val_loss: 1.1481 - val_acc: 0.4859
# Epoch 87/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9923 - acc: 0.5655
# Epoch 87: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 19s 636us/sample - loss: 0.9923 - acc: 0.5655 - val_loss: 1.1593 - val_acc: 0.4789
# Epoch 88/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9930 - acc: 0.5698
# Epoch 88: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 18s 615us/sample - loss: 0.9930 - acc: 0.5698 - val_loss: 1.1586 - val_acc: 0.4802
# Epoch 89/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9932 - acc: 0.5684
# Epoch 89: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 19s 641us/sample - loss: 0.9932 - acc: 0.5684 - val_loss: 1.1519 - val_acc: 0.4865
# Epoch 90/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9901 - acc: 0.5700
# Epoch 90: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 21s 693us/sample - loss: 0.9901 - acc: 0.5700 - val_loss: 1.1573 - val_acc: 0.4792
# Epoch 91/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9935 - acc: 0.5687
# Epoch 91: val_acc did not improve from 0.48809
# 29601/29601 [==============================] - 21s 699us/sample - loss: 0.9935 - acc: 0.5687 - val_loss: 1.1541 - val_acc: 0.4870
# Epoch 92/100
# 29601/29601 [==============================] - ETA: 0s - loss: 1.0041 - acc: 0.5630
# Epoch 92: val_acc improved from 0.48809 to 0.48863, saving model to ./checkpoints/Adaptive_prune_model_classify_nobalance_9.h5
# 29601/29601 [==============================] - 21s 703us/sample - loss: 1.0041 - acc: 0.5630 - val_loss: 1.1515 - val_acc: 0.4886
# Epoch 93/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9983 - acc: 0.5613
# Epoch 93: val_acc did not improve from 0.48863
# 29601/29601 [==============================] - 20s 679us/sample - loss: 0.9983 - acc: 0.5613 - val_loss: 1.1563 - val_acc: 0.4829
# Epoch 94/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9932 - acc: 0.5666
# Epoch 94: val_acc did not improve from 0.48863
# 29601/29601 [==============================] - 20s 687us/sample - loss: 0.9932 - acc: 0.5666 - val_loss: 1.1534 - val_acc: 0.4813
# Epoch 95/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9907 - acc: 0.5710
# Epoch 95: val_acc did not improve from 0.48863
# 29601/29601 [==============================] - 18s 599us/sample - loss: 0.9907 - acc: 0.5710 - val_loss: 1.1529 - val_acc: 0.4829
# Epoch 96/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9881 - acc: 0.5720
# Epoch 96: val_acc did not improve from 0.48863
# 29601/29601 [==============================] - 18s 601us/sample - loss: 0.9881 - acc: 0.5720 - val_loss: 1.1525 - val_acc: 0.4884
# Epoch 97/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9902 - acc: 0.5672
# Epoch 97: val_acc did not improve from 0.48863
# 29601/29601 [==============================] - 18s 602us/sample - loss: 0.9902 - acc: 0.5672 - val_loss: 1.1505 - val_acc: 0.4843
# Epoch 98/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9880 - acc: 0.5706
# Epoch 98: val_acc did not improve from 0.48863
# 29601/29601 [==============================] - 18s 603us/sample - loss: 0.9880 - acc: 0.5706 - val_loss: 1.1523 - val_acc: 0.4813
# Epoch 99/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9906 - acc: 0.5717
# Epoch 99: val_acc did not improve from 0.48863
# 29601/29601 [==============================] - 18s 603us/sample - loss: 0.9906 - acc: 0.5717 - val_loss: 1.1538 - val_acc: 0.4838
# Epoch 100/100
# 29601/29601 [==============================] - ETA: 0s - loss: 0.9875 - acc: 0.5703
# Epoch 100: val_acc did not improve from 0.48863
# 29601/29601 [==============================] - 18s 602us/sample - loss: 0.9875 - acc: 0.5703 - val_loss: 1.1562 - val_acc: 0.4854
